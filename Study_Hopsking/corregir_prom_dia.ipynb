# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
data=pd.read_csv("../Study_Hopsking\data_minus1.csv")
data["DateTime"]=pd.to_datetime(data["DateTime"])

data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26401         26401     26395.0 2019-04-01 01:00:00     51.912   4.0     0.0
# 26402         26402     26396.0 2019-04-01 00:45:00     50.980   4.0     0.0
# 26403         26403     26397.0 2019-04-01 00:30:00     51.873   4.0     0.0
# 26404         26404     26398.0 2019-04-01 00:15:00     51.186   4.0     0.0
# 26405         26405     26399.0 2019-04-01 00:00:00     50.676   4.0     0.0
#
# ...

# %% [markdown]
# *hago lo mismo con la temperatura y el hay sol*
#
# *lo disminuyo todo a las menos un dia*

# %%
data['temp_ant'] = data['temp'].shift(-96)
data['Hay_Sol_ant'] = data['Hay_Sol'].shift(-96)

data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26401         26401     26395.0 2019-04-01 01:00:00     51.912   4.0     0.0
# 26402         26402     26396.0 2019-04-01 00:45:00     50.980   4.0     0.0
# 26403         26403     26397.0 2019-04-01 00:30:00     51.873   4.0     0.0
# 26404         26404     26398.0 2019-04-01 00:15:00     51.186   4.0     0.0
# 26405         26405     26399.0 2019-04-01 00:00:00     50.676   4.0     0.0
#
# ...

# %%
data = data[data['Hay_Sol_ant'].notna()]
data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26305         26305     26299.0 2019-04-02 01:00:00     51.206   4.0     0.0
# 26306         26306     26300.0 2019-04-02 00:45:00     50.765   4.0     0.0
# 26307         26307     26301.0 2019-04-02 00:30:00     51.397   4.0     0.0
# 26308         26308     26302.0 2019-04-02 00:15:00     51.794   4.0     0.0
# 26309         26309     26303.0 2019-04-02 00:00:00     51.488   4.0     0.0
#
# ...

# %%
del data["temp"]
del data ["Hay_Sol"]

data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26305         26305     26299.0 2019-04-02 01:00:00     51.206   4.0     0.0
# 26306         26306     26300.0 2019-04-02 00:45:00     50.765   4.0     0.0
# 26307         26307     26301.0 2019-04-02 00:30:00     51.397   4.0     0.0
# 26308         26308     26302.0 2019-04-02 00:15:00     51.794   4.0     0.0
# 26309         26309     26303.0 2019-04-02 00:00:00     51.488   4.0     0.0
#
# ...

# %% [markdown]
# *Me he dado cuenta que al poner valores exactos en las columnas promedio, estoy ya diciendole al modelo cuál es el valor de la potencia.*
#
# *Para evitar errores, voy a retroceder 4 espacios anteriores para que sea el de una hora antes.*

# %%
data['Prom_hora_mes_dia_ant'] = data['Prom_hora_mes_dia'].shift(-4)
data['mayor_promedio_dia_ant'] = data['mayor_promedio_dia'].shift(-4)

data
# Out:
# C:\Users\giuliana\AppData\Local\Temp\ipykernel_3276\3532212060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Prom_hora_mes_dia_ant'] = data['Prom_hora_mes_dia'].shift(-4)
# C:\Users\giuliana\AppData\Local\Temp\ipykernel_3276\3532212060.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['mayor_promedio_dia_ant'] = data['mayor_promedio_dia'].shift(-4)
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# ...

# %%
data = data[data['Prom_hora_mes_dia_ant'].notna()]
data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26301         26301     26295.0 2019-04-02 02:00:00     50.577   4.0     0.0
# 26302         26302     26296.0 2019-04-02 01:45:00     50.491   4.0     0.0
# 26303         26303     26297.0 2019-04-02 01:30:00     50.654   4.0     0.0
# 26304         26304     26298.0 2019-04-02 01:15:00     51.219   4.0     0.0
# 26305         26305     26299.0 2019-04-02 01:00:00     51.206   4.0     0.0
#
# ...

# %%
del data["mayor_promedio_dia"]
del data ["Prom_hora_mes_dia"]

data
# Out:
#        Unnamed: 0.1  Unnamed: 0            DateTime  RealPower   mes  verano  \
# 0                 0         0.0 2019-12-31 23:45:00     38.394  12.0     0.0
# 1                 1         1.0 2019-12-31 23:30:00     38.619  12.0     0.0
# 2                 2         2.0 2019-12-31 23:15:00     38.577  12.0     0.0
# 3                 3         3.0 2019-12-31 23:00:00     38.493  12.0     0.0
# 4                 4         4.0 2019-12-31 22:45:00     38.313  12.0     0.0
# ...             ...         ...                 ...        ...   ...     ...
# 26301         26301     26295.0 2019-04-02 02:00:00     50.577   4.0     0.0
# 26302         26302     26296.0 2019-04-02 01:45:00     50.491   4.0     0.0
# 26303         26303     26297.0 2019-04-02 01:30:00     50.654   4.0     0.0
# 26304         26304     26298.0 2019-04-02 01:15:00     51.219   4.0     0.0
# 26305         26305     26299.0 2019-04-02 01:00:00     51.206   4.0     0.0
#
# ...

# %%
data.to_csv("data_corregida.csv")
