# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# ...

# %%
del df["Unnamed: 0"]
del df["Timestamp"]

# %%
#Set column DateTime as index of df

df=df.set_index("DateTime")

# %%
#verify if there are NaN in the df

for column in df: #iterate over all colums 
    nans=df[column].isna().sum()
    print(f'{column}:{nans}') #f': indicate that has a format string
# Out:
# RealPower:0
# EV_Power:0
# month:0
# season_fall:0
# season_spring:0
# season_summer:0
# season_winter:0
# day:0
# Vacation:0
# summer_classes:0
# Theres_sun:0
# temp_ant:0
# Hour:0
# Average_hour_month:0
# Its_higher_than_average:0
# Average_hour_day_ant:0
# Its_higher_than_average_day_ant:0

# %% [markdown]
# **Plots**

# %%
#April

rows=2784
colums=df.columns
plots=df[colums][0:rows]
plots.index=df.index[0:rows]
plots.plot(subplots=True, figsize=(12,16))
# Out:
# array([<Axes: xlabel='DateTime'>, <Axes: xlabel='DateTime'>,
#        <Axes: xlabel='DateTime'>, <Axes: xlabel='DateTime'>,
#        <Axes: xlabel='DateTime'>, <Axes: xlabel='DateTime'>,
#        <Axes: xlabel='DateTime'>, <Axes: xlabel='DateTime'>,
#        <Axes: xlabel='DateTime'>, <Axes: xlabel='DateTime'>,
#        <Axes: xlabel='DateTime'>], dtype=object)
