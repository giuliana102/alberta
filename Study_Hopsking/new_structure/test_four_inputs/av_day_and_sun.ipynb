# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
# Out:
# C:\Users\lagg\AppData\Local\Temp\ipykernel_25872\388347847.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["Vacation"]
del df["summer_classes"]
del df["temp_ant"]
del df["Average_hour_month"]
del df["month"]
del df["Timestamp"]

df
# Out:
#        RealPower  EV_Power  Theres_sun  Average_hour_day_ant
# 0         51.488       0.0       False              51.17875
# 1         51.794       0.0       False              51.17875
# 2         51.397       0.0       False              51.17875
# 3         50.765       0.0       False              51.17875
# 4         51.206       0.0       False              51.05075
# ...          ...       ...         ...                   ...
# 26299     38.313       0.0       False              38.95800
# 26300     38.493       0.0       False              38.56300
# 26301     38.577       0.0       False              38.56300
# 26302     38.619       0.0       False              38.56300
# 26303     38.394       0.0       False              38.56300
#
# [26304 rows x 4 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
#df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power  Average_hour_day_ant
# count  26304.000000  26304.000000          26304.000000
# mean      48.307932      6.167214             48.365179
# std        5.717560      9.099070              5.451674
# min       -1.161000     -6.400000             24.301250
# 25%       45.886000      0.000000             46.230312
# 50%       48.319000      0.000000             48.350000
# 75%       51.776500      9.480000             51.845500
# max       82.339000     55.150000             75.317750

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (21043, 4)
# Validation set size: (2630, 4)
# Testing set size: (2631, 4)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20946, 96, 4), y_tr: (20946, 1, 1)
# Set de validación - x_vl: (2533, 96, 4), y_vl: (2533, 1, 1)
# Set de prueba - x_ts: (2534, 96, 4), y_ts: (2534, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488, 0.0, False, 51.17875],
#        [51.794, 0.0, False, 51.17875],
#        [51.397, 0.0, False, 51.17875],
#        [50.765, 0.0, False, 51.17875],
#        [51.206, 0.0, False, 51.05075],
#        [51.219, 0.0, False, 51.05075],
#        [50.654, 0.0, False, 51.05075],
#        [50.491, 0.0, False, 51.05075],
#        [50.577, 0.0, False, 50.98025],
#        [50.654, 0.0, False, 50.98025],
#        [50.275, 0.0, False, 50.98025],
#        [50.022, 0.0, False, 50.98025],
#        [49.987, 0.0, False, 51.11675],
#        [50.443, 0.0, False, 51.11675],
#        [50.345, 0.0, False, 51.11675],
#        [50.239, 0.0, False, 51.11675],
#        [50.716, 0.0, False, 50.65825],
#        [50.673, 0.0, False, 50.65825],
#        [50.407, 0.0, False, 50.65825],
#        [50.605, 0.0, False, 50.65825],
#        [50.733, 0.0, False, 52.50525],
#        [52.101, 0.0, False, 52.50525],
#        [52.23, 0.0, False, 52.50525],
#        [53.73, 0.0, False, 52.50525],
#        [53.611, 0.0, False, 53.2305],
#        [53.646, 0.0, False, 53.2305],
#        [53.21, 0.0, False, 53.2305],
#        [53.806, 0.0, True, 53.2305],
#        [53.582, 0.0, True, 54.05325],
#        [52.526, 0.0, True, 54.05325],
#        [49.983, 5.2, True, 54.05325],
#        [50.513, 8.11, True, 54.05325],
#        [53.22, 11.01, True, 52.93675],
#        [55.027, 16.35, True, 52.93675],
#        [53.067, 17.54, True, 52.93675],
#        [52.949, 22.48, True, 52.93675],
#        [51.79, 23.2, True, 52.32525],
#        [50.477, 22.37, True, 52.32525],
#        [48.413, 29.37, True, 52.32525],
#        [50.593, 25.27, True, 52.32525],
#        [51.712, 28.57, True, 51.233],
#        [49.816, 33.57, True, 51.233],
#        [54.568, 22.7, True, 51.233],
#        [59.61, 15.93, True, 51.233],
#        [56.574, 10.3, True, 53.382],
#        [52.774, 9.7, True, 53.382],
#        [56.809, 9.7, True, 53.382],
#        [51.718, 5.7, True, 53.382],
#        [53.128, 3.18, True, 56.719],
#        [54.716, 12.23, True, 56.719],
#        [48.839, 13.79, True, 56.719],
#        [53.15, 18.32, True, 56.719],
#        [56.602, 10.62, True, 64.79775000000001],
#        [67.519, 21.57, True, 64.79775000000001],
#        [65.695, 24.67, True, 64.79775000000001],
#        [62.946, 11.98, True, 64.79775000000001],
#        [50.613, 11.69, True, 58.654250000000005],
#        [48.255, 10.14, True, 58.654250000000005],
#        [46.57, 8.14, True, 58.654250000000005],
#        [45.438, 8.54, True, 58.654250000000005],
#        [59.025, 7.12, True, 51.72725],
#        [57.188, 7.27, True, 51.72725],
#        [59.485, 10.95, True, 51.72725],
#        [59.79, 16.3, True, 51.72725],
#        [59.683, 14.12, True, 55.278],
#        [59.392, 8.99, True, 55.278],
#        [57.961, 8.59, True, 55.278],
#        [58.789, 6.0, True, 55.278],
#        [61.564, 5.53, True, 53.22725],
#        [54.152, 5.53, True, 53.22725],
#        [54.354, 5.53, True, 53.22725],
#        [55.792, 5.53, True, 53.22725],
#        [53.667, 5.53, True, 50.2135],
#        [55.323, 5.53, True, 50.2135],
#        [53.986, 5.06, True, 50.2135],
#        [53.523, 4.3, True, 50.2135],
#        [56.197, 5.07, True, 52.95475],
#        [56.316, 12.39, False, 52.95475],
#        [57.141, 15.58, False, 52.95475],
#        [56.48, 15.58, False, 52.95475],
#        [56.714, 14.87, False, 54.2575],
#        [56.187, 12.17, False, 54.2575],
#        [55.675, 19.89, False, 54.2575],
#        [57.27, 14.77, False, 54.2575],
#        [55.669, 9.07, False, 55.98625],
#        [56.501, 9.07, False, 55.98625],
#        [55.379, 9.07, False, 55.98625],
#        [53.727, 4.67, False, 55.98625],
#        [53.533, 0.4, False, 52.03325],
#        [53.248, 0.0, False, 52.03325],
#        [52.776, 0.0, False, 52.03325],
#        [52.309, 0.0, False, 52.03325],
#        [52.465, 0.0, False, 51.53925],
#        [51.948, 0.0, False, 51.53925],
#        [51.993, 0.0, False, 51.53925],
#        [51.682, 0.0, False, 51.53925]], dtype=object)

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]], dtype=object)

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -1.0
# Maximun value per dimension: 1.0

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (4):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 110 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/110
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 45s - loss: 0.2220 - accuracy: 0.0000e+00 - val_loss: 0.1782 - val_accuracy: 0.0000e+00 - 45s/epoch - 555ms/step
# Epoch 2/110
# 82/82 - 34s - loss: 0.1798 - accuracy: 0.0000e+00 - val_loss: 0.1664 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 3/110
# 82/82 - 34s - loss: 0.1480 - accuracy: 0.0000e+00 - val_loss: 0.1717 - val_accuracy: 0.0000e+00 - 34s/epoch - 409ms/step
# Epoch 4/110
# 82/82 - 33s - loss: 0.1289 - accuracy: 0.0000e+00 - val_loss: 0.1772 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 5/110
# 82/82 - 33s - loss: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.1695 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 6/110
# 82/82 - 34s - loss: 0.1107 - accuracy: 0.0000e+00 - val_loss: 0.1569 - val_accuracy: 0.0000e+00 - 34s/epoch - 411ms/step
# Epoch 7/110
# 82/82 - 34s - loss: 0.1034 - accuracy: 0.0000e+00 - val_loss: 0.1436 - val_accuracy: 0.0000e+00 - 34s/epoch - 409ms/step
# Epoch 8/110
# 82/82 - 35s - loss: 0.0969 - accuracy: 0.0000e+00 - val_loss: 0.1298 - val_accuracy: 0.0000e+00 - 35s/epoch - 426ms/step
# Epoch 9/110
# 82/82 - 34s - loss: 0.0910 - accuracy: 0.0000e+00 - val_loss: 0.1173 - val_accuracy: 0.0000e+00 - 34s/epoch - 415ms/step
# Epoch 10/110
# 82/82 - 33s - loss: 0.0860 - accuracy: 0.0000e+00 - val_loss: 0.1056 - val_accuracy: 0.0000e+00 - 33s/epoch - 407ms/step
# Epoch 11/110
# 82/82 - 34s - loss: 0.0817 - accuracy: 0.0000e+00 - val_loss: 0.0946 - val_accuracy: 0.0000e+00 - 34s/epoch - 412ms/step
# Epoch 12/110
# 82/82 - 33s - loss: 0.0784 - accuracy: 0.0000e+00 - val_loss: 0.0863 - val_accuracy: 0.0000e+00 - 33s/epoch - 400ms/step
# Epoch 13/110
# 82/82 - 34s - loss: 0.0757 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00 - 34s/epoch - 416ms/step
# Epoch 14/110
# 82/82 - 34s - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0749 - val_accuracy: 0.0000e+00 - 34s/epoch - 410ms/step
# Epoch 15/110
# 82/82 - 33s - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0716 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 16/110
# 82/82 - 34s - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0700 - val_accuracy: 0.0000e+00 - 34s/epoch - 417ms/step
# Epoch 17/110
# 82/82 - 34s - loss: 0.0706 - accuracy: 0.0000e+00 - val_loss: 0.0684 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 18/110
# 82/82 - 33s - loss: 0.0697 - accuracy: 0.0000e+00 - val_loss: 0.0678 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 19/110
# 82/82 - 33s - loss: 0.0691 - accuracy: 0.0000e+00 - val_loss: 0.0673 - val_accuracy: 0.0000e+00 - 33s/epoch - 402ms/step
# Epoch 20/110
# 82/82 - 33s - loss: 0.0685 - accuracy: 0.0000e+00 - val_loss: 0.0661 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 21/110
# 82/82 - 32s - loss: 0.0680 - accuracy: 0.0000e+00 - val_loss: 0.0651 - val_accuracy: 0.0000e+00 - 32s/epoch - 396ms/step
# Epoch 22/110
# 82/82 - 33s - loss: 0.0675 - accuracy: 0.0000e+00 - val_loss: 0.0645 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 23/110
# 82/82 - 33s - loss: 0.0670 - accuracy: 0.0000e+00 - val_loss: 0.0648 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 24/110
# 82/82 - 33s - loss: 0.0664 - accuracy: 0.0000e+00 - val_loss: 0.0639 - val_accuracy: 0.0000e+00 - 33s/epoch - 401ms/step
# Epoch 25/110
# 82/82 - 33s - loss: 0.0661 - accuracy: 0.0000e+00 - val_loss: 0.0629 - val_accuracy: 0.0000e+00 - 33s/epoch - 402ms/step
# Epoch 26/110
# 82/82 - 33s - loss: 0.0658 - accuracy: 0.0000e+00 - val_loss: 0.0624 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 27/110
# 82/82 - 33s - loss: 0.0653 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00 - 33s/epoch - 407ms/step
# Epoch 28/110
# 82/82 - 33s - loss: 0.0651 - accuracy: 0.0000e+00 - val_loss: 0.0618 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 29/110
# 82/82 - 33s - loss: 0.0646 - accuracy: 0.0000e+00 - val_loss: 0.0615 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 30/110
# 82/82 - 34s - loss: 0.0644 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00 - 34s/epoch - 417ms/step
# Epoch 31/110
# 82/82 - 34s - loss: 0.0641 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00 - 34s/epoch - 410ms/step
# Epoch 32/110
# 82/82 - 33s - loss: 0.0638 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00 - 33s/epoch - 401ms/step
# Epoch 33/110
# 82/82 - 28s - loss: 0.0637 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00 - 28s/epoch - 336ms/step
# Epoch 34/110
# 82/82 - 26s - loss: 0.0633 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00 - 26s/epoch - 312ms/step
# Epoch 35/110
# 82/82 - 25s - loss: 0.0631 - accuracy: 4.7742e-05 - val_loss: 0.0587 - val_accuracy: 0.0000e+00 - 25s/epoch - 307ms/step
# Epoch 36/110
# 82/82 - 20s - loss: 0.0629 - accuracy: 4.7742e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 37/110
# 82/82 - 20s - loss: 0.0628 - accuracy: 4.7742e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 38/110
# 82/82 - 21s - loss: 0.0625 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 21s/epoch - 251ms/step
# Epoch 39/110
# 82/82 - 20s - loss: 0.0623 - accuracy: 4.7742e-05 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 40/110
# 82/82 - 20s - loss: 0.0621 - accuracy: 4.7742e-05 - val_loss: 0.0572 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 41/110
# 82/82 - 21s - loss: 0.0620 - accuracy: 4.7742e-05 - val_loss: 0.0567 - val_accuracy: 0.0000e+00 - 21s/epoch - 256ms/step
# Epoch 42/110
# 82/82 - 20s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0565 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 43/110
# 82/82 - 20s - loss: 0.0617 - accuracy: 4.7742e-05 - val_loss: 0.0559 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 44/110
# 82/82 - 20s - loss: 0.0616 - accuracy: 4.7742e-05 - val_loss: 0.0559 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 45/110
# 82/82 - 20s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0555 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 46/110
# 82/82 - 20s - loss: 0.0613 - accuracy: 4.7742e-05 - val_loss: 0.0554 - val_accuracy: 0.0000e+00 - 20s/epoch - 248ms/step
# Epoch 47/110
# 82/82 - 20s - loss: 0.0612 - accuracy: 4.7742e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 48/110
# 82/82 - 20s - loss: 0.0611 - accuracy: 4.7742e-05 - val_loss: 0.0547 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 49/110
# 82/82 - 20s - loss: 0.0611 - accuracy: 4.7742e-05 - val_loss: 0.0546 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 50/110
# 82/82 - 20s - loss: 0.0608 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 51/110
# 82/82 - 20s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0535 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 52/110
# 82/82 - 20s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0534 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 53/110
# 82/82 - 20s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0540 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 54/110
# 82/82 - 20s - loss: 0.0604 - accuracy: 4.7742e-05 - val_loss: 0.0538 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 55/110
# 82/82 - 20s - loss: 0.0603 - accuracy: 4.7742e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 20s/epoch - 245ms/step
# Epoch 56/110
# 82/82 - 20s - loss: 0.0603 - accuracy: 4.7742e-05 - val_loss: 0.0533 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 57/110
# 82/82 - 20s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0529 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 58/110
# 82/82 - 20s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0528 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 59/110
# 82/82 - 20s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0526 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 60/110
# 82/82 - 20s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0527 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 61/110
# 82/82 - 20s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0528 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 62/110
# 82/82 - 20s - loss: 0.0597 - accuracy: 4.7742e-05 - val_loss: 0.0528 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 63/110
# 82/82 - 20s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0525 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 64/110
# 82/82 - 20s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 65/110
# 82/82 - 20s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0522 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 66/110
# 82/82 - 20s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 20s/epoch - 245ms/step
# Epoch 67/110
# 82/82 - 20s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 68/110
# 82/82 - 20s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 69/110
# 82/82 - 20s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 70/110
# 82/82 - 20s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 71/110
# 82/82 - 20s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 72/110
# 82/82 - 20s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0517 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 73/110
# 82/82 - 20s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 74/110
# 82/82 - 20s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 75/110
# 82/82 - 20s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 76/110
# 82/82 - 20s - loss: 0.0589 - accuracy: 4.7742e-05 - val_loss: 0.0510 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 77/110
# 82/82 - 20s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 78/110
# 82/82 - 20s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0512 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 79/110
# 82/82 - 20s - loss: 0.0586 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 80/110
# 82/82 - 21s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 21s/epoch - 253ms/step
# Epoch 81/110
# 82/82 - 20s - loss: 0.0584 - accuracy: 4.7742e-05 - val_loss: 0.0504 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 82/110
# 82/82 - 20s - loss: 0.0584 - accuracy: 4.7742e-05 - val_loss: 0.0509 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 83/110
# 82/82 - 20s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 84/110
# 82/82 - 20s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0502 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 85/110
# 82/82 - 20s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 86/110
# 82/82 - 20s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 87/110
# 82/82 - 21s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 21s/epoch - 251ms/step
# Epoch 88/110
# 82/82 - 20s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0496 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 89/110
# 82/82 - 20s - loss: 0.0581 - accuracy: 4.7742e-05 - val_loss: 0.0506 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 90/110
# 82/82 - 20s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 91/110
# 82/82 - 20s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0498 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 92/110
# 82/82 - 22s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 22s/epoch - 265ms/step
# Epoch 93/110
# 82/82 - 20s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 20s/epoch - 238ms/step
# Epoch 94/110
# 82/82 - 20s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 95/110
# 82/82 - 19s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0496 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 96/110
# 82/82 - 19s - loss: 0.0577 - accuracy: 4.7742e-05 - val_loss: 0.0490 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 97/110
# 82/82 - 19s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0492 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 98/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0490 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 99/110
# 82/82 - 19s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0489 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 100/110
# 82/82 - 20s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0492 - val_accuracy: 0.0000e+00 - 20s/epoch - 238ms/step
# Epoch 101/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0493 - val_accuracy: 0.0000e+00 - 19s/epoch - 238ms/step
# Epoch 102/110
# 82/82 - 19s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0491 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 103/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0487 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 104/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0490 - val_accuracy: 0.0000e+00 - 19s/epoch - 235ms/step
# Epoch 105/110
# 82/82 - 20s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0491 - val_accuracy: 0.0000e+00 - 20s/epoch - 239ms/step
# Epoch 106/110
# 82/82 - 19s - loss: 0.0574 - accuracy: 4.7742e-05 - val_loss: 0.0488 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 107/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0493 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 108/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0487 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 109/110
# 82/82 - 19s - loss: 0.0572 - accuracy: 4.7742e-05 - val_loss: 0.0489 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 110/110
# 82/82 - 19s - loss: 0.0572 - accuracy: 4.7742e-05 - val_loss: 0.0486 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 655/655 [==============================] - 15s 22ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.047
#   RMSE val:	 0.043
#   RMSE test:	 0.043

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 80/80 [==============================] - 2s 24ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values
# Out:
# array([[39.16718 ],
#        [39.145233],
#        [39.120094],
#        [39.173763],
#        [39.275105],
#        [39.33413 ],
#        [39.34987 ],
#        [39.341595],
#        [39.321915],
#        [39.319813]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()

# %%
similar=0
different=0

for i in range(len(y_predict_trans)):
    
    print("Modelo:", y_predict_trans[i])
    print("Real:  ", y_mesuared[i])
    
    diff= y_predict_trans[i]-y_mesuared[i]

    print("Diff: ", diff)

    if -1.5<diff<1.5 :
        similar+=1
        print("Same Numbers")
    else:
        different+=1
        print("Different")

ratio=np.round((similar/(similar+different))*100,1)

print("Quantity of same numbers: ", similar, " records")
print("Quantity of different numbers: ", different, " records")
print("Percentage: ", ratio, "%")
# Out:
# Modelo: [39.94794]
# Real:   [39.416]
# Diff:  [0.53194083]
# Same Numbers
# Modelo: [40.015945]
# Real:   [38.634]
# Diff:  [1.38194543]
# Same Numbers
# Modelo: [39.99241]
# Real:   [39.007]
# Diff:  [0.98540875]
# Same Numbers
# Modelo: [40.000793]
# Real:   [40.407]
# Diff:  [-0.40620654]
# Same Numbers
# Modelo: [40.12336]
# Real:   [36.734]
# Diff:  [3.38935968]
# Different
# Modelo: [39.791035]
# Real:   [39.16]
# Diff:  [0.6310347]
# Same Numbers
# Modelo: [39.76566]
# Real:   [40.376]
# Diff:  [-0.61034067]
# Same Numbers
# Modelo: [39.91155]
# Real:   [40.18]
# Diff:  [-0.26845139]
# Same Numbers
# Modelo: [40.185093]
# Real:   [40.988]
# Diff:  [-0.80290707]
# Same Numbers
# Modelo: [40.484642]
# Real:   [44.586]
# Diff:  [-4.10135797]
# Different
# Modelo: [41.180145]
# Real:   [44.598]
# Diff:  [-3.41785474]
# Different
# Modelo: [42.179424]
# Real:   [44.401]
# Diff:  [-2.22157571]
# Different
# Modelo: [42.748325]
# Real:   [44.495]
# Diff:  [-1.74667465]
# Different
# Modelo: [43.280838]
# Real:   [44.073]
# Diff:  [-0.79216199]
# Same Numbers
# Modelo: [43.60662]
# Real:   [44.705]
# Diff:  [-1.09837921]
# Same Numbers
# Modelo: [43.844215]
# Real:   [42.5]
# Diff:  [1.34421539]
# Same Numbers
# Modelo: [43.69875]
# Real:   [41.697]
# Diff:  [2.00174954]
# Different
# Modelo: [43.31175]
# Real:   [41.067]
# Diff:  [2.2447485]
# Different
# Modelo: [42.9007]
# Real:   [42.264]
# Diff:  [0.63669962]
# Same Numbers
# Modelo: [42.741055]
# Real:   [41.4]
# Diff:  [1.34105453]
# Same Numbers
# Modelo: [42.504707]
# Real:   [41.701]
# Diff:  [0.80370734]
# Same Numbers
# Modelo: [42.30149]
# Real:   [40.553]
# Diff:  [1.74849078]
# Different
# Modelo: [42.050983]
# Real:   [43.069]
# Diff:  [-1.01801657]
# Same Numbers
# Modelo: [42.047417]
# Real:   [43.542]
# Diff:  [-1.49458331]
# Same Numbers
# Modelo: [42.162766]
# Real:   [46.468]
# Diff:  [-4.3052345]
# Different
# Modelo: [42.54276]
# Real:   [44.944]
# Diff:  [-2.40124106]
# Different
# Modelo: [42.78765]
# Real:   [41.796]
# Diff:  [0.99165106]
# Same Numbers
# Modelo: [42.68146]
# Real:   [41.322]
# Diff:  [1.35946133]
# Same Numbers
# Modelo: [42.4506]
# Real:   [40.461]
# Diff:  [1.98959967]
# Different
# Modelo: [42.14339]
# Real:   [42.685]
# Diff:  [-0.54160934]
# Same Numbers
# Modelo: [42.128704]
# Real:   [43.59]
# Diff:  [-1.46129593]
# Same Numbers
# Modelo: [42.313087]
# Real:   [42.227]
# Diff:  [0.08608746]
# Same Numbers
# Modelo: [42.375484]
# Real:   [42.92]
# Diff:  [-0.54451553]
# Same Numbers
# Modelo: [42.48906]
# Real:   [42.136]
# Diff:  [0.35305945]
# Same Numbers
# Modelo: [42.551983]
# Real:   [42.206]
# Diff:  [0.34598288]
# Same Numbers
# Modelo: [42.591984]
# Real:   [42.15]
# Diff:  [0.4419838]
# Same Numbers
# Modelo: [42.622417]
# Real:   [42.506]
# Diff:  [0.11641745]
# Same Numbers
# Modelo: [42.672718]
# Real:   [41.596]
# Diff:  [1.07671805]
# Same Numbers
# Modelo: [42.61466]
# Real:   [42.652]
# Diff:  [-0.03734164]
# Same Numbers
# Modelo: [42.66163]
# Real:   [41.632]
# Diff:  [1.02962872]
# Same Numbers
# Modelo: [42.557934]
# Real:   [41.695]
# Diff:  [0.86293381]
# Same Numbers
# Modelo: [42.470383]
# Real:   [40.924]
# Diff:  [1.54638269]
# Different
# Modelo: [42.318058]
# Real:   [41.594]
# Diff:  [0.72405801]
# Same Numbers
# Modelo: [42.253834]
# Real:   [41.169]
# Diff:  [1.08483377]
# Same Numbers
# Modelo: [42.140446]
# Real:   [41.221]
# Diff:  [0.91944571]
# Same Numbers
# Modelo: [42.054417]
# Real:   [41.359]
# Diff:  [0.69541666]
# Same Numbers
# Modelo: [42.00559]
# Real:   [40.942]
# Diff:  [1.06358853]
# Same Numbers
# Modelo: [41.929913]
# Real:   [41.298]
# Diff:  [0.63191257]
# Same Numbers
# Modelo: [41.906063]
# Real:   [40.885]
# Diff:  [1.02106308]
# Same Numbers
# Modelo: [41.850716]
# Real:   [41.373]
# Diff:  [0.47771564]
# Same Numbers
# Modelo: [41.855766]
# Real:   [41.481]
# Diff:  [0.3747663]
# Same Numbers
# Modelo: [41.881966]
# Real:   [41.236]
# Diff:  [0.64596564]
# Same Numbers
# Modelo: [41.86255]
# Real:   [41.438]
# Diff:  [0.42454883]
# Same Numbers
# Modelo: [41.871487]
# Real:   [40.847]
# Diff:  [1.02448666]
# Same Numbers
# Modelo: [41.82387]
# Real:   [41.443]
# Diff:  [0.38087161]
# Same Numbers
# Modelo: [41.843155]
# Real:   [41.068]
# Diff:  [0.77515491]
# Same Numbers
# Modelo: [41.817722]
# Real:   [40.776]
# Diff:  [1.04172232]
# Same Numbers
# Modelo: [41.764587]
# Real:   [40.8]
# Diff:  [0.9645874]
# Same Numbers
# Modelo: [41.719017]
# Real:   [40.85]
# Diff:  [0.86901703]
# Same Numbers
# Modelo: [41.685814]
# Real:   [40.522]
# Diff:  [1.1638139]
# Same Numbers
# Modelo: [41.614674]
# Real:   [40.813]
# Diff:  [0.80167361]
# Same Numbers
# Modelo: [41.582893]
# Real:   [40.724]
# Diff:  [0.85889337]
# Same Numbers
# Modelo: [41.552074]
# Real:   [40.906]
# Diff:  [0.64607443]
# Same Numbers
# Modelo: [41.547947]
# Real:   [42.892]
# Diff:  [-1.34405307]
# Same Numbers
# Modelo: [41.808613]
# Real:   [49.045]
# Diff:  [-7.23638718]
# Different
# Modelo: [42.720898]
# Real:   [55.624]
# Diff:  [-12.90310233]
# Different
# Modelo: [44.31702]
# Real:   [52.876]
# Diff:  [-8.55897958]
# Different
# Modelo: [46.085705]
# Real:   [48.549]
# Diff:  [-2.4632952]
# Different
# Modelo: [46.420036]
# Real:   [45.784]
# Diff:  [0.63603632]
# Same Numbers
# Modelo: [46.2163]
# Real:   [43.407]
# Diff:  [2.80930096]
# Different
# Modelo: [45.707443]
# Real:   [39.319]
# Diff:  [6.38844324]
# Different
# Modelo: [44.80954]
# Real:   [39.733]
# Diff:  [5.07653979]
# Different
# Modelo: [43.952717]
# Real:   [43.025]
# Diff:  [0.92771683]
# Same Numbers
# Modelo: [43.56814]
# Real:   [43.494]
# Diff:  [0.07413812]
# Same Numbers
# Modelo: [43.49328]
# Real:   [43.343]
# Diff:  [0.1502785]
# Same Numbers
# Modelo: [43.481857]
# Real:   [43.486]
# Diff:  [-0.0041427]
# Same Numbers
# Modelo: [43.5256]
# Real:   [46.992]
# Diff:  [-3.46639957]
# Different
# Modelo: [44.002014]
# Real:   [42.763]
# Diff:  [1.23901416]
# Same Numbers
# Modelo: [43.913704]
# Real:   [43.891]
# Diff:  [0.02270392]
# Same Numbers
# Modelo: [43.968422]
# Real:   [41.062]
# Diff:  [2.90642194]
# Different
# Modelo: [43.6937]
# Real:   [43.763]
# Diff:  [-0.06930112]
# Same Numbers
# Modelo: [43.75174]
# Real:   [41.619]
# Diff:  [2.1327395]
# Different
# Modelo: [43.551067]
# Real:   [41.615]
# Diff:  [1.93606735]
# Different
# Modelo: [43.351883]
# Real:   [39.766]
# Diff:  [3.58588293]
# Different
# Modelo: [43.14343]
# Real:   [43.123]
# Diff:  [0.0204288]
# Same Numbers
# Modelo: [43.290688]
# Real:   [42.54]
# Diff:  [0.75068756]
# Same Numbers
# Modelo: [43.40168]
# Real:   [43.792]
# Diff:  [-0.39032001]
# Same Numbers
# Modelo: [43.64476]
# Real:   [42.813]
# Diff:  [0.83176013]
# Same Numbers
# Modelo: [43.55051]
# Real:   [43.172]
# Diff:  [0.37851041]
# Same Numbers
# Modelo: [43.533104]
# Real:   [43.726]
# Diff:  [-0.19289606]
# Same Numbers
# Modelo: [43.56982]
# Real:   [41.698]
# Diff:  [1.8718204]
# Different
# Modelo: [43.372116]
# Real:   [43.299]
# Diff:  [0.07311609]
# Same Numbers
# Modelo: [43.325146]
# Real:   [42.36]
# Diff:  [0.96514572]
# Same Numbers
# Modelo: [43.2032]
# Real:   [42.901]
# Diff:  [0.30220129]
# Same Numbers
# Modelo: [43.148823]
# Real:   [42.173]
# Diff:  [0.97582278]
# Same Numbers
# Modelo: [43.012936]
# Real:   [38.832]
# Diff:  [4.18093564]
# Different
# Modelo: [42.44805]
# Real:   [41.038]
# Diff:  [1.41005145]
# Same Numbers
# Modelo: [42.217674]
# Real:   [39.24]
# Diff:  [2.97767426]
# Different
# Modelo: [41.81107]
# Real:   [35.782]
# Diff:  [6.02906949]
# Different
# Modelo: [41.021057]
# Real:   [38.161]
# Diff:  [2.86005713]
# Different
# Modelo: [40.64215]
# Real:   [41.717]
# Diff:  [-1.07484912]
# Same Numbers
# Modelo: [40.73791]
# Real:   [41.033]
# Diff:  [-0.29508878]
# Same Numbers
# Modelo: [40.784466]
# Real:   [44.079]
# Diff:  [-3.29453421]
# Different
# Modelo: [41.21782]
# Real:   [43.993]
# Diff:  [-2.77518079]
# Different
# Modelo: [41.890594]
# Real:   [43.786]
# Diff:  [-1.89540552]
# Different
# Modelo: [42.41244]
# Real:   [41.159]
# Diff:  [1.25344125]
# Same Numbers
# Modelo: [42.474678]
# Real:   [43.316]
# Diff:  [-0.84132196]
# Same Numbers
# Modelo: [43.19026]
# Real:   [42.658]
# Diff:  [0.53226184]
# Same Numbers
# Modelo: [43.5103]
# Real:   [40.079]
# Diff:  [3.43129968]
# Different
# Modelo: [43.48675]
# Real:   [38.861]
# Diff:  [4.62575156]
# Different
# Modelo: [43.23038]
# Real:   [38.608]
# Diff:  [4.62238101]
# Different
# Modelo: [42.858154]
# Real:   [40.026]
# Diff:  [2.8321543]
# Different
# Modelo: [42.427986]
# Real:   [40.731]
# Diff:  [1.69698615]
# Different
# Modelo: [42.108715]
# Real:   [40.393]
# Diff:  [1.71571506]
# Different
# Modelo: [41.78541]
# Real:   [40.471]
# Diff:  [1.31441183]
# Same Numbers
# Modelo: [41.491383]
# Real:   [40.66]
# Diff:  [0.8313826]
# Same Numbers
# Modelo: [41.274548]
# Real:   [40.93]
# Diff:  [0.34454758]
# Same Numbers
# Modelo: [41.151222]
# Real:   [40.848]
# Diff:  [0.30322223]
# Same Numbers
# Modelo: [41.06538]
# Real:   [40.97]
# Diff:  [0.0953801]
# Same Numbers
# Modelo: [41.024597]
# Real:   [40.919]
# Diff:  [0.10559717]
# Same Numbers
# Modelo: [41.18583]
# Real:   [42.365]
# Diff:  [-1.17917084]
# Same Numbers
# Modelo: [41.473083]
# Real:   [42.082]
# Diff:  [-0.6089165]
# Same Numbers
# Modelo: [41.69655]
# Real:   [41.558]
# Diff:  [0.13854846]
# Same Numbers
# Modelo: [41.827442]
# Real:   [41.839]
# Diff:  [-0.01155783]
# Same Numbers
# Modelo: [41.80034]
# Real:   [42.011]
# Diff:  [-0.21066125]
# Same Numbers
# Modelo: [41.81557]
# Real:   [42.098]
# Diff:  [-0.28242917]
# Same Numbers
# Modelo: [41.867573]
# Real:   [41.648]
# Diff:  [0.21957278]
# Same Numbers
# Modelo: [41.88693]
# Real:   [41.314]
# Diff:  [0.57292856]
# Same Numbers
# Modelo: [41.902905]
# Real:   [41.805]
# Diff:  [0.09790451]
# Same Numbers
# Modelo: [41.969734]
# Real:   [41.789]
# Diff:  [0.18073419]
# Same Numbers
# Modelo: [42.02176]
# Real:   [41.928]
# Diff:  [0.09375903]
# Same Numbers
# Modelo: [42.07093]
# Real:   [42.081]
# Diff:  [-0.01006952]
# Same Numbers
# Modelo: [42.112816]
# Real:   [41.699]
# Diff:  [0.41381586]
# Same Numbers
# Modelo: [42.11817]
# Real:   [42.008]
# Diff:  [0.11017169]
# Same Numbers
# Modelo: [42.163517]
# Real:   [41.412]
# Diff:  [0.751517]
# Same Numbers
# Modelo: [42.14871]
# Real:   [40.601]
# Diff:  [1.54770834]
# Different
# Modelo: [42.003384]
# Real:   [40.556]
# Diff:  [1.44738364]
# Same Numbers
# Modelo: [41.87509]
# Real:   [40.065]
# Diff:  [1.81009155]
# Different
# Modelo: [41.726486]
# Real:   [40.863]
# Diff:  [0.86348621]
# Same Numbers
# Modelo: [41.683384]
# Real:   [40.541]
# Diff:  [1.14238394]
# Same Numbers
# Modelo: [41.598312]
# Real:   [40.751]
# Diff:  [0.84731238]
# Same Numbers
# Modelo: [41.547653]
# Real:   [40.5]
# Diff:  [1.0476532]
# Same Numbers
# Modelo: [41.484478]
# Real:   [40.394]
# Diff:  [1.090478]
# Same Numbers
# Modelo: [41.420483]
# Real:   [40.104]
# Diff:  [1.31648264]
# Same Numbers
# Modelo: [41.34195]
# Real:   [39.949]
# Diff:  [1.39294946]
# Same Numbers
# Modelo: [41.25497]
# Real:   [40.067]
# Diff:  [1.18797055]
# Same Numbers
# Modelo: [41.190586]
# Real:   [39.899]
# Diff:  [1.29158609]
# Same Numbers
# Modelo: [41.1198]
# Real:   [39.848]
# Diff:  [1.27180057]
# Same Numbers
# Modelo: [41.052372]
# Real:   [39.567]
# Diff:  [1.48537198]
# Same Numbers
# Modelo: [40.96539]
# Real:   [40.049]
# Diff:  [0.91638925]
# Same Numbers
# Modelo: [40.940487]
# Real:   [39.724]
# Diff:  [1.21648691]
# Same Numbers
# Modelo: [40.892796]
# Real:   [39.638]
# Diff:  [1.25479556]
# Same Numbers
# Modelo: [40.81609]
# Real:   [39.481]
# Diff:  [1.33508963]
# Same Numbers
# Modelo: [40.73681]
# Real:   [39.752]
# Diff:  [0.98480878]
# Same Numbers
# Modelo: [40.70129]
# Real:   [42.071]
# Diff:  [-1.36970987]
# Same Numbers
# Modelo: [40.929745]
# Real:   [39.802]
# Diff:  [1.12774472]
# Same Numbers
# Modelo: [40.91594]
# Real:   [39.608]
# Diff:  [1.30793933]
# Same Numbers
# Modelo: [40.86741]
# Real:   [39.696]
# Diff:  [1.17140875]
# Same Numbers
# Modelo: [40.82683]
# Real:   [39.764]
# Diff:  [1.06283182]
# Same Numbers
# Modelo: [40.797073]
# Real:   [39.838]
# Diff:  [0.95907336]
# Same Numbers
# Modelo: [41.45171]
# Real:   [39.766]
# Diff:  [1.68570975]
# Different
# Modelo: [41.922478]
# Real:   [39.486]
# Diff:  [2.43647772]
# Different
# Modelo: [42.17782]
# Real:   [39.837]
# Diff:  [2.3408183]
# Different
# Modelo: [42.799976]
# Real:   [39.871]
# Diff:  [2.92897635]
# Different
# Modelo: [42.151684]
# Real:   [39.53]
# Diff:  [2.62168381]
# Different
# Modelo: [41.467964]
# Real:   [39.885]
# Diff:  [1.58296417]
# Different
# Modelo: [40.970642]
# Real:   [39.667]
# Diff:  [1.30364209]
# Same Numbers
# Modelo: [40.619476]
# Real:   [39.634]
# Diff:  [0.98547632]
# Same Numbers
# Modelo: [40.265373]
# Real:   [40.116]
# Diff:  [0.14937323]
# Same Numbers
# Modelo: [40.153557]
# Real:   [39.261]
# Diff:  [0.89255682]
# Same Numbers
# Modelo: [40.052143]
# Real:   [37.172]
# Diff:  [2.8801431]
# Different
# Modelo: [39.772335]
# Real:   [37.194]
# Diff:  [2.57833505]
# Different
# Modelo: [39.709526]
# Real:   [37.002]
# Diff:  [2.70752606]
# Different
# Modelo: [39.602158]
# Real:   [37.931]
# Diff:  [1.67115759]
# Different
# Modelo: [39.633778]
# Real:   [40.908]
# Diff:  [-1.27422238]
# Same Numbers
# Modelo: [40.011524]
# Real:   [40.263]
# Diff:  [-0.2514758]
# Same Numbers
# Modelo: [40.09951]
# Real:   [37.525]
# Diff:  [2.57451019]
# Different
# Modelo: [39.904312]
# Real:   [36.471]
# Diff:  [3.43331213]
# Different
# Modelo: [39.600983]
# Real:   [38.398]
# Diff:  [1.20298267]
# Same Numbers
# Modelo: [39.56245]
# Real:   [39.184]
# Diff:  [0.37845041]
# Same Numbers
# Modelo: [39.658173]
# Real:   [41.067]
# Diff:  [-1.40882739]
# Same Numbers
# Modelo: [39.984684]
# Real:   [40.875]
# Diff:  [-0.89031601]
# Same Numbers
# Modelo: [40.26151]
# Real:   [38.565]
# Diff:  [1.69650894]
# Different
# Modelo: [40.224903]
# Real:   [40.753]
# Diff:  [-0.52809689]
# Same Numbers
# Modelo: [40.491673]
# Real:   [40.949]
# Diff:  [-0.45732748]
# Same Numbers
# Modelo: [40.753647]
# Real:   [40.105]
# Diff:  [0.64864685]
# Same Numbers
# Modelo: [40.846]
# Real:   [37.283]
# Diff:  [3.56300067]
# Different
# Modelo: [40.586765]
# Real:   [39.554]
# Diff:  [1.03276529]
# Same Numbers
# Modelo: [40.593895]
# Real:   [37.953]
# Diff:  [2.64089496]
# Different
# Modelo: [40.386982]
# Real:   [38.739]
# Diff:  [1.64798196]
# Different
# Modelo: [40.296303]
# Real:   [38.029]
# Diff:  [2.2673028]
# Different
# Modelo: [40.151424]
# Real:   [38.356]
# Diff:  [1.79542441]
# Different
# Modelo: [39.75764]
# Real:   [40.713]
# Diff:  [-0.95535916]
# Same Numbers
# Modelo: [39.791576]
# Real:   [40.797]
# Diff:  [-1.00542361]
# Same Numbers
# Modelo: [39.904]
# Real:   [40.028]
# Diff:  [-0.12400067]
# Same Numbers
# Modelo: [39.962624]
# Real:   [41.173]
# Diff:  [-1.2103764]
# Same Numbers
# Modelo: [40.38002]
# Real:   [41.386]
# Diff:  [-1.00597986]
# Same Numbers
# Modelo: [40.732315]
# Real:   [40.837]
# Diff:  [-0.10468494]
# Same Numbers
# Modelo: [40.959618]
# Real:   [40.746]
# Diff:  [0.21361761]
# Same Numbers
# Modelo: [41.12699]
# Real:   [40.821]
# Diff:  [0.30599127]
# Same Numbers
# Modelo: [41.403996]
# Real:   [40.13]
# Diff:  [1.27399551]
# Same Numbers
# Modelo: [41.499306]
# Real:   [41.081]
# Diff:  [0.41830573]
# Same Numbers
# Modelo: [41.659683]
# Real:   [40.763]
# Diff:  [0.89668323]
# Same Numbers
# Modelo: [41.99554]
# Real:   [41.357]
# Diff:  [0.63854062]
# Same Numbers
# Modelo: [41.827568]
# Real:   [41.849]
# Diff:  [-0.02143195]
# Same Numbers
# Modelo: [41.878723]
# Real:   [41.397]
# Diff:  [0.48172314]
# Same Numbers
# Modelo: [41.96611]
# Real:   [40.881]
# Diff:  [1.08511023]
# Same Numbers
# Modelo: [42.003006]
# Real:   [40.274]
# Diff:  [1.72900598]
# Different
# Modelo: [41.812855]
# Real:   [41.479]
# Diff:  [0.33385477]
# Same Numbers
# Modelo: [41.70921]
# Real:   [41.665]
# Diff:  [0.04420944]
# Same Numbers
# Modelo: [41.63877]
# Real:   [40.688]
# Diff:  [0.95077106]
# Same Numbers
# Modelo: [41.50479]
# Real:   [41.227]
# Diff:  [0.27779126]
# Same Numbers
# Modelo: [41.43653]
# Real:   [40.801]
# Diff:  [0.63553107]
# Same Numbers
# Modelo: [41.315178]
# Real:   [40.637]
# Diff:  [0.67817792]
# Same Numbers
# Modelo: [41.13287]
# Real:   [40.991]
# Diff:  [0.14186972]
# Same Numbers
# Modelo: [41.014378]
# Real:   [40.64]
# Diff:  [0.37437759]
# Same Numbers
# Modelo: [41.004353]
# Real:   [41.449]
# Diff:  [-0.44464743]
# Same Numbers
# Modelo: [41.080017]
# Real:   [41.128]
# Diff:  [-0.04798291]
# Same Numbers
# Modelo: [41.118954]
# Real:   [41.028]
# Diff:  [0.0909537]
# Same Numbers
# Modelo: [41.14206]
# Real:   [40.601]
# Diff:  [0.54105933]
# Same Numbers
# Modelo: [41.114082]
# Real:   [41.952]
# Diff:  [-0.83791766]
# Same Numbers
# Modelo: [41.185837]
# Real:   [41.368]
# Diff:  [-0.18216321]
# Same Numbers
# Modelo: [41.214134]
# Real:   [41.765]
# Diff:  [-0.55086578]
# Same Numbers
# Modelo: [41.358883]
# Real:   [41.118]
# Diff:  [0.2408829]
# Same Numbers
# Modelo: [41.413303]
# Real:   [41.574]
# Diff:  [-0.16069662]
# Same Numbers
# Modelo: [41.49639]
# Real:   [41.549]
# Diff:  [-0.0526087]
# Same Numbers
# Modelo: [41.568085]
# Real:   [40.961]
# Diff:  [0.60708472]
# Same Numbers
# Modelo: [41.56694]
# Real:   [41.165]
# Diff:  [0.40194031]
# Same Numbers
# Modelo: [41.584652]
# Real:   [40.824]
# Diff:  [0.76065195]
# Same Numbers
# Modelo: [41.562122]
# Real:   [41.091]
# Diff:  [0.47112234]
# Same Numbers
# Modelo: [41.56475]
# Real:   [41.153]
# Diff:  [0.41175067]
# Same Numbers
# Modelo: [41.575996]
# Real:   [41.28]
# Diff:  [0.2959964]
# Same Numbers
# Modelo: [41.509727]
# Real:   [40.522]
# Diff:  [0.98772748]
# Same Numbers
# Modelo: [41.38718]
# Real:   [41.043]
# Diff:  [0.34418033]
# Same Numbers
# Modelo: [41.3437]
# Real:   [40.812]
# Diff:  [0.53170041]
# Same Numbers
# Modelo: [41.299404]
# Real:   [40.405]
# Diff:  [0.89440414]
# Same Numbers
# Modelo: [41.22751]
# Real:   [40.454]
# Diff:  [0.77350854]
# Same Numbers
# Modelo: [41.17089]
# Real:   [41.006]
# Diff:  [0.16489081]
# Same Numbers
# Modelo: [41.18507]
# Real:   [40.731]
# Diff:  [0.45407004]
# Same Numbers
# Modelo: [41.181057]
# Real:   [40.631]
# Diff:  [0.55005698]
# Same Numbers
# Modelo: [41.130585]
# Real:   [38.213]
# Diff:  [2.91758472]
# Different
# Modelo: [40.83344]
# Real:   [37.796]
# Diff:  [3.03743887]
# Different
# Modelo: [40.519962]
# Real:   [40.327]
# Diff:  [0.19296231]
# Same Numbers
# Modelo: [40.529728]
# Real:   [40.296]
# Diff:  [0.23372794]
# Same Numbers
# Modelo: [40.55632]
# Real:   [39.928]
# Diff:  [0.62832019]
# Same Numbers
# Modelo: [40.55061]
# Real:   [40.149]
# Diff:  [0.40160959]
# Same Numbers
# Modelo: [40.571537]
# Real:   [39.861]
# Diff:  [0.71053702]
# Same Numbers
# Modelo: [40.565353]
# Real:   [39.7]
# Diff:  [0.86535339]
# Same Numbers
# Modelo: [40.57386]
# Real:   [39.728]
# Diff:  [0.84586017]
# Same Numbers
# Modelo: [40.578888]
# Real:   [40.279]
# Diff:  [0.29988794]
# Same Numbers
# Modelo: [40.638187]
# Real:   [40.236]
# Diff:  [0.40218741]
# Same Numbers
# Modelo: [40.691418]
# Real:   [40.006]
# Diff:  [0.68541769]
# Same Numbers
# Modelo: [40.677254]
# Real:   [39.618]
# Diff:  [1.05925372]
# Same Numbers
# Modelo: [40.625206]
# Real:   [39.51]
# Diff:  [1.11520599]
# Same Numbers
# Modelo: [40.56769]
# Real:   [39.426]
# Diff:  [1.1416918]
# Same Numbers
# Modelo: [40.50913]
# Real:   [39.866]
# Diff:  [0.64312857]
# Same Numbers
# Modelo: [40.50761]
# Real:   [39.714]
# Diff:  [0.79361032]
# Same Numbers
# Modelo: [40.499123]
# Real:   [39.173]
# Diff:  [1.32612262]
# Same Numbers
# Modelo: [40.43648]
# Real:   [39.124]
# Diff:  [1.31248148]
# Same Numbers
# Modelo: [40.833355]
# Real:   [39.253]
# Diff:  [1.58035495]
# Different
# Modelo: [40.461063]
# Real:   [39.331]
# Diff:  [1.13006339]
# Same Numbers
# Modelo: [40.05199]
# Real:   [39.408]
# Diff:  [0.64399051]
# Same Numbers
# Modelo: [39.740475]
# Real:   [39.217]
# Diff:  [0.5234747]
# Same Numbers
# Modelo: [39.531254]
# Real:   [39.25]
# Diff:  [0.28125381]
# Same Numbers
# Modelo: [39.38603]
# Real:   [39.202]
# Diff:  [0.18402829]
# Same Numbers
# Modelo: [39.34896]
# Real:   [39.358]
# Diff:  [-0.00903912]
# Same Numbers
# Modelo: [39.405663]
# Real:   [39.333]
# Diff:  [0.07266254]
# Same Numbers
# Modelo: [39.503616]
# Real:   [39.317]
# Diff:  [0.18661633]
# Same Numbers
# Modelo: [39.55916]
# Real:   [39.384]
# Diff:  [0.17515833]
# Same Numbers
# Modelo: [39.681473]
# Real:   [37.984]
# Diff:  [1.69747278]
# Different
# Modelo: [39.6083]
# Real:   [37.125]
# Diff:  [2.48329926]
# Different
# Modelo: [39.44198]
# Real:   [37.665]
# Diff:  [1.77697845]
# Different
# Modelo: [39.346878]
# Real:   [37.25]
# Diff:  [2.09687805]
# Different
# Modelo: [39.21176]
# Real:   [36.505]
# Diff:  [2.70676147]
# Different
# Modelo: [38.99894]
# Real:   [37.169]
# Diff:  [1.82993951]
# Different
# Modelo: [38.8619]
# Real:   [37.23]
# Diff:  [1.63190033]
# Different
# Modelo: [38.909374]
# Real:   [37.61]
# Diff:  [1.29937424]
# Same Numbers
# Modelo: [38.95082]
# Real:   [37.462]
# Diff:  [1.48882092]
# Same Numbers
# Modelo: [38.947163]
# Real:   [37.784]
# Diff:  [1.16316263]
# Same Numbers
# Modelo: [39.01535]
# Real:   [37.443]
# Diff:  [1.57235034]
# Different
# Modelo: [38.98231]
# Real:   [37.643]
# Diff:  [1.33931125]
# Same Numbers
# Modelo: [38.96145]
# Real:   [38.711]
# Diff:  [0.25044867]
# Same Numbers
# Modelo: [39.050926]
# Real:   [37.681]
# Diff:  [1.36992621]
# Same Numbers
# Modelo: [39.0444]
# Real:   [37.515]
# Diff:  [1.52939926]
# Different
# Modelo: [38.90984]
# Real:   [38.034]
# Diff:  [0.87583963]
# Same Numbers
# Modelo: [38.88431]
# Real:   [37.877]
# Diff:  [1.00731168]
# Same Numbers
# Modelo: [38.84204]
# Real:   [38.145]
# Diff:  [0.69704102]
# Same Numbers
# Modelo: [38.845745]
# Real:   [38.219]
# Diff:  [0.62674509]
# Same Numbers
# Modelo: [38.996357]
# Real:   [38.922]
# Diff:  [0.07435696]
# Same Numbers
# Modelo: [39.173096]
# Real:   [38.806]
# Diff:  [0.3670957]
# Same Numbers
# Modelo: [39.3012]
# Real:   [35.905]
# Diff:  [3.39620087]
# Different
# Modelo: [39.055515]
# Real:   [37.209]
# Diff:  [1.84651529]
# Different
# Modelo: [39.058067]
# Real:   [38.804]
# Diff:  [0.25406732]
# Same Numbers
# Modelo: [39.220066]
# Real:   [38.885]
# Diff:  [0.33506607]
# Same Numbers
# Modelo: [39.369244]
# Real:   [41.406]
# Diff:  [-2.03675638]
# Different
# Modelo: [39.811283]
# Real:   [40.843]
# Diff:  [-1.03171689]
# Same Numbers
# Modelo: [40.1148]
# Real:   [42.78]
# Diff:  [-2.6652005]
# Different
# Modelo: [40.63626]
# Real:   [44.988]
# Diff:  [-4.35173901]
# Different
# Modelo: [41.36828]
# Real:   [42.765]
# Diff:  [-1.3967215]
# Same Numbers
# Modelo: [42.136787]
# Real:   [39.839]
# Diff:  [2.29778741]
# Different
# Modelo: [42.189083]
# Real:   [38.466]
# Diff:  [3.7230831]
# Different
# Modelo: [42.073956]
# Real:   [38.041]
# Diff:  [4.03295554]
# Different
# Modelo: [41.834053]
# Real:   [39.112]
# Diff:  [2.72205304]
# Different
# Modelo: [41.603252]
# Real:   [40.245]
# Diff:  [1.35825241]
# Same Numbers
# Modelo: [41.475105]
# Real:   [40.676]
# Diff:  [0.79910529]
# Same Numbers
# Modelo: [41.3698]
# Real:   [40.9]
# Diff:  [0.46980057]
# Same Numbers
# Modelo: [41.278843]
# Real:   [41.082]
# Diff:  [0.19684293]
# Same Numbers
# Modelo: [41.155323]
# Real:   [40.562]
# Diff:  [0.59332303]
# Same Numbers
# Modelo: [40.915882]
# Real:   [41.76]
# Diff:  [-0.84411789]
# Same Numbers
# Modelo: [40.81149]
# Real:   [41.72]
# Diff:  [-0.90851089]
# Same Numbers
# Modelo: [40.839024]
# Real:   [41.269]
# Diff:  [-0.42997641]
# Same Numbers
# Modelo: [40.84955]
# Real:   [41.19]
# Diff:  [-0.34045166]
# Same Numbers
# Modelo: [40.865112]
# Real:   [41.512]
# Diff:  [-0.6468877]
# Same Numbers
# Modelo: [40.91725]
# Real:   [41.407]
# Diff:  [-0.48974841]
# Same Numbers
# Modelo: [40.961884]
# Real:   [42.034]
# Diff:  [-1.07211646]
# Same Numbers
# Modelo: [41.146492]
# Real:   [40.776]
# Diff:  [0.370492]
# Same Numbers
# Modelo: [41.204407]
# Real:   [41.377]
# Diff:  [-0.17259326]
# Same Numbers
# Modelo: [41.289364]
# Real:   [40.787]
# Diff:  [0.50236386]
# Same Numbers
# Modelo: [41.293427]
# Real:   [41.484]
# Diff:  [-0.19057349]
# Same Numbers
# Modelo: [41.357594]
# Real:   [40.652]
# Diff:  [0.70559354]
# Same Numbers
# Modelo: [41.321415]
# Real:   [41.609]
# Diff:  [-0.28758505]
# Same Numbers
# Modelo: [41.383453]
# Real:   [41.055]
# Diff:  [0.32845337]
# Same Numbers
# Modelo: [41.392857]
# Real:   [41.127]
# Diff:  [0.2658566]
# Same Numbers
# Modelo: [41.384064]
# Real:   [41.511]
# Diff:  [-0.12693628]
# Same Numbers
# Modelo: [41.433243]
# Real:   [41.068]
# Diff:  [0.3652428]
# Same Numbers
# Modelo: [41.46229]
# Real:   [40.984]
# Diff:  [0.47829172]
# Same Numbers
# Modelo: [41.475506]
# Real:   [41.201]
# Diff:  [0.27450583]
# Same Numbers
# Modelo: [41.50424]
# Real:   [41.615]
# Diff:  [-0.11076187]
# Same Numbers
# Modelo: [41.564278]
# Real:   [41.014]
# Diff:  [0.55027765]
# Same Numbers
# Modelo: [41.5606]
# Real:   [40.984]
# Diff:  [0.57660028]
# Same Numbers
# Modelo: [41.549843]
# Real:   [40.209]
# Diff:  [1.34084283]
# Same Numbers
# Modelo: [41.460426]
# Real:   [40.665]
# Diff:  [0.79542633]
# Same Numbers
# Modelo: [41.418182]
# Real:   [40.818]
# Diff:  [0.60018237]
# Same Numbers
# Modelo: [41.406097]
# Real:   [40.675]
# Diff:  [0.73109741]
# Same Numbers
# Modelo: [41.38265]
# Real:   [40.45]
# Diff:  [0.93264847]
# Same Numbers
# Modelo: [41.33835]
# Real:   [40.821]
# Diff:  [0.51734839]
# Same Numbers
# Modelo: [41.23635]
# Real:   [40.671]
# Diff:  [0.56535101]
# Same Numbers
# Modelo: [41.15274]
# Real:   [40.625]
# Diff:  [0.52774048]
# Same Numbers
# Modelo: [41.09625]
# Real:   [41.004]
# Diff:  [0.09224863]
# Same Numbers
# Modelo: [41.104195]
# Real:   [40.75]
# Diff:  [0.35419464]
# Same Numbers
# Modelo: [41.161602]
# Real:   [40.623]
# Diff:  [0.53860202]
# Same Numbers
# Modelo: [41.197704]
# Real:   [40.268]
# Diff:  [0.92970432]
# Same Numbers
# Modelo: [41.184525]
# Real:   [40.079]
# Diff:  [1.10552454]
# Same Numbers
# Modelo: [41.143055]
# Real:   [40.64]
# Diff:  [0.50305496]
# Same Numbers
# Modelo: [41.154533]
# Real:   [40.279]
# Diff:  [0.87553339]
# Same Numbers
# Modelo: [41.131767]
# Real:   [39.899]
# Diff:  [1.23276727]
# Same Numbers
# Modelo: [41.068733]
# Real:   [40.446]
# Diff:  [0.62273322]
# Same Numbers
# Modelo: [41.06686]
# Real:   [40.212]
# Diff:  [0.8548602]
# Same Numbers
# Modelo: [41.021873]
# Real:   [40.561]
# Diff:  [0.46087347]
# Same Numbers
# Modelo: [41.023758]
# Real:   [39.825]
# Diff:  [1.19875793]
# Same Numbers
# Modelo: [40.956963]
# Real:   [39.409]
# Diff:  [1.54796259]
# Different
# Modelo: [40.83949]
# Real:   [40.789]
# Diff:  [0.05048898]
# Same Numbers
# Modelo: [40.83998]
# Real:   [40.881]
# Diff:  [-0.04101892]
# Same Numbers
# Modelo: [40.841682]
# Real:   [42.672]
# Diff:  [-1.83031757]
# Different
# Modelo: [41.019093]
# Real:   [39.205]
# Diff:  [1.81409256]
# Different
# Modelo: [41.406754]
# Real:   [43.222]
# Diff:  [-1.81524646]
# Different
# Modelo: [41.41441]
# Real:   [43.112]
# Diff:  [-1.69759036]
# Different
# Modelo: [41.411526]
# Real:   [39.499]
# Diff:  [1.91252573]
# Different
# Modelo: [41.068203]
# Real:   [42.537]
# Diff:  [-1.46879703]
# Same Numbers
# Modelo: [41.116543]
# Real:   [39.843]
# Diff:  [1.27354282]
# Same Numbers
# Modelo: [40.959637]
# Real:   [36.875]
# Diff:  [4.08463669]
# Different
# Modelo: [40.508526]
# Real:   [36.37]
# Diff:  [4.13852585]
# Different
# Modelo: [40.08566]
# Real:   [38.162]
# Diff:  [1.92365903]
# Different
# Modelo: [39.937897]
# Real:   [38.971]
# Diff:  [0.96689673]
# Same Numbers
# Modelo: [39.881344]
# Real:   [39.334]
# Diff:  [0.54734384]
# Same Numbers
# Modelo: [39.905807]
# Real:   [35.639]
# Diff:  [4.2668075]
# Different
# Modelo: [39.55123]
# Real:   [43.085]
# Diff:  [-3.53376862]
# Different
# Modelo: [40.094986]
# Real:   [32.322]
# Diff:  [7.77298596]
# Different
# Modelo: [39.256245]
# Real:   [42.964]
# Diff:  [-3.70775534]
# Different
# Modelo: [39.722904]
# Real:   [34.067]
# Diff:  [5.65590421]
# Different
# Modelo: [39.162834]
# Real:   [36.011]
# Diff:  [3.15183417]
# Different
# Modelo: [38.84019]
# Real:   [39.145]
# Diff:  [-0.30480911]
# Same Numbers
# Modelo: [38.96921]
# Real:   [40.071]
# Diff:  [-1.10178842]
# Same Numbers
# Modelo: [39.194534]
# Real:   [40.702]
# Diff:  [-1.5074657]
# Different
# Modelo: [39.46399]
# Real:   [40.091]
# Diff:  [-0.62701074]
# Same Numbers
# Modelo: [39.667404]
# Real:   [40.665]
# Diff:  [-0.99759583]
# Same Numbers
# Modelo: [39.968113]
# Real:   [39.91]
# Diff:  [0.05811295]
# Same Numbers
# Modelo: [40.138332]
# Real:   [40.762]
# Diff:  [-0.62366763]
# Same Numbers
# Modelo: [40.35223]
# Real:   [39.753]
# Diff:  [0.59923007]
# Same Numbers
# Modelo: [40.39226]
# Real:   [40.126]
# Diff:  [0.26626151]
# Same Numbers
# Modelo: [40.535763]
# Real:   [40.312]
# Diff:  [0.22376279]
# Same Numbers
# Modelo: [40.68113]
# Real:   [40.623]
# Diff:  [0.05812946]
# Same Numbers
# Modelo: [40.79213]
# Real:   [39.761]
# Diff:  [1.03112952]
# Same Numbers
# Modelo: [40.769764]
# Real:   [39.379]
# Diff:  [1.39076395]
# Same Numbers
# Modelo: [40.709923]
# Real:   [37.673]
# Diff:  [3.03692279]
# Different
# Modelo: [40.429264]
# Real:   [35.7]
# Diff:  [4.72926407]
# Different
# Modelo: [39.929516]
# Real:   [35.352]
# Diff:  [4.57751584]
# Different
# Modelo: [39.43894]
# Real:   [34.873]
# Diff:  [4.56593814]
# Different
# Modelo: [39.02109]
# Real:   [33.229]
# Diff:  [5.79209146]
# Different
# Modelo: [38.410137]
# Real:   [33.278]
# Diff:  [5.13213718]
# Different
# Modelo: [37.84368]
# Real:   [33.535]
# Diff:  [4.30868134]
# Different
# Modelo: [37.362038]
# Real:   [37.601]
# Diff:  [-0.23896234]
# Same Numbers
# Modelo: [37.71813]
# Real:   [39.737]
# Diff:  [-2.0188718]
# Different
# Modelo: [38.25638]
# Real:   [40.297]
# Diff:  [-2.04062183]
# Different
# Modelo: [38.795067]
# Real:   [41.432]
# Diff:  [-2.63693317]
# Different
# Modelo: [39.729362]
# Real:   [40.973]
# Diff:  [-1.24363751]
# Same Numbers
# Modelo: [39.915478]
# Real:   [47.4]
# Diff:  [-7.48452225]
# Different
# Modelo: [41.015167]
# Real:   [52.602]
# Diff:  [-11.58683276]
# Different
# Modelo: [42.66721]
# Real:   [54.211]
# Diff:  [-11.54379037]
# Different
# Modelo: [44.31581]
# Real:   [52.169]
# Diff:  [-7.85318884]
# Different
# Modelo: [45.630936]
# Real:   [52.5]
# Diff:  [-6.86906433]
# Different
# Modelo: [46.697147]
# Real:   [53.106]
# Diff:  [-6.40885263]
# Different
# Modelo: [47.530033]
# Real:   [52.942]
# Diff:  [-5.41196689]
# Different
# Modelo: [48.16105]
# Real:   [52.189]
# Diff:  [-4.02795111]
# Different
# Modelo: [48.620914]
# Real:   [47.108]
# Diff:  [1.51291446]
# Different
# Modelo: [48.406025]
# Real:   [44.88]
# Diff:  [3.52602493]
# Different
# Modelo: [47.858177]
# Real:   [42.179]
# Diff:  [5.67917719]
# Different
# Modelo: [46.996746]
# Real:   [42.042]
# Diff:  [4.95474606]
# Different
# Modelo: [46.17058]
# Real:   [41.631]
# Diff:  [4.53958182]
# Different
# Modelo: [45.38125]
# Real:   [42.575]
# Diff:  [2.80624847]
# Different
# Modelo: [44.7945]
# Real:   [42.384]
# Diff:  [2.41049844]
# Different
# Modelo: [44.29634]
# Real:   [41.833]
# Diff:  [2.46334094]
# Different
# Modelo: [43.801754]
# Real:   [42.204]
# Diff:  [1.597754]
# Different
# Modelo: [43.438454]
# Real:   [41.641]
# Diff:  [1.79745367]
# Different
# Modelo: [43.099007]
# Real:   [42.113]
# Diff:  [0.98600665]
# Same Numbers
# Modelo: [42.877254]
# Real:   [41.852]
# Diff:  [1.02525449]
# Same Numbers
# Modelo: [42.682026]
# Real:   [41.819]
# Diff:  [0.86302591]
# Same Numbers
# Modelo: [42.505966]
# Real:   [42.403]
# Diff:  [0.10296619]
# Same Numbers
# Modelo: [42.457535]
# Real:   [41.655]
# Diff:  [0.80253479]
# Same Numbers
# Modelo: [42.39295]
# Real:   [41.488]
# Diff:  [0.90494815]
# Same Numbers
# Modelo: [42.326405]
# Real:   [41.174]
# Diff:  [1.15240457]
# Same Numbers
# Modelo: [42.228268]
# Real:   [40.929]
# Diff:  [1.29926767]
# Same Numbers
# Modelo: [42.10944]
# Real:   [40.454]
# Diff:  [1.65543985]
# Different
# Modelo: [41.94973]
# Real:   [39.813]
# Diff:  [2.13672992]
# Different
# Modelo: [41.729008]
# Real:   [40.868]
# Diff:  [0.86100772]
# Same Numbers
# Modelo: [41.65354]
# Real:   [40.851]
# Diff:  [0.80254156]
# Same Numbers
# Modelo: [41.603157]
# Real:   [40.387]
# Diff:  [1.21615704]
# Same Numbers
# Modelo: [41.51591]
# Real:   [40.585]
# Diff:  [0.9309111]
# Same Numbers
# Modelo: [41.43795]
# Real:   [39.837]
# Diff:  [1.60095013]
# Different
# Modelo: [41.297943]
# Real:   [40.037]
# Diff:  [1.26094312]
# Same Numbers
# Modelo: [41.194973]
# Real:   [40.16]
# Diff:  [1.03497299]
# Same Numbers
# Modelo: [41.125053]
# Real:   [40.14]
# Diff:  [0.98505341]
# Same Numbers
# Modelo: [41.07972]
# Real:   [40.026]
# Diff:  [1.05371954]
# Same Numbers
# Modelo: [41.03342]
# Real:   [39.959]
# Diff:  [1.07442056]
# Same Numbers
# Modelo: [40.988285]
# Real:   [40.4]
# Diff:  [0.58828506]
# Same Numbers
# Modelo: [40.998535]
# Real:   [39.95]
# Diff:  [1.04853516]
# Same Numbers
# Modelo: [40.94302]
# Real:   [40.321]
# Diff:  [0.62201987]
# Same Numbers
# Modelo: [40.93658]
# Real:   [40.229]
# Diff:  [0.70758066]
# Same Numbers
# Modelo: [40.932026]
# Real:   [39.809]
# Diff:  [1.12302591]
# Same Numbers
# Modelo: [40.888218]
# Real:   [39.889]
# Diff:  [0.99921793]
# Same Numbers
# Modelo: [40.848072]
# Real:   [39.792]
# Diff:  [1.05607205]
# Same Numbers
# Modelo: [40.80548]
# Real:   [39.88]
# Diff:  [0.92548096]
# Same Numbers
# Modelo: [40.77979]
# Real:   [39.591]
# Diff:  [1.18878897]
# Same Numbers
# Modelo: [40.730133]
# Real:   [39.293]
# Diff:  [1.43713306]
# Same Numbers
# Modelo: [40.630726]
# Real:   [39.694]
# Diff:  [0.93672586]
# Same Numbers
# Modelo: [40.586815]
# Real:   [39.68]
# Diff:  [0.90681488]
# Same Numbers
# Modelo: [40.557312]
# Real:   [39.743]
# Diff:  [0.81431201]
# Same Numbers
# Modelo: [40.54514]
# Real:   [39.626]
# Diff:  [0.91913931]
# Same Numbers
# Modelo: [40.59158]
# Real:   [42.53]
# Diff:  [-1.93842056]
# Different
# Modelo: [40.917953]
# Real:   [38.22]
# Diff:  [2.69795349]
# Different
# Modelo: [40.709652]
# Real:   [47.561]
# Diff:  [-6.85134805]
# Different
# Modelo: [42.04535]
# Real:   [48.207]
# Diff:  [-6.16165088]
# Different
# Modelo: [42.81081]
# Real:   [55.878]
# Diff:  [-13.06718991]
# Different
# Modelo: [44.315235]
# Real:   [51.09]
# Diff:  [-6.77476486]
# Different
# Modelo: [45.253574]
# Real:   [53.1]
# Diff:  [-7.84642563]
# Different
# Modelo: [46.339226]
# Real:   [53.651]
# Diff:  [-7.31177423]
# Different
# Modelo: [47.070335]
# Real:   [40.003]
# Diff:  [7.06733539]
# Different
# Modelo: [46.17668]
# Real:   [45.539]
# Diff:  [0.63768152]
# Same Numbers
# Modelo: [46.01202]
# Real:   [38.191]
# Diff:  [7.82102011]
# Different
# Modelo: [45.026783]
# Real:   [36.112]
# Diff:  [8.91478299]
# Different
# Modelo: [43.924446]
# Real:   [38.302]
# Diff:  [5.62244611]
# Different
# Modelo: [43.176987]
# Real:   [36.757]
# Diff:  [6.41998669]
# Different
# Modelo: [42.392365]
# Real:   [38.954]
# Diff:  [3.4383645]
# Different
# Modelo: [41.991577]
# Real:   [34.64]
# Diff:  [7.35157715]
# Different
# Modelo: [40.886475]
# Real:   [41.112]
# Diff:  [-0.22552539]
# Same Numbers
# Modelo: [40.752876]
# Real:   [35.764]
# Diff:  [4.98887628]
# Different
# Modelo: [40.082634]
# Real:   [35.547]
# Diff:  [4.53563397]
# Different
# Modelo: [39.50176]
# Real:   [38.682]
# Diff:  [0.81975858]
# Same Numbers
# Modelo: [39.681007]
# Real:   [37.256]
# Diff:  [2.42500739]
# Different
# Modelo: [39.616642]
# Real:   [39.039]
# Diff:  [0.577642]
# Same Numbers
# Modelo: [39.739483]
# Real:   [35.717]
# Diff:  [4.02248288]
# Different
# Modelo: [39.42303]
# Real:   [41.692]
# Diff:  [-2.26896915]
# Different
# Modelo: [39.84154]
# Real:   [41.816]
# Diff:  [-1.97445871]
# Different
# Modelo: [40.242897]
# Real:   [36.365]
# Diff:  [3.87789703]
# Different
# Modelo: [39.927097]
# Real:   [40.525]
# Diff:  [-0.59790268]
# Same Numbers
# Modelo: [40.126423]
# Real:   [37.861]
# Diff:  [2.26542288]
# Different
# Modelo: [39.977837]
# Real:   [38.686]
# Diff:  [1.29183661]
# Same Numbers
# Modelo: [39.89033]
# Real:   [39.812]
# Diff:  [0.07833127]
# Same Numbers
# Modelo: [39.93231]
# Real:   [37.766]
# Diff:  [2.1663082]
# Different
# Modelo: [39.7872]
# Real:   [41.157]
# Diff:  [-1.36979907]
# Same Numbers
# Modelo: [39.873104]
# Real:   [35.558]
# Diff:  [4.3151041]
# Different
# Modelo: [39.366924]
# Real:   [45.7]
# Diff:  [-6.33307571]
# Different
# Modelo: [40.144882]
# Real:   [38.309]
# Diff:  [1.8358822]
# Different
# Modelo: [40.029392]
# Real:   [34.23]
# Diff:  [5.79939224]
# Different
# Modelo: [39.162018]
# Real:   [36.715]
# Diff:  [2.44701782]
# Different
# Modelo: [38.715317]
# Real:   [38.479]
# Diff:  [0.23631677]
# Same Numbers
# Modelo: [38.566444]
# Real:   [37.77]
# Diff:  [0.7964444]
# Same Numbers
# Modelo: [38.40101]
# Real:   [38.281]
# Diff:  [0.12000861]
# Same Numbers
# Modelo: [38.805202]
# Real:   [37.822]
# Diff:  [0.98320248]
# Same Numbers
# Modelo: [38.988014]
# Real:   [41.026]
# Diff:  [-2.03798578]
# Different
# Modelo: [39.4825]
# Real:   [42.223]
# Diff:  [-2.74050183]
# Different
# Modelo: [40.39923]
# Real:   [42.744]
# Diff:  [-2.34476904]
# Different
# Modelo: [41.678516]
# Real:   [43.136]
# Diff:  [-1.45748361]
# Same Numbers
# Modelo: [42.74777]
# Real:   [40.908]
# Diff:  [1.8397684]
# Different
# Modelo: [43.279938]
# Real:   [42.95]
# Diff:  [0.32993774]
# Same Numbers
# Modelo: [43.7496]
# Real:   [43.276]
# Diff:  [0.47359946]
# Same Numbers
# Modelo: [44.333782]
# Real:   [40.61]
# Diff:  [3.7237822]
# Different
# Modelo: [44.364834]
# Real:   [39.596]
# Diff:  [4.76883383]
# Different
# Modelo: [44.082436]
# Real:   [40.484]
# Diff:  [3.59843561]
# Different
# Modelo: [43.80685]
# Real:   [43.988]
# Diff:  [-0.18114957]
# Same Numbers
# Modelo: [43.43027]
# Real:   [42.646]
# Diff:  [0.78427115]
# Same Numbers
# Modelo: [43.046516]
# Real:   [39.937]
# Diff:  [3.10951642]
# Different
# Modelo: [42.54271]
# Real:   [38.544]
# Diff:  [3.99870935]
# Different
# Modelo: [41.965126]
# Real:   [37.423]
# Diff:  [4.54212604]
# Different
# Modelo: [41.004154]
# Real:   [40.774]
# Diff:  [0.23015421]
# Same Numbers
# Modelo: [40.53457]
# Real:   [41.217]
# Diff:  [-0.68243121]
# Same Numbers
# Modelo: [40.313065]
# Real:   [40.362]
# Diff:  [-0.04893542]
# Same Numbers
# Modelo: [40.116516]
# Real:   [41.594]
# Diff:  [-1.47748389]
# Same Numbers
# Modelo: [40.08357]
# Real:   [40.919]
# Diff:  [-0.83543143]
# Same Numbers
# Modelo: [40.095013]
# Real:   [41.322]
# Diff:  [-1.22698734]
# Same Numbers
# Modelo: [40.211918]
# Real:   [41.27]
# Diff:  [-1.05808212]
# Same Numbers
# Modelo: [40.344025]
# Real:   [39.634]
# Diff:  [0.71002466]
# Same Numbers
# Modelo: [40.34096]
# Real:   [40.214]
# Diff:  [0.12696146]
# Same Numbers
# Modelo: [40.449883]
# Real:   [39.82]
# Diff:  [0.62988251]
# Same Numbers
# Modelo: [40.515144]
# Real:   [38.017]
# Diff:  [2.49814435]
# Different
# Modelo: [40.363873]
# Real:   [39.677]
# Diff:  [0.68687253]
# Same Numbers
# Modelo: [40.318977]
# Real:   [39.509]
# Diff:  [0.80997736]
# Same Numbers
# Modelo: [40.277046]
# Real:   [40.647]
# Diff:  [-0.3699538]
# Same Numbers
# Modelo: [40.367905]
# Real:   [40.183]
# Diff:  [0.18490466]
# Same Numbers
# Modelo: [40.421864]
# Real:   [40.692]
# Diff:  [-0.27013644]
# Same Numbers
# Modelo: [40.49139]
# Real:   [39.539]
# Diff:  [0.95239023]
# Same Numbers
# Modelo: [40.447224]
# Real:   [40.304]
# Diff:  [0.14322366]
# Same Numbers
# Modelo: [40.487644]
# Real:   [40.37]
# Diff:  [0.1176442]
# Same Numbers
# Modelo: [40.545532]
# Real:   [39.671]
# Diff:  [0.87453223]
# Same Numbers
# Modelo: [40.507942]
# Real:   [39.83]
# Diff:  [0.6779422]
# Same Numbers
# Modelo: [40.49182]
# Real:   [39.74]
# Diff:  [0.75182129]
# Same Numbers
# Modelo: [40.47586]
# Real:   [39.787]
# Diff:  [0.6888606]
# Same Numbers
# Modelo: [40.472218]
# Real:   [39.525]
# Diff:  [0.94721756]
# Same Numbers
# Modelo: [40.445007]
# Real:   [39.814]
# Diff:  [0.63100732]
# Same Numbers
# Modelo: [40.453438]
# Real:   [40.069]
# Diff:  [0.38443781]
# Same Numbers
# Modelo: [40.4955]
# Real:   [39.648]
# Diff:  [0.84749866]
# Same Numbers
# Modelo: [40.495434]
# Real:   [39.133]
# Diff:  [1.36243381]
# Same Numbers
# Modelo: [40.43431]
# Real:   [39.629]
# Diff:  [0.80531091]
# Same Numbers
# Modelo: [40.427387]
# Real:   [39.266]
# Diff:  [1.16138724]
# Same Numbers
# Modelo: [40.388443]
# Real:   [39.771]
# Diff:  [0.61744299]
# Same Numbers
# Modelo: [40.406963]
# Real:   [39.433]
# Diff:  [0.97396335]
# Same Numbers
# Modelo: [40.37418]
# Real:   [40.003]
# Diff:  [0.37117984]
# Same Numbers
# Modelo: [40.408962]
# Real:   [39.472]
# Diff:  [0.93696225]
# Same Numbers
# Modelo: [40.39514]
# Real:   [39.531]
# Diff:  [0.8641416]
# Same Numbers
# Modelo: [40.388165]
# Real:   [39.282]
# Diff:  [1.10616452]
# Same Numbers
# Modelo: [40.34353]
# Real:   [39.471]
# Diff:  [0.87252875]
# Same Numbers
# Modelo: [40.32437]
# Real:   [39.123]
# Diff:  [1.20137134]
# Same Numbers
# Modelo: [40.273685]
# Real:   [39.961]
# Diff:  [0.31268546]
# Same Numbers
# Modelo: [40.290676]
# Real:   [40.57]
# Diff:  [-0.27932388]
# Same Numbers
# Modelo: [40.545185]
# Real:   [39.199]
# Diff:  [1.34618509]
# Same Numbers
# Modelo: [40.595757]
# Real:   [42.499]
# Diff:  [-1.90324347]
# Different
# Modelo: [40.887745]
# Real:   [39.643]
# Diff:  [1.2447449]
# Same Numbers
# Modelo: [41.442745]
# Real:   [46.86]
# Diff:  [-5.41725479]
# Different
# Modelo: [42.741676]
# Real:   [48.837]
# Diff:  [-6.09532367]
# Different
# Modelo: [43.99121]
# Real:   [54.652]
# Diff:  [-10.66078906]
# Different
# Modelo: [45.735325]
# Real:   [52.908]
# Diff:  [-7.17267514]
# Different
# Modelo: [47.109943]
# Real:   [45.927]
# Diff:  [1.18294339]
# Same Numbers
# Modelo: [46.800095]
# Real:   [44.386]
# Diff:  [2.4140946]
# Different
# Modelo: [46.426746]
# Real:   [44.317]
# Diff:  [2.10974637]
# Different
# Modelo: [46.148438]
# Real:   [38.08]
# Diff:  [8.0684375]
# Different
# Modelo: [45.133186]
# Real:   [39.55]
# Diff:  [5.58318634]
# Different
# Modelo: [43.87249]
# Real:   [36.584]
# Diff:  [7.28848993]
# Different
# Modelo: [42.619495]
# Real:   [40.498]
# Diff:  [2.12149539]
# Different
# Modelo: [42.074146]
# Real:   [36.703]
# Diff:  [5.37114627]
# Different
# Modelo: [41.22915]
# Real:   [34.665]
# Diff:  [6.56414886]
# Different
# Modelo: [40.23808]
# Real:   [39.532]
# Diff:  [0.70607907]
# Same Numbers
# Modelo: [40.054565]
# Real:   [36.291]
# Diff:  [3.76356543]
# Different
# Modelo: [39.573574]
# Real:   [39.915]
# Diff:  [-0.34142593]
# Same Numbers
# Modelo: [39.598934]
# Real:   [35.358]
# Diff:  [4.24093417]
# Different
# Modelo: [39.18785]
# Real:   [39.943]
# Diff:  [-0.75514905]
# Same Numbers
# Modelo: [39.336227]
# Real:   [39.816]
# Diff:  [-0.47977258]
# Same Numbers
# Modelo: [39.469105]
# Real:   [41.907]
# Diff:  [-2.43789523]
# Different
# Modelo: [39.85324]
# Real:   [37.536]
# Diff:  [2.31724097]
# Different
# Modelo: [39.86029]
# Real:   [43.065]
# Diff:  [-3.20470947]
# Different
# Modelo: [40.46505]
# Real:   [42.058]
# Diff:  [-1.59295026]
# Different
# Modelo: [40.85304]
# Real:   [40.269]
# Diff:  [0.58403879]
# Same Numbers
# Modelo: [40.9129]
# Real:   [46.605]
# Diff:  [-5.69210098]
# Different
# Modelo: [41.62857]
# Real:   [41.157]
# Diff:  [0.47157056]
# Same Numbers
# Modelo: [41.676464]
# Real:   [37.905]
# Diff:  [3.77146408]
# Different
# Modelo: [41.31082]
# Real:   [39.427]
# Diff:  [1.88382153]
# Different
# Modelo: [41.007347]
# Real:   [35.534]
# Diff:  [5.47334711]
# Different
# Modelo: [40.45086]
# Real:   [39.641]
# Diff:  [0.80985907]
# Same Numbers
# Modelo: [40.519585]
# Real:   [36.619]
# Diff:  [3.90058466]
# Different
# Modelo: [40.23256]
# Real:   [39.764]
# Diff:  [0.4685592]
# Same Numbers
# Modelo: [40.372482]
# Real:   [38.751]
# Diff:  [1.6214823]
# Different
# Modelo: [40.083572]
# Real:   [39.868]
# Diff:  [0.21557239]
# Same Numbers
# Modelo: [39.99336]
# Real:   [40.224]
# Diff:  [-0.23064139]
# Same Numbers
# Modelo: [39.977856]
# Real:   [39.194]
# Diff:  [0.78385568]
# Same Numbers
# Modelo: [39.866184]
# Real:   [40.113]
# Diff:  [-0.24681577]
# Same Numbers
# Modelo: [40.125336]
# Real:   [41.133]
# Diff:  [-1.00766431]
# Same Numbers
# Modelo: [40.424465]
# Real:   [43.527]
# Diff:  [-3.10253482]
# Different
# Modelo: [40.96347]
# Real:   [44.217]
# Diff:  [-3.25352954]
# Different
# Modelo: [41.897797]
# Real:   [42.011]
# Diff:  [-0.11320337]
# Same Numbers
# Modelo: [42.353394]
# Real:   [43.188]
# Diff:  [-0.83460645]
# Same Numbers
# Modelo: [42.85846]
# Real:   [45.187]
# Diff:  [-2.32854053]
# Different
# Modelo: [43.455166]
# Real:   [45.923]
# Diff:  [-2.46783414]
# Different
# Modelo: [43.981358]
# Real:   [43.849]
# Diff:  [0.13235757]
# Same Numbers
# Modelo: [44.018074]
# Real:   [44.06]
# Diff:  [-0.04192596]
# Same Numbers
# Modelo: [43.989033]
# Real:   [49.266]
# Diff:  [-5.27696725]
# Different
# Modelo: [44.53352]
# Real:   [54.688]
# Diff:  [-10.15448026]
# Different
# Modelo: [45.66225]
# Real:   [48.434]
# Diff:  [-2.77174948]
# Different
# Modelo: [46.052338]
# Real:   [43.778]
# Diff:  [2.27433765]
# Different
# Modelo: [45.808254]
# Real:   [41.98]
# Diff:  [3.82825424]
# Different
# Modelo: [45.292175]
# Real:   [41.886]
# Diff:  [3.40617529]
# Different
# Modelo: [44.75169]
# Real:   [41.835]
# Diff:  [2.91668991]
# Different
# Modelo: [44.134495]
# Real:   [41.975]
# Diff:  [2.15949478]
# Different
# Modelo: [43.585293]
# Real:   [41.615]
# Diff:  [1.97029282]
# Different
# Modelo: [43.101925]
# Real:   [41.335]
# Diff:  [1.7669249]
# Different
# Modelo: [42.69441]
# Real:   [42.424]
# Diff:  [0.27040842]
# Same Numbers
# Modelo: [42.57071]
# Real:   [42.373]
# Diff:  [0.19770923]
# Same Numbers
# Modelo: [42.45996]
# Real:   [42.25]
# Diff:  [0.20996094]
# Same Numbers
# Modelo: [42.37306]
# Real:   [41.755]
# Diff:  [0.61805832]
# Same Numbers
# Modelo: [42.267643]
# Real:   [41.978]
# Diff:  [0.28964297]
# Same Numbers
# Modelo: [42.074345]
# Real:   [40.936]
# Diff:  [1.13834464]
# Same Numbers
# Modelo: [41.82609]
# Real:   [41.409]
# Diff:  [0.41709177]
# Same Numbers
# Modelo: [41.677425]
# Real:   [41.551]
# Diff:  [0.12642538]
# Same Numbers
# Modelo: [41.58999]
# Real:   [40.523]
# Diff:  [1.06698871]
# Same Numbers
# Modelo: [41.467354]
# Real:   [41.363]
# Diff:  [0.10435382]
# Same Numbers
# Modelo: [41.45193]
# Real:   [41.161]
# Diff:  [0.290931]
# Same Numbers
# Modelo: [41.482418]
# Real:   [41.259]
# Diff:  [0.22341806]
# Same Numbers
# Modelo: [41.51337]
# Real:   [40.775]
# Diff:  [0.73837051]
# Same Numbers
# Modelo: [41.49405]
# Real:   [40.864]
# Diff:  [0.63004907]
# Same Numbers
# Modelo: [41.51127]
# Real:   [41.077]
# Diff:  [0.43426862]
# Same Numbers
# Modelo: [41.548286]
# Real:   [41.129]
# Diff:  [0.41928644]
# Same Numbers
# Modelo: [41.57319]
# Real:   [40.38]
# Diff:  [1.19318878]
# Same Numbers
# Modelo: [41.470013]
# Real:   [40.152]
# Diff:  [1.31801266]
# Same Numbers
# Modelo: [41.342243]
# Real:   [40.743]
# Diff:  [0.59924319]
# Same Numbers
# Modelo: [41.290134]
# Real:   [39.777]
# Diff:  [1.51313443]
# Different
# Modelo: [41.152084]
# Real:   [40.039]
# Diff:  [1.11308435]
# Same Numbers
# Modelo: [41.053574]
# Real:   [40.152]
# Diff:  [0.90157361]
# Same Numbers
# Modelo: [40.985497]
# Real:   [40.002]
# Diff:  [0.98349652]
# Same Numbers
# Modelo: [40.917877]
# Real:   [40.169]
# Diff:  [0.7488772]
# Same Numbers
# Modelo: [40.881603]
# Real:   [39.912]
# Diff:  [0.96960324]
# Same Numbers
# Modelo: [40.80765]
# Real:   [40.143]
# Diff:  [0.66465152]
# Same Numbers
# Modelo: [40.77344]
# Real:   [40.119]
# Diff:  [0.65444131]
# Same Numbers
# Modelo: [40.752396]
# Real:   [40.016]
# Diff:  [0.73639563]
# Same Numbers
# Modelo: [40.73078]
# Real:   [40.218]
# Diff:  [0.51278156]
# Same Numbers
# Modelo: [40.749645]
# Real:   [39.846]
# Diff:  [0.90364523]
# Same Numbers
# Modelo: [40.731476]
# Real:   [39.662]
# Diff:  [1.06947583]
# Same Numbers
# Modelo: [40.692352]
# Real:   [39.792]
# Diff:  [0.90035229]
# Same Numbers
# Modelo: [40.6686]
# Real:   [39.691]
# Diff:  [0.97759818]
# Same Numbers
# Modelo: [40.627323]
# Real:   [39.812]
# Diff:  [0.81532315]
# Same Numbers
# Modelo: [40.605576]
# Real:   [39.952]
# Diff:  [0.65357556]
# Same Numbers
# Modelo: [40.606342]
# Real:   [39.955]
# Diff:  [0.65134232]
# Same Numbers
# Modelo: [40.612846]
# Real:   [40.093]
# Diff:  [0.51984637]
# Same Numbers
# Modelo: [40.71006]
# Real:   [42.6]
# Diff:  [-1.88993988]
# Different
# Modelo: [41.01458]
# Real:   [41.991]
# Diff:  [-0.97642023]
# Same Numbers
# Modelo: [41.224552]
# Real:   [41.442]
# Diff:  [-0.21744785]
# Same Numbers
# Modelo: [41.892212]
# Real:   [43.658]
# Diff:  [-1.76578809]
# Different
# Modelo: [42.769127]
# Real:   [40.165]
# Diff:  [2.60412689]
# Different
# Modelo: [42.94167]
# Real:   [42.812]
# Diff:  [0.12966946]
# Same Numbers
# Modelo: [43.20024]
# Real:   [43.845]
# Diff:  [-0.64475891]
# Same Numbers
# Modelo: [43.513805]
# Real:   [49.775]
# Diff:  [-6.26119461]
# Different
# Modelo: [43.87882]
# Real:   [45.852]
# Diff:  [-1.97318149]
# Different
# Modelo: [44.048134]
# Real:   [44.033]
# Diff:  [0.01513385]
# Same Numbers
# Modelo: [44.106285]
# Real:   [36.189]
# Diff:  [7.9172851]
# Different
# Modelo: [43.19575]
# Real:   [38.133]
# Diff:  [5.06275119]
# Different
# Modelo: [42.207066]
# Real:   [38.968]
# Diff:  [3.23906558]
# Different
# Modelo: [41.614662]
# Real:   [37.213]
# Diff:  [4.40166217]
# Different
# Modelo: [40.989857]
# Real:   [38.828]
# Diff:  [2.16185672]
# Different
# Modelo: [40.69184]
# Real:   [43.063]
# Diff:  [-2.37115887]
# Different
# Modelo: [40.946724]
# Real:   [38.043]
# Diff:  [2.90372394]
# Different
# Modelo: [40.624786]
# Real:   [43.024]
# Diff:  [-2.39921362]
# Different
# Modelo: [40.932686]
# Real:   [38.614]
# Diff:  [2.31868585]
# Different
# Modelo: [40.712173]
# Real:   [43.031]
# Diff:  [-2.31882654]
# Different
# Modelo: [41.19302]
# Real:   [39.061]
# Diff:  [2.13201987]
# Different
# Modelo: [41.124115]
# Real:   [38.927]
# Diff:  [2.19711499]
# Different
# Modelo: [41.01264]
# Real:   [35.241]
# Diff:  [5.77164191]
# Different
# Modelo: [40.419395]
# Real:   [39.502]
# Diff:  [0.91739545]
# Same Numbers
# Modelo: [40.491177]
# Real:   [41.981]
# Diff:  [-1.48982339]
# Same Numbers
# Modelo: [40.858734]
# Real:   [39.763]
# Diff:  [1.09573413]
# Same Numbers
# Modelo: [40.91268]
# Real:   [44.164]
# Diff:  [-3.25131842]
# Different
# Modelo: [41.471355]
# Real:   [37.483]
# Diff:  [3.98835544]
# Different
# Modelo: [41.204315]
# Real:   [37.322]
# Diff:  [3.88231519]
# Different
# Modelo: [40.860775]
# Real:   [38.363]
# Diff:  [2.49777499]
# Different
# Modelo: [40.644592]
# Real:   [40.053]
# Diff:  [0.59159229]
# Same Numbers
# Modelo: [40.64553]
# Real:   [38.957]
# Diff:  [1.6885307]
# Different
# Modelo: [40.242702]
# Real:   [41.986]
# Diff:  [-1.74329752]
# Different
# Modelo: [40.35015]
# Real:   [40.29]
# Diff:  [0.06015106]
# Same Numbers
# Modelo: [40.331127]
# Real:   [42.745]
# Diff:  [-2.41387283]
# Different
# Modelo: [40.61754]
# Real:   [39.907]
# Diff:  [0.71053845]
# Same Numbers
# Modelo: [40.705524]
# Real:   [36.032]
# Diff:  [4.67352444]
# Different
# Modelo: [40.277054]
# Real:   [36.196]
# Diff:  [4.08105383]
# Different
# Modelo: [39.86892]
# Real:   [36.291]
# Diff:  [3.57791937]
# Different
# Modelo: [39.490414]
# Real:   [38.2]
# Diff:  [1.29041367]
# Same Numbers
# Modelo: [39.59448]
# Real:   [40.18]
# Diff:  [-0.58552139]
# Same Numbers
# Modelo: [39.873634]
# Real:   [40.973]
# Diff:  [-1.09936566]
# Same Numbers
# Modelo: [40.223835]
# Real:   [40.636]
# Diff:  [-0.41216501]
# Same Numbers
# Modelo: [40.90721]
# Real:   [41.071]
# Diff:  [-0.1637887]
# Same Numbers
# Modelo: [41.36319]
# Real:   [40.904]
# Diff:  [0.4591897]
# Same Numbers
# Modelo: [41.764503]
# Real:   [41.373]
# Diff:  [0.39150348]
# Same Numbers
# Modelo: [42.10363]
# Real:   [40.692]
# Diff:  [1.41163007]
# Same Numbers
# Modelo: [42.228672]
# Real:   [40.761]
# Diff:  [1.46767203]
# Same Numbers
# Modelo: [42.529766]
# Real:   [40.909]
# Diff:  [1.62076608]
# Different
# Modelo: [42.677635]
# Real:   [41.223]
# Diff:  [1.45463519]
# Same Numbers
# Modelo: [42.7151]
# Real:   [41.952]
# Diff:  [0.76309933]
# Same Numbers
# Modelo: [42.75013]
# Real:   [41.086]
# Diff:  [1.6641297]
# Different
# Modelo: [42.364132]
# Real:   [42.072]
# Diff:  [0.29213193]
# Same Numbers
# Modelo: [42.15285]
# Real:   [41.972]
# Diff:  [0.1808511]
# Same Numbers
# Modelo: [42.01169]
# Real:   [42.735]
# Diff:  [-0.72331177]
# Same Numbers
# Modelo: [42.01428]
# Real:   [42.152]
# Diff:  [-0.13772159]
# Same Numbers
# Modelo: [41.828827]
# Real:   [41.463]
# Diff:  [0.3658269]
# Same Numbers
# Modelo: [41.644207]
# Real:   [41.805]
# Diff:  [-0.160793]
# Same Numbers
# Modelo: [41.572384]
# Real:   [42.491]
# Diff:  [-0.91861612]
# Same Numbers
# Modelo: [41.640575]
# Real:   [42.399]
# ...
# Different
# Modelo: [38.53522]
# Real:   [36.505]
# Diff:  [2.0302211]
# Different
# Modelo: [38.321747]
# Real:   [36.256]
# Diff:  [2.06574683]
# Different
# Modelo: [38.10568]
# Real:   [36.393]
# Diff:  [1.71267856]
# Different
# Modelo: [37.937332]
# Real:   [36.242]
# Diff:  [1.69533215]
# Different
# Modelo: [37.778152]
# Real:   [36.194]
# Diff:  [1.58415247]
# Different
# Modelo: [37.640167]
# Real:   [37.512]
# Diff:  [0.12816724]
# Same Numbers
# Modelo: [37.68895]
# Real:   [43.147]
# Diff:  [-5.45805042]
# Different
# Modelo: [38.443577]
# Real:   [42.856]
# Diff:  [-4.41242319]
# Different
# Modelo: [39.241707]
# Real:   [43.051]
# Diff:  [-3.80929315]
# Different
# Modelo: [39.957977]
# Real:   [42.8]
# Diff:  [-2.84202271]
# Different
# Modelo: [40.541107]
# Real:   [45.305]
# Diff:  [-4.76389282]
# Different
# Modelo: [41.338955]
# Real:   [45.868]
# Diff:  [-4.52904507]
# Different
# Modelo: [42.745483]
# Real:   [42.337]
# Diff:  [0.4084834]
# Same Numbers
# Modelo: [43.098904]
# Real:   [45.553]
# Diff:  [-2.45409634]
# Different
# Modelo: [43.7801]
# Real:   [44.538]
# Diff:  [-0.75789822]
# Same Numbers
# Modelo: [44.18507]
# Real:   [38.613]
# Diff:  [5.57207004]
# Different
# Modelo: [43.710705]
# Real:   [38.683]
# Diff:  [5.0277048]
# Different
# Modelo: [43.149025]
# Real:   [38.916]
# Diff:  [4.23302496]
# Different
# Modelo: [42.580273]
# Real:   [39.045]
# Diff:  [3.53527267]
# Different
# Modelo: [42.040676]
# Real:   [38.758]
# Diff:  [3.28267612]
# Different
# Modelo: [41.51261]
# Real:   [38.754]
# Diff:  [2.75861139]
# Different
# Modelo: [41.043167]
# Real:   [38.764]
# Diff:  [2.27916711]
# Different
# Modelo: [40.642487]
# Real:   [38.676]
# Diff:  [1.96648657]
# Different
# Modelo: [40.300976]
# Real:   [38.5]
# Diff:  [1.8009758]
# Different
# Modelo: [39.986313]
# Real:   [38.972]
# Diff:  [1.01431287]
# Same Numbers
# Modelo: [39.78737]
# Real:   [38.805]
# Diff:  [0.98236877]
# Same Numbers
# Modelo: [39.6298]
# Real:   [38.732]
# Diff:  [0.89779889]
# Same Numbers
# Modelo: [39.51019]
# Real:   [38.314]
# Diff:  [1.19618906]
# Same Numbers
# Modelo: [39.398026]
# Real:   [38.363]
# Diff:  [1.03502551]
# Same Numbers
# Modelo: [39.316082]
# Real:   [38.346]
# Diff:  [0.970082]
# Same Numbers
# Modelo: [39.25476]
# Real:   [38.27]
# Diff:  [0.98476074]
# Same Numbers
# Modelo: [39.204197]
# Real:   [38.617]
# Diff:  [0.58719693]
# Same Numbers
# Modelo: [39.225536]
# Real:   [38.82]
# Diff:  [0.40553635]
# Same Numbers
# Modelo: [39.27697]
# Real:   [38.742]
# Diff:  [0.53496991]
# Same Numbers
# Modelo: [39.322235]
# Real:   [38.465]
# Diff:  [0.85723511]
# Same Numbers
# Modelo: [39.3358]
# Real:   [38.613]
# Diff:  [0.72280017]
# Same Numbers
# Modelo: [39.348137]
# Real:   [38.806]
# Diff:  [0.5421369]
# Same Numbers
# Modelo: [39.383724]
# Real:   [38.717]
# Diff:  [0.66672421]
# Same Numbers
# Modelo: [39.411957]
# Real:   [38.634]
# Diff:  [0.77795679]
# Same Numbers
# Modelo: [39.430103]
# Real:   [38.398]
# Diff:  [1.0321033]
# Same Numbers
# Modelo: [39.42187]
# Real:   [38.368]
# Diff:  [1.05387119]
# Same Numbers
# Modelo: [39.40818]
# Real:   [38.469]
# Diff:  [0.93918024]
# Same Numbers
# Modelo: [39.405495]
# Real:   [38.376]
# Diff:  [1.02949469]
# Same Numbers
# Modelo: [39.394363]
# Real:   [38.292]
# Diff:  [1.1023634]
# Same Numbers
# Modelo: [39.36979]
# Real:   [38.327]
# Diff:  [1.04278912]
# Same Numbers
# Modelo: [39.35177]
# Real:   [38.335]
# Diff:  [1.01676849]
# Same Numbers
# Modelo: [39.33846]
# Real:   [38.224]
# Diff:  [1.11445901]
# Same Numbers
# Modelo: [39.31648]
# Real:   [38.323]
# Diff:  [0.99347873]
# Same Numbers
# Modelo: [39.306114]
# Real:   [38.432]
# Diff:  [0.8741142]
# Same Numbers
# Modelo: [39.310993]
# Real:   [38.33]
# Diff:  [0.98099319]
# Same Numbers
# Modelo: [39.307575]
# Real:   [38.353]
# Diff:  [0.95457523]
# Same Numbers
# Modelo: [39.307285]
# Real:   [38.336]
# Diff:  [0.97128531]
# Same Numbers
# Modelo: [39.32066]
# Real:   [38.339]
# Diff:  [0.98165964]
# Same Numbers
# Modelo: [39.330845]
# Real:   [38.444]
# Diff:  [0.88684488]
# Same Numbers
# Modelo: [39.348503]
# Real:   [38.26]
# Diff:  [1.08850311]
# Same Numbers
# Modelo: [39.343876]
# Real:   [38.39]
# Diff:  [0.95387589]
# Same Numbers
# Modelo: [39.335537]
# Real:   [38.339]
# Diff:  [0.99653696]
# Same Numbers
# Modelo: [39.324932]
# Real:   [38.236]
# Diff:  [1.0889321]
# Same Numbers
# Modelo: [39.306263]
# Real:   [38.185]
# Diff:  [1.12126297]
# Same Numbers
# Modelo: [39.284367]
# Real:   [38.347]
# Diff:  [0.93736661]
# Same Numbers
# Modelo: [39.290466]
# Real:   [38.366]
# Diff:  [0.92446631]
# Same Numbers
# Modelo: [39.29965]
# Real:   [38.197]
# Diff:  [1.10264828]
# Same Numbers
# Modelo: [39.28989]
# Real:   [38.17]
# Diff:  [1.11989029]
# Same Numbers
# Modelo: [39.27583]
# Real:   [38.271]
# Diff:  [1.00482932]
# Same Numbers
# Modelo: [39.289112]
# Real:   [38.206]
# Diff:  [1.08311209]
# Same Numbers
# Modelo: [39.292316]
# Real:   [38.158]
# Diff:  [1.13431644]
# Same Numbers
# Modelo: [39.286266]
# Real:   [38.352]
# Diff:  [0.93426633]
# Same Numbers
# Modelo: [39.298634]
# Real:   [38.506]
# Diff:  [0.79263358]
# Same Numbers
# Modelo: [39.752193]
# Real:   [38.54]
# Diff:  [1.21219345]
# Same Numbers
# Modelo: [39.42414]
# Real:   [38.345]
# Diff:  [1.07914093]
# Same Numbers
# Modelo: [39.037094]
# Real:   [38.658]
# Diff:  [0.37909412]
# Same Numbers
# Modelo: [38.782063]
# Real:   [38.451]
# Diff:  [0.33106253]
# Same Numbers
# Modelo: [38.47272]
# Real:   [39.089]
# Diff:  [-0.6162789]
# Same Numbers
# Modelo: [38.390213]
# Real:   [38.814]
# Diff:  [-0.42378699]
# Same Numbers
# Modelo: [38.40866]
# Real:   [36.408]
# Diff:  [2.00066089]
# Different
# Modelo: [38.193684]
# Real:   [36.341]
# Diff:  [1.85268362]
# Different
# Modelo: [38.082783]
# Real:   [34.11]
# Diff:  [3.97278275]
# Different
# Modelo: [37.737194]
# Real:   [36.079]
# Diff:  [1.65819406]
# Different
# Modelo: [37.63945]
# Real:   [36.315]
# Diff:  [1.32445007]
# Same Numbers
# Modelo: [37.615715]
# Real:   [36.336]
# Diff:  [1.27971503]
# Same Numbers
# Modelo: [37.600628]
# Real:   [35.951]
# Diff:  [1.6496279]
# Different
# Modelo: [37.548214]
# Real:   [36.161]
# Diff:  [1.38721396]
# Same Numbers
# Modelo: [37.546803]
# Real:   [36.022]
# Diff:  [1.52480252]
# Different
# Modelo: [37.50407]
# Real:   [36.241]
# Diff:  [1.26307028]
# Same Numbers
# Modelo: [37.49855]
# Real:   [35.864]
# Diff:  [1.63455042]
# Different
# Modelo: [37.447933]
# Real:   [35.981]
# Diff:  [1.4669332]
# Same Numbers
# Modelo: [37.414658]
# Real:   [36.223]
# Diff:  [1.19165759]
# Same Numbers
# Modelo: [37.412006]
# Real:   [36.071]
# Diff:  [1.34100638]
# Same Numbers
# Modelo: [37.717815]
# Real:   [36.155]
# Diff:  [1.5628154]
# Different
# Modelo: [37.892746]
# Real:   [36.084]
# Diff:  [1.80874597]
# Different
# Modelo: [37.977173]
# Real:   [36.603]
# Diff:  [1.37417285]
# Same Numbers
# Modelo: [38.079956]
# Real:   [36.149]
# Diff:  [1.93095605]
# Different
# Modelo: [37.810913]
# Real:   [36.137]
# Diff:  [1.67391309]
# Different
# Modelo: [37.641266]
# Real:   [36.255]
# Diff:  [1.38626587]
# Same Numbers
# Modelo: [37.53222]
# Real:   [36.103]
# Diff:  [1.42921893]
# Same Numbers
# Modelo: [37.438534]
# Real:   [36.263]
# Diff:  [1.17553378]
# Same Numbers
# Modelo: [37.342117]
# Real:   [36.281]
# Diff:  [1.06111731]
# Same Numbers
# Modelo: [37.287525]
# Real:   [36.026]
# Diff:  [1.26152518]
# Same Numbers
# Modelo: [37.225227]
# Real:   [36.715]
# Diff:  [0.51022736]
# Same Numbers
# Modelo: [37.265656]
# Real:   [36.337]
# Diff:  [0.92865552]
# Same Numbers
# Modelo: [37.412884]
# Real:   [35.232]
# Diff:  [2.18088376]
# Different
# Modelo: [37.361343]
# Real:   [36.081]
# Diff:  [1.28034338]
# Same Numbers
# Modelo: [37.385624]
# Real:   [34.963]
# Diff:  [2.42262393]
# Different
# Modelo: [37.26277]
# Real:   [35.827]
# Diff:  [1.43577161]
# Same Numbers
# Modelo: [37.634075]
# Real:   [37.951]
# Diff:  [-0.31692484]
# Same Numbers
# Modelo: [38.098743]
# Real:   [38.625]
# Diff:  [-0.52625656]
# Same Numbers
# Modelo: [38.53152]
# Real:   [39.14]
# Diff:  [-0.60847916]
# Same Numbers
# Modelo: [38.93527]
# Real:   [38.919]
# Diff:  [0.0162684]
# Same Numbers
# Modelo: [39.80545]
# Real:   [39.105]
# Diff:  [0.70045044]
# Same Numbers
# Modelo: [40.153553]
# Real:   [38.768]
# Diff:  [1.38555301]
# Same Numbers
# Modelo: [40.4577]
# Real:   [39.084]
# Diff:  [1.37369882]
# Same Numbers
# Modelo: [40.70293]
# Real:   [39.085]
# Diff:  [1.61793045]
# Different
# Modelo: [40.410812]
# Real:   [38.884]
# Diff:  [1.52681238]
# Different
# Modelo: [40.127907]
# Real:   [39.493]
# Diff:  [0.6349068]
# Same Numbers
# Modelo: [39.949837]
# Real:   [39.036]
# Diff:  [0.91383673]
# Same Numbers
# Modelo: [39.753094]
# Real:   [39.16]
# Diff:  [0.59309372]
# Same Numbers
# Modelo: [39.59342]
# Real:   [38.788]
# Diff:  [0.80541812]
# Same Numbers
# Modelo: [39.425888]
# Real:   [38.916]
# Diff:  [0.50988806]
# Same Numbers
# Modelo: [39.304646]
# Real:   [39.108]
# Diff:  [0.19664554]
# Same Numbers
# Modelo: [39.23795]
# Real:   [39.068]
# Diff:  [0.16994937]
# Same Numbers
# Modelo: [39.19888]
# Real:   [38.953]
# Diff:  [0.24587924]
# Same Numbers
# Modelo: [39.17245]
# Real:   [38.758]
# Diff:  [0.41445102]
# Same Numbers
# Modelo: [39.14539]
# Real:   [38.771]
# Diff:  [0.37438956]
# Same Numbers
# Modelo: [39.136597]
# Real:   [38.909]
# Diff:  [0.22759668]
# Same Numbers
# Modelo: [39.126915]
# Real:   [38.863]
# Diff:  [0.26391498]
# Same Numbers
# Modelo: [39.13307]
# Real:   [38.957]
# Diff:  [0.1760719]
# Same Numbers
# Modelo: [39.165802]
# Real:   [38.71]
# Diff:  [0.455802]
# Same Numbers
# Modelo: [39.183277]
# Real:   [38.817]
# Diff:  [0.36627713]
# Same Numbers
# Modelo: [39.24201]
# Real:   [39.007]
# Diff:  [0.23500821]
# Same Numbers
# Modelo: [39.319126]
# Real:   [38.955]
# Diff:  [0.36412613]
# Same Numbers
# Modelo: [39.385834]
# Real:   [39.053]
# Diff:  [0.33283374]
# Same Numbers
# Modelo: [39.456375]
# Real:   [38.585]
# Diff:  [0.87137512]
# Same Numbers
# Modelo: [39.472477]
# Real:   [38.436]
# Diff:  [1.03647696]
# Same Numbers
# Modelo: [39.464046]
# Real:   [38.761]
# Diff:  [0.70304648]
# Same Numbers
# Modelo: [39.486507]
# Real:   [38.47]
# Diff:  [1.01650742]
# Same Numbers
# Modelo: [39.47781]
# Real:   [38.423]
# Diff:  [1.05480991]
# Same Numbers
# Modelo: [39.441345]
# Real:   [38.268]
# Diff:  [1.17334521]
# Same Numbers
# Modelo: [39.394302]
# Real:   [38.346]
# Diff:  [1.04830237]
# Same Numbers
# Modelo: [39.362995]
# Real:   [38.396]
# Diff:  [0.96699515]
# Same Numbers
# Modelo: [39.344826]
# Real:   [38.372]
# Diff:  [0.97282574]
# Same Numbers
# Modelo: [39.32263]
# Real:   [38.575]
# Diff:  [0.74763184]
# Same Numbers
# Modelo: [39.328773]
# Real:   [38.628]
# Diff:  [0.7007735]
# Same Numbers
# Modelo: [39.346577]
# Real:   [38.877]
# Diff:  [0.46957669]
# Same Numbers
# Modelo: [39.393574]
# Real:   [38.702]
# Diff:  [0.69157376]
# Same Numbers
# Modelo: [39.426933]
# Real:   [38.411]
# Diff:  [1.01593329]
# Same Numbers
# Modelo: [39.424244]
# Real:   [38.393]
# Diff:  [1.03124393]
# Same Numbers
# Modelo: [39.41456]
# Real:   [38.295]
# Diff:  [1.11955841]
# Same Numbers
# Modelo: [39.392673]
# Real:   [38.343]
# Diff:  [1.04967349]
# Same Numbers
# Modelo: [39.374702]
# Real:   [38.443]
# Diff:  [0.93170245]
# Same Numbers
# Modelo: [39.369503]
# Real:   [38.455]
# Diff:  [0.91450302]
# Same Numbers
# Modelo: [39.368034]
# Real:   [38.53]
# Diff:  [0.83803436]
# Same Numbers
# Modelo: [39.376038]
# Real:   [38.291]
# Diff:  [1.0850376]
# Same Numbers
# Modelo: [39.355225]
# Real:   [38.485]
# Diff:  [0.87022461]
# Same Numbers
# Modelo: [39.355686]
# Real:   [38.531]
# Diff:  [0.82468619]
# Same Numbers
# Modelo: [39.363853]
# Real:   [38.634]
# Diff:  [0.72985345]
# Same Numbers
# Modelo: [39.384182]
# Real:   [38.409]
# Diff:  [0.97518198]
# Same Numbers
# Modelo: [39.379223]
# Real:   [38.478]
# Diff:  [0.90122287]
# Same Numbers
# Modelo: [39.380116]
# Real:   [38.311]
# Diff:  [1.06911551]
# Same Numbers
# Modelo: [39.363335]
# Real:   [38.31]
# Diff:  [1.05333466]
# Same Numbers
# Modelo: [39.346153]
# Real:   [38.385]
# Diff:  [0.96115326]
# Same Numbers
# Modelo: [39.336735]
# Real:   [38.514]
# Diff:  [0.82273477]
# Same Numbers
# Modelo: [39.343605]
# Real:   [38.862]
# Diff:  [0.48160504]
# Same Numbers
# Modelo: [39.389896]
# Real:   [38.809]
# Diff:  [0.58089639]
# Same Numbers
# Modelo: [39.431404]
# Real:   [38.589]
# Diff:  [0.84240411]
# Same Numbers
# Modelo: [39.920185]
# Real:   [38.843]
# Diff:  [1.07718509]
# Same Numbers
# Modelo: [39.631477]
# Real:   [38.705]
# Diff:  [0.92647736]
# Same Numbers
# Modelo: [39.271965]
# Real:   [38.66]
# Diff:  [0.61196503]
# Same Numbers
# Modelo: [38.984535]
# Real:   [38.353]
# Diff:  [0.63153522]
# Same Numbers
# Modelo: [38.751022]
# Real:   [37.638]
# Diff:  [1.11302234]
# Same Numbers
# Modelo: [38.55272]
# Real:   [37.993]
# Diff:  [0.55971912]
# Same Numbers
# Modelo: [38.494205]
# Real:   [35.892]
# Diff:  [2.60220547]
# Different
# Modelo: [38.25029]
# Real:   [35.976]
# Diff:  [2.27428992]
# Different
# Modelo: [37.87642]
# Real:   [36.004]
# Diff:  [1.87241907]
# Different
# Modelo: [37.635426]
# Real:   [35.822]
# Diff:  [1.81342557]
# Different
# Modelo: [37.45081]
# Real:   [35.973]
# Diff:  [1.47780948]
# Same Numbers
# Modelo: [37.342182]
# Real:   [36.049]
# Diff:  [1.29318216]
# Same Numbers
# Modelo: [37.313713]
# Real:   [35.924]
# Diff:  [1.38971307]
# Same Numbers
# Modelo: [37.280727]
# Real:   [36.]
# Diff:  [1.28072739]
# Same Numbers
# Modelo: [37.265816]
# Real:   [36.133]
# Diff:  [1.13281573]
# Same Numbers
# Modelo: [37.270588]
# Real:   [35.882]
# Diff:  [1.38858792]
# Same Numbers
# Modelo: [37.24096]
# Real:   [36.018]
# Diff:  [1.22295917]
# Same Numbers
# Modelo: [37.22955]
# Real:   [36.124]
# Diff:  [1.10554941]
# Same Numbers
# Modelo: [37.22993]
# Real:   [35.889]
# Diff:  [1.34093088]
# Same Numbers
# Modelo: [37.19945]
# Real:   [36.049]
# Diff:  [1.15045145]
# Same Numbers
# Modelo: [37.20052]
# Real:   [36.075]
# Diff:  [1.12551956]
# Same Numbers
# Modelo: [37.198185]
# Real:   [36.146]
# Diff:  [1.05218497]
# Same Numbers
# Modelo: [37.20124]
# Real:   [36.204]
# Diff:  [0.99724054]
# Same Numbers
# Modelo: [37.20833]
# Real:   [35.996]
# Diff:  [1.21232825]
# Same Numbers
# Modelo: [37.18158]
# Real:   [36.156]
# Diff:  [1.02557959]
# Same Numbers
# Modelo: [37.17628]
# Real:   [36.031]
# Diff:  [1.14528098]
# Same Numbers
# Modelo: [37.155136]
# Real:   [36.364]
# Diff:  [0.79113611]
# Same Numbers
# Modelo: [37.176445]
# Real:   [36.003]
# Diff:  [1.17344501]
# Same Numbers
# Modelo: [37.164036]
# Real:   [36.14]
# Diff:  [1.0240358]
# Same Numbers
# Modelo: [37.16474]
# Real:   [36.048]
# Diff:  [1.11674152]
# Same Numbers
# Modelo: [37.151123]
# Real:   [35.809]
# Diff:  [1.34212305]
# Same Numbers
# Modelo: [37.10747]
# Real:   [35.793]
# Diff:  [1.31447147]
# Same Numbers
# Modelo: [37.011944]
# Real:   [36.333]
# Diff:  [0.67894382]
# Same Numbers
# Modelo: [37.009476]
# Real:   [35.747]
# Diff:  [1.26247571]
# Same Numbers
# Modelo: [36.945976]
# Real:   [35.9]
# Diff:  [1.04597626]
# Same Numbers
# Modelo: [36.914574]
# Real:   [35.788]
# Diff:  [1.12657367]
# Same Numbers
# Modelo: [37.05125]
# Real:   [36.277]
# Diff:  [0.77425046]
# Same Numbers
# Modelo: [37.178516]
# Real:   [38.027]
# Diff:  [-0.84848361]
# Same Numbers
# Modelo: [37.484905]
# Real:   [38.887]
# Diff:  [-1.40209476]
# Same Numbers
# Modelo: [37.854588]
# Real:   [38.761]
# Diff:  [-0.90641245]
# Same Numbers
# Modelo: [38.76311]
# Real:   [39.185]
# Diff:  [-0.42188889]
# Same Numbers
# Modelo: [39.208984]
# Real:   [39.057]
# Diff:  [0.15198437]
# Same Numbers
# Modelo: [39.62593]
# Real:   [38.697]
# Diff:  [0.92893079]
# Same Numbers
# Modelo: [39.894478]
# Real:   [38.446]
# Diff:  [1.44847784]
# Same Numbers
# Modelo: [40.020947]
# Real:   [38.76]
# Diff:  [1.2609465]
# Same Numbers
# Modelo: [40.07188]
# Real:   [38.994]
# Diff:  [1.07788034]
# Same Numbers
# Modelo: [40.067284]
# Real:   [39.027]
# Diff:  [1.04028363]
# Same Numbers
# Modelo: [40.01329]
# Real:   [38.644]
# Diff:  [1.36929041]
# Same Numbers
# Modelo: [39.878147]
# Real:   [38.42]
# Diff:  [1.45814713]
# Same Numbers
# Modelo: [39.710598]
# Real:   [38.528]
# Diff:  [1.18259799]
# Same Numbers
# Modelo: [39.56327]
# Real:   [38.313]
# Diff:  [1.25027057]
# Same Numbers
# Modelo: [39.41194]
# Real:   [38.273]
# Diff:  [1.13894153]
# Same Numbers
# Modelo: [39.27206]
# Real:   [38.848]
# Diff:  [0.42406039]
# Same Numbers
# Modelo: [39.22271]
# Real:   [38.98]
# Diff:  [0.24270966]
# Same Numbers
# Modelo: [39.21644]
# Real:   [38.676]
# Diff:  [0.54043829]
# Same Numbers
# Modelo: [39.198135]
# Real:   [38.451]
# Diff:  [0.74713538]
# Same Numbers
# Modelo: [39.16718]
# Real:   [38.424]
# Diff:  [0.74317911]
# Same Numbers
# Modelo: [39.145233]
# Real:   [38.288]
# Diff:  [0.85723315]
# Same Numbers
# Modelo: [39.120094]
# Real:   [38.932]
# Diff:  [0.1880943]
# Same Numbers
# Modelo: [39.173763]
# Real:   [39.218]
# Diff:  [-0.04423672]
# Same Numbers
# Modelo: [39.275105]
# Real:   [38.82]
# Diff:  [0.45510452]
# Same Numbers
# Modelo: [39.33413]
# Real:   [38.481]
# Diff:  [0.85312933]
# Same Numbers
# Modelo: [39.34987]
# Real:   [38.313]
# Diff:  [1.03686877]
# Same Numbers
# Modelo: [39.341595]
# Real:   [38.493]
# Diff:  [0.8485947]
# Same Numbers
# Modelo: [39.321915]
# Real:   [38.577]
# Diff:  [0.74491467]
# Same Numbers
# Modelo: [39.319813]
# Real:   [38.619]
# Diff:  [0.70081277]
# Same Numbers
# Quantity of same numbers:  1874  records
# Quantity of different numbers:  660  records
# Percentage:  74.0 %
