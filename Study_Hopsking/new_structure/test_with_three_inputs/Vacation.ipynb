# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
# Out:
# C:\Users\lagg\AppData\Local\Temp\ipykernel_29064\388347847.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["summer_classes"]
del df["Theres_sun"]
del df["temp_ant"]
del df["Average_hour_month"]
del df["Average_hour_day_ant"]
del df["month"]
del df["Timestamp"]

df
# Out:
#        RealPower  EV_Power  Vacation
# 0         51.488       0.0     False
# 1         51.794       0.0     False
# 2         51.397       0.0     False
# 3         50.765       0.0     False
# 4         51.206       0.0     False
# ...          ...       ...       ...
# 26299     38.313       0.0      True
# 26300     38.493       0.0      True
# 26301     38.577       0.0      True
# 26302     38.619       0.0      True
# 26303     38.394       0.0      True
#
# [26304 rows x 3 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
#df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power
# count  26304.000000  26304.000000
# mean      48.307932      6.167214
# std        5.717560      9.099070
# min       -1.161000     -6.400000
# 25%       45.886000      0.000000
# 50%       48.319000      0.000000
# 75%       51.776500      9.480000
# max       82.339000     55.150000

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (21043, 3)
# Validation set size: (2630, 3)
# Testing set size: (2631, 3)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20946, 96, 3), y_tr: (20946, 1, 1)
# Set de validación - x_vl: (2533, 96, 3), y_vl: (2533, 1, 1)
# Set de prueba - x_ts: (2534, 96, 3), y_ts: (2534, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488, 0.0, False],
#        [51.794, 0.0, False],
#        [51.397, 0.0, False],
#        [50.765, 0.0, False],
#        [51.206, 0.0, False],
#        [51.219, 0.0, False],
#        [50.654, 0.0, False],
#        [50.491, 0.0, False],
#        [50.577, 0.0, False],
#        [50.654, 0.0, False],
#        [50.275, 0.0, False],
#        [50.022, 0.0, False],
#        [49.987, 0.0, False],
#        [50.443, 0.0, False],
#        [50.345, 0.0, False],
#        [50.239, 0.0, False],
#        [50.716, 0.0, False],
#        [50.673, 0.0, False],
#        [50.407, 0.0, False],
#        [50.605, 0.0, False],
#        [50.733, 0.0, False],
#        [52.101, 0.0, False],
#        [52.23, 0.0, False],
#        [53.73, 0.0, False],
#        [53.611, 0.0, False],
#        [53.646, 0.0, False],
#        [53.21, 0.0, False],
#        [53.806, 0.0, False],
#        [53.582, 0.0, False],
#        [52.526, 0.0, False],
#        [49.983, 5.2, False],
#        [50.513, 8.11, False],
#        [53.22, 11.01, False],
#        [55.027, 16.35, False],
#        [53.067, 17.54, False],
#        [52.949, 22.48, False],
#        [51.79, 23.2, False],
#        [50.477, 22.37, False],
#        [48.413, 29.37, False],
#        [50.593, 25.27, False],
#        [51.712, 28.57, False],
#        [49.816, 33.57, False],
#        [54.568, 22.7, False],
#        [59.61, 15.93, False],
#        [56.574, 10.3, False],
#        [52.774, 9.7, False],
#        [56.809, 9.7, False],
#        [51.718, 5.7, False],
#        [53.128, 3.18, False],
#        [54.716, 12.23, False],
#        [48.839, 13.79, False],
#        [53.15, 18.32, False],
#        [56.602, 10.62, False],
#        [67.519, 21.57, False],
#        [65.695, 24.67, False],
#        [62.946, 11.98, False],
#        [50.613, 11.69, False],
#        [48.255, 10.14, False],
#        [46.57, 8.14, False],
#        [45.438, 8.54, False],
#        [59.025, 7.12, False],
#        [57.188, 7.27, False],
#        [59.485, 10.95, False],
#        [59.79, 16.3, False],
#        [59.683, 14.12, False],
#        [59.392, 8.99, False],
#        [57.961, 8.59, False],
#        [58.789, 6.0, False],
#        [61.564, 5.53, False],
#        [54.152, 5.53, False],
#        [54.354, 5.53, False],
#        [55.792, 5.53, False],
#        [53.667, 5.53, False],
#        [55.323, 5.53, False],
#        [53.986, 5.06, False],
#        [53.523, 4.3, False],
#        [56.197, 5.07, False],
#        [56.316, 12.39, False],
#        [57.141, 15.58, False],
#        [56.48, 15.58, False],
#        [56.714, 14.87, False],
#        [56.187, 12.17, False],
#        [55.675, 19.89, False],
#        [57.27, 14.77, False],
#        [55.669, 9.07, False],
#        [56.501, 9.07, False],
#        [55.379, 9.07, False],
#        [53.727, 4.67, False],
#        [53.533, 0.4, False],
#        [53.248, 0.0, False],
#        [52.776, 0.0, False],
#        [52.309, 0.0, False],
#        [52.465, 0.0, False],
#        [51.948, 0.0, False],
#        [51.993, 0.0, False],
#        [51.682, 0.0, False]], dtype=object)

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]], dtype=object)

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -1.0
# Maximun value per dimension: 1.0

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (3):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 110 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/110
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 25s - loss: 0.3000 - accuracy: 0.0000e+00 - val_loss: 0.1137 - val_accuracy: 0.0000e+00 - 25s/epoch - 300ms/step
# Epoch 2/110
# 82/82 - 26s - loss: 0.2534 - accuracy: 0.0000e+00 - val_loss: 0.1141 - val_accuracy: 0.0000e+00 - 26s/epoch - 314ms/step
# Epoch 3/110
# 82/82 - 25s - loss: 0.2089 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_accuracy: 0.0000e+00 - 25s/epoch - 308ms/step
# Epoch 4/110
# 82/82 - 23s - loss: 0.1675 - accuracy: 0.0000e+00 - val_loss: 0.1397 - val_accuracy: 0.0000e+00 - 23s/epoch - 280ms/step
# Epoch 5/110
# 82/82 - 23s - loss: 0.1328 - accuracy: 0.0000e+00 - val_loss: 0.1643 - val_accuracy: 0.0000e+00 - 23s/epoch - 276ms/step
# Epoch 6/110
# 82/82 - 21s - loss: 0.1120 - accuracy: 0.0000e+00 - val_loss: 0.1853 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 7/110
# 82/82 - 22s - loss: 0.1041 - accuracy: 0.0000e+00 - val_loss: 0.1832 - val_accuracy: 0.0000e+00 - 22s/epoch - 272ms/step
# Epoch 8/110
# 82/82 - 22s - loss: 0.0987 - accuracy: 0.0000e+00 - val_loss: 0.1760 - val_accuracy: 0.0000e+00 - 22s/epoch - 274ms/step
# Epoch 9/110
# 82/82 - 19s - loss: 0.0936 - accuracy: 0.0000e+00 - val_loss: 0.1669 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 10/110
# 82/82 - 20s - loss: 0.0889 - accuracy: 0.0000e+00 - val_loss: 0.1583 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 11/110
# 82/82 - 22s - loss: 0.0845 - accuracy: 0.0000e+00 - val_loss: 0.1500 - val_accuracy: 0.0000e+00 - 22s/epoch - 272ms/step
# Epoch 12/110
# 82/82 - 20s - loss: 0.0806 - accuracy: 0.0000e+00 - val_loss: 0.1434 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 13/110
# 82/82 - 23s - loss: 0.0773 - accuracy: 0.0000e+00 - val_loss: 0.1351 - val_accuracy: 0.0000e+00 - 23s/epoch - 281ms/step
# Epoch 14/110
# 82/82 - 22s - loss: 0.0746 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_accuracy: 0.0000e+00 - 22s/epoch - 270ms/step
# Epoch 15/110
# 82/82 - 23s - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_accuracy: 0.0000e+00 - 23s/epoch - 279ms/step
# Epoch 16/110
# 82/82 - 22s - loss: 0.0707 - accuracy: 0.0000e+00 - val_loss: 0.1119 - val_accuracy: 0.0000e+00 - 22s/epoch - 263ms/step
# Epoch 17/110
# 82/82 - 22s - loss: 0.0694 - accuracy: 0.0000e+00 - val_loss: 0.1060 - val_accuracy: 0.0000e+00 - 22s/epoch - 263ms/step
# Epoch 18/110
# 82/82 - 22s - loss: 0.0683 - accuracy: 0.0000e+00 - val_loss: 0.1002 - val_accuracy: 0.0000e+00 - 22s/epoch - 264ms/step
# Epoch 19/110
# 82/82 - 22s - loss: 0.0678 - accuracy: 0.0000e+00 - val_loss: 0.0959 - val_accuracy: 0.0000e+00 - 22s/epoch - 270ms/step
# Epoch 20/110
# 82/82 - 20s - loss: 0.0673 - accuracy: 0.0000e+00 - val_loss: 0.0912 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 21/110
# 82/82 - 22s - loss: 0.0669 - accuracy: 0.0000e+00 - val_loss: 0.0876 - val_accuracy: 0.0000e+00 - 22s/epoch - 272ms/step
# Epoch 22/110
# 82/82 - 21s - loss: 0.0664 - accuracy: 0.0000e+00 - val_loss: 0.0853 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 23/110
# 82/82 - 22s - loss: 0.0661 - accuracy: 0.0000e+00 - val_loss: 0.0823 - val_accuracy: 0.0000e+00 - 22s/epoch - 270ms/step
# Epoch 24/110
# 82/82 - 21s - loss: 0.0657 - accuracy: 0.0000e+00 - val_loss: 0.0814 - val_accuracy: 0.0000e+00 - 21s/epoch - 261ms/step
# Epoch 25/110
# 82/82 - 22s - loss: 0.0655 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00 - 22s/epoch - 264ms/step
# Epoch 26/110
# 82/82 - 21s - loss: 0.0653 - accuracy: 0.0000e+00 - val_loss: 0.0767 - val_accuracy: 0.0000e+00 - 21s/epoch - 256ms/step
# Epoch 27/110
# 82/82 - 21s - loss: 0.0649 - accuracy: 0.0000e+00 - val_loss: 0.0757 - val_accuracy: 0.0000e+00 - 21s/epoch - 254ms/step
# Epoch 28/110
# 82/82 - 21s - loss: 0.0648 - accuracy: 4.7742e-05 - val_loss: 0.0752 - val_accuracy: 0.0000e+00 - 21s/epoch - 253ms/step
# Epoch 29/110
# 82/82 - 21s - loss: 0.0645 - accuracy: 4.7742e-05 - val_loss: 0.0743 - val_accuracy: 0.0000e+00 - 21s/epoch - 259ms/step
# Epoch 30/110
# 82/82 - 20s - loss: 0.0644 - accuracy: 4.7742e-05 - val_loss: 0.0733 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 31/110
# 82/82 - 20s - loss: 0.0642 - accuracy: 4.7742e-05 - val_loss: 0.0726 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 32/110
# 82/82 - 20s - loss: 0.0640 - accuracy: 4.7742e-05 - val_loss: 0.0714 - val_accuracy: 0.0000e+00 - 20s/epoch - 246ms/step
# Epoch 33/110
# 82/82 - 20s - loss: 0.0639 - accuracy: 4.7742e-05 - val_loss: 0.0694 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 34/110
# 82/82 - 20s - loss: 0.0637 - accuracy: 4.7742e-05 - val_loss: 0.0679 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 35/110
# 82/82 - 20s - loss: 0.0635 - accuracy: 4.7742e-05 - val_loss: 0.0686 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 36/110
# 82/82 - 20s - loss: 0.0634 - accuracy: 4.7742e-05 - val_loss: 0.0676 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 37/110
# 82/82 - 20s - loss: 0.0633 - accuracy: 4.7742e-05 - val_loss: 0.0677 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 38/110
# 82/82 - 21s - loss: 0.0631 - accuracy: 4.7742e-05 - val_loss: 0.0662 - val_accuracy: 0.0000e+00 - 21s/epoch - 254ms/step
# Epoch 39/110
# 82/82 - 21s - loss: 0.0630 - accuracy: 4.7742e-05 - val_loss: 0.0660 - val_accuracy: 0.0000e+00 - 21s/epoch - 261ms/step
# Epoch 40/110
# 82/82 - 21s - loss: 0.0627 - accuracy: 4.7742e-05 - val_loss: 0.0656 - val_accuracy: 0.0000e+00 - 21s/epoch - 250ms/step
# Epoch 41/110
# 82/82 - 21s - loss: 0.0627 - accuracy: 4.7742e-05 - val_loss: 0.0642 - val_accuracy: 0.0000e+00 - 21s/epoch - 253ms/step
# Epoch 42/110
# 82/82 - 20s - loss: 0.0626 - accuracy: 4.7742e-05 - val_loss: 0.0651 - val_accuracy: 0.0000e+00 - 20s/epoch - 246ms/step
# Epoch 43/110
# 82/82 - 22s - loss: 0.0624 - accuracy: 4.7742e-05 - val_loss: 0.0639 - val_accuracy: 0.0000e+00 - 22s/epoch - 265ms/step
# Epoch 44/110
# 82/82 - 20s - loss: 0.0624 - accuracy: 4.7742e-05 - val_loss: 0.0644 - val_accuracy: 0.0000e+00 - 20s/epoch - 246ms/step
# Epoch 45/110
# 82/82 - 20s - loss: 0.0623 - accuracy: 4.7742e-05 - val_loss: 0.0632 - val_accuracy: 0.0000e+00 - 20s/epoch - 245ms/step
# Epoch 46/110
# 82/82 - 19s - loss: 0.0621 - accuracy: 4.7742e-05 - val_loss: 0.0636 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 47/110
# 82/82 - 20s - loss: 0.0620 - accuracy: 4.7742e-05 - val_loss: 0.0628 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 48/110
# 82/82 - 21s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0625 - val_accuracy: 0.0000e+00 - 21s/epoch - 251ms/step
# Epoch 49/110
# 82/82 - 20s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0623 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 50/110
# 82/82 - 23s - loss: 0.0617 - accuracy: 4.7742e-05 - val_loss: 0.0619 - val_accuracy: 0.0000e+00 - 23s/epoch - 277ms/step
# Epoch 51/110
# 82/82 - 21s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0612 - val_accuracy: 0.0000e+00 - 21s/epoch - 262ms/step
# Epoch 52/110
# 82/82 - 21s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0605 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 53/110
# 82/82 - 20s - loss: 0.0614 - accuracy: 4.7742e-05 - val_loss: 0.0612 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 54/110
# 82/82 - 20s - loss: 0.0613 - accuracy: 4.7742e-05 - val_loss: 0.0611 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 55/110
# 82/82 - 20s - loss: 0.0612 - accuracy: 4.7742e-05 - val_loss: 0.0611 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 56/110
# 82/82 - 20s - loss: 0.0612 - accuracy: 4.7742e-05 - val_loss: 0.0599 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 57/110
# 82/82 - 20s - loss: 0.0609 - accuracy: 4.7742e-05 - val_loss: 0.0602 - val_accuracy: 0.0000e+00 - 20s/epoch - 239ms/step
# Epoch 58/110
# 82/82 - 22s - loss: 0.0609 - accuracy: 4.7742e-05 - val_loss: 0.0592 - val_accuracy: 0.0000e+00 - 22s/epoch - 269ms/step
# Epoch 59/110
# 82/82 - 20s - loss: 0.0609 - accuracy: 4.7742e-05 - val_loss: 0.0589 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 60/110
# 82/82 - 20s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0597 - val_accuracy: 0.0000e+00 - 20s/epoch - 245ms/step
# Epoch 61/110
# 82/82 - 21s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0602 - val_accuracy: 0.0000e+00 - 21s/epoch - 261ms/step
# Epoch 62/110
# 82/82 - 20s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0588 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 63/110
# 82/82 - 20s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0590 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 64/110
# 82/82 - 19s - loss: 0.0604 - accuracy: 4.7742e-05 - val_loss: 0.0585 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 65/110
# 82/82 - 21s - loss: 0.0604 - accuracy: 4.7742e-05 - val_loss: 0.0586 - val_accuracy: 0.0000e+00 - 21s/epoch - 261ms/step
# Epoch 66/110
# 82/82 - 21s - loss: 0.0603 - accuracy: 4.7742e-05 - val_loss: 0.0585 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 67/110
# 82/82 - 23s - loss: 0.0602 - accuracy: 4.7742e-05 - val_loss: 0.0590 - val_accuracy: 0.0000e+00 - 23s/epoch - 276ms/step
# Epoch 68/110
# 82/82 - 25s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0584 - val_accuracy: 0.0000e+00 - 25s/epoch - 303ms/step
# Epoch 69/110
# 82/82 - 21s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 21s/epoch - 261ms/step
# Epoch 70/110
# 82/82 - 19s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0583 - val_accuracy: 0.0000e+00 - 19s/epoch - 235ms/step
# Epoch 71/110
# 82/82 - 22s - loss: 0.0599 - accuracy: 4.7742e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 22s/epoch - 268ms/step
# Epoch 72/110
# 82/82 - 25s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0584 - val_accuracy: 0.0000e+00 - 25s/epoch - 309ms/step
# Epoch 73/110
# 82/82 - 23s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0583 - val_accuracy: 0.0000e+00 - 23s/epoch - 283ms/step
# Epoch 74/110
# 82/82 - 24s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0578 - val_accuracy: 0.0000e+00 - 24s/epoch - 296ms/step
# Epoch 75/110
# 82/82 - 25s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0567 - val_accuracy: 0.0000e+00 - 25s/epoch - 301ms/step
# Epoch 76/110
# 82/82 - 23s - loss: 0.0597 - accuracy: 4.7742e-05 - val_loss: 0.0567 - val_accuracy: 0.0000e+00 - 23s/epoch - 278ms/step
# Epoch 77/110
# 82/82 - 23s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 23s/epoch - 277ms/step
# Epoch 78/110
# 82/82 - 23s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 23s/epoch - 276ms/step
# Epoch 79/110
# 82/82 - 33s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0572 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 80/110
# 82/82 - 33s - loss: 0.0593 - accuracy: 4.7742e-05 - val_loss: 0.0570 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 81/110
# 82/82 - 33s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0572 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 82/110
# 82/82 - 33s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0569 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 83/110
# 82/82 - 33s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0560 - val_accuracy: 0.0000e+00 - 33s/epoch - 401ms/step
# Epoch 84/110
# 82/82 - 34s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0557 - val_accuracy: 0.0000e+00 - 34s/epoch - 409ms/step
# Epoch 85/110
# 82/82 - 34s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0562 - val_accuracy: 0.0000e+00 - 34s/epoch - 410ms/step
# Epoch 86/110
# 82/82 - 35s - loss: 0.0589 - accuracy: 4.7742e-05 - val_loss: 0.0562 - val_accuracy: 0.0000e+00 - 35s/epoch - 429ms/step
# Epoch 87/110
# 82/82 - 35s - loss: 0.0589 - accuracy: 4.7742e-05 - val_loss: 0.0563 - val_accuracy: 0.0000e+00 - 35s/epoch - 421ms/step
# Epoch 88/110
# 82/82 - 34s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0548 - val_accuracy: 0.0000e+00 - 34s/epoch - 412ms/step
# Epoch 89/110
# 82/82 - 34s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0559 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 90/110
# 82/82 - 33s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0561 - val_accuracy: 0.0000e+00 - 33s/epoch - 401ms/step
# Epoch 91/110
# 82/82 - 34s - loss: 0.0586 - accuracy: 4.7742e-05 - val_loss: 0.0561 - val_accuracy: 0.0000e+00 - 34s/epoch - 420ms/step
# Epoch 92/110
# 82/82 - 33s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0566 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 93/110
# 82/82 - 34s - loss: 0.0586 - accuracy: 4.7742e-05 - val_loss: 0.0556 - val_accuracy: 0.0000e+00 - 34s/epoch - 412ms/step
# Epoch 94/110
# 82/82 - 34s - loss: 0.0586 - accuracy: 4.7742e-05 - val_loss: 0.0557 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 95/110
# 82/82 - 34s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 96/110
# 82/82 - 34s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0545 - val_accuracy: 0.0000e+00 - 34s/epoch - 409ms/step
# Epoch 97/110
# 82/82 - 33s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 33s/epoch - 407ms/step
# Epoch 98/110
# 82/82 - 34s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0560 - val_accuracy: 0.0000e+00 - 34s/epoch - 409ms/step
# Epoch 99/110
# 82/82 - 33s - loss: 0.0584 - accuracy: 4.7742e-05 - val_loss: 0.0548 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 100/110
# 82/82 - 33s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0551 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 101/110
# 82/82 - 33s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0552 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 102/110
# 82/82 - 33s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 103/110
# 82/82 - 33s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 104/110
# 82/82 - 33s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0552 - val_accuracy: 0.0000e+00 - 33s/epoch - 403ms/step
# Epoch 105/110
# 82/82 - 33s - loss: 0.0581 - accuracy: 4.7742e-05 - val_loss: 0.0549 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 106/110
# 82/82 - 33s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0547 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 107/110
# 82/82 - 34s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 34s/epoch - 410ms/step
# Epoch 108/110
# 82/82 - 34s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0545 - val_accuracy: 0.0000e+00 - 34s/epoch - 420ms/step
# Epoch 109/110
# 82/82 - 33s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0547 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 110/110
# 82/82 - 34s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 34s/epoch - 415ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 655/655 [==============================] - 28s 40ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.048
#   RMSE val:	 0.049
#   RMSE test:	 0.049

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 80/80 [==============================] - 4s 43ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values
# Out:
# array([[39.755344],
#        [39.72306 ],
#        [39.672832],
#        [39.71758 ],
#        [39.8005  ],
#        [39.822357],
#        [39.79376 ],
#        [39.740795],
#        [39.71526 ],
#        [39.70347 ]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()

# %%
similar=0
different=0

for i in range(len(y_predict_trans)):
    
    print("Modelo:", y_predict_trans[i])
    print("Real:  ", y_mesuared[i])
    
    diff= y_predict_trans[i]-y_mesuared[i]

    print("Diff: ", diff)

    if -1.5<diff<1.5 :
        similar+=1
        print("Same Numbers")
    else:
        different+=1
        print("Different")

ratio=np.round((similar/(similar+different))*100,1)

print("Quantity of same numbers: ", similar, " records")
print("Quantity of different numbers: ", different, " records")
print("Percentage: ", ratio, "%")
# Out:
# Modelo: [41.52322]
# Real:   [39.416]
# Diff:  [2.10722006]
# Different
# Modelo: [41.20673]
# Real:   [38.634]
# Diff:  [2.57272989]
# Different
# Modelo: [40.950813]
# Real:   [39.007]
# Diff:  [1.94381329]
# Different
# Modelo: [40.822536]
# Real:   [40.407]
# Diff:  [0.41553647]
# Same Numbers
# Modelo: [40.965202]
# Real:   [36.734]
# Diff:  [4.23120233]
# Different
# Modelo: [40.720146]
# Real:   [39.16]
# Diff:  [1.56014618]
# Different
# Modelo: [40.67359]
# Real:   [40.376]
# Diff:  [0.29759161]
# Same Numbers
# Modelo: [40.79636]
# Real:   [40.18]
# Diff:  [0.61636002]
# Same Numbers
# Modelo: [40.907753]
# Real:   [40.988]
# Diff:  [-0.08024701]
# Same Numbers
# Modelo: [41.079643]
# Real:   [44.586]
# Diff:  [-3.50635675]
# Different
# Modelo: [41.68897]
# Real:   [44.598]
# Diff:  [-2.90903134]
# Different
# Modelo: [42.300076]
# Real:   [44.401]
# Diff:  [-2.10092447]
# Different
# Modelo: [42.858856]
# Real:   [44.495]
# Diff:  [-1.6361438]
# Different
# Modelo: [43.402065]
# Real:   [44.073]
# Diff:  [-0.67093472]
# Same Numbers
# Modelo: [43.830326]
# Real:   [44.705]
# Diff:  [-0.87467392]
# Same Numbers
# Modelo: [44.2563]
# Real:   [42.5]
# Diff:  [1.75630188]
# Different
# Modelo: [44.277664]
# Real:   [41.697]
# Diff:  [2.58066418]
# Different
# Modelo: [44.223106]
# Real:   [41.067]
# Diff:  [3.15610638]
# Different
# Modelo: [43.93219]
# Real:   [42.264]
# Diff:  [1.66818994]
# Different
# Modelo: [43.672825]
# Real:   [41.4]
# Diff:  [2.27282486]
# Different
# Modelo: [43.368492]
# Real:   [41.701]
# Diff:  [1.66749213]
# Different
# Modelo: [43.2264]
# Real:   [40.553]
# Diff:  [2.67339847]
# Different
# Modelo: [42.911743]
# Real:   [43.069]
# Diff:  [-0.15725684]
# Same Numbers
# Modelo: [43.089382]
# Real:   [43.542]
# Diff:  [-0.45261783]
# Same Numbers
# Modelo: [43.377792]
# Real:   [46.468]
# Diff:  [-3.09020764]
# Different
# Modelo: [44.108517]
# Real:   [44.944]
# Diff:  [-0.83548331]
# Same Numbers
# Modelo: [44.491966]
# Real:   [41.796]
# Diff:  [2.69596625]
# Different
# Modelo: [44.36722]
# Real:   [41.322]
# Diff:  [3.04522183]
# Different
# Modelo: [44.137783]
# Real:   [40.461]
# Diff:  [3.67678305]
# Different
# Modelo: [43.784927]
# Real:   [42.685]
# Diff:  [1.09992737]
# Same Numbers
# Modelo: [43.708595]
# Real:   [43.59]
# Diff:  [0.11859528]
# Same Numbers
# Modelo: [43.70084]
# Real:   [42.227]
# Diff:  [1.47384]
# Same Numbers
# Modelo: [43.578247]
# Real:   [42.92]
# Diff:  [0.65824707]
# Same Numbers
# Modelo: [43.613647]
# Real:   [42.136]
# Diff:  [1.47764746]
# Same Numbers
# Modelo: [43.469738]
# Real:   [42.206]
# Diff:  [1.26373801]
# Same Numbers
# Modelo: [43.41898]
# Real:   [42.15]
# Diff:  [1.26897964]
# Same Numbers
# Modelo: [43.392]
# Real:   [42.506]
# Diff:  [0.88599829]
# Same Numbers
# Modelo: [43.416866]
# Real:   [41.596]
# Diff:  [1.8208663]
# Different
# Modelo: [43.306683]
# Real:   [42.652]
# Diff:  [0.65468259]
# Same Numbers
# Modelo: [43.335037]
# Real:   [41.632]
# Diff:  [1.70303723]
# Different
# Modelo: [43.210796]
# Real:   [41.695]
# Diff:  [1.51579636]
# Different
# Modelo: [43.097126]
# Real:   [40.924]
# Diff:  [2.17312601]
# Different
# Modelo: [42.8811]
# Real:   [41.594]
# Diff:  [1.2870997]
# Same Numbers
# Modelo: [42.77305]
# Real:   [41.169]
# Diff:  [1.6040484]
# Different
# Modelo: [42.619934]
# Real:   [41.221]
# Diff:  [1.39893408]
# Same Numbers
# Modelo: [42.495388]
# Real:   [41.359]
# Diff:  [1.13638803]
# Same Numbers
# Modelo: [42.409595]
# Real:   [40.942]
# Diff:  [1.46759549]
# Same Numbers
# Modelo: [42.28495]
# Real:   [41.298]
# Diff:  [0.98695026]
# Same Numbers
# Modelo: [42.23017]
# Real:   [40.885]
# Diff:  [1.3451712]
# Same Numbers
# Modelo: [42.133575]
# Real:   [41.373]
# Diff:  [0.76057544]
# Same Numbers
# Modelo: [42.122044]
# Real:   [41.481]
# Diff:  [0.64104361]
# Same Numbers
# Modelo: [42.13545]
# Real:   [41.236]
# Diff:  [0.89944846]
# Same Numbers
# Modelo: [42.1232]
# Real:   [41.438]
# Diff:  [0.68519946]
# Same Numbers
# Modelo: [42.14582]
# Real:   [40.847]
# Diff:  [1.29882062]
# Same Numbers
# Modelo: [42.089405]
# Real:   [41.443]
# Diff:  [0.64640506]
# Same Numbers
# Modelo: [42.12201]
# Real:   [41.068]
# Diff:  [1.05400928]
# Same Numbers
# Modelo: [42.10245]
# Real:   [40.776]
# Diff:  [1.32645132]
# Same Numbers
# Modelo: [42.047195]
# Real:   [40.8]
# Diff:  [1.24719543]
# Same Numbers
# Modelo: [42.000553]
# Real:   [40.85]
# Diff:  [1.15055313]
# Same Numbers
# Modelo: [41.965958]
# Real:   [40.522]
# Diff:  [1.44395764]
# Same Numbers
# Modelo: [41.891953]
# Real:   [40.813]
# Diff:  [1.07895251]
# Same Numbers
# Modelo: [41.86697]
# Real:   [40.724]
# Diff:  [1.14297006]
# Same Numbers
# Modelo: [41.835167]
# Real:   [40.906]
# Diff:  [0.92916693]
# Same Numbers
# Modelo: [41.83525]
# Real:   [42.892]
# Diff:  [-1.05674915]
# Same Numbers
# Modelo: [42.11198]
# Real:   [49.045]
# Diff:  [-6.93301956]
# Different
# Modelo: [43.246376]
# Real:   [55.624]
# Diff:  [-12.37762396]
# Different
# Modelo: [45.208656]
# Real:   [52.876]
# Diff:  [-7.66734369]
# Different
# Modelo: [46.612816]
# Real:   [48.549]
# Diff:  [-1.93618414]
# Different
# Modelo: [47.26515]
# Real:   [45.784]
# Diff:  [1.48114816]
# Same Numbers
# Modelo: [47.399654]
# Real:   [43.407]
# Diff:  [3.99265439]
# Different
# Modelo: [47.13899]
# Real:   [39.319]
# Diff:  [7.81998849]
# Different
# Modelo: [46.396694]
# Real:   [39.733]
# Diff:  [6.66369418]
# Different
# Modelo: [45.815483]
# Real:   [43.025]
# Diff:  [2.79048309]
# Different
# Modelo: [45.378025]
# Real:   [43.494]
# Diff:  [1.88402505]
# Different
# Modelo: [45.14849]
# Real:   [43.343]
# Diff:  [1.80549091]
# Different
# Modelo: [45.026806]
# Real:   [43.486]
# Diff:  [1.54080588]
# Different
# Modelo: [45.00498]
# Real:   [46.992]
# Diff:  [-1.98702182]
# Different
# Modelo: [45.489994]
# Real:   [42.763]
# Diff:  [2.72699405]
# Different
# Modelo: [45.517315]
# Real:   [43.891]
# Diff:  [1.62631491]
# Different
# Modelo: [45.51386]
# Real:   [41.062]
# Diff:  [4.4518588]
# Different
# Modelo: [45.168945]
# Real:   [43.763]
# Diff:  [1.40594531]
# Same Numbers
# Modelo: [45.17881]
# Real:   [41.619]
# Diff:  [3.55981012]
# Different
# Modelo: [44.979855]
# Real:   [41.615]
# Diff:  [3.36485458]
# Different
# Modelo: [44.81778]
# Real:   [39.766]
# Diff:  [5.05177954]
# Different
# Modelo: [44.449642]
# Real:   [43.123]
# Diff:  [1.32664218]
# Same Numbers
# Modelo: [44.491997]
# Real:   [42.54]
# Diff:  [1.95199677]
# Different
# Modelo: [44.416527]
# Real:   [43.792]
# Diff:  [0.62452679]
# Same Numbers
# Modelo: [44.53973]
# Real:   [42.813]
# Diff:  [1.72673007]
# Different
# Modelo: [44.568146]
# Real:   [43.172]
# Diff:  [1.39614575]
# Same Numbers
# Modelo: [44.66095]
# Real:   [43.726]
# Diff:  [0.93494971]
# Same Numbers
# Modelo: [44.858013]
# Real:   [41.698]
# Diff:  [3.16001315]
# Different
# Modelo: [44.728634]
# Real:   [43.299]
# Diff:  [1.42963388]
# Same Numbers
# Modelo: [44.77121]
# Real:   [42.36]
# Diff:  [2.41120972]
# Different
# Modelo: [44.622154]
# Real:   [42.901]
# Diff:  [1.72115424]
# Different
# Modelo: [44.633068]
# Real:   [42.173]
# Diff:  [2.46006808]
# Different
# Modelo: [44.509224]
# Real:   [38.832]
# Diff:  [5.67722394]
# Different
# Modelo: [43.87593]
# Real:   [41.038]
# Diff:  [2.83793079]
# Different
# Modelo: [43.478355]
# Real:   [39.24]
# Diff:  [4.23835541]
# Different
# Modelo: [42.952606]
# Real:   [35.782]
# Diff:  [7.1706062]
# Different
# Modelo: [42.04664]
# Real:   [38.161]
# Diff:  [3.88563849]
# Different
# Modelo: [41.465054]
# Real:   [41.717]
# Diff:  [-0.25194644]
# Same Numbers
# Modelo: [41.415768]
# Real:   [41.033]
# Diff:  [0.38276767]
# Same Numbers
# Modelo: [41.40182]
# Real:   [44.079]
# Diff:  [-2.67717886]
# Different
# Modelo: [41.86575]
# Real:   [43.993]
# Diff:  [-2.12725064]
# Different
# Modelo: [42.311687]
# Real:   [43.786]
# Diff:  [-1.47431253]
# Same Numbers
# Modelo: [42.7957]
# Real:   [41.159]
# Diff:  [1.63670007]
# Different
# Modelo: [42.791588]
# Real:   [43.316]
# Diff:  [-0.52441217]
# Same Numbers
# Modelo: [42.93624]
# Real:   [42.658]
# Diff:  [0.27824115]
# Same Numbers
# Modelo: [43.007927]
# Real:   [40.079]
# Diff:  [2.92892694]
# Different
# Modelo: [42.72935]
# Real:   [38.861]
# Diff:  [3.86835104]
# Different
# Modelo: [42.298717]
# Real:   [38.608]
# Diff:  [3.6907175]
# Different
# Modelo: [41.8601]
# Real:   [40.026]
# Diff:  [1.83409979]
# Different
# Modelo: [41.61416]
# Real:   [40.731]
# Diff:  [0.88315863]
# Same Numbers
# Modelo: [41.528496]
# Real:   [40.393]
# Diff:  [1.13549579]
# Same Numbers
# Modelo: [41.461334]
# Real:   [40.471]
# Diff:  [0.99033423]
# Same Numbers
# Modelo: [41.47269]
# Real:   [40.66]
# Diff:  [0.81269058]
# Same Numbers
# Modelo: [41.452557]
# Real:   [40.93]
# Diff:  [0.52255661]
# Same Numbers
# Modelo: [41.46591]
# Real:   [40.848]
# Diff:  [0.61791187]
# Same Numbers
# Modelo: [41.48493]
# Real:   [40.97]
# Diff:  [0.51492813]
# Same Numbers
# Modelo: [41.540962]
# Real:   [40.919]
# Diff:  [0.62196222]
# Same Numbers
# Modelo: [41.597992]
# Real:   [42.365]
# Diff:  [-0.76700806]
# Same Numbers
# Modelo: [41.85199]
# Real:   [42.082]
# Diff:  [-0.23001025]
# Same Numbers
# Modelo: [42.04688]
# Real:   [41.558]
# Diff:  [0.48887881]
# Same Numbers
# Modelo: [42.15053]
# Real:   [41.839]
# Diff:  [0.31153177]
# Same Numbers
# Modelo: [42.27333]
# Real:   [42.011]
# Diff:  [0.26233069]
# Same Numbers
# Modelo: [42.39748]
# Real:   [42.098]
# Diff:  [0.29948001]
# Same Numbers
# Modelo: [42.51332]
# Real:   [41.648]
# Diff:  [0.86532092]
# Same Numbers
# Modelo: [42.548584]
# Real:   [41.314]
# Diff:  [1.23458398]
# Same Numbers
# Modelo: [42.525543]
# Real:   [41.805]
# Diff:  [0.72054321]
# Same Numbers
# Modelo: [42.5626]
# Real:   [41.789]
# Diff:  [0.77359918]
# Same Numbers
# Modelo: [42.632076]
# Real:   [41.928]
# Diff:  [0.70407626]
# Same Numbers
# Modelo: [42.721684]
# Real:   [42.081]
# Diff:  [0.6406835]
# Same Numbers
# Modelo: [42.826073]
# Real:   [41.699]
# Diff:  [1.12707269]
# Same Numbers
# Modelo: [42.8279]
# Real:   [42.008]
# Diff:  [0.81989993]
# Same Numbers
# Modelo: [42.85254]
# Real:   [41.412]
# Diff:  [1.44053906]
# Same Numbers
# Modelo: [42.79075]
# Real:   [40.601]
# Diff:  [2.1897486]
# Different
# Modelo: [42.587532]
# Real:   [40.556]
# Diff:  [2.03153204]
# Different
# Modelo: [42.4028]
# Real:   [40.065]
# Diff:  [2.33780151]
# Different
# Modelo: [42.152916]
# Real:   [40.863]
# Diff:  [1.28991595]
# Same Numbers
# Modelo: [42.065933]
# Real:   [40.541]
# Diff:  [1.52493323]
# Different
# Modelo: [41.98038]
# Real:   [40.751]
# Diff:  [1.22938101]
# Same Numbers
# Modelo: [41.950428]
# Real:   [40.5]
# Diff:  [1.45042801]
# Same Numbers
# Modelo: [41.895588]
# Real:   [40.394]
# Diff:  [1.50158792]
# Different
# Modelo: [41.83169]
# Real:   [40.104]
# Diff:  [1.72769174]
# Different
# Modelo: [41.731316]
# Real:   [39.949]
# Diff:  [1.78231561]
# Different
# Modelo: [41.615894]
# Real:   [40.067]
# Diff:  [1.54889432]
# Different
# Modelo: [41.52548]
# Real:   [39.899]
# Diff:  [1.62647836]
# Different
# Modelo: [41.421604]
# Real:   [39.848]
# Diff:  [1.57360416]
# Different
# Modelo: [41.32352]
# Real:   [39.567]
# Diff:  [1.75652066]
# Different
# Modelo: [41.20009]
# Real:   [40.049]
# Diff:  [1.1510885]
# Same Numbers
# Modelo: [41.158867]
# Real:   [39.724]
# Diff:  [1.43486688]
# Same Numbers
# Modelo: [41.083706]
# Real:   [39.638]
# Diff:  [1.4457059]
# Same Numbers
# Modelo: [41.010735]
# Real:   [39.481]
# Diff:  [1.52973456]
# Different
# Modelo: [40.92829]
# Real:   [39.752]
# Diff:  [1.17629132]
# Same Numbers
# Modelo: [40.895737]
# Real:   [42.071]
# Diff:  [-1.17526331]
# Same Numbers
# Modelo: [41.190685]
# Real:   [39.802]
# Diff:  [1.38868527]
# Same Numbers
# Modelo: [41.15902]
# Real:   [39.608]
# Diff:  [1.55101947]
# Different
# Modelo: [41.10728]
# Real:   [39.696]
# Diff:  [1.41128073]
# Same Numbers
# Modelo: [41.06537]
# Real:   [39.764]
# Diff:  [1.30136865]
# Same Numbers
# Modelo: [41.03336]
# Real:   [39.838]
# Diff:  [1.19535953]
# Same Numbers
# Modelo: [41.014423]
# Real:   [39.766]
# Diff:  [1.24842337]
# Same Numbers
# Modelo: [40.988956]
# Real:   [39.486]
# Diff:  [1.50295645]
# Different
# Modelo: [40.929268]
# Real:   [39.837]
# Diff:  [1.09226788]
# Same Numbers
# Modelo: [40.924324]
# Real:   [39.871]
# Diff:  [1.05332404]
# Same Numbers
# Modelo: [40.926716]
# Real:   [39.53]
# Diff:  [1.39671585]
# Same Numbers
# Modelo: [40.88534]
# Real:   [39.885]
# Diff:  [1.00034164]
# Same Numbers
# Modelo: [40.89791]
# Real:   [39.667]
# Diff:  [1.23091107]
# Same Numbers
# Modelo: [40.88096]
# Real:   [39.634]
# Diff:  [1.24695856]
# Same Numbers
# Modelo: [40.862743]
# Real:   [40.116]
# Diff:  [0.74674338]
# Same Numbers
# Modelo: [40.913006]
# Real:   [39.261]
# Diff:  [1.65200583]
# Different
# Modelo: [40.84328]
# Real:   [37.172]
# Diff:  [3.67128079]
# Different
# Modelo: [40.49303]
# Real:   [37.194]
# Diff:  [3.29903055]
# Different
# Modelo: [40.170956]
# Real:   [37.002]
# Diff:  [3.16895566]
# Different
# Modelo: [39.854137]
# Real:   [37.931]
# Diff:  [1.92313742]
# Different
# Modelo: [39.74622]
# Real:   [40.908]
# Diff:  [-1.16178036]
# Same Numbers
# Modelo: [40.049404]
# Real:   [40.263]
# Diff:  [-0.21359586]
# Same Numbers
# Modelo: [40.242535]
# Real:   [37.525]
# Diff:  [2.71753464]
# Different
# Modelo: [40.055954]
# Real:   [36.471]
# Diff:  [3.58495398]
# Different
# Modelo: [39.72474]
# Real:   [38.398]
# Diff:  [1.32673907]
# Same Numbers
# Modelo: [39.66977]
# Real:   [39.184]
# Diff:  [0.48576929]
# Same Numbers
# Modelo: [39.741882]
# Real:   [41.067]
# Diff:  [-1.32511768]
# Same Numbers
# Modelo: [40.093704]
# Real:   [40.875]
# Diff:  [-0.78129578]
# Same Numbers
# Modelo: [40.409122]
# Real:   [38.565]
# Diff:  [1.84412247]
# Different
# Modelo: [40.39557]
# Real:   [40.753]
# Diff:  [-0.35743115]
# Same Numbers
# Modelo: [40.67221]
# Real:   [40.949]
# Diff:  [-0.27678931]
# Same Numbers
# Modelo: [41.00629]
# Real:   [40.105]
# Diff:  [0.90129044]
# Same Numbers
# Modelo: [41.140224]
# Real:   [37.283]
# Diff:  [3.85722446]
# Different
# Modelo: [40.902004]
# Real:   [39.554]
# Diff:  [1.34800424]
# Same Numbers
# Modelo: [40.977886]
# Real:   [37.953]
# Diff:  [3.0248862]
# Different
# Modelo: [40.77002]
# Real:   [38.739]
# Diff:  [2.03101953]
# Different
# Modelo: [40.601036]
# Real:   [38.029]
# Diff:  [2.57203607]
# Different
# Modelo: [40.401596]
# Real:   [38.356]
# Diff:  [2.04559607]
# Different
# Modelo: [40.348488]
# Real:   [40.713]
# Diff:  [-0.36451215]
# Same Numbers
# Modelo: [40.602848]
# Real:   [40.797]
# Diff:  [-0.19415195]
# Same Numbers
# Modelo: [40.856274]
# Real:   [40.028]
# Diff:  [0.82827365]
# Same Numbers
# Modelo: [40.996433]
# Real:   [41.173]
# Diff:  [-0.17656674]
# Same Numbers
# Modelo: [41.276352]
# Real:   [41.386]
# Diff:  [-0.10964807]
# Same Numbers
# Modelo: [41.560547]
# Real:   [40.837]
# Diff:  [0.72354687]
# Same Numbers
# Modelo: [41.74349]
# Real:   [40.746]
# Diff:  [0.99748831]
# Same Numbers
# Modelo: [41.88554]
# Real:   [40.821]
# Diff:  [1.06454001]
# Same Numbers
# Modelo: [42.00933]
# Real:   [40.13]
# Diff:  [1.87933075]
# Different
# Modelo: [42.02406]
# Real:   [41.081]
# Diff:  [0.9430593]
# Same Numbers
# Modelo: [42.253826]
# Real:   [40.763]
# Diff:  [1.49082614]
# Same Numbers
# Modelo: [42.341923]
# Real:   [41.357]
# Diff:  [0.98492276]
# Same Numbers
# Modelo: [42.45694]
# Real:   [41.849]
# Diff:  [0.6079397]
# Same Numbers
# Modelo: [42.59889]
# Real:   [41.397]
# Diff:  [1.2018884]
# Same Numbers
# Modelo: [42.556854]
# Real:   [40.881]
# Diff:  [1.67585425]
# Different
# Modelo: [42.408386]
# Real:   [40.274]
# Diff:  [2.13438623]
# Different
# Modelo: [42.41089]
# Real:   [41.479]
# Diff:  [0.93188867]
# Same Numbers
# Modelo: [42.548996]
# Real:   [41.665]
# Diff:  [0.88399597]
# Same Numbers
# Modelo: [42.635242]
# Real:   [40.688]
# Diff:  [1.94724246]
# Different
# Modelo: [42.506123]
# Real:   [41.227]
# Diff:  [1.27912259]
# Same Numbers
# Modelo: [42.502068]
# Real:   [40.801]
# Diff:  [1.70106757]
# Different
# Modelo: [42.45843]
# Real:   [40.637]
# Diff:  [1.82143124]
# Different
# Modelo: [42.467613]
# Real:   [40.991]
# Diff:  [1.47661322]
# Same Numbers
# Modelo: [42.474934]
# Real:   [40.64]
# Diff:  [1.83493362]
# Different
# Modelo: [42.32392]
# Real:   [41.449]
# Diff:  [0.8749212]
# Same Numbers
# Modelo: [42.32619]
# Real:   [41.128]
# Diff:  [1.19819095]
# Same Numbers
# Modelo: [42.30796]
# Real:   [41.028]
# Diff:  [1.27996051]
# Same Numbers
# Modelo: [42.287495]
# Real:   [40.601]
# Diff:  [1.68649466]
# Different
# Modelo: [42.244144]
# Real:   [41.952]
# Diff:  [0.29214444]
# Same Numbers
# Modelo: [42.450348]
# Real:   [41.368]
# Diff:  [1.0823479]
# Same Numbers
# Modelo: [42.50179]
# Real:   [41.765]
# Diff:  [0.73678909]
# Same Numbers
# Modelo: [42.45223]
# Real:   [41.118]
# Diff:  [1.33422855]
# Same Numbers
# Modelo: [42.38451]
# Real:   [41.574]
# Diff:  [0.81051004]
# Same Numbers
# Modelo: [42.41981]
# Real:   [41.549]
# Diff:  [0.87081125]
# Same Numbers
# Modelo: [42.465443]
# Real:   [40.961]
# Diff:  [1.50444266]
# Different
# Modelo: [42.43327]
# Real:   [41.165]
# Diff:  [1.2682695]
# Same Numbers
# Modelo: [42.42752]
# Real:   [40.824]
# Diff:  [1.60352075]
# Different
# Modelo: [42.371597]
# Real:   [41.091]
# Diff:  [1.28059729]
# Same Numbers
# Modelo: [42.351818]
# Real:   [41.153]
# Diff:  [1.19881808]
# Same Numbers
# Modelo: [42.340042]
# Real:   [41.28]
# Diff:  [1.06004211]
# Same Numbers
# Modelo: [42.346443]
# Real:   [40.522]
# Diff:  [1.82444318]
# Different
# Modelo: [42.2508]
# Real:   [41.043]
# Diff:  [1.20780109]
# Same Numbers
# Modelo: [42.23181]
# Real:   [40.812]
# Diff:  [1.41981152]
# Same Numbers
# Modelo: [42.184486]
# Real:   [40.405]
# Diff:  [1.77948639]
# Different
# Modelo: [42.088715]
# Real:   [40.454]
# Diff:  [1.6347146]
# Different
# Modelo: [42.008842]
# Real:   [41.006]
# Diff:  [1.00284247]
# Same Numbers
# Modelo: [42.013138]
# Real:   [40.731]
# Diff:  [1.28213782]
# Same Numbers
# Modelo: [41.986427]
# Real:   [40.631]
# Diff:  [1.35542731]
# Same Numbers
# Modelo: [41.953575]
# Real:   [38.213]
# Diff:  [3.74057513]
# Different
# Modelo: [41.599827]
# Real:   [37.796]
# Diff:  [3.80382681]
# Different
# Modelo: [41.162216]
# Real:   [40.327]
# Diff:  [0.83521619]
# Same Numbers
# Modelo: [41.070633]
# Real:   [40.296]
# Diff:  [0.77463293]
# Same Numbers
# Modelo: [41.056442]
# Real:   [39.928]
# Diff:  [1.12844226]
# Same Numbers
# Modelo: [41.039803]
# Real:   [40.149]
# Diff:  [0.89080255]
# Same Numbers
# Modelo: [41.07262]
# Real:   [39.861]
# Diff:  [1.21162039]
# Same Numbers
# Modelo: [41.06712]
# Real:   [39.7]
# Diff:  [1.3671196]
# Same Numbers
# Modelo: [41.037212]
# Real:   [39.728]
# Diff:  [1.30921237]
# Same Numbers
# Modelo: [41.007904]
# Real:   [40.279]
# Diff:  [0.72890405]
# Same Numbers
# Modelo: [41.051796]
# Real:   [40.236]
# Diff:  [0.81579596]
# Same Numbers
# Modelo: [41.084503]
# Real:   [40.006]
# Diff:  [1.07850317]
# Same Numbers
# Modelo: [41.082504]
# Real:   [39.618]
# Diff:  [1.46450427]
# Same Numbers
# Modelo: [41.025665]
# Real:   [39.51]
# Diff:  [1.51566528]
# Different
# Modelo: [40.956383]
# Real:   [39.426]
# Diff:  [1.53038275]
# Different
# Modelo: [40.88031]
# Real:   [39.866]
# Diff:  [1.01431006]
# Same Numbers
# Modelo: [40.872406]
# Real:   [39.714]
# Diff:  [1.15840601]
# Same Numbers
# Modelo: [40.848457]
# Real:   [39.173]
# Diff:  [1.67545734]
# Different
# Modelo: [40.75727]
# Real:   [39.124]
# Diff:  [1.63327081]
# Different
# Modelo: [40.669872]
# Real:   [39.253]
# Diff:  [1.41687228]
# Same Numbers
# Modelo: [40.61022]
# Real:   [39.331]
# Diff:  [1.27922186]
# Same Numbers
# Modelo: [40.571167]
# Real:   [39.408]
# Diff:  [1.16316699]
# Same Numbers
# Modelo: [40.55198]
# Real:   [39.217]
# Diff:  [1.33497906]
# Same Numbers
# Modelo: [40.513977]
# Real:   [39.25]
# Diff:  [1.26397705]
# Same Numbers
# Modelo: [40.488285]
# Real:   [39.202]
# Diff:  [1.28628506]
# Same Numbers
# Modelo: [40.461723]
# Real:   [39.358]
# Diff:  [1.10372333]
# Same Numbers
# Modelo: [40.462177]
# Real:   [39.333]
# Diff:  [1.12917728]
# Same Numbers
# Modelo: [40.462353]
# Real:   [39.317]
# Diff:  [1.14535275]
# Same Numbers
# Modelo: [40.467064]
# Real:   [39.384]
# Diff:  [1.0830639]
# Same Numbers
# Modelo: [40.53479]
# Real:   [37.984]
# Diff:  [2.55079004]
# Different
# Modelo: [40.372593]
# Real:   [37.125]
# Diff:  [3.24759293]
# Different
# Modelo: [40.08651]
# Real:   [37.665]
# Diff:  [2.4215097]
# Different
# Modelo: [39.88983]
# Real:   [37.25]
# Diff:  [2.63983154]
# Different
# Modelo: [39.658913]
# Real:   [36.505]
# Diff:  [3.15391266]
# Different
# Modelo: [39.360184]
# Real:   [37.169]
# Diff:  [2.19118372]
# Different
# Modelo: [39.13403]
# Real:   [37.23]
# Diff:  [1.90402939]
# Different
# Modelo: [38.986404]
# Real:   [37.61]
# Diff:  [1.37640442]
# Same Numbers
# Modelo: [38.943607]
# Real:   [37.462]
# Diff:  [1.48160733]
# Same Numbers
# Modelo: [38.909046]
# Real:   [37.784]
# Diff:  [1.12504617]
# Same Numbers
# Modelo: [39.05861]
# Real:   [37.443]
# Diff:  [1.61560901]
# Different
# Modelo: [39.143784]
# Real:   [37.643]
# Diff:  [1.50078357]
# Different
# Modelo: [39.175045]
# Real:   [38.711]
# Diff:  [0.46404501]
# Same Numbers
# Modelo: [39.200726]
# Real:   [37.681]
# Diff:  [1.51972556]
# Different
# Modelo: [39.13917]
# Real:   [37.515]
# Diff:  [1.6241716]
# Different
# Modelo: [39.092255]
# Real:   [38.034]
# Diff:  [1.05825464]
# Same Numbers
# Modelo: [39.17241]
# Real:   [37.877]
# Diff:  [1.29540906]
# Same Numbers
# Modelo: [39.22646]
# Real:   [38.145]
# Diff:  [1.0814595]
# Same Numbers
# Modelo: [39.308693]
# Real:   [38.219]
# Diff:  [1.08969293]
# Same Numbers
# Modelo: [39.45607]
# Real:   [38.922]
# Diff:  [0.53406995]
# Same Numbers
# Modelo: [39.673973]
# Real:   [38.806]
# Diff:  [0.86797308]
# Same Numbers
# Modelo: [39.810806]
# Real:   [35.905]
# Diff:  [3.90580627]
# Different
# Modelo: [39.528465]
# Real:   [37.209]
# Diff:  [2.31946527]
# Different
# Modelo: [39.421547]
# Real:   [38.804]
# Diff:  [0.61754694]
# Same Numbers
# Modelo: [39.53128]
# Real:   [38.885]
# Diff:  [0.64628052]
# Same Numbers
# Modelo: [39.655956]
# Real:   [41.406]
# Diff:  [-1.75004373]
# Different
# Modelo: [40.121708]
# Real:   [40.843]
# Diff:  [-0.72129208]
# Same Numbers
# Modelo: [40.48743]
# Real:   [42.78]
# Diff:  [-2.29256943]
# Different
# Modelo: [41.119614]
# Real:   [44.988]
# Diff:  [-3.86838635]
# Different
# Modelo: [41.973274]
# Real:   [42.765]
# Diff:  [-0.79172577]
# Same Numbers
# Modelo: [42.343216]
# Real:   [39.839]
# Diff:  [2.50421594]
# Different
# Modelo: [42.305416]
# Real:   [38.466]
# Diff:  [3.83941611]
# Different
# Modelo: [42.060207]
# Real:   [38.041]
# Diff:  [4.01920737]
# Different
# Modelo: [41.74121]
# Real:   [39.112]
# Diff:  [2.62921094]
# Different
# Modelo: [41.63344]
# Real:   [40.245]
# Diff:  [1.38843811]
# Same Numbers
# Modelo: [41.573067]
# Real:   [40.676]
# Diff:  [0.89706671]
# Same Numbers
# Modelo: [41.600193]
# Real:   [40.9]
# Diff:  [0.70019302]
# Same Numbers
# Modelo: [41.671257]
# Real:   [41.082]
# Diff:  [0.58925702]
# Same Numbers
# Modelo: [41.851173]
# Real:   [40.562]
# Diff:  [1.2891734]
# Same Numbers
# Modelo: [42.008007]
# Real:   [41.76]
# Diff:  [0.24800705]
# Same Numbers
# Modelo: [42.275146]
# Real:   [41.72]
# Diff:  [0.55514648]
# Same Numbers
# Modelo: [42.33641]
# Real:   [41.269]
# Diff:  [1.06741052]
# Same Numbers
# Modelo: [42.345364]
# Real:   [41.19]
# Diff:  [1.15536362]
# Same Numbers
# Modelo: [42.37699]
# Real:   [41.512]
# Diff:  [0.86499127]
# Same Numbers
# Modelo: [42.465652]
# Real:   [41.407]
# Diff:  [1.05865247]
# Same Numbers
# Modelo: [42.541107]
# Real:   [42.034]
# Diff:  [0.50710718]
# Same Numbers
# Modelo: [42.576393]
# Real:   [40.776]
# Diff:  [1.80039313]
# Different
# Modelo: [42.50798]
# Real:   [41.377]
# Diff:  [1.13098035]
# Same Numbers
# Modelo: [42.553997]
# Real:   [40.787]
# Diff:  [1.76699704]
# Different
# Modelo: [42.521782]
# Real:   [41.484]
# Diff:  [1.03778192]
# Same Numbers
# Modelo: [42.576862]
# Real:   [40.652]
# Diff:  [1.92486234]
# Different
# Modelo: [42.50524]
# Real:   [41.609]
# Diff:  [0.89624139]
# Same Numbers
# Modelo: [42.554996]
# Real:   [41.055]
# Diff:  [1.49999649]
# Same Numbers
# Modelo: [42.518047]
# Real:   [41.127]
# Diff:  [1.39104733]
# Same Numbers
# Modelo: [42.53714]
# Real:   [41.511]
# Diff:  [1.02613989]
# Same Numbers
# Modelo: [42.504475]
# Real:   [41.068]
# Diff:  [1.43647464]
# Same Numbers
# Modelo: [42.39733]
# Real:   [40.984]
# Diff:  [1.41333124]
# Same Numbers
# Modelo: [42.326015]
# Real:   [41.201]
# Diff:  [1.12501547]
# Same Numbers
# Modelo: [42.308506]
# Real:   [41.615]
# Diff:  [0.69350601]
# Same Numbers
# Modelo: [42.3563]
# Real:   [41.014]
# Diff:  [1.34230035]
# Same Numbers
# Modelo: [42.321613]
# Real:   [40.984]
# Diff:  [1.33761331]
# Same Numbers
# Modelo: [42.28329]
# Real:   [40.209]
# Diff:  [2.07429086]
# Different
# Modelo: [42.1267]
# Real:   [40.665]
# Diff:  [1.46170135]
# Same Numbers
# Modelo: [41.99798]
# Real:   [40.818]
# Diff:  [1.17997821]
# Same Numbers
# Modelo: [41.93525]
# Real:   [40.675]
# Diff:  [1.26024933]
# Same Numbers
# Modelo: [41.880337]
# Real:   [40.45]
# Diff:  [1.43033676]
# Same Numbers
# Modelo: [41.80917]
# Real:   [40.821]
# Diff:  [0.98816977]
# Same Numbers
# Modelo: [41.797703]
# Real:   [40.671]
# Diff:  [1.12670279]
# Same Numbers
# Modelo: [41.76821]
# Real:   [40.625]
# Diff:  [1.14321136]
# Same Numbers
# Modelo: [41.73614]
# Real:   [41.004]
# Diff:  [0.7321412]
# Same Numbers
# Modelo: [41.759132]
# Real:   [40.75]
# Diff:  [1.00913239]
# Same Numbers
# Modelo: [41.74693]
# Real:   [40.623]
# Diff:  [1.12392917]
# Same Numbers
# Modelo: [41.719875]
# Real:   [40.268]
# Diff:  [1.45187534]
# Same Numbers
# Modelo: [41.646748]
# Real:   [40.079]
# Diff:  [1.56774759]
# Different
# Modelo: [41.554195]
# Real:   [40.64]
# Diff:  [0.9141954]
# Same Numbers
# Modelo: [41.547638]
# Real:   [40.279]
# Diff:  [1.26863794]
# Same Numbers
# Modelo: [41.49632]
# Real:   [39.899]
# Diff:  [1.59731882]
# Different
# Modelo: [41.40235]
# Real:   [40.446]
# Diff:  [0.95635138]
# Same Numbers
# Modelo: [41.39456]
# Real:   [40.212]
# Diff:  [1.18256177]
# Same Numbers
# Modelo: [41.359867]
# Real:   [40.561]
# Diff:  [0.7988671]
# Same Numbers
# Modelo: [41.381542]
# Real:   [39.825]
# Diff:  [1.55654221]
# Different
# Modelo: [41.304718]
# Real:   [39.409]
# Diff:  [1.89571802]
# Different
# Modelo: [41.217648]
# Real:   [40.789]
# Diff:  [0.42864755]
# Same Numbers
# Modelo: [41.380573]
# Real:   [40.881]
# Diff:  [0.49957327]
# Same Numbers
# Modelo: [41.56444]
# Real:   [42.672]
# Diff:  [-1.10755832]
# Same Numbers
# Modelo: [41.987606]
# Real:   [39.205]
# Diff:  [2.78260605]
# Different
# Modelo: [41.968555]
# Real:   [43.222]
# Diff:  [-1.25344455]
# Same Numbers
# Modelo: [42.22895]
# Real:   [43.112]
# Diff:  [-0.8830495]
# Same Numbers
# Modelo: [42.44151]
# Real:   [39.499]
# Diff:  [2.94250925]
# Different
# Modelo: [42.374672]
# Real:   [42.537]
# Diff:  [-0.16232806]
# Same Numbers
# Modelo: [42.632095]
# Real:   [39.843]
# Diff:  [2.78909534]
# Different
# Modelo: [42.526485]
# Real:   [36.875]
# Diff:  [5.65148544]
# Different
# Modelo: [41.953625]
# Real:   [36.37]
# Diff:  [5.58362473]
# Different
# Modelo: [41.379982]
# Real:   [38.162]
# Diff:  [3.21798199]
# Different
# Modelo: [41.094353]
# Real:   [38.971]
# Diff:  [2.12335272]
# Different
# Modelo: [41.01173]
# Real:   [39.334]
# Diff:  [1.67773019]
# Different
# Modelo: [40.867447]
# Real:   [35.639]
# Diff:  [5.2284469]
# Different
# Modelo: [40.391438]
# Real:   [43.085]
# Diff:  [-2.69356247]
# Different
# Modelo: [40.843857]
# Real:   [32.322]
# Diff:  [8.52185681]
# Different
# Modelo: [40.109474]
# Real:   [42.964]
# Diff:  [-2.85452582]
# Different
# Modelo: [40.6123]
# Real:   [34.067]
# Diff:  [6.54530087]
# Different
# Modelo: [40.126675]
# Real:   [36.011]
# Diff:  [4.11567465]
# Different
# Modelo: [39.83692]
# Real:   [39.145]
# Diff:  [0.69192169]
# Same Numbers
# Modelo: [40.02725]
# Real:   [40.071]
# Diff:  [-0.04375162]
# Same Numbers
# Modelo: [40.428852]
# Real:   [40.702]
# Diff:  [-0.27314792]
# Same Numbers
# Modelo: [40.89366]
# Real:   [40.091]
# Diff:  [0.8026615]
# Same Numbers
# Modelo: [41.10116]
# Real:   [40.665]
# Diff:  [0.43615814]
# Same Numbers
# Modelo: [41.34996]
# Real:   [39.91]
# Diff:  [1.43996033]
# Same Numbers
# Modelo: [41.501125]
# Real:   [40.762]
# Diff:  [0.73912534]
# Same Numbers
# Modelo: [41.80955]
# Real:   [39.753]
# Diff:  [2.05655124]
# Different
# Modelo: [41.987316]
# Real:   [40.126]
# Diff:  [1.86131613]
# Different
# Modelo: [41.962864]
# Real:   [40.312]
# Diff:  [1.65086392]
# Different
# Modelo: [42.023373]
# Real:   [40.623]
# Diff:  [1.40037265]
# Same Numbers
# Modelo: [42.251118]
# Real:   [39.761]
# Diff:  [2.49011771]
# Different
# Modelo: [42.326977]
# Real:   [39.379]
# Diff:  [2.94797678]
# Different
# Modelo: [42.269627]
# Real:   [37.673]
# Diff:  [4.59662662]
# Different
# Modelo: [42.016907]
# Real:   [35.7]
# Diff:  [6.31690674]
# Different
# Modelo: [41.45911]
# Real:   [35.352]
# Diff:  [6.10711026]
# Different
# Modelo: [40.78867]
# Real:   [34.873]
# Diff:  [5.91566959]
# Different
# Modelo: [40.103733]
# Real:   [33.229]
# Diff:  [6.87473306]
# Different
# Modelo: [39.32923]
# Real:   [33.278]
# Diff:  [6.05123126]
# Different
# Modelo: [38.614723]
# Real:   [33.535]
# Diff:  [5.07972321]
# Different
# Modelo: [38.064007]
# Real:   [37.601]
# Diff:  [0.46300681]
# Same Numbers
# Modelo: [38.040318]
# Real:   [39.737]
# Diff:  [-1.69668246]
# Different
# Modelo: [38.413284]
# Real:   [40.297]
# Diff:  [-1.8837157]
# Different
# Modelo: [38.897415]
# Real:   [41.432]
# Diff:  [-2.53458484]
# Different
# Modelo: [39.513363]
# Real:   [40.973]
# Diff:  [-1.45963712]
# Same Numbers
# Modelo: [40.01184]
# Real:   [47.4]
# Diff:  [-7.38815918]
# Different
# Modelo: [41.227047]
# Real:   [52.602]
# Diff:  [-11.37495303]
# Different
# Modelo: [43.02873]
# Real:   [54.211]
# Diff:  [-11.18227151]
# Different
# Modelo: [44.940567]
# Real:   [52.169]
# Diff:  [-7.22843298]
# Different
# Modelo: [46.393555]
# Real:   [52.5]
# Diff:  [-6.10644531]
# Different
# Modelo: [47.68419]
# Real:   [53.106]
# Diff:  [-5.42181116]
# Different
# Modelo: [48.938038]
# Real:   [52.942]
# Diff:  [-4.00396213]
# Different
# Modelo: [49.896103]
# Real:   [52.189]
# Diff:  [-2.29289709]
# Different
# Modelo: [50.526253]
# Real:   [47.108]
# Diff:  [3.41825275]
# Different
# Modelo: [50.303436]
# Real:   [44.88]
# Diff:  [5.42343628]
# Different
# Modelo: [49.697315]
# Real:   [42.179]
# Diff:  [7.51831522]
# Different
# Modelo: [48.700832]
# Real:   [42.042]
# Diff:  [6.65883237]
# Different
# Modelo: [47.728855]
# Real:   [41.631]
# Diff:  [6.09785513]
# Different
# Modelo: [46.782337]
# Real:   [42.575]
# Diff:  [4.20733719]
# Different
# Modelo: [46.074142]
# Real:   [42.384]
# Diff:  [3.69014246]
# Different
# Modelo: [45.452072]
# Real:   [41.833]
# Diff:  [3.61907214]
# Different
# Modelo: [44.866505]
# Real:   [42.204]
# Diff:  [2.66250467]
# Different
# Modelo: [44.43518]
# Real:   [41.641]
# Diff:  [2.79418066]
# Different
# Modelo: [44.016514]
# Real:   [42.113]
# Diff:  [1.90351382]
# Different
# Modelo: [43.743557]
# Real:   [41.852]
# Diff:  [1.89155698]
# Different
# Modelo: [43.51269]
# Real:   [41.819]
# Diff:  [1.6936915]
# Different
# Modelo: [43.374134]
# Real:   [42.403]
# Diff:  [0.97113406]
# Same Numbers
# Modelo: [43.270958]
# Real:   [41.655]
# Diff:  [1.61595795]
# Different
# Modelo: [43.053547]
# Real:   [41.488]
# Diff:  [1.56554691]
# Different
# Modelo: [42.901855]
# Real:   [41.174]
# Diff:  [1.72785547]
# Different
# Modelo: [42.760853]
# Real:   [40.929]
# Diff:  [1.83185281]
# Different
# Modelo: [42.61934]
# Real:   [40.454]
# Diff:  [2.16533899]
# Different
# Modelo: [42.4358]
# Real:   [39.813]
# Diff:  [2.62279865]
# Different
# Modelo: [42.153057]
# Real:   [40.868]
# Diff:  [1.2850571]
# Same Numbers
# Modelo: [42.03463]
# Real:   [40.851]
# Diff:  [1.18362982]
# Same Numbers
# Modelo: [41.960884]
# Real:   [40.387]
# Diff:  [1.57388409]
# Different
# Modelo: [41.85431]
# Real:   [40.585]
# Diff:  [1.26930908]
# Same Numbers
# Modelo: [41.794697]
# Real:   [39.837]
# Diff:  [1.95769681]
# Different
# Modelo: [41.64285]
# Real:   [40.037]
# Diff:  [1.60584897]
# Different
# Modelo: [41.5336]
# Real:   [40.16]
# Diff:  [1.37359985]
# Same Numbers
# Modelo: [41.452957]
# Real:   [40.14]
# Diff:  [1.31295715]
# Same Numbers
# Modelo: [41.382046]
# Real:   [40.026]
# Diff:  [1.35604575]
# Same Numbers
# Modelo: [41.30804]
# Real:   [39.959]
# Diff:  [1.34904062]
# Same Numbers
# Modelo: [41.237396]
# Real:   [40.4]
# Diff:  [0.83739624]
# Same Numbers
# Modelo: [41.239323]
# Real:   [39.95]
# Diff:  [1.28932266]
# Same Numbers
# Modelo: [41.18629]
# Real:   [40.321]
# Diff:  [0.86529074]
# Same Numbers
# Modelo: [41.194664]
# Real:   [40.229]
# Diff:  [0.965664]
# Same Numbers
# Modelo: [41.194305]
# Real:   [39.809]
# Diff:  [1.38530542]
# Same Numbers
# Modelo: [41.140915]
# Real:   [39.889]
# Diff:  [1.25191492]
# Same Numbers
# Modelo: [41.10533]
# Real:   [39.792]
# Diff:  [1.31333142]
# Same Numbers
# Modelo: [41.061325]
# Real:   [39.88]
# Diff:  [1.18132507]
# Same Numbers
# Modelo: [41.03606]
# Real:   [39.591]
# Diff:  [1.44506033]
# Same Numbers
# Modelo: [40.97657]
# Real:   [39.293]
# Diff:  [1.68357013]
# Different
# Modelo: [40.884346]
# Real:   [39.694]
# Diff:  [1.19034601]
# Same Numbers
# Modelo: [40.857414]
# Real:   [39.68]
# Diff:  [1.17741425]
# Same Numbers
# Modelo: [40.834866]
# Real:   [39.743]
# Diff:  [1.09186557]
# Same Numbers
# Modelo: [40.828224]
# Real:   [39.626]
# Diff:  [1.20222418]
# Same Numbers
# Modelo: [40.810383]
# Real:   [42.53]
# Diff:  [-1.71961716]
# Different
# Modelo: [41.2699]
# Real:   [38.22]
# Diff:  [3.04990128]
# Different
# Modelo: [41.221893]
# Real:   [47.561]
# Diff:  [-6.33910669]
# Different
# Modelo: [42.298656]
# Real:   [48.207]
# Diff:  [-5.90834354]
# Different
# Modelo: [43.474262]
# Real:   [55.878]
# Diff:  [-12.40373776]
# Different
# Modelo: [45.462383]
# Real:   [51.09]
# Diff:  [-5.62761673]
# Different
# Modelo: [46.72549]
# Real:   [53.1]
# Diff:  [-6.37450943]
# Different
# Modelo: [48.03746]
# Real:   [53.651]
# Diff:  [-5.61353967]
# Different
# Modelo: [49.40383]
# Real:   [40.003]
# Diff:  [9.40083148]
# Different
# Modelo: [48.693775]
# Real:   [45.539]
# Diff:  [3.15477518]
# Different
# Modelo: [48.440086]
# Real:   [38.191]
# Diff:  [10.24908636]
# Different
# Modelo: [47.3506]
# Real:   [36.112]
# Diff:  [11.2386012]
# Different
# Modelo: [46.135666]
# Real:   [38.302]
# Diff:  [7.83366589]
# Different
# Modelo: [45.05386]
# Real:   [36.757]
# Diff:  [8.29685971]
# Different
# Modelo: [43.892418]
# Real:   [38.954]
# Diff:  [4.93841791]
# Different
# Modelo: [43.141193]
# Real:   [34.64]
# Diff:  [8.50119339]
# Different
# Modelo: [42.26074]
# Real:   [41.112]
# Diff:  [1.14873837]
# Same Numbers
# Modelo: [42.09982]
# Real:   [35.764]
# Diff:  [6.33581918]
# Different
# Modelo: [41.530045]
# Real:   [35.547]
# Diff:  [5.98304456]
# Different
# Modelo: [40.82745]
# Real:   [38.682]
# Diff:  [2.1454498]
# Different
# Modelo: [40.553204]
# Real:   [37.256]
# Diff:  [3.29720358]
# Different
# Modelo: [40.303997]
# Real:   [39.039]
# Diff:  [1.26499704]
# Same Numbers
# Modelo: [40.29634]
# Real:   [35.717]
# Diff:  [4.57934094]
# Different
# Modelo: [40.038864]
# Real:   [41.692]
# Diff:  [-1.65313586]
# Different
# Modelo: [40.46911]
# Real:   [41.816]
# Diff:  [-1.34689142]
# Same Numbers
# Modelo: [41.000893]
# Real:   [36.365]
# Diff:  [4.63589264]
# Different
# Modelo: [40.84877]
# Real:   [40.525]
# Diff:  [0.32377014]
# Same Numbers
# Modelo: [41.011936]
# Real:   [37.861]
# Diff:  [3.15093619]
# Different
# Modelo: [40.93639]
# Real:   [38.686]
# Diff:  [2.25038992]
# Different
# Modelo: [41.04545]
# Real:   [39.812]
# Diff:  [1.2334483]
# Same Numbers
# Modelo: [41.232048]
# Real:   [37.766]
# Diff:  [3.46604803]
# Different
# Modelo: [40.9903]
# Real:   [41.157]
# Diff:  [-0.16670078]
# Same Numbers
# Modelo: [41.092]
# Real:   [35.558]
# Diff:  [5.53399905]
# Different
# Modelo: [40.622574]
# Real:   [45.7]
# Diff:  [-5.07742615]
# Different
# Modelo: [41.398064]
# Real:   [38.309]
# Diff:  [3.08906366]
# Different
# Modelo: [41.287796]
# Real:   [34.23]
# Diff:  [7.05779602]
# Different
# Modelo: [40.643284]
# Real:   [36.715]
# Diff:  [3.92828384]
# Different
# Modelo: [40.28097]
# Real:   [38.479]
# Diff:  [1.80197153]
# Different
# Modelo: [40.173985]
# Real:   [37.77]
# Diff:  [2.40398453]
# Different
# Modelo: [40.06815]
# Real:   [38.281]
# Diff:  [1.78714957]
# Different
# Modelo: [40.040157]
# Real:   [37.822]
# Diff:  [2.21815732]
# Different
# Modelo: [39.956455]
# Real:   [41.026]
# Diff:  [-1.06954477]
# Same Numbers
# Modelo: [40.270653]
# Real:   [42.223]
# Diff:  [-1.95234723]
# Different
# Modelo: [40.714005]
# Real:   [42.744]
# Diff:  [-2.02999548]
# Different
# Modelo: [41.20863]
# Real:   [43.136]
# Diff:  [-1.92737039]
# Different
# Modelo: [41.680576]
# Real:   [40.908]
# Diff:  [0.77257632]
# Same Numbers
# Modelo: [41.788277]
# Real:   [42.95]
# Diff:  [-1.16172333]
# Same Numbers
# Modelo: [42.214138]
# Real:   [43.276]
# Diff:  [-1.06186197]
# Same Numbers
# Modelo: [42.599297]
# Real:   [40.61]
# Diff:  [1.98929657]
# Different
# Modelo: [42.575546]
# Real:   [39.596]
# Diff:  [2.97954626]
# Different
# Modelo: [42.40493]
# Real:   [40.484]
# Diff:  [1.92093011]
# Different
# Modelo: [42.31321]
# Real:   [43.988]
# Diff:  [-1.67479047]
# Different
# Modelo: [42.699886]
# Real:   [42.646]
# Diff:  [0.05388632]
# Same Numbers
# Modelo: [42.854527]
# Real:   [39.937]
# Diff:  [2.91752652]
# Different
# Modelo: [42.54177]
# Real:   [38.544]
# Diff:  [3.99777094]
# Different
# Modelo: [42.104366]
# Real:   [37.423]
# Diff:  [4.6813663]
# Different
# Modelo: [41.60252]
# Real:   [40.774]
# Diff:  [0.82851999]
# Same Numbers
# Modelo: [41.677906]
# Real:   [41.217]
# Diff:  [0.46090604]
# Same Numbers
# Modelo: [41.776608]
# Real:   [40.362]
# Diff:  [1.41460751]
# Same Numbers
# Modelo: [41.791046]
# Real:   [41.594]
# Diff:  [0.19704614]
# Same Numbers
# Modelo: [42.01843]
# Real:   [40.919]
# Diff:  [1.0994288]
# Same Numbers
# Modelo: [42.04881]
# Real:   [41.322]
# Diff:  [0.72680905]
# Same Numbers
# Modelo: [42.11117]
# Real:   [41.27]
# Diff:  [0.84117172]
# Same Numbers
# Modelo: [42.192112]
# Real:   [39.634]
# Diff:  [2.55811197]
# Different
# Modelo: [42.010002]
# Real:   [40.214]
# Diff:  [1.79600214]
# Different
# Modelo: [41.837322]
# Real:   [39.82]
# Diff:  [2.01732224]
# Different
# Modelo: [41.677578]
# Real:   [38.017]
# Diff:  [3.66057797]
# Different
# Modelo: [41.341316]
# Real:   [39.677]
# Diff:  [1.66431622]
# Different
# Modelo: [41.23762]
# Real:   [39.509]
# Diff:  [1.72862131]
# Different
# Modelo: [41.159035]
# Real:   [40.647]
# Diff:  [0.51203473]
# Same Numbers
# Modelo: [41.262512]
# Real:   [40.183]
# Diff:  [1.07951221]
# Same Numbers
# Modelo: [41.298145]
# Real:   [40.692]
# Diff:  [0.60614529]
# Same Numbers
# Modelo: [41.391716]
# Real:   [39.539]
# Diff:  [1.852716]
# Different
# Modelo: [41.307175]
# Real:   [40.304]
# Diff:  [1.00317468]
# Same Numbers
# Modelo: [41.31841]
# Real:   [40.37]
# Diff:  [0.94840897]
# Same Numbers
# Modelo: [41.325924]
# Real:   [39.671]
# Diff:  [1.65492392]
# Different
# Modelo: [41.23168]
# Real:   [39.83]
# Diff:  [1.40168182]
# Same Numbers
# Modelo: [41.162148]
# Real:   [39.74]
# Diff:  [1.42214752]
# Same Numbers
# Modelo: [41.08385]
# Real:   [39.787]
# Diff:  [1.29685086]
# Same Numbers
# Modelo: [41.02049]
# Real:   [39.525]
# Diff:  [1.49548874]
# Same Numbers
# Modelo: [40.930737]
# Real:   [39.814]
# Diff:  [1.11673654]
# Same Numbers
# Modelo: [40.893402]
# Real:   [40.069]
# Diff:  [0.8244021]
# Same Numbers
# Modelo: [40.900585]
# Real:   [39.648]
# Diff:  [1.25258517]
# Same Numbers
# Modelo: [40.85712]
# Real:   [39.133]
# Diff:  [1.72412051]
# Different
# Modelo: [40.752457]
# Real:   [39.629]
# Diff:  [1.12345667]
# Same Numbers
# Modelo: [40.727783]
# Real:   [39.266]
# Diff:  [1.4617832]
# Same Numbers
# Modelo: [40.65994]
# Real:   [39.771]
# Diff:  [0.88893881]
# Same Numbers
# Modelo: [40.672974]
# Real:   [39.433]
# Diff:  [1.23997363]
# Same Numbers
# Modelo: [40.64412]
# Real:   [40.003]
# Diff:  [0.64111926]
# Same Numbers
# Modelo: [40.7012]
# Real:   [39.472]
# Diff:  [1.22919858]
# Same Numbers
# Modelo: [40.68463]
# Real:   [39.531]
# Diff:  [1.15363135]
# Same Numbers
# Modelo: [40.680332]
# Real:   [39.282]
# Diff:  [1.39833218]
# Same Numbers
# Modelo: [40.642586]
# Real:   [39.471]
# Diff:  [1.17158575]
# Same Numbers
# Modelo: [40.634514]
# Real:   [39.123]
# Diff:  [1.51151385]
# Different
# Modelo: [40.58707]
# Real:   [39.961]
# Diff:  [0.62607047]
# Same Numbers
# Modelo: [40.75027]
# Real:   [40.57]
# Diff:  [0.18027084]
# Same Numbers
# Modelo: [40.926987]
# Real:   [39.199]
# Diff:  [1.72798669]
# Different
# Modelo: [40.94977]
# Real:   [42.499]
# Diff:  [-1.54922812]
# Different
# Modelo: [41.49632]
# Real:   [39.643]
# Diff:  [1.85331882]
# Different
# Modelo: [41.587776]
# Real:   [46.86]
# Diff:  [-5.27222382]
# Different
# Modelo: [42.457134]
# Real:   [48.837]
# Diff:  [-6.37986575]
# Different
# Modelo: [43.557358]
# Real:   [54.652]
# Diff:  [-11.09464221]
# Different
# Modelo: [45.361366]
# Real:   [52.908]
# Diff:  [-7.54663373]
# Different
# Modelo: [46.909832]
# Real:   [45.927]
# Diff:  [0.982832]
# Same Numbers
# Modelo: [47.569023]
# Real:   [44.386]
# Diff:  [3.18302313]
# Different
# Modelo: [47.516018]
# Real:   [44.317]
# Diff:  [3.19901791]
# Different
# Modelo: [47.457882]
# Real:   [38.08]
# Diff:  [9.37788193]
# Different
# Modelo: [46.615696]
# Real:   [39.55]
# Diff:  [7.06569595]
# Different
# Modelo: [45.837116]
# Real:   [36.584]
# Diff:  [9.25311624]
# Different
# Modelo: [44.705868]
# Real:   [40.498]
# Diff:  [4.20786777]
# Different
# Modelo: [44.164368]
# Real:   [36.703]
# Diff:  [7.46136768]
# Different
# Modelo: [43.384422]
# Real:   [34.665]
# Diff:  [8.7194223]
# Different
# Modelo: [42.379814]
# Real:   [39.532]
# Diff:  [2.84781415]
# Different
# Modelo: [41.849495]
# Real:   [36.291]
# Diff:  [5.55849493]
# Different
# Modelo: [41.296772]
# Real:   [39.915]
# Diff:  [1.381772]
# Same Numbers
# Modelo: [41.213272]
# Real:   [35.358]
# Diff:  [5.85527209]
# Different
# Modelo: [40.73234]
# Real:   [39.943]
# Diff:  [0.78934177]
# Same Numbers
# Modelo: [40.833195]
# Real:   [39.816]
# Diff:  [1.01719473]
# Same Numbers
# Modelo: [41.03357]
# Real:   [41.907]
# Diff:  [-0.87343066]
# Same Numbers
# Modelo: [41.446217]
# Real:   [37.536]
# Diff:  [3.91021658]
# Different
# Modelo: [41.365116]
# Real:   [43.065]
# Diff:  [-1.69988388]
# Different
# Modelo: [41.81344]
# Real:   [42.058]
# Diff:  [-0.24456158]
# Same Numbers
# Modelo: [42.261536]
# Real:   [40.269]
# Diff:  [1.99253564]
# Different
# Modelo: [42.506542]
# Real:   [46.605]
# Diff:  [-4.09845779]
# Different
# Modelo: [43.27766]
# Real:   [41.157]
# Diff:  [2.12066037]
# Different
# Modelo: [43.402634]
# Real:   [37.905]
# Diff:  [5.49763367]
# Different
# Modelo: [43.05368]
# Real:   [39.427]
# Diff:  [3.62668042]
# Different
# Modelo: [43.095985]
# Real:   [35.534]
# Diff:  [7.56198541]
# Different
# Modelo: [42.422417]
# Real:   [39.641]
# Diff:  [2.78141669]
# Different
# Modelo: [41.999615]
# Real:   [36.619]
# Diff:  [5.38061472]
# Different
# Modelo: [41.381947]
# Real:   [39.764]
# Diff:  [1.61794656]
# Different
# Modelo: [41.08085]
# Real:   [38.751]
# Diff:  [2.32984869]
# Different
# Modelo: [40.9128]
# Real:   [39.868]
# Diff:  [1.04479984]
# Same Numbers
# Modelo: [41.044483]
# Real:   [40.224]
# Diff:  [0.82048318]
# Same Numbers
# Modelo: [41.2267]
# Real:   [39.194]
# Diff:  [2.03269983]
# Different
# Modelo: [41.253]
# Real:   [40.113]
# Diff:  [1.13999835]
# Same Numbers
# Modelo: [41.337383]
# Real:   [41.133]
# Diff:  [0.20438327]
# Same Numbers
# Modelo: [41.493626]
# Real:   [43.527]
# Diff:  [-2.03337436]
# Different
# Modelo: [41.881474]
# Real:   [44.217]
# Diff:  [-2.33552646]
# Different
# Modelo: [42.388542]
# Real:   [42.011]
# Diff:  [0.37754218]
# Same Numbers
# Modelo: [42.611668]
# Real:   [43.188]
# Diff:  [-0.57633237]
# Same Numbers
# Modelo: [42.958317]
# Real:   [45.187]
# Diff:  [-2.2286832]
# Different
# Modelo: [43.478035]
# Real:   [45.923]
# Diff:  [-2.44496503]
# Different
# Modelo: [44.013973]
# Real:   [43.849]
# Diff:  [0.16497324]
# Same Numbers
# Modelo: [44.199135]
# Real:   [44.06]
# Diff:  [0.13913483]
# Same Numbers
# Modelo: [44.36058]
# Real:   [49.266]
# Diff:  [-4.90541956]
# Different
# Modelo: [45.11071]
# Real:   [54.688]
# Diff:  [-9.57728986]
# Different
# Modelo: [46.531208]
# Real:   [48.434]
# Diff:  [-1.90279196]
# Different
# Modelo: [47.044266]
# Real:   [43.778]
# Diff:  [3.26626575]
# Different
# Modelo: [46.853855]
# Real:   [41.98]
# Diff:  [4.87385513]
# Different
# Modelo: [46.350334]
# Real:   [41.886]
# Diff:  [4.46433417]
# Different
# Modelo: [45.820892]
# Real:   [41.835]
# Diff:  [3.98589233]
# Different
# Modelo: [45.32166]
# Real:   [41.975]
# Diff:  [3.34665909]
# Different
# Modelo: [44.95535]
# Real:   [41.615]
# Diff:  [3.34034897]
# Different
# Modelo: [44.517868]
# Real:   [41.335]
# Diff:  [3.18286804]
# Different
# Modelo: [44.065746]
# Real:   [42.424]
# Diff:  [1.64174631]
# Different
# Modelo: [43.86094]
# Real:   [42.373]
# Diff:  [1.48793903]
# Same Numbers
# Modelo: [43.741714]
# Real:   [42.25]
# Diff:  [1.49171448]
# Same Numbers
# Modelo: [43.59684]
# Real:   [41.755]
# Diff:  [1.8418399]
# Different
# Modelo: [43.4046]
# Real:   [41.978]
# Diff:  [1.42659824]
# Same Numbers
# Modelo: [43.279385]
# Real:   [40.936]
# Diff:  [2.34338461]
# Different
# Modelo: [43.05348]
# Real:   [41.409]
# Diff:  [1.64447824]
# Different
# Modelo: [42.93413]
# Real:   [41.551]
# Diff:  [1.38313162]
# Same Numbers
# Modelo: [42.869156]
# Real:   [40.523]
# Diff:  [2.34615588]
# Different
# Modelo: [42.696796]
# Real:   [41.363]
# Diff:  [1.33379642]
# Same Numbers
# Modelo: [42.64892]
# Real:   [41.161]
# Diff:  [1.48791815]
# Same Numbers
# Modelo: [42.500237]
# Real:   [41.259]
# Diff:  [1.24123651]
# Same Numbers
# Modelo: [42.459583]
# Real:   [40.775]
# Diff:  [1.68458328]
# Different
# Modelo: [42.40019]
# Real:   [40.864]
# Diff:  [1.53618845]
# Different
# Modelo: [42.277184]
# Real:   [41.077]
# Diff:  [1.20018353]
# Same Numbers
# Modelo: [42.225994]
# Real:   [41.129]
# Diff:  [1.09699411]
# Same Numbers
# Modelo: [42.22841]
# Real:   [40.38]
# Diff:  [1.84840881]
# Different
# Modelo: [42.14128]
# Real:   [40.152]
# Diff:  [1.98928113]
# Different
# Modelo: [42.024265]
# Real:   [40.743]
# Diff:  [1.28126529]
# Same Numbers
# Modelo: [41.985744]
# Real:   [39.777]
# Diff:  [2.20874448]
# Different
# Modelo: [41.810474]
# Real:   [40.039]
# Diff:  [1.7714744]
# Different
# Modelo: [41.679333]
# Real:   [40.152]
# Diff:  [1.52733273]
# Different
# Modelo: [41.57154]
# Real:   [40.002]
# Diff:  [1.56954083]
# Different
# Modelo: [41.45519]
# Real:   [40.169]
# Diff:  [1.28618875]
# Same Numbers
# Modelo: [41.376938]
# Real:   [39.912]
# Diff:  [1.46493787]
# Same Numbers
# Modelo: [41.277187]
# Real:   [40.143]
# Diff:  [1.13418735]
# Same Numbers
# Modelo: [41.2253]
# Real:   [40.119]
# Diff:  [1.10629984]
# Same Numbers
# Modelo: [41.18258]
# Real:   [40.016]
# Diff:  [1.16657904]
# Same Numbers
# Modelo: [41.13774]
# Real:   [40.218]
# Diff:  [0.91974109]
# Same Numbers
# Modelo: [41.131546]
# Real:   [39.846]
# Diff:  [1.28554602]
# Same Numbers
# Modelo: [41.08136]
# Real:   [39.662]
# Diff:  [1.41935986]
# Same Numbers
# Modelo: [41.015446]
# Real:   [39.792]
# Diff:  [1.22344571]
# Same Numbers
# Modelo: [40.97662]
# Real:   [39.691]
# Diff:  [1.28561972]
# Same Numbers
# Modelo: [40.931633]
# Real:   [39.812]
# Diff:  [1.119633]
# Same Numbers
# Modelo: [40.912037]
# Real:   [39.952]
# Diff:  [0.9600369]
# Same Numbers
# Modelo: [40.91811]
# Real:   [39.955]
# Diff:  [0.96310989]
# Same Numbers
# Modelo: [40.92889]
# Real:   [40.093]
# Diff:  [0.83589023]
# Same Numbers
# Modelo: [40.96153]
# Real:   [42.6]
# Diff:  [-1.63847122]
# Different
# Modelo: [41.48602]
# Real:   [41.991]
# Diff:  [-0.50498087]
# Same Numbers
# Modelo: [41.799446]
# Real:   [41.442]
# Diff:  [0.35744611]
# Same Numbers
# Modelo: [42.03857]
# Real:   [43.658]
# Diff:  [-1.6194296]
# Different
# Modelo: [42.415787]
# Real:   [40.165]
# Diff:  [2.25078674]
# Different
# Modelo: [42.51709]
# Real:   [42.812]
# Diff:  [-0.29491016]
# Same Numbers
# Modelo: [42.91191]
# Real:   [43.845]
# Diff:  [-0.93308899]
# Same Numbers
# Modelo: [43.47162]
# Real:   [49.775]
# Diff:  [-6.30338135]
# Different
# Modelo: [44.70967]
# Real:   [45.852]
# Diff:  [-1.14232898]
# Same Numbers
# Modelo: [45.0674]
# Real:   [44.033]
# Diff:  [1.03440189]
# Same Numbers
# Modelo: [45.328808]
# Real:   [36.189]
# Diff:  [9.13980783]
# Different
# Modelo: [44.637463]
# Real:   [38.133]
# Diff:  [6.50446262]
# Different
# Modelo: [44.08157]
# Real:   [38.968]
# Diff:  [5.11356967]
# Different
# Modelo: [43.51684]
# Real:   [37.213]
# Diff:  [6.30384189]
# Different
# Modelo: [42.841537]
# Real:   [38.828]
# Diff:  [4.01353748]
# Different
# Modelo: [42.432793]
# Real:   [43.063]
# Diff:  [-0.63020734]
# Same Numbers
# Modelo: [42.626038]
# Real:   [38.043]
# Diff:  [4.5830376]
# Different
# Modelo: [42.441925]
# Real:   [43.024]
# Diff:  [-0.58207495]
# Same Numbers
# Modelo: [42.801792]
# Real:   [38.614]
# Diff:  [4.18779214]
# Different
# Modelo: [42.684643]
# Real:   [43.031]
# Diff:  [-0.34635721]
# Same Numbers
# Modelo: [42.923523]
# Real:   [39.061]
# Diff:  [3.86252295]
# Different
# Modelo: [42.776283]
# Real:   [38.927]
# Diff:  [3.84928326]
# Different
# Modelo: [42.51822]
# Real:   [35.241]
# Diff:  [7.27721899]
# Different
# Modelo: [41.8966]
# Real:   [39.502]
# Diff:  [2.39459882]
# Different
# Modelo: [41.65758]
# Real:   [41.981]
# Diff:  [-0.32341867]
# Same Numbers
# Modelo: [41.72488]
# Real:   [39.763]
# Diff:  [1.96188022]
# Different
# Modelo: [41.69788]
# Real:   [44.164]
# Diff:  [-2.46612021]
# Different
# Modelo: [42.114655]
# Real:   [37.483]
# Diff:  [4.63165454]
# Different
# Modelo: [41.833115]
# Real:   [37.322]
# Diff:  [4.51111462]
# Different
# Modelo: [41.420555]
# Real:   [38.363]
# Diff:  [3.05755511]
# Different
# Modelo: [41.15896]
# Real:   [40.053]
# Diff:  [1.10595844]
# Same Numbers
# Modelo: [41.238117]
# Real:   [38.957]
# Diff:  [2.28111722]
# Different
# Modelo: [41.1098]
# Real:   [41.986]
# Diff:  [-0.87620157]
# Same Numbers
# Modelo: [41.292725]
# Real:   [40.29]
# Diff:  [1.00272461]
# Same Numbers
# Modelo: [41.44042]
# Real:   [42.745]
# Diff:  [-1.30458176]
# Same Numbers
# Modelo: [41.795666]
# Real:   [39.907]
# Diff:  [1.88866574]
# Different
# Modelo: [41.72657]
# Real:   [36.032]
# Diff:  [5.69457013]
# Different
# Modelo: [41.147972]
# Real:   [36.196]
# Diff:  [4.95197211]
# Different
# Modelo: [40.616173]
# Real:   [36.291]
# Diff:  [4.32517279]
# Different
# Modelo: [40.127506]
# Real:   [38.2]
# Diff:  [1.92750626]
# Different
# Modelo: [39.910576]
# Real:   [40.18]
# Diff:  [-0.26942413]
# Same Numbers
# Modelo: [39.9237]
# Real:   [40.973]
# Diff:  [-1.04930157]
# Same Numbers
# Modelo: [40.12757]
# Real:   [40.636]
# Diff:  [-0.50842889]
# Same Numbers
# Modelo: [40.354904]
# Real:   [41.071]
# Diff:  [-0.71609583]
# Same Numbers
# Modelo: [40.66861]
# Real:   [40.904]
# Diff:  [-0.23539038]
# Same Numbers
# Modelo: [40.93878]
# Real:   [41.373]
# Diff:  [-0.43421826]
# Same Numbers
# Modelo: [41.23284]
# Real:   [40.692]
# Diff:  [0.54084149]
# Same Numbers
# Modelo: [41.38373]
# Real:   [40.761]
# Diff:  [0.62273184]
# Same Numbers
# Modelo: [41.501595]
# Real:   [40.909]
# Diff:  [0.59259454]
# Same Numbers
# Modelo: [41.601757]
# Real:   [41.223]
# Diff:  [0.37875705]
# Same Numbers
# Modelo: [41.752056]
# Real:   [41.952]
# Diff:  [-0.19994388]
# Same Numbers
# Modelo: [41.96973]
# Real:   [41.086]
# Diff:  [0.88373038]
# Same Numbers
# Modelo: [42.017036]
# Real:   [42.072]
# Diff:  [-0.05496356]
# Same Numbers
# Modelo: [42.1739]
# Real:   [41.972]
# Diff:  [0.2019006]
# Same Numbers
# Modelo: [42.293655]
# Real:   [42.735]
# Diff:  [-0.4413446]
# Same Numbers
# Modelo: [42.5037]
# Real:   [42.152]
# Diff:  [0.35170026]
# Same Numbers
# Modelo: [42.614586]
# Real:   [41.463]
# Diff:  [1.15158588]
# Same Numbers
# Modelo: [42.61796]
# Real:   [41.805]
# Diff:  [0.81296188]
# Same Numbers
# Modelo: [42.637093]
# Real:   [42.491]
# Diff:  [0.14609259]
# Same Numbers
# Modelo: [42.72203]
# Real:   [42.399]
# Diff:  [0.32303064]
# Same Numbers
# Modelo: [42.81307]
# Real:   [42.601]
# Diff:  [0.21206839]
# Same Numbers
# Modelo: [42.93557]
# Real:   [41.88]
# Diff:  [1.05556976]
# Same Numbers
# Modelo: [42.948174]
# Real:   [41.978]
# Diff:  [0.97017352]
# Same Numbers
# Modelo: [42.964878]
# Real:   [41.318]
# Diff:  [1.64687808]
# Different
# Modelo: [42.91785]
# Real:   [41.063]
# ...
# Diff:  [3.32485376]
# Different
# Modelo: [39.115177]
# Real:   [36.399]
# Diff:  [2.71617715]
# Different
# Modelo: [38.89688]
# Real:   [36.505]
# Diff:  [2.3918811]
# Different
# Modelo: [38.721176]
# Real:   [36.256]
# Diff:  [2.46517615]
# Different
# Modelo: [38.531876]
# Real:   [36.393]
# Diff:  [2.13887561]
# Different
# Modelo: [38.382504]
# Real:   [36.242]
# Diff:  [2.14050351]
# Different
# Modelo: [38.22967]
# Real:   [36.194]
# Diff:  [2.03567148]
# Different
# Modelo: [38.08923]
# Real:   [37.512]
# Diff:  [0.57722958]
# Same Numbers
# Modelo: [38.153103]
# Real:   [43.147]
# Diff:  [-4.99389713]
# Different
# Modelo: [39.01558]
# Real:   [42.856]
# Diff:  [-3.84042078]
# Different
# Modelo: [39.779415]
# Real:   [43.051]
# Diff:  [-3.27158487]
# Different
# Modelo: [40.50783]
# Real:   [42.8]
# Diff:  [-2.29216843]
# Different
# Modelo: [41.114597]
# Real:   [45.305]
# Diff:  [-4.19040268]
# Different
# Modelo: [41.98607]
# Real:   [45.868]
# Diff:  [-3.88193127]
# Different
# Modelo: [42.82201]
# Real:   [42.337]
# Diff:  [0.48501004]
# Same Numbers
# Modelo: [43.043663]
# Real:   [45.553]
# Diff:  [-2.50933698]
# Different
# Modelo: [43.64613]
# Real:   [44.538]
# Diff:  [-0.89187039]
# Same Numbers
# Modelo: [44.001804]
# Real:   [38.613]
# Diff:  [5.38880435]
# Different
# Modelo: [43.448017]
# Real:   [38.683]
# Diff:  [4.76501712]
# Different
# Modelo: [42.903793]
# Real:   [38.916]
# Diff:  [3.98779333]
# Different
# Modelo: [42.40437]
# Real:   [39.045]
# Diff:  [3.35936935]
# Different
# Modelo: [41.962185]
# Real:   [38.758]
# Diff:  [3.20418491]
# Different
# Modelo: [41.5318]
# Real:   [38.754]
# Diff:  [2.77779932]
# Different
# Modelo: [41.160786]
# Real:   [38.764]
# Diff:  [2.39678568]
# Different
# Modelo: [40.849796]
# Real:   [38.676]
# Diff:  [2.1737963]
# Different
# Modelo: [40.581417]
# Real:   [38.5]
# Diff:  [2.08141708]
# Different
# Modelo: [40.338657]
# Real:   [38.972]
# Diff:  [1.36665738]
# Same Numbers
# Modelo: [40.208572]
# Real:   [38.805]
# Diff:  [1.40357239]
# Same Numbers
# Modelo: [40.08946]
# Real:   [38.732]
# Diff:  [1.35745847]
# Same Numbers
# Modelo: [39.990738]
# Real:   [38.314]
# Diff:  [1.67673792]
# Different
# Modelo: [39.85751]
# Real:   [38.363]
# Diff:  [1.49450961]
# Same Numbers
# Modelo: [39.755306]
# Real:   [38.346]
# Diff:  [1.40930624]
# Same Numbers
# Modelo: [39.67041]
# Real:   [38.27]
# Diff:  [1.40041016]
# Same Numbers
# Modelo: [39.592636]
# Real:   [38.617]
# Diff:  [0.97563611]
# Same Numbers
# Modelo: [39.58]
# Real:   [38.82]
# Diff:  [0.76000183]
# Same Numbers
# Modelo: [39.60593]
# Real:   [38.742]
# Diff:  [0.86393033]
# Same Numbers
# Modelo: [39.626328]
# Real:   [38.465]
# Diff:  [1.16132751]
# Same Numbers
# Modelo: [39.610775]
# Real:   [38.613]
# Diff:  [0.99777499]
# Same Numbers
# Modelo: [39.61949]
# Real:   [38.806]
# Diff:  [0.81349158]
# Same Numbers
# Modelo: [39.655823]
# Real:   [38.717]
# Diff:  [0.93882275]
# Same Numbers
# Modelo: [39.67787]
# Real:   [38.634]
# Diff:  [1.0438717]
# Same Numbers
# Modelo: [39.686813]
# Real:   [38.398]
# Diff:  [1.28881335]
# Same Numbers
# Modelo: [39.660988]
# Real:   [38.368]
# Diff:  [1.29298785]
# Same Numbers
# Modelo: [39.63197]
# Real:   [38.469]
# Diff:  [1.16296945]
# Same Numbers
# Modelo: [39.61899]
# Real:   [38.376]
# Diff:  [1.24299185]
# Same Numbers
# Modelo: [39.594574]
# Real:   [38.292]
# Diff:  [1.30257397]
# Same Numbers
# Modelo: [39.561523]
# Real:   [38.327]
# Diff:  [1.23452344]
# Same Numbers
# Modelo: [39.537342]
# Real:   [38.335]
# Diff:  [1.20234207]
# Same Numbers
# Modelo: [39.517883]
# Real:   [38.224]
# Diff:  [1.2938833]
# Same Numbers
# Modelo: [39.48633]
# Real:   [38.323]
# Diff:  [1.16332812]
# Same Numbers
# Modelo: [39.473206]
# Real:   [38.432]
# Diff:  [1.04120557]
# Same Numbers
# Modelo: [39.47843]
# Real:   [38.33]
# Diff:  [1.1484317]
# Same Numbers
# Modelo: [39.47091]
# Real:   [38.353]
# Diff:  [1.11790912]
# Same Numbers
# Modelo: [39.468735]
# Real:   [38.336]
# Diff:  [1.13273474]
# Same Numbers
# Modelo: [39.465168]
# Real:   [38.339]
# Diff:  [1.126168]
# Same Numbers
# Modelo: [39.46301]
# Real:   [38.444]
# Diff:  [1.01900888]
# Same Numbers
# Modelo: [39.47636]
# Real:   [38.26]
# Diff:  [1.21636032]
# Same Numbers
# Modelo: [39.46313]
# Real:   [38.39]
# Diff:  [1.07313095]
# Same Numbers
# Modelo: [39.469505]
# Real:   [38.339]
# Diff:  [1.13050531]
# Same Numbers
# Modelo: [39.46811]
# Real:   [38.236]
# Diff:  [1.23210913]
# Same Numbers
# Modelo: [39.45252]
# Real:   [38.185]
# Diff:  [1.26751846]
# Same Numbers
# Modelo: [39.43096]
# Real:   [38.347]
# Diff:  [1.08396161]
# Same Numbers
# Modelo: [39.43412]
# Real:   [38.366]
# Diff:  [1.06812018]
# Same Numbers
# Modelo: [39.440395]
# Real:   [38.197]
# Diff:  [1.24339536]
# Same Numbers
# Modelo: [39.423264]
# Real:   [38.17]
# Diff:  [1.25326355]
# Same Numbers
# Modelo: [39.404083]
# Real:   [38.271]
# Diff:  [1.13308325]
# Same Numbers
# Modelo: [39.400875]
# Real:   [38.206]
# Diff:  [1.19487509]
# Same Numbers
# Modelo: [39.38946]
# Real:   [38.158]
# Diff:  [1.23146152]
# Same Numbers
# Modelo: [39.3731]
# Real:   [38.352]
# Diff:  [1.02110028]
# Same Numbers
# Modelo: [39.38613]
# Real:   [38.506]
# Diff:  [0.88013129]
# Same Numbers
# Modelo: [39.42074]
# Real:   [38.54]
# Diff:  [0.88073822]
# Same Numbers
# Modelo: [39.458282]
# Real:   [38.345]
# Diff:  [1.11328247]
# Same Numbers
# Modelo: [39.47913]
# Real:   [38.658]
# Diff:  [0.82112979]
# Same Numbers
# Modelo: [39.55927]
# Real:   [38.451]
# Diff:  [1.10826895]
# Same Numbers
# Modelo: [39.648674]
# Real:   [39.089]
# Diff:  [0.55967401]
# Same Numbers
# Modelo: [39.767914]
# Real:   [38.814]
# Diff:  [0.95391382]
# Same Numbers
# Modelo: [39.80002]
# Real:   [36.408]
# Diff:  [3.39201831]
# Different
# Modelo: [39.419914]
# Real:   [36.341]
# Diff:  [3.07891425]
# Different
# Modelo: [39.08178]
# Real:   [34.11]
# Diff:  [4.97177948]
# Different
# Modelo: [38.504723]
# Real:   [36.079]
# Diff:  [2.4257226]
# Different
# Modelo: [38.238483]
# Real:   [36.315]
# Diff:  [1.92348343]
# Different
# Modelo: [38.084106]
# Real:   [36.336]
# Diff:  [1.74810645]
# Different
# Modelo: [37.98799]
# Real:   [35.951]
# Diff:  [2.03699133]
# Different
# Modelo: [37.87539]
# Real:   [36.161]
# Diff:  [1.7143891]
# Different
# Modelo: [37.84984]
# Real:   [36.022]
# Diff:  [1.82783826]
# Different
# Modelo: [37.782486]
# Real:   [36.241]
# Diff:  [1.54148596]
# Different
# Modelo: [37.73905]
# Real:   [35.864]
# Diff:  [1.87505182]
# Different
# Modelo: [37.64598]
# Real:   [35.981]
# Diff:  [1.66498083]
# Different
# Modelo: [37.58162]
# Real:   [36.223]
# Diff:  [1.35861926]
# Same Numbers
# Modelo: [37.563606]
# Real:   [36.071]
# Diff:  [1.49260626]
# Same Numbers
# Modelo: [37.55626]
# Real:   [36.155]
# Diff:  [1.40125916]
# Same Numbers
# Modelo: [37.579086]
# Real:   [36.084]
# Diff:  [1.4950863]
# Same Numbers
# Modelo: [37.571617]
# Real:   [36.603]
# Diff:  [0.96861713]
# Same Numbers
# Modelo: [37.630432]
# Real:   [36.149]
# Diff:  [1.48143213]
# Same Numbers
# Modelo: [37.624367]
# Real:   [36.137]
# Diff:  [1.48736676]
# Same Numbers
# Modelo: [37.621452]
# Real:   [36.255]
# Diff:  [1.36645233]
# Same Numbers
# Modelo: [37.639076]
# Real:   [36.103]
# Diff:  [1.53607623]
# Different
# Modelo: [37.638508]
# Real:   [36.263]
# Diff:  [1.37550784]
# Same Numbers
# Modelo: [37.663136]
# Real:   [36.281]
# Diff:  [1.38213553]
# Same Numbers
# Modelo: [37.690536]
# Real:   [36.026]
# Diff:  [1.6645365]
# Different
# Modelo: [37.68169]
# Real:   [36.715]
# Diff:  [0.96669022]
# Same Numbers
# Modelo: [37.768276]
# Real:   [36.337]
# Diff:  [1.43127621]
# Same Numbers
# Modelo: [37.796207]
# Real:   [35.232]
# Diff:  [2.56420743]
# Different
# Modelo: [37.653458]
# Real:   [36.081]
# Diff:  [1.57245764]
# Different
# Modelo: [37.607697]
# Real:   [34.963]
# Diff:  [2.64469653]
# Different
# Modelo: [37.43114]
# Real:   [35.827]
# Diff:  [1.6041409]
# Different
# Modelo: [37.369987]
# Real:   [37.951]
# Diff:  [-0.58101251]
# Same Numbers
# Modelo: [37.646343]
# Real:   [38.625]
# Diff:  [-0.97865677]
# Same Numbers
# Modelo: [38.016182]
# Real:   [39.14]
# Diff:  [-1.12381805]
# Same Numbers
# Modelo: [38.430912]
# Real:   [38.919]
# Diff:  [-0.48808798]
# Same Numbers
# Modelo: [38.767162]
# Real:   [39.105]
# Diff:  [-0.33783768]
# Same Numbers
# Modelo: [39.077614]
# Real:   [38.768]
# Diff:  [0.30961383]
# Same Numbers
# Modelo: [39.28603]
# Real:   [39.084]
# Diff:  [0.20202982]
# Same Numbers
# Modelo: [39.492424]
# Real:   [39.085]
# Diff:  [0.40742401]
# Same Numbers
# Modelo: [39.655235]
# Real:   [38.884]
# Diff:  [0.77123529]
# Same Numbers
# Modelo: [39.753662]
# Real:   [39.493]
# Diff:  [0.26066211]
# Same Numbers
# Modelo: [39.910107]
# Real:   [39.036]
# Diff:  [0.87410666]
# Same Numbers
# Modelo: [39.973488]
# Real:   [39.16]
# Diff:  [0.81348785]
# Same Numbers
# Modelo: [40.036106]
# Real:   [38.788]
# Diff:  [1.24810611]
# Same Numbers
# Modelo: [40.029392]
# Real:   [38.916]
# Diff:  [1.11339224]
# Same Numbers
# Modelo: [40.03224]
# Real:   [39.108]
# Diff:  [0.92424182]
# Same Numbers
# Modelo: [40.055397]
# Real:   [39.068]
# Diff:  [0.98739703]
# Same Numbers
# Modelo: [40.06757]
# Real:   [38.953]
# Diff:  [1.11456973]
# Same Numbers
# Modelo: [40.060383]
# Real:   [38.758]
# Diff:  [1.30238284]
# Same Numbers
# Modelo: [40.024372]
# Real:   [38.771]
# Diff:  [1.2533721]
# Same Numbers
# Modelo: [39.991734]
# Real:   [38.909]
# Diff:  [1.08273355]
# Same Numbers
# Modelo: [39.980927]
# Real:   [38.863]
# Diff:  [1.11792651]
# Same Numbers
# Modelo: [39.9656]
# Real:   [38.957]
# Diff:  [1.00859906]
# Same Numbers
# Modelo: [39.966393]
# Real:   [38.71]
# Diff:  [1.25639252]
# Same Numbers
# Modelo: [39.933674]
# Real:   [38.817]
# Diff:  [1.11667386]
# Same Numbers
# Modelo: [39.91987]
# Real:   [39.007]
# Diff:  [0.91286847]
# Same Numbers
# Modelo: [39.935]
# Real:   [38.955]
# Diff:  [0.98000137]
# Same Numbers
# Modelo: [39.943203]
# Real:   [39.053]
# Diff:  [0.89020297]
# Same Numbers
# Modelo: [39.965828]
# Real:   [38.585]
# Diff:  [1.38082794]
# Same Numbers
# Modelo: [39.92092]
# Real:   [38.436]
# Diff:  [1.48492133]
# Same Numbers
# Modelo: [39.858288]
# Real:   [38.761]
# Diff:  [1.09728781]
# Same Numbers
# Modelo: [39.846138]
# Real:   [38.47]
# Diff:  [1.376138]
# Same Numbers
# Modelo: [39.795338]
# Real:   [38.423]
# Diff:  [1.37233768]
# Same Numbers
# Modelo: [39.744457]
# Real:   [38.268]
# Diff:  [1.47645724]
# Same Numbers
# Modelo: [39.67795]
# Real:   [38.346]
# Diff:  [1.33195181]
# Same Numbers
# Modelo: [39.63066]
# Real:   [38.396]
# Diff:  [1.23466101]
# Same Numbers
# Modelo: [39.59774]
# Real:   [38.372]
# Diff:  [1.22574017]
# Same Numbers
# Modelo: [39.5682]
# Real:   [38.575]
# Diff:  [0.99319916]
# Same Numbers
# Modelo: [39.573578]
# Real:   [38.628]
# Diff:  [0.94557788]
# Same Numbers
# Modelo: [39.589443]
# Real:   [38.877]
# Diff:  [0.71244321]
# Same Numbers
# Modelo: [39.641968]
# Real:   [38.702]
# Diff:  [0.93996777]
# Same Numbers
# Modelo: [39.66708]
# Real:   [38.411]
# Diff:  [1.25607993]
# Same Numbers
# Modelo: [39.649174]
# Real:   [38.393]
# Diff:  [1.25617374]
# Same Numbers
# Modelo: [39.628635]
# Real:   [38.295]
# Diff:  [1.33363541]
# Same Numbers
# Modelo: [39.594513]
# Real:   [38.343]
# Diff:  [1.25151294]
# Same Numbers
# Modelo: [39.56968]
# Real:   [38.443]
# Diff:  [1.12667926]
# Same Numbers
# Modelo: [39.561665]
# Real:   [38.455]
# Diff:  [1.10666458]
# Same Numbers
# Modelo: [39.557507]
# Real:   [38.53]
# Diff:  [1.02750656]
# Same Numbers
# Modelo: [39.56589]
# Real:   [38.291]
# Diff:  [1.27489127]
# Same Numbers
# Modelo: [39.5411]
# Real:   [38.485]
# Diff:  [1.05609955]
# Same Numbers
# Modelo: [39.546368]
# Real:   [38.531]
# Diff:  [1.01536765]
# Same Numbers
# Modelo: [39.558163]
# Real:   [38.634]
# Diff:  [0.92416269]
# Same Numbers
# Modelo: [39.584423]
# Real:   [38.409]
# Diff:  [1.17542307]
# Same Numbers
# Modelo: [39.577175]
# Real:   [38.478]
# Diff:  [1.09917514]
# Same Numbers
# Modelo: [39.579906]
# Real:   [38.311]
# Diff:  [1.26890646]
# Same Numbers
# Modelo: [39.558064]
# Real:   [38.31]
# Diff:  [1.24806351]
# Same Numbers
# Modelo: [39.537468]
# Real:   [38.385]
# Diff:  [1.15246796]
# Same Numbers
# Modelo: [39.52901]
# Real:   [38.514]
# Diff:  [1.01501077]
# Same Numbers
# Modelo: [39.54011]
# Real:   [38.862]
# Diff:  [0.67811154]
# Same Numbers
# Modelo: [39.600502]
# Real:   [38.809]
# Diff:  [0.79150201]
# Same Numbers
# Modelo: [39.64945]
# Real:   [38.589]
# Diff:  [1.06044839]
# Same Numbers
# Modelo: [39.663208]
# Real:   [38.843]
# Diff:  [0.82020801]
# Same Numbers
# Modelo: [39.709663]
# Real:   [38.705]
# Diff:  [1.00466339]
# Same Numbers
# Modelo: [39.730427]
# Real:   [38.66]
# Diff:  [1.07042679]
# Same Numbers
# Modelo: [39.74098]
# Real:   [38.353]
# Diff:  [1.38797824]
# Same Numbers
# Modelo: [39.70473]
# Real:   [37.638]
# Diff:  [2.06673099]
# Different
# Modelo: [39.5682]
# Real:   [37.993]
# Diff:  [1.57519916]
# Different
# Modelo: [39.491123]
# Real:   [35.892]
# Diff:  [3.5991232]
# Different
# Modelo: [39.124866]
# Real:   [35.976]
# Diff:  [3.14886649]
# Different
# Modelo: [38.80367]
# Real:   [36.004]
# Diff:  [2.79966898]
# Different
# Modelo: [38.51913]
# Real:   [35.822]
# Diff:  [2.69713071]
# Different
# Modelo: [38.247326]
# Real:   [35.973]
# Diff:  [2.2743259]
# Different
# Modelo: [38.03795]
# Real:   [36.049]
# Diff:  [1.98894861]
# Different
# Modelo: [37.87668]
# Real:   [35.924]
# Diff:  [1.95267847]
# Different
# Modelo: [37.73123]
# Real:   [36.]
# Diff:  [1.73123169]
# Different
# Modelo: [37.626637]
# Real:   [36.133]
# Diff:  [1.49363651]
# Same Numbers
# Modelo: [37.565216]
# Real:   [35.882]
# Diff:  [1.68321606]
# Different
# Modelo: [37.487335]
# Real:   [36.018]
# Diff:  [1.46933521]
# Same Numbers
# Modelo: [37.446175]
# Real:   [36.124]
# Diff:  [1.32217462]
# Same Numbers
# Modelo: [37.432198]
# Real:   [35.889]
# Diff:  [1.54319757]
# Different
# Modelo: [37.393948]
# Real:   [36.049]
# Diff:  [1.3449476]
# Same Numbers
# Modelo: [37.387062]
# Real:   [36.075]
# Diff:  [1.31206207]
# Same Numbers
# Modelo: [37.388638]
# Real:   [36.146]
# Diff:  [1.24263754]
# Same Numbers
# Modelo: [37.403763]
# Real:   [36.204]
# Diff:  [1.19976282]
# Same Numbers
# Modelo: [37.42837]
# Real:   [35.996]
# Diff:  [1.43237143]
# Same Numbers
# Modelo: [37.423218]
# Real:   [36.156]
# Diff:  [1.26721777]
# Same Numbers
# Modelo: [37.441395]
# Real:   [36.031]
# Diff:  [1.41039481]
# Same Numbers
# Modelo: [37.440334]
# Real:   [36.364]
# Diff:  [1.07633432]
# Same Numbers
# Modelo: [37.4862]
# Real:   [36.003]
# Diff:  [1.48319843]
# Same Numbers
# Modelo: [37.477303]
# Real:   [36.14]
# Diff:  [1.33730255]
# Same Numbers
# Modelo: [37.487896]
# Real:   [36.048]
# Diff:  [1.43989597]
# Same Numbers
# Modelo: [37.483418]
# Real:   [35.809]
# Diff:  [1.67441751]
# Different
# Modelo: [37.44504]
# Real:   [35.793]
# Diff:  [1.65204166]
# Different
# Modelo: [37.406864]
# Real:   [36.333]
# Diff:  [1.07386417]
# Same Numbers
# Modelo: [37.447838]
# Real:   [35.747]
# Diff:  [1.70083783]
# Different
# Modelo: [37.404522]
# Real:   [35.9]
# Diff:  [1.50452194]
# Different
# Modelo: [37.387558]
# Real:   [35.788]
# Diff:  [1.59955798]
# Different
# Modelo: [37.35636]
# Real:   [36.277]
# Diff:  [1.07936139]
# Same Numbers
# Modelo: [37.397747]
# Real:   [38.027]
# Diff:  [-0.62925296]
# Same Numbers
# Modelo: [37.68395]
# Real:   [38.887]
# Diff:  [-1.20305148]
# Same Numbers
# Modelo: [38.070606]
# Real:   [38.761]
# Diff:  [-0.69039377]
# Same Numbers
# Modelo: [38.40702]
# Real:   [39.185]
# Diff:  [-0.77797943]
# Same Numbers
# Modelo: [38.76543]
# Real:   [39.057]
# Diff:  [-0.29156955]
# Same Numbers
# Modelo: [39.058598]
# Real:   [38.697]
# Diff:  [0.36159756]
# Same Numbers
# Modelo: [39.255447]
# Real:   [38.446]
# Diff:  [0.80944739]
# Same Numbers
# Modelo: [39.37687]
# Real:   [38.76]
# Diff:  [0.6168692]
# Same Numbers
# Modelo: [39.509693]
# Real:   [38.994]
# Diff:  [0.51569315]
# Same Numbers
# Modelo: [39.645527]
# Real:   [39.027]
# Diff:  [0.61852689]
# Same Numbers
# Modelo: [39.759792]
# Real:   [38.644]
# Diff:  [1.11579233]
# Same Numbers
# Modelo: [39.79744]
# Real:   [38.42]
# Diff:  [1.37743958]
# Same Numbers
# Modelo: [39.78804]
# Real:   [38.528]
# Diff:  [1.26004016]
# Same Numbers
# Modelo: [39.783928]
# Real:   [38.313]
# Diff:  [1.47092792]
# Same Numbers
# Modelo: [39.74245]
# Real:   [38.273]
# Diff:  [1.46945071]
# Same Numbers
# Modelo: [39.694347]
# Real:   [38.848]
# Diff:  [0.84634738]
# Same Numbers
# Modelo: [39.728962]
# Real:   [38.98]
# Diff:  [0.74896194]
# Same Numbers
# Modelo: [39.77951]
# Real:   [38.676]
# Diff:  [1.1035105]
# Same Numbers
# Modelo: [39.783974]
# Real:   [38.451]
# Diff:  [1.33297369]
# Same Numbers
# Modelo: [39.755344]
# Real:   [38.424]
# Diff:  [1.33134439]
# Same Numbers
# Modelo: [39.72306]
# Real:   [38.288]
# Diff:  [1.43506061]
# Same Numbers
# Modelo: [39.672832]
# Real:   [38.932]
# Diff:  [0.74083249]
# Same Numbers
# Modelo: [39.71758]
# Real:   [39.218]
# Diff:  [0.49957889]
# Same Numbers
# Modelo: [39.8005]
# Real:   [38.82]
# Diff:  [0.98049896]
# Same Numbers
# Modelo: [39.822357]
# Real:   [38.481]
# Diff:  [1.34135718]
# Same Numbers
# Modelo: [39.79376]
# Real:   [38.313]
# Diff:  [1.48075839]
# Same Numbers
# Modelo: [39.740795]
# Real:   [38.493]
# Diff:  [1.24779514]
# Same Numbers
# Modelo: [39.71526]
# Real:   [38.577]
# Diff:  [1.13825955]
# Same Numbers
# Modelo: [39.70347]
# Real:   [38.619]
# Diff:  [1.08446832]
# Same Numbers
# Quantity of same numbers:  1630  records
# Quantity of different numbers:  904  records
# Percentage:  64.3 %
