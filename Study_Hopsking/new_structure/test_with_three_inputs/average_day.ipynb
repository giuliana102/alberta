# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
# Out:
# C:\Users\lagg\AppData\Local\Temp\ipykernel_25280\388347847.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["Vacation"]
del df["summer_classes"]
del df["Theres_sun"]
del df["temp_ant"]
del df["Average_hour_month"]
del df["month"]
del df["Timestamp"]

df
# Out:
#        RealPower  EV_Power  Average_hour_day_ant
# 0         51.488       0.0              51.17875
# 1         51.794       0.0              51.17875
# 2         51.397       0.0              51.17875
# 3         50.765       0.0              51.17875
# 4         51.206       0.0              51.05075
# ...          ...       ...                   ...
# 26299     38.313       0.0              38.95800
# 26300     38.493       0.0              38.56300
# 26301     38.577       0.0              38.56300
# 26302     38.619       0.0              38.56300
# 26303     38.394       0.0              38.56300
#
# [26304 rows x 3 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
#df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power  Average_hour_day_ant
# count  26304.000000  26304.000000          26304.000000
# mean      48.307932      6.167214             48.365179
# std        5.717560      9.099070              5.451674
# min       -1.161000     -6.400000             24.301250
# 25%       45.886000      0.000000             46.230312
# 50%       48.319000      0.000000             48.350000
# 75%       51.776500      9.480000             51.845500
# max       82.339000     55.150000             75.317750

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (21043, 3)
# Validation set size: (2630, 3)
# Testing set size: (2631, 3)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20946, 96, 3), y_tr: (20946, 1, 1)
# Set de validación - x_vl: (2533, 96, 3), y_vl: (2533, 1, 1)
# Set de prueba - x_ts: (2534, 96, 3), y_ts: (2534, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488  ,  0.     , 51.17875],
#        [51.794  ,  0.     , 51.17875],
#        [51.397  ,  0.     , 51.17875],
#        [50.765  ,  0.     , 51.17875],
#        [51.206  ,  0.     , 51.05075],
#        [51.219  ,  0.     , 51.05075],
#        [50.654  ,  0.     , 51.05075],
#        [50.491  ,  0.     , 51.05075],
#        [50.577  ,  0.     , 50.98025],
#        [50.654  ,  0.     , 50.98025],
#        [50.275  ,  0.     , 50.98025],
#        [50.022  ,  0.     , 50.98025],
#        [49.987  ,  0.     , 51.11675],
#        [50.443  ,  0.     , 51.11675],
#        [50.345  ,  0.     , 51.11675],
#        [50.239  ,  0.     , 51.11675],
#        [50.716  ,  0.     , 50.65825],
#        [50.673  ,  0.     , 50.65825],
#        [50.407  ,  0.     , 50.65825],
#        [50.605  ,  0.     , 50.65825],
#        [50.733  ,  0.     , 52.50525],
#        [52.101  ,  0.     , 52.50525],
#        [52.23   ,  0.     , 52.50525],
#        [53.73   ,  0.     , 52.50525],
#        [53.611  ,  0.     , 53.2305 ],
#        [53.646  ,  0.     , 53.2305 ],
#        [53.21   ,  0.     , 53.2305 ],
#        [53.806  ,  0.     , 53.2305 ],
#        [53.582  ,  0.     , 54.05325],
#        [52.526  ,  0.     , 54.05325],
#        [49.983  ,  5.2    , 54.05325],
#        [50.513  ,  8.11   , 54.05325],
#        [53.22   , 11.01   , 52.93675],
#        [55.027  , 16.35   , 52.93675],
#        [53.067  , 17.54   , 52.93675],
#        [52.949  , 22.48   , 52.93675],
#        [51.79   , 23.2    , 52.32525],
#        [50.477  , 22.37   , 52.32525],
#        [48.413  , 29.37   , 52.32525],
#        [50.593  , 25.27   , 52.32525],
#        [51.712  , 28.57   , 51.233  ],
#        [49.816  , 33.57   , 51.233  ],
#        [54.568  , 22.7    , 51.233  ],
#        [59.61   , 15.93   , 51.233  ],
#        [56.574  , 10.3    , 53.382  ],
#        [52.774  ,  9.7    , 53.382  ],
#        [56.809  ,  9.7    , 53.382  ],
#        [51.718  ,  5.7    , 53.382  ],
#        [53.128  ,  3.18   , 56.719  ],
#        [54.716  , 12.23   , 56.719  ],
#        [48.839  , 13.79   , 56.719  ],
#        [53.15   , 18.32   , 56.719  ],
#        [56.602  , 10.62   , 64.79775],
#        [67.519  , 21.57   , 64.79775],
#        [65.695  , 24.67   , 64.79775],
#        [62.946  , 11.98   , 64.79775],
#        [50.613  , 11.69   , 58.65425],
#        [48.255  , 10.14   , 58.65425],
#        [46.57   ,  8.14   , 58.65425],
#        [45.438  ,  8.54   , 58.65425],
#        [59.025  ,  7.12   , 51.72725],
#        [57.188  ,  7.27   , 51.72725],
#        [59.485  , 10.95   , 51.72725],
#        [59.79   , 16.3    , 51.72725],
#        [59.683  , 14.12   , 55.278  ],
#        [59.392  ,  8.99   , 55.278  ],
#        [57.961  ,  8.59   , 55.278  ],
#        [58.789  ,  6.     , 55.278  ],
#        [61.564  ,  5.53   , 53.22725],
#        [54.152  ,  5.53   , 53.22725],
#        [54.354  ,  5.53   , 53.22725],
#        [55.792  ,  5.53   , 53.22725],
#        [53.667  ,  5.53   , 50.2135 ],
#        [55.323  ,  5.53   , 50.2135 ],
#        [53.986  ,  5.06   , 50.2135 ],
#        [53.523  ,  4.3    , 50.2135 ],
#        [56.197  ,  5.07   , 52.95475],
#        [56.316  , 12.39   , 52.95475],
#        [57.141  , 15.58   , 52.95475],
#        [56.48   , 15.58   , 52.95475],
#        [56.714  , 14.87   , 54.2575 ],
#        [56.187  , 12.17   , 54.2575 ],
#        [55.675  , 19.89   , 54.2575 ],
#        [57.27   , 14.77   , 54.2575 ],
#        [55.669  ,  9.07   , 55.98625],
#        [56.501  ,  9.07   , 55.98625],
#        [55.379  ,  9.07   , 55.98625],
#        [53.727  ,  4.67   , 55.98625],
#        [53.533  ,  0.4    , 52.03325],
#        [53.248  ,  0.     , 52.03325],
#        [52.776  ,  0.     , 52.03325],
#        [52.309  ,  0.     , 52.03325],
#        [52.465  ,  0.     , 51.53925],
#        [51.948  ,  0.     , 51.53925],
#        [51.993  ,  0.     , 51.53925],
#        [51.682  ,  0.     , 51.53925]])

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]])

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -0.8830219333874898
# Maximun value per dimension: 0.8385052802599514

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (3):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 110 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/110
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 24s - loss: 0.1876 - accuracy: 0.0000e+00 - val_loss: 0.0779 - val_accuracy: 0.0000e+00 - 24s/epoch - 297ms/step
# Epoch 2/110
# 82/82 - 21s - loss: 0.1502 - accuracy: 0.0000e+00 - val_loss: 0.0901 - val_accuracy: 0.0000e+00 - 21s/epoch - 252ms/step
# Epoch 3/110
# 82/82 - 21s - loss: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1078 - val_accuracy: 0.0000e+00 - 21s/epoch - 259ms/step
# Epoch 4/110
# 82/82 - 21s - loss: 0.1032 - accuracy: 0.0000e+00 - val_loss: 0.1125 - val_accuracy: 0.0000e+00 - 21s/epoch - 259ms/step
# Epoch 5/110
# 82/82 - 21s - loss: 0.0945 - accuracy: 0.0000e+00 - val_loss: 0.1009 - val_accuracy: 0.0000e+00 - 21s/epoch - 256ms/step
# Epoch 6/110
# 82/82 - 20s - loss: 0.0869 - accuracy: 0.0000e+00 - val_loss: 0.0883 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 7/110
# 82/82 - 21s - loss: 0.0802 - accuracy: 0.0000e+00 - val_loss: 0.0772 - val_accuracy: 0.0000e+00 - 21s/epoch - 250ms/step
# Epoch 8/110
# 82/82 - 21s - loss: 0.0749 - accuracy: 0.0000e+00 - val_loss: 0.0682 - val_accuracy: 0.0000e+00 - 21s/epoch - 252ms/step
# Epoch 9/110
# 82/82 - 21s - loss: 0.0709 - accuracy: 0.0000e+00 - val_loss: 0.0628 - val_accuracy: 0.0000e+00 - 21s/epoch - 256ms/step
# Epoch 10/110
# 82/82 - 21s - loss: 0.0681 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00 - 21s/epoch - 253ms/step
# Epoch 11/110
# 82/82 - 21s - loss: 0.0662 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00 - 21s/epoch - 252ms/step
# Epoch 12/110
# 82/82 - 21s - loss: 0.0651 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 21s/epoch - 257ms/step
# Epoch 13/110
# 82/82 - 22s - loss: 0.0644 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00 - 22s/epoch - 270ms/step
# Epoch 14/110
# 82/82 - 21s - loss: 0.0638 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 21s/epoch - 259ms/step
# Epoch 15/110
# 82/82 - 21s - loss: 0.0634 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00 - 21s/epoch - 254ms/step
# Epoch 16/110
# 82/82 - 21s - loss: 0.0631 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00 - 21s/epoch - 256ms/step
# Epoch 17/110
# 82/82 - 20s - loss: 0.0630 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00 - 20s/epoch - 249ms/step
# Epoch 18/110
# 82/82 - 20s - loss: 0.0625 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 19/110
# 82/82 - 24s - loss: 0.0625 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00 - 24s/epoch - 287ms/step
# Epoch 20/110
# 82/82 - 24s - loss: 0.0622 - accuracy: 4.7742e-05 - val_loss: 0.0577 - val_accuracy: 0.0000e+00 - 24s/epoch - 287ms/step
# Epoch 21/110
# 82/82 - 20s - loss: 0.0621 - accuracy: 4.7742e-05 - val_loss: 0.0571 - val_accuracy: 0.0000e+00 - 20s/epoch - 246ms/step
# Epoch 22/110
# 82/82 - 19s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0566 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 23/110
# 82/82 - 20s - loss: 0.0618 - accuracy: 4.7742e-05 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 20s/epoch - 246ms/step
# Epoch 24/110
# 82/82 - 20s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0569 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 25/110
# 82/82 - 21s - loss: 0.0614 - accuracy: 4.7742e-05 - val_loss: 0.0562 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 26/110
# 82/82 - 25s - loss: 0.0614 - accuracy: 4.7742e-05 - val_loss: 0.0558 - val_accuracy: 0.0000e+00 - 25s/epoch - 299ms/step
# Epoch 27/110
# 82/82 - 20s - loss: 0.0610 - accuracy: 4.7742e-05 - val_loss: 0.0559 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 28/110
# 82/82 - 21s - loss: 0.0610 - accuracy: 4.7742e-05 - val_loss: 0.0557 - val_accuracy: 0.0000e+00 - 21s/epoch - 250ms/step
# Epoch 29/110
# 82/82 - 19s - loss: 0.0608 - accuracy: 4.7742e-05 - val_loss: 0.0556 - val_accuracy: 0.0000e+00 - 19s/epoch - 234ms/step
# Epoch 30/110
# 82/82 - 21s - loss: 0.0607 - accuracy: 4.7742e-05 - val_loss: 0.0548 - val_accuracy: 0.0000e+00 - 21s/epoch - 252ms/step
# Epoch 31/110
# 82/82 - 20s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0556 - val_accuracy: 0.0000e+00 - 20s/epoch - 241ms/step
# Epoch 32/110
# 82/82 - 23s - loss: 0.0604 - accuracy: 4.7742e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 23s/epoch - 281ms/step
# Epoch 33/110
# 82/82 - 20s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 34/110
# 82/82 - 19s - loss: 0.0603 - accuracy: 4.7742e-05 - val_loss: 0.0540 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 35/110
# 82/82 - 20s - loss: 0.0602 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 20s/epoch - 238ms/step
# Epoch 36/110
# 82/82 - 20s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0534 - val_accuracy: 0.0000e+00 - 20s/epoch - 242ms/step
# Epoch 37/110
# 82/82 - 20s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 20s/epoch - 243ms/step
# Epoch 38/110
# 82/82 - 19s - loss: 0.0599 - accuracy: 4.7742e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 39/110
# 82/82 - 19s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 40/110
# 82/82 - 19s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0535 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 41/110
# 82/82 - 19s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0532 - val_accuracy: 0.0000e+00 - 19s/epoch - 235ms/step
# Epoch 42/110
# 82/82 - 21s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0529 - val_accuracy: 0.0000e+00 - 21s/epoch - 251ms/step
# Epoch 43/110
# 82/82 - 21s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0526 - val_accuracy: 0.0000e+00 - 21s/epoch - 262ms/step
# Epoch 44/110
# 82/82 - 20s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0527 - val_accuracy: 0.0000e+00 - 20s/epoch - 250ms/step
# Epoch 45/110
# 82/82 - 19s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0524 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 46/110
# 82/82 - 19s - loss: 0.0593 - accuracy: 4.7742e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 19s/epoch - 234ms/step
# Epoch 47/110
# 82/82 - 19s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 19s/epoch - 233ms/step
# Epoch 48/110
# 82/82 - 19s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 19s/epoch - 235ms/step
# Epoch 49/110
# 82/82 - 21s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 21s/epoch - 257ms/step
# Epoch 50/110
# 82/82 - 24s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 24s/epoch - 296ms/step
# Epoch 51/110
# 82/82 - 23s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 23s/epoch - 280ms/step
# Epoch 52/110
# 82/82 - 22s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0509 - val_accuracy: 0.0000e+00 - 22s/epoch - 266ms/step
# Epoch 53/110
# 82/82 - 24s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 24s/epoch - 290ms/step
# Epoch 54/110
# 82/82 - 21s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 21s/epoch - 262ms/step
# Epoch 55/110
# 82/82 - 24s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0511 - val_accuracy: 0.0000e+00 - 24s/epoch - 287ms/step
# Epoch 56/110
# 82/82 - 24s - loss: 0.0587 - accuracy: 4.7742e-05 - val_loss: 0.0510 - val_accuracy: 0.0000e+00 - 24s/epoch - 294ms/step
# Epoch 57/110
# 82/82 - 25s - loss: 0.0584 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 25s/epoch - 306ms/step
# Epoch 58/110
# 82/82 - 30s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0506 - val_accuracy: 0.0000e+00 - 30s/epoch - 366ms/step
# Epoch 59/110
# 82/82 - 32s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 32s/epoch - 387ms/step
# Epoch 60/110
# 82/82 - 33s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0506 - val_accuracy: 0.0000e+00 - 33s/epoch - 397ms/step
# Epoch 61/110
# 82/82 - 32s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0507 - val_accuracy: 0.0000e+00 - 32s/epoch - 388ms/step
# Epoch 62/110
# 82/82 - 32s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 32s/epoch - 388ms/step
# Epoch 63/110
# 82/82 - 33s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0504 - val_accuracy: 0.0000e+00 - 33s/epoch - 398ms/step
# Epoch 64/110
# 82/82 - 32s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 32s/epoch - 388ms/step
# Epoch 65/110
# 82/82 - 42s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 42s/epoch - 513ms/step
# Epoch 66/110
# 82/82 - 42s - loss: 0.0581 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 42s/epoch - 508ms/step
# Epoch 67/110
# 82/82 - 45s - loss: 0.0581 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 68/110
# 82/82 - 45s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 45s/epoch - 546ms/step
# Epoch 69/110
# 82/82 - 45s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0502 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 70/110
# 82/82 - 44s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0498 - val_accuracy: 0.0000e+00 - 44s/epoch - 541ms/step
# Epoch 71/110
# 82/82 - 44s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 44s/epoch - 542ms/step
# Epoch 72/110
# 82/82 - 43s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 43s/epoch - 528ms/step
# Epoch 73/110
# 82/82 - 45s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0496 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 74/110
# 82/82 - 44s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0498 - val_accuracy: 0.0000e+00 - 44s/epoch - 536ms/step
# Epoch 75/110
# 82/82 - 45s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0496 - val_accuracy: 0.0000e+00 - 45s/epoch - 543ms/step
# Epoch 76/110
# 82/82 - 45s - loss: 0.0577 - accuracy: 4.7742e-05 - val_loss: 0.0495 - val_accuracy: 0.0000e+00 - 45s/epoch - 543ms/step
# Epoch 77/110
# 82/82 - 45s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 78/110
# 82/82 - 45s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0497 - val_accuracy: 0.0000e+00 - 45s/epoch - 543ms/step
# Epoch 79/110
# 82/82 - 45s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0493 - val_accuracy: 0.0000e+00 - 45s/epoch - 546ms/step
# Epoch 80/110
# 82/82 - 44s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0494 - val_accuracy: 0.0000e+00 - 44s/epoch - 535ms/step
# Epoch 81/110
# 82/82 - 45s - loss: 0.0574 - accuracy: 4.7742e-05 - val_loss: 0.0489 - val_accuracy: 0.0000e+00 - 45s/epoch - 544ms/step
# Epoch 82/110
# 82/82 - 44s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0496 - val_accuracy: 0.0000e+00 - 44s/epoch - 541ms/step
# Epoch 83/110
# 82/82 - 44s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0488 - val_accuracy: 0.0000e+00 - 44s/epoch - 536ms/step
# Epoch 84/110
# 82/82 - 44s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0490 - val_accuracy: 0.0000e+00 - 44s/epoch - 536ms/step
# Epoch 85/110
# 82/82 - 44s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0487 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 86/110
# 82/82 - 44s - loss: 0.0572 - accuracy: 4.7742e-05 - val_loss: 0.0485 - val_accuracy: 0.0000e+00 - 44s/epoch - 533ms/step
# Epoch 87/110
# 82/82 - 45s - loss: 0.0572 - accuracy: 4.7742e-05 - val_loss: 0.0488 - val_accuracy: 0.0000e+00 - 45s/epoch - 544ms/step
# Epoch 88/110
# 82/82 - 45s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0485 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 89/110
# 82/82 - 45s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0495 - val_accuracy: 0.0000e+00 - 45s/epoch - 553ms/step
# Epoch 90/110
# 82/82 - 44s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0486 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 91/110
# 82/82 - 44s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0486 - val_accuracy: 0.0000e+00 - 44s/epoch - 537ms/step
# Epoch 92/110
# 82/82 - 44s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0489 - val_accuracy: 0.0000e+00 - 44s/epoch - 542ms/step
# Epoch 93/110
# 82/82 - 45s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0488 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 94/110
# 82/82 - 45s - loss: 0.0570 - accuracy: 4.7742e-05 - val_loss: 0.0488 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 95/110
# 82/82 - 46s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0486 - val_accuracy: 0.0000e+00 - 46s/epoch - 558ms/step
# Epoch 96/110
# 82/82 - 45s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0480 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 97/110
# 82/82 - 45s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0481 - val_accuracy: 0.0000e+00 - 45s/epoch - 551ms/step
# Epoch 98/110
# 82/82 - 44s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0478 - val_accuracy: 0.0000e+00 - 44s/epoch - 542ms/step
# Epoch 99/110
# 82/82 - 45s - loss: 0.0568 - accuracy: 4.7742e-05 - val_loss: 0.0477 - val_accuracy: 0.0000e+00 - 45s/epoch - 554ms/step
# Epoch 100/110
# 82/82 - 44s - loss: 0.0568 - accuracy: 4.7742e-05 - val_loss: 0.0480 - val_accuracy: 0.0000e+00 - 44s/epoch - 534ms/step
# Epoch 101/110
# 82/82 - 44s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0483 - val_accuracy: 0.0000e+00 - 44s/epoch - 532ms/step
# Epoch 102/110
# 82/82 - 44s - loss: 0.0568 - accuracy: 4.7742e-05 - val_loss: 0.0480 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 103/110
# 82/82 - 44s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0477 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 104/110
# 82/82 - 43s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0480 - val_accuracy: 0.0000e+00 - 43s/epoch - 530ms/step
# Epoch 105/110
# 82/82 - 47s - loss: 0.0566 - accuracy: 4.7742e-05 - val_loss: 0.0481 - val_accuracy: 0.0000e+00 - 47s/epoch - 574ms/step
# Epoch 106/110
# 82/82 - 41s - loss: 0.0566 - accuracy: 4.7742e-05 - val_loss: 0.0477 - val_accuracy: 0.0000e+00 - 41s/epoch - 505ms/step
# Epoch 107/110
# 82/82 - 42s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0486 - val_accuracy: 0.0000e+00 - 42s/epoch - 516ms/step
# Epoch 108/110
# 82/82 - 45s - loss: 0.0566 - accuracy: 4.7742e-05 - val_loss: 0.0478 - val_accuracy: 0.0000e+00 - 45s/epoch - 553ms/step
# Epoch 109/110
# 82/82 - 43s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0480 - val_accuracy: 0.0000e+00 - 43s/epoch - 530ms/step
# Epoch 110/110
# 82/82 - 44s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0477 - val_accuracy: 0.0000e+00 - 44s/epoch - 538ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 655/655 [==============================] - 38s 47ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.046
#   RMSE val:	 0.042
#   RMSE test:	 0.042

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 80/80 [==============================] - 4s 46ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values
# Out:
# array([[39.39442 ],
#        [39.358746],
#        [39.30738 ],
#        [39.36067 ],
#        [39.4632  ],
#        [39.493416],
#        [39.465527],
#        [39.410873],
#        [39.351685],
#        [39.323387]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()

# %%
similar=0
different=0

for i in range(len(y_predict_trans)):
    
    print("Modelo:", y_predict_trans[i])
    print("Real:  ", y_mesuared[i])
    
    diff= y_predict_trans[i]-y_mesuared[i]

    print("Diff: ", diff)

    if -1<diff<1 :
        similar+=1
        print("Same Numbers")
    else:
        different+=1
        print("Different")

ratio=np.round((similar/(similar+different))*100,1)

print("Quantity of same numbers: ", similar, " records")
print("Quantity of different numbers: ", different, " records")
print("Percentage: ", ratio, "%")
# Out:
# Modelo: [40.019234]
# Real:   [39.416]
# Diff:  [0.6032337]
# Same Numbers
# Modelo: [40.05678]
# Real:   [38.634]
# Diff:  [1.42278177]
# Different
# Modelo: [40.01859]
# Real:   [39.007]
# Diff:  [1.01158902]
# Different
# Modelo: [40.04153]
# Real:   [40.407]
# Diff:  [-0.36546939]
# Same Numbers
# Modelo: [40.226894]
# Real:   [36.734]
# Diff:  [3.49289438]
# Different
# Modelo: [39.869682]
# Real:   [39.16]
# Diff:  [0.70968231]
# Same Numbers
# Modelo: [39.863388]
# Real:   [40.376]
# Diff:  [-0.51261194]
# Same Numbers
# Modelo: [40.0495]
# Real:   [40.18]
# Diff:  [-0.13050049]
# Same Numbers
# Modelo: [40.365055]
# Real:   [40.988]
# Diff:  [-0.62294492]
# Same Numbers
# Modelo: [40.704453]
# Real:   [44.586]
# Diff:  [-3.88154749]
# Different
# Modelo: [41.499832]
# Real:   [44.598]
# Diff:  [-3.09816785]
# Different
# Modelo: [42.19564]
# Real:   [44.401]
# Diff:  [-2.20535944]
# Different
# Modelo: [42.787193]
# Real:   [44.495]
# Diff:  [-1.7078067]
# Different
# Modelo: [43.27695]
# Real:   [44.073]
# Diff:  [-0.79604916]
# Same Numbers
# Modelo: [43.597015]
# Real:   [44.705]
# Diff:  [-1.10798462]
# Different
# Modelo: [43.924534]
# Real:   [42.5]
# Diff:  [1.42453384]
# Different
# Modelo: [43.81628]
# Real:   [41.697]
# Diff:  [2.11928036]
# Different
# Modelo: [43.5937]
# Real:   [41.067]
# Diff:  [2.52670041]
# Different
# Modelo: [43.25276]
# Real:   [42.264]
# Diff:  [0.98876184]
# Same Numbers
# Modelo: [43.10884]
# Real:   [41.4]
# Diff:  [1.70884094]
# Different
# Modelo: [42.867393]
# Real:   [41.701]
# Diff:  [1.16639349]
# Different
# Modelo: [42.73685]
# Real:   [40.553]
# Diff:  [2.18385074]
# Different
# Modelo: [42.4478]
# Real:   [43.069]
# Diff:  [-0.62120032]
# Same Numbers
# Modelo: [42.609005]
# Real:   [43.542]
# Diff:  [-0.93299503]
# Same Numbers
# Modelo: [42.911465]
# Real:   [46.468]
# Diff:  [-3.55653531]
# Different
# Modelo: [43.619385]
# Real:   [44.944]
# Diff:  [-1.32461523]
# Different
# Modelo: [43.98459]
# Real:   [41.796]
# Diff:  [2.18858862]
# Different
# Modelo: [43.80688]
# Real:   [41.322]
# Diff:  [2.48488095]
# Different
# Modelo: [43.482197]
# Real:   [40.461]
# Diff:  [3.02119681]
# Different
# Modelo: [43.063873]
# Real:   [42.685]
# Diff:  [0.37887329]
# Same Numbers
# Modelo: [43.02576]
# Real:   [43.59]
# Diff:  [-0.56423935]
# Same Numbers
# Modelo: [43.140278]
# Real:   [42.227]
# Diff:  [0.91327786]
# Same Numbers
# Modelo: [43.082733]
# Real:   [42.92]
# Diff:  [0.16273315]
# Same Numbers
# Modelo: [43.14548]
# Real:   [42.136]
# Diff:  [1.00948111]
# Different
# Modelo: [43.056854]
# Real:   [42.206]
# Diff:  [0.85085425]
# Same Numbers
# Modelo: [43.003902]
# Real:   [42.15]
# Diff:  [0.85390244]
# Same Numbers
# Modelo: [42.968307]
# Real:   [42.506]
# Diff:  [0.4623075]
# Same Numbers
# Modelo: [42.97425]
# Real:   [41.596]
# Diff:  [1.37825079]
# Different
# Modelo: [42.830074]
# Real:   [42.652]
# Diff:  [0.17807431]
# Same Numbers
# Modelo: [42.851734]
# Real:   [41.632]
# Diff:  [1.21973416]
# Different
# Modelo: [42.657455]
# Real:   [41.695]
# Diff:  [0.96245544]
# Same Numbers
# Modelo: [42.510265]
# Real:   [40.924]
# Diff:  [1.58626535]
# Different
# Modelo: [42.274822]
# Real:   [41.594]
# Diff:  [0.68082224]
# Same Numbers
# Modelo: [42.17938]
# Real:   [41.169]
# Diff:  [1.01037851]
# Different
# Modelo: [42.01345]
# Real:   [41.221]
# Diff:  [0.79245062]
# Same Numbers
# Modelo: [41.89793]
# Real:   [41.359]
# Diff:  [0.53893015]
# Same Numbers
# Modelo: [41.835163]
# Real:   [40.942]
# Diff:  [0.89316312]
# Same Numbers
# Modelo: [41.732365]
# Real:   [41.298]
# Diff:  [0.43436465]
# Same Numbers
# Modelo: [41.708633]
# Real:   [40.885]
# Diff:  [0.82363342]
# Same Numbers
# Modelo: [41.635487]
# Real:   [41.373]
# Diff:  [0.2624866]
# Same Numbers
# Modelo: [41.652985]
# Real:   [41.481]
# Diff:  [0.17198462]
# Same Numbers
# Modelo: [41.692455]
# Real:   [41.236]
# Diff:  [0.45645529]
# Same Numbers
# Modelo: [41.667397]
# Real:   [41.438]
# Diff:  [0.22939655]
# Same Numbers
# Modelo: [41.687794]
# Real:   [40.847]
# Diff:  [0.84079373]
# Same Numbers
# Modelo: [41.62358]
# Real:   [41.443]
# Diff:  [0.18058093]
# Same Numbers
# Modelo: [41.661232]
# Real:   [41.068]
# Diff:  [0.59323199]
# Same Numbers
# Modelo: [41.628544]
# Real:   [40.776]
# Diff:  [0.85254385]
# Same Numbers
# Modelo: [41.562416]
# Real:   [40.8]
# Diff:  [0.76241608]
# Same Numbers
# Modelo: [41.51151]
# Real:   [40.85]
# Diff:  [0.66150894]
# Same Numbers
# Modelo: [41.478245]
# Real:   [40.522]
# Diff:  [0.95624478]
# Same Numbers
# Modelo: [41.39208]
# Real:   [40.813]
# Diff:  [0.5790784]
# Same Numbers
# Modelo: [41.36748]
# Real:   [40.724]
# Diff:  [0.64348123]
# Same Numbers
# Modelo: [41.339043]
# Real:   [40.906]
# Diff:  [0.43304266]
# Same Numbers
# Modelo: [41.347244]
# Real:   [42.892]
# Diff:  [-1.54475574]
# Different
# Modelo: [41.714962]
# Real:   [49.045]
# Diff:  [-7.33003799]
# Different
# Modelo: [42.97308]
# Real:   [55.624]
# Diff:  [-12.65092032]
# Different
# Modelo: [45.086636]
# Real:   [52.876]
# Diff:  [-7.78936441]
# Different
# Modelo: [46.51653]
# Real:   [48.549]
# Diff:  [-2.03247092]
# Different
# Modelo: [47.012295]
# Real:   [45.784]
# Diff:  [1.22829477]
# Different
# Modelo: [46.948753]
# Real:   [43.407]
# Diff:  [3.54175336]
# Different
# Modelo: [46.46598]
# Real:   [39.319]
# Diff:  [7.14698053]
# Different
# Modelo: [45.408768]
# Real:   [39.733]
# Diff:  [5.6757677]
# Different
# Modelo: [44.41125]
# Real:   [43.025]
# Diff:  [1.38625107]
# Different
# Modelo: [43.97325]
# Real:   [43.494]
# Diff:  [0.47925134]
# Same Numbers
# Modelo: [43.784267]
# Real:   [43.343]
# Diff:  [0.44126743]
# Same Numbers
# Modelo: [43.67787]
# Real:   [43.486]
# Diff:  [0.1918717]
# Same Numbers
# Modelo: [43.65793]
# Real:   [46.992]
# Diff:  [-3.33407153]
# Different
# Modelo: [44.198112]
# Real:   [42.763]
# Diff:  [1.43511249]
# Different
# Modelo: [44.103176]
# Real:   [43.891]
# Diff:  [0.21217612]
# Same Numbers
# Modelo: [44.140503]
# Real:   [41.062]
# Diff:  [3.07850293]
# Different
# Modelo: [43.7814]
# Real:   [43.763]
# Diff:  [0.01839877]
# Same Numbers
# Modelo: [43.852177]
# Real:   [41.619]
# Diff:  [2.23317667]
# Different
# Modelo: [43.63981]
# Real:   [41.615]
# Diff:  [2.02480865]
# Different
# Modelo: [43.454494]
# Real:   [39.766]
# Diff:  [3.68849448]
# Different
# Modelo: [43.24336]
# Real:   [43.123]
# Diff:  [0.12035861]
# Same Numbers
# Modelo: [43.474804]
# Real:   [42.54]
# Diff:  [0.93480392]
# Same Numbers
# Modelo: [43.58361]
# Real:   [43.792]
# Diff:  [-0.20838947]
# Same Numbers
# Modelo: [43.852127]
# Real:   [42.813]
# Diff:  [1.03912708]
# Different
# Modelo: [43.73884]
# Real:   [43.172]
# Diff:  [0.5668382]
# Same Numbers
# Modelo: [43.71984]
# Real:   [43.726]
# Diff:  [-0.006159]
# Same Numbers
# Modelo: [43.806477]
# Real:   [41.698]
# Diff:  [2.10847659]
# Different
# Modelo: [43.582817]
# Real:   [43.299]
# Diff:  [0.28381708]
# Same Numbers
# Modelo: [43.547935]
# Real:   [42.36]
# Diff:  [1.18793549]
# Different
# Modelo: [43.388126]
# Real:   [42.901]
# Diff:  [0.48712637]
# Same Numbers
# Modelo: [43.35283]
# Real:   [42.173]
# Diff:  [1.17982898]
# Different
# Modelo: [43.208473]
# Real:   [38.832]
# Diff:  [4.37647321]
# Different
# Modelo: [42.516426]
# Real:   [41.038]
# Diff:  [1.47842609]
# Different
# Modelo: [42.22114]
# Real:   [39.24]
# Diff:  [2.98114182]
# Different
# Modelo: [41.741333]
# Real:   [35.782]
# Diff:  [5.95933301]
# Different
# Modelo: [40.82216]
# Real:   [38.161]
# Diff:  [2.66115881]
# Different
# Modelo: [40.420242]
# Real:   [41.717]
# Diff:  [-1.29675769]
# Different
# Modelo: [40.60824]
# Real:   [41.033]
# Diff:  [-0.42476178]
# Same Numbers
# Modelo: [40.72385]
# Real:   [44.079]
# Diff:  [-3.35514975]
# Different
# Modelo: [41.298607]
# Real:   [43.993]
# Diff:  [-2.69439313]
# Different
# Modelo: [42.1044]
# Real:   [43.786]
# Diff:  [-1.68159937]
# Different
# Modelo: [42.70702]
# Real:   [41.159]
# Diff:  [1.54801981]
# Different
# Modelo: [42.730442]
# Real:   [43.316]
# Diff:  [-0.58555795]
# Same Numbers
# Modelo: [42.975388]
# Real:   [42.658]
# Diff:  [0.31738757]
# Same Numbers
# Modelo: [43.23213]
# Real:   [40.079]
# Diff:  [3.15312814]
# Different
# Modelo: [42.987255]
# Real:   [38.861]
# Diff:  [4.1262551]
# Different
# Modelo: [42.52353]
# Real:   [38.608]
# Diff:  [3.91552905]
# Different
# Modelo: [42.035526]
# Real:   [40.026]
# Diff:  [2.00952628]
# Different
# Modelo: [41.56789]
# Real:   [40.731]
# Diff:  [0.83689017]
# Same Numbers
# Modelo: [41.352997]
# Real:   [40.393]
# Diff:  [0.95999683]
# Same Numbers
# Modelo: [41.182034]
# Real:   [40.471]
# Diff:  [0.71103354]
# Same Numbers
# Modelo: [41.096756]
# Real:   [40.66]
# Diff:  [0.43675598]
# Same Numbers
# Modelo: [41.042736]
# Real:   [40.93]
# Diff:  [0.11273605]
# Same Numbers
# Modelo: [41.065605]
# Real:   [40.848]
# Diff:  [0.21760516]
# Same Numbers
# Modelo: [41.097195]
# Real:   [40.97]
# Diff:  [0.12719467]
# Same Numbers
# Modelo: [41.15908]
# Real:   [40.919]
# Diff:  [0.24008051]
# Same Numbers
# Modelo: [41.437893]
# Real:   [42.365]
# Diff:  [-0.92710709]
# Same Numbers
# Modelo: [41.834267]
# Real:   [42.082]
# Diff:  [-0.24773334]
# Same Numbers
# Modelo: [42.098137]
# Real:   [41.558]
# Diff:  [0.5401369]
# Same Numbers
# Modelo: [42.21523]
# Real:   [41.839]
# Diff:  [0.37622903]
# Same Numbers
# Modelo: [42.13328]
# Real:   [42.011]
# Diff:  [0.12228171]
# Same Numbers
# Modelo: [42.12437]
# Real:   [42.098]
# Diff:  [0.02637057]
# Same Numbers
# Modelo: [42.151733]
# Real:   [41.648]
# Diff:  [0.5037334]
# Same Numbers
# Modelo: [42.122128]
# Real:   [41.314]
# Diff:  [0.80812753]
# Same Numbers
# Modelo: [42.085293]
# Real:   [41.805]
# Diff:  [0.28029282]
# Same Numbers
# Modelo: [42.12184]
# Real:   [41.789]
# Diff:  [0.33284143]
# Same Numbers
# Modelo: [42.164448]
# Real:   [41.928]
# Diff:  [0.23644778]
# Same Numbers
# Modelo: [42.224373]
# Real:   [42.081]
# Diff:  [0.14337286]
# Same Numbers
# Modelo: [42.290154]
# Real:   [41.699]
# Diff:  [0.5911535]
# Same Numbers
# Modelo: [42.28581]
# Real:   [42.008]
# Diff:  [0.27780856]
# Same Numbers
# Modelo: [42.331303]
# Real:   [41.412]
# Diff:  [0.91930264]
# Same Numbers
# Modelo: [42.28659]
# Real:   [40.601]
# Diff:  [1.68559058]
# Different
# Modelo: [42.048733]
# Real:   [40.556]
# Diff:  [1.49273276]
# Different
# Modelo: [41.857723]
# Real:   [40.065]
# Diff:  [1.79272324]
# Different
# Modelo: [41.625828]
# Real:   [40.863]
# Diff:  [0.76282779]
# Same Numbers
# Modelo: [41.563267]
# Real:   [40.541]
# Diff:  [1.02226675]
# Different
# Modelo: [41.45324]
# Real:   [40.751]
# Diff:  [0.70223944]
# Same Numbers
# Modelo: [41.40606]
# Real:   [40.5]
# Diff:  [0.90605927]
# Same Numbers
# Modelo: [41.33734]
# Real:   [40.394]
# Diff:  [0.94334131]
# Same Numbers
# Modelo: [41.267014]
# Real:   [40.104]
# Diff:  [1.16301355]
# Different
# Modelo: [41.17294]
# Real:   [39.949]
# Diff:  [1.2239393]
# Different
# Modelo: [41.06738]
# Real:   [40.067]
# Diff:  [1.000379]
# Different
# Modelo: [40.994564]
# Real:   [39.899]
# Diff:  [1.09556406]
# Different
# Modelo: [40.909492]
# Real:   [39.848]
# Diff:  [1.06149249]
# Different
# Modelo: [40.83014]
# Real:   [39.567]
# Diff:  [1.26313916]
# Different
# Modelo: [40.723297]
# Real:   [40.049]
# Diff:  [0.67429712]
# Same Numbers
# Modelo: [40.707424]
# Real:   [39.724]
# Diff:  [0.98342416]
# Same Numbers
# Modelo: [40.65118]
# Real:   [39.638]
# Diff:  [1.01318027]
# Different
# Modelo: [40.561024]
# Real:   [39.481]
# Diff:  [1.08002371]
# Different
# Modelo: [40.4722]
# Real:   [39.752]
# Diff:  [0.72019849]
# Same Numbers
# Modelo: [40.445454]
# Real:   [42.071]
# Diff:  [-1.62554636]
# Different
# Modelo: [40.782948]
# Real:   [39.802]
# Diff:  [0.98094754]
# Same Numbers
# Modelo: [40.73734]
# Real:   [39.608]
# Diff:  [1.12933902]
# Different
# Modelo: [40.66947]
# Real:   [39.696]
# Diff:  [0.97347174]
# Same Numbers
# Modelo: [40.619026]
# Real:   [39.764]
# Diff:  [0.85502618]
# Same Numbers
# Modelo: [40.584858]
# Real:   [39.838]
# Diff:  [0.74685794]
# Same Numbers
# Modelo: [41.404438]
# Real:   [39.766]
# Diff:  [1.63843802]
# Different
# Modelo: [41.854458]
# Real:   [39.486]
# Diff:  [2.36845786]
# Different
# Modelo: [42.04149]
# Real:   [39.837]
# Diff:  [2.20448865]
# Different
# Modelo: [42.14119]
# Real:   [39.871]
# Diff:  [2.27018958]
# Different
# Modelo: [41.62867]
# Real:   [39.53]
# Diff:  [2.09866974]
# Different
# Modelo: [41.238]
# Real:   [39.885]
# Diff:  [1.35299896]
# Different
# Modelo: [41.015865]
# Real:   [39.667]
# Diff:  [1.34886533]
# Different
# Modelo: [40.83946]
# Real:   [39.634]
# Diff:  [1.20545847]
# Different
# Modelo: [40.550194]
# Real:   [40.116]
# Diff:  [0.43419379]
# Same Numbers
# Modelo: [40.449913]
# Real:   [39.261]
# Diff:  [1.18891302]
# Different
# Modelo: [40.287964]
# Real:   [37.172]
# Diff:  [3.11596387]
# Different
# Modelo: [39.8655]
# Real:   [37.194]
# Diff:  [2.6715014]
# Different
# Modelo: [39.68642]
# Real:   [37.002]
# Diff:  [2.68442044]
# Different
# Modelo: [39.46965]
# Real:   [37.931]
# Diff:  [1.53865027]
# Different
# Modelo: [39.42086]
# Real:   [40.908]
# Diff:  [-1.48713971]
# Different
# Modelo: [39.825153]
# Real:   [40.263]
# Diff:  [-0.43784665]
# Same Numbers
# Modelo: [39.894676]
# Real:   [37.525]
# Diff:  [2.36967621]
# Different
# Modelo: [39.607967]
# Real:   [36.471]
# Diff:  [3.13696738]
# Different
# Modelo: [39.218143]
# Real:   [38.398]
# Diff:  [0.82014346]
# Same Numbers
# Modelo: [39.181152]
# Real:   [39.184]
# Diff:  [-0.00284766]
# Same Numbers
# Modelo: [39.32254]
# Real:   [41.067]
# Diff:  [-1.74445972]
# Different
# Modelo: [39.750427]
# Real:   [40.875]
# Diff:  [-1.12457275]
# Different
# Modelo: [40.11181]
# Real:   [38.565]
# Diff:  [1.54680878]
# Different
# Modelo: [40.07997]
# Real:   [40.753]
# Diff:  [-0.67302869]
# Same Numbers
# Modelo: [40.41139]
# Real:   [40.949]
# Diff:  [-0.5376116]
# Same Numbers
# Modelo: [40.725197]
# Real:   [40.105]
# Diff:  [0.62019684]
# Same Numbers
# Modelo: [40.840683]
# Real:   [37.283]
# Diff:  [3.55768298]
# Different
# Modelo: [40.507607]
# Real:   [39.554]
# Diff:  [0.95360651]
# Same Numbers
# Modelo: [40.516243]
# Real:   [37.953]
# Diff:  [2.56324298]
# Different
# Modelo: [40.27565]
# Real:   [38.739]
# Diff:  [1.53665002]
# Different
# Modelo: [40.172306]
# Real:   [38.029]
# Diff:  [2.14330606]
# Different
# Modelo: [40.002434]
# Real:   [38.356]
# Diff:  [1.64643378]
# Different
# Modelo: [39.579403]
# Real:   [40.713]
# Diff:  [-1.13359708]
# Different
# Modelo: [39.670143]
# Real:   [40.797]
# Diff:  [-1.12685687]
# Different
# Modelo: [39.85458]
# Real:   [40.028]
# Diff:  [-0.17342007]
# Same Numbers
# Modelo: [39.961582]
# Real:   [41.173]
# Diff:  [-1.21141782]
# Different
# Modelo: [40.474686]
# Real:   [41.386]
# Diff:  [-0.91131433]
# Same Numbers
# Modelo: [40.91194]
# Real:   [40.837]
# Diff:  [0.07494153]
# Same Numbers
# Modelo: [41.176556]
# Real:   [40.746]
# Diff:  [0.43055563]
# Same Numbers
# Modelo: [41.356907]
# Real:   [40.821]
# Diff:  [0.53590689]
# Same Numbers
# Modelo: [41.651253]
# Real:   [40.13]
# Diff:  [1.52125275]
# Different
# Modelo: [41.735146]
# Real:   [41.081]
# Diff:  [0.65414557]
# Same Numbers
# Modelo: [41.915684]
# Real:   [40.763]
# Diff:  [1.15268375]
# Different
# Modelo: [41.971336]
# Real:   [41.357]
# Diff:  [0.61433636]
# Same Numbers
# Modelo: [41.82136]
# Real:   [41.849]
# Diff:  [-0.02763846]
# Same Numbers
# Modelo: [41.826305]
# Real:   [41.397]
# Diff:  [0.42930539]
# Same Numbers
# Modelo: [41.790325]
# Real:   [40.881]
# Diff:  [0.90932516]
# Same Numbers
# Modelo: [41.707333]
# Real:   [40.274]
# Diff:  [1.43333261]
# Different
# Modelo: [41.638252]
# Real:   [41.479]
# Diff:  [0.15925226]
# Same Numbers
# Modelo: [41.733265]
# Real:   [41.665]
# Diff:  [0.06826492]
# Same Numbers
# Modelo: [41.832554]
# Real:   [40.688]
# Diff:  [1.14455386]
# Different
# Modelo: [41.76003]
# Real:   [41.227]
# Diff:  [0.53302884]
# Same Numbers
# Modelo: [41.823437]
# Real:   [40.801]
# Diff:  [1.02243674]
# Different
# Modelo: [41.800785]
# Real:   [40.637]
# Diff:  [1.16378506]
# Different
# Modelo: [41.75817]
# Real:   [40.991]
# Diff:  [0.76717108]
# Same Numbers
# Modelo: [41.74769]
# Real:   [40.64]
# Diff:  [1.10768829]
# Different
# Modelo: [41.736294]
# Real:   [41.449]
# Diff:  [0.28729379]
# Same Numbers
# Modelo: [41.836815]
# Real:   [41.128]
# Diff:  [0.70881488]
# Same Numbers
# Modelo: [41.86707]
# Real:   [41.028]
# Diff:  [0.83906924]
# Same Numbers
# Modelo: [41.86719]
# Real:   [40.601]
# Diff:  [1.26619131]
# Different
# Modelo: [41.81511]
# Real:   [41.952]
# Diff:  [-0.13689075]
# Same Numbers
# Modelo: [41.973167]
# Real:   [41.368]
# Diff:  [0.60516742]
# Same Numbers
# Modelo: [42.00418]
# Real:   [41.765]
# Diff:  [0.23918091]
# Same Numbers
# Modelo: [42.056385]
# Real:   [41.118]
# Diff:  [0.93838504]
# Same Numbers
# Modelo: [42.0126]
# Real:   [41.574]
# Diff:  [0.43859995]
# Same Numbers
# Modelo: [42.04788]
# Real:   [41.549]
# Diff:  [0.49887827]
# Same Numbers
# Modelo: [42.076935]
# Real:   [40.961]
# Diff:  [1.11593481]
# Different
# Modelo: [42.01267]
# Real:   [41.165]
# Diff:  [0.84766861]
# Same Numbers
# Modelo: [41.989635]
# Real:   [40.824]
# Diff:  [1.16563547]
# Different
# Modelo: [41.9133]
# Real:   [41.091]
# Diff:  [0.82229956]
# Same Numbers
# Modelo: [41.883175]
# Real:   [41.153]
# Diff:  [0.7301749]
# Same Numbers
# Modelo: [41.86663]
# Real:   [41.28]
# Diff:  [0.58663055]
# Same Numbers
# Modelo: [41.760143]
# Real:   [40.522]
# Diff:  [1.23814328]
# Different
# Modelo: [41.58955]
# Real:   [41.043]
# Diff:  [0.54655002]
# Same Numbers
# Modelo: [41.539833]
# Real:   [40.812]
# Diff:  [0.72783307]
# Same Numbers
# Modelo: [41.480812]
# Real:   [40.405]
# Diff:  [1.07581207]
# Different
# Modelo: [41.384045]
# Real:   [40.454]
# Diff:  [0.93004465]
# Same Numbers
# Modelo: [41.314697]
# Real:   [41.006]
# Diff:  [0.30869727]
# Same Numbers
# Modelo: [41.344975]
# Real:   [40.731]
# Diff:  [0.61397452]
# Same Numbers
# Modelo: [41.339993]
# Real:   [40.631]
# Diff:  [0.70899252]
# Same Numbers
# Modelo: [41.27819]
# Real:   [38.213]
# Diff:  [3.06519061]
# Different
# Modelo: [40.87736]
# Real:   [37.796]
# Diff:  [3.0813613]
# Different
# Modelo: [40.452187]
# Real:   [40.327]
# Diff:  [0.12518658]
# Same Numbers
# Modelo: [40.461864]
# Real:   [40.296]
# Diff:  [0.16586447]
# Same Numbers
# Modelo: [40.487553]
# Real:   [39.928]
# Diff:  [0.55955264]
# Same Numbers
# Modelo: [40.48009]
# Real:   [40.149]
# Diff:  [0.33109109]
# Same Numbers
# Modelo: [40.515583]
# Real:   [39.861]
# Diff:  [0.65458304]
# Same Numbers
# Modelo: [40.506065]
# Real:   [39.7]
# Diff:  [0.80606537]
# Same Numbers
# Modelo: [40.511375]
# Real:   [39.728]
# Diff:  [0.78337543]
# Same Numbers
# Modelo: [40.505928]
# Real:   [40.279]
# Diff:  [0.22692804]
# Same Numbers
# Modelo: [40.575882]
# Real:   [40.236]
# Diff:  [0.33988196]
# Same Numbers
# Modelo: [40.627407]
# Real:   [40.006]
# Diff:  [0.62140707]
# Same Numbers
# Modelo: [40.588634]
# Real:   [39.618]
# Diff:  [0.97063449]
# Same Numbers
# Modelo: [40.506348]
# Real:   [39.51]
# Diff:  [0.99634766]
# Same Numbers
# Modelo: [40.42307]
# Real:   [39.426]
# Diff:  [0.997069]
# Same Numbers
# Modelo: [40.342205]
# Real:   [39.866]
# Diff:  [0.47620505]
# Same Numbers
# Modelo: [40.34471]
# Real:   [39.714]
# Diff:  [0.6307113]
# Same Numbers
# Modelo: [40.330868]
# Real:   [39.173]
# Diff:  [1.15786777]
# Different
# Modelo: [40.242092]
# Real:   [39.124]
# Diff:  [1.11809213]
# Different
# Modelo: [40.15882]
# Real:   [39.253]
# Diff:  [0.90582111]
# Same Numbers
# Modelo: [40.108643]
# Real:   [39.331]
# Diff:  [0.77764258]
# Same Numbers
# Modelo: [40.081066]
# Real:   [39.408]
# Diff:  [0.67306613]
# Same Numbers
# Modelo: [40.073677]
# Real:   [39.217]
# Diff:  [0.85667706]
# Same Numbers
# Modelo: [40.042835]
# Real:   [39.25]
# Diff:  [0.79283524]
# Same Numbers
# Modelo: [39.96171]
# Real:   [39.202]
# Diff:  [0.75971188]
# Same Numbers
# Modelo: [39.905003]
# Real:   [39.358]
# Diff:  [0.54700259]
# Same Numbers
# Modelo: [39.893456]
# Real:   [39.333]
# Diff:  [0.56045551]
# Same Numbers
# Modelo: [39.890755]
# Real:   [39.317]
# Diff:  [0.5737547]
# Same Numbers
# Modelo: [39.82471]
# Real:   [39.384]
# Diff:  [0.44071085]
# Same Numbers
# Modelo: [39.818497]
# Real:   [37.984]
# Diff:  [1.8344967]
# Different
# Modelo: [39.60794]
# Real:   [37.125]
# Diff:  [2.48294067]
# Different
# Modelo: [39.300903]
# Real:   [37.665]
# Diff:  [1.63590332]
# Different
# Modelo: [39.112476]
# Real:   [37.25]
# Diff:  [1.86247635]
# Different
# Modelo: [38.90335]
# Real:   [36.505]
# Diff:  [2.39835083]
# Different
# Modelo: [38.626026]
# Real:   [37.169]
# Diff:  [1.45702615]
# Different
# Modelo: [38.48326]
# Real:   [37.23]
# Diff:  [1.25326111]
# Different
# Modelo: [38.55152]
# Real:   [37.61]
# Diff:  [0.9415213]
# Same Numbers
# Modelo: [38.63801]
# Real:   [37.462]
# Diff:  [1.17600812]
# Different
# Modelo: [38.67191]
# Real:   [37.784]
# Diff:  [0.88790933]
# Same Numbers
# Modelo: [38.763268]
# Real:   [37.443]
# Diff:  [1.32026752]
# Different
# Modelo: [38.75703]
# Real:   [37.643]
# Diff:  [1.11403049]
# Different
# Modelo: [38.76164]
# Real:   [38.711]
# Diff:  [0.05063864]
# Same Numbers
# Modelo: [38.89944]
# Real:   [37.681]
# Diff:  [1.21844077]
# Different
# Modelo: [38.892086]
# Real:   [37.515]
# Diff:  [1.37708603]
# Different
# Modelo: [38.75551]
# Real:   [38.034]
# Diff:  [0.72150842]
# Same Numbers
# Modelo: [38.75076]
# Real:   [37.877]
# Diff:  [0.87375912]
# Same Numbers
# Modelo: [38.73869]
# Real:   [38.145]
# Diff:  [0.59368942]
# Same Numbers
# Modelo: [38.778595]
# Real:   [38.219]
# Diff:  [0.55959497]
# Same Numbers
# Modelo: [38.97073]
# Real:   [38.922]
# Diff:  [0.04872983]
# Same Numbers
# Modelo: [39.20558]
# Real:   [38.806]
# Diff:  [0.39958167]
# Same Numbers
# Modelo: [39.365437]
# Real:   [35.905]
# Diff:  [3.46043655]
# Different
# Modelo: [39.054142]
# Real:   [37.209]
# Diff:  [1.845142]
# Different
# Modelo: [39.042496]
# Real:   [38.804]
# Diff:  [0.23849573]
# Same Numbers
# Modelo: [39.238396]
# Real:   [38.885]
# Diff:  [0.35339569]
# Same Numbers
# Modelo: [39.415184]
# Real:   [41.406]
# Diff:  [-1.99081598]
# Different
# Modelo: [39.940895]
# Real:   [40.843]
# Diff:  [-0.90210492]
# Same Numbers
# Modelo: [40.290127]
# Real:   [42.78]
# Diff:  [-2.4898732]
# Different
# Modelo: [40.890022]
# Real:   [44.988]
# Diff:  [-4.09797772]
# Different
# Modelo: [41.73603]
# Real:   [42.765]
# Diff:  [-1.02896942]
# Different
# Modelo: [42.11233]
# Real:   [39.839]
# Diff:  [2.27333139]
# Different
# Modelo: [42.04288]
# Real:   [38.466]
# Diff:  [3.57688101]
# Different
# Modelo: [41.70798]
# Real:   [38.041]
# Diff:  [3.66698111]
# Different
# Modelo: [41.298073]
# Real:   [39.112]
# Diff:  [2.18607281]
# Different
# Modelo: [41.08794]
# Real:   [40.245]
# Diff:  [0.84294022]
# Same Numbers
# Modelo: [41.013615]
# Real:   [40.676]
# Diff:  [0.33761465]
# Same Numbers
# Modelo: [41.046074]
# Real:   [40.9]
# Diff:  [0.14607391]
# Same Numbers
# Modelo: [41.127056]
# Real:   [41.082]
# Diff:  [0.04505612]
# Same Numbers
# Modelo: [41.255722]
# Real:   [40.562]
# Diff:  [0.69372205]
# Same Numbers
# Modelo: [41.2932]
# Real:   [41.76]
# Diff:  [-0.46679855]
# Same Numbers
# Modelo: [41.49492]
# Real:   [41.72]
# Diff:  [-0.22508118]
# Same Numbers
# Modelo: [41.638226]
# Real:   [41.269]
# Diff:  [0.36922556]
# Same Numbers
# Modelo: [41.716007]
# Real:   [41.19]
# Diff:  [0.52600723]
# Same Numbers
# Modelo: [41.791714]
# Real:   [41.512]
# Diff:  [0.27971371]
# Same Numbers
# Modelo: [41.90056]
# Real:   [41.407]
# Diff:  [0.49355847]
# Same Numbers
# Modelo: [41.975307]
# Real:   [42.034]
# Diff:  [-0.05869254]
# Same Numbers
# Modelo: [42.100483]
# Real:   [40.776]
# Diff:  [1.32448294]
# Different
# Modelo: [42.070873]
# Real:   [41.377]
# Diff:  [0.69387326]
# Same Numbers
# Modelo: [42.114628]
# Real:   [40.787]
# Diff:  [1.32762784]
# Different
# Modelo: [42.04814]
# Real:   [41.484]
# Diff:  [0.56414148]
# Same Numbers
# Modelo: [42.077988]
# Real:   [40.652]
# Diff:  [1.42598767]
# Different
# Modelo: [41.95988]
# Real:   [41.609]
# Diff:  [0.35088083]
# Same Numbers
# Modelo: [41.993515]
# Real:   [41.055]
# Diff:  [0.93851501]
# Same Numbers
# Modelo: [41.94053]
# Real:   [41.127]
# Diff:  [0.81352887]
# Same Numbers
# Modelo: [41.916233]
# Real:   [41.511]
# Diff:  [0.40523306]
# Same Numbers
# Modelo: [41.90391]
# Real:   [41.068]
# Diff:  [0.83591159]
# Same Numbers
# Modelo: [41.837696]
# Real:   [40.984]
# Diff:  [0.85369608]
# Same Numbers
# Modelo: [41.78194]
# Real:   [41.201]
# Diff:  [0.58094046]
# Same Numbers
# Modelo: [41.769783]
# Real:   [41.615]
# Diff:  [0.15478302]
# Same Numbers
# Modelo: [41.81139]
# Real:   [41.014]
# Diff:  [0.79738992]
# Same Numbers
# Modelo: [41.763718]
# Real:   [40.984]
# Diff:  [0.77971765]
# Same Numbers
# Modelo: [41.71784]
# Real:   [40.209]
# Diff:  [1.50883829]
# Different
# Modelo: [41.557243]
# Real:   [40.665]
# Diff:  [0.89224335]
# Same Numbers
# Modelo: [41.448746]
# Real:   [40.818]
# Diff:  [0.63074573]
# Same Numbers
# Modelo: [41.398956]
# Real:   [40.675]
# Diff:  [0.7239563]
# Same Numbers
# Modelo: [41.345394]
# Real:   [40.45]
# Diff:  [0.89539413]
# Same Numbers
# Modelo: [41.270718]
# Real:   [40.821]
# Diff:  [0.44971762]
# Same Numbers
# Modelo: [41.138744]
# Real:   [40.671]
# Diff:  [0.46774435]
# Same Numbers
# Modelo: [41.04374]
# Real:   [40.625]
# Diff:  [0.41873932]
# Same Numbers
# Modelo: [40.98195]
# Real:   [41.004]
# Diff:  [-0.02205115]
# Same Numbers
# Modelo: [41.00536]
# Real:   [40.75]
# Diff:  [0.25535965]
# Same Numbers
# Modelo: [41.076378]
# Real:   [40.623]
# Diff:  [0.45337787]
# Same Numbers
# Modelo: [41.10671]
# Real:   [40.268]
# Diff:  [0.83870853]
# Same Numbers
# Modelo: [41.070797]
# Real:   [40.079]
# Diff:  [0.99179697]
# Same Numbers
# Modelo: [41.00376]
# Real:   [40.64]
# Diff:  [0.36376129]
# Same Numbers
# Modelo: [41.01948]
# Real:   [40.279]
# Diff:  [0.74048166]
# Same Numbers
# Modelo: [40.98171]
# Real:   [39.899]
# Diff:  [1.08270853]
# Different
# Modelo: [40.89309]
# Real:   [40.446]
# Diff:  [0.44708929]
# Same Numbers
# Modelo: [40.898914]
# Real:   [40.212]
# Diff:  [0.68691434]
# Same Numbers
# Modelo: [40.841484]
# Real:   [40.561]
# Diff:  [0.28048407]
# Same Numbers
# Modelo: [40.856853]
# Real:   [39.825]
# Diff:  [1.03185349]
# Different
# Modelo: [40.768192]
# Real:   [39.409]
# Diff:  [1.35919229]
# Different
# Modelo: [40.642883]
# Real:   [40.789]
# Diff:  [-0.1461167]
# Same Numbers
# Modelo: [40.742603]
# Real:   [40.881]
# Diff:  [-0.1383967]
# Same Numbers
# Modelo: [40.861282]
# Real:   [42.672]
# Diff:  [-1.81071765]
# Different
# Modelo: [41.2501]
# Real:   [39.205]
# Diff:  [2.04509918]
# Different
# Modelo: [41.096813]
# Real:   [43.222]
# Diff:  [-2.1251868]
# Different
# Modelo: [41.48342]
# Real:   [43.112]
# Diff:  [-1.62857867]
# Different
# Modelo: [41.842163]
# Real:   [39.499]
# Diff:  [2.34316309]
# Different
# Modelo: [41.678955]
# Real:   [42.537]
# Diff:  [-0.85804492]
# Same Numbers
# Modelo: [41.939564]
# Real:   [39.843]
# Diff:  [2.09656375]
# Different
# Modelo: [41.776123]
# Real:   [36.875]
# Diff:  [4.90112305]
# Different
# Modelo: [41.161438]
# Real:   [36.37]
# Diff:  [4.79143799]
# Different
# Modelo: [40.538948]
# Real:   [38.162]
# Diff:  [2.37694806]
# Different
# Modelo: [40.257774]
# Real:   [38.971]
# Diff:  [1.28677435]
# Different
# Modelo: [40.095642]
# Real:   [39.334]
# Diff:  [0.76164209]
# Same Numbers
# Modelo: [40.02829]
# Real:   [35.639]
# Diff:  [4.38928979]
# Different
# Modelo: [39.488472]
# Real:   [43.085]
# Diff:  [-3.59652802]
# Different
# Modelo: [40.09737]
# Real:   [32.322]
# Diff:  [7.77537015]
# Different
# Modelo: [39.02087]
# Real:   [42.964]
# Diff:  [-3.94312979]
# Different
# Modelo: [39.598255]
# Real:   [34.067]
# Diff:  [5.53125516]
# Different
# Modelo: [38.9035]
# Real:   [36.011]
# Diff:  [2.8924996]
# Different
# Modelo: [38.546223]
# Real:   [39.145]
# Diff:  [-0.59877731]
# Same Numbers
# Modelo: [38.755524]
# Real:   [40.071]
# Diff:  [-1.31547632]
# Different
# Modelo: [39.118687]
# Real:   [40.702]
# Diff:  [-1.58331332]
# Different
# Modelo: [39.547363]
# Real:   [40.091]
# Diff:  [-0.54363672]
# Same Numbers
# Modelo: [39.827232]
# Real:   [40.665]
# Diff:  [-0.83776764]
# Same Numbers
# Modelo: [40.191574]
# Real:   [39.91]
# Diff:  [0.2815741]
# Same Numbers
# Modelo: [40.39964]
# Real:   [40.762]
# Diff:  [-0.36236087]
# Same Numbers
# Modelo: [40.696625]
# Real:   [39.753]
# Diff:  [0.94362476]
# Same Numbers
# Modelo: [40.799847]
# Real:   [40.126]
# Diff:  [0.67384665]
# Same Numbers
# Modelo: [40.89963]
# Real:   [40.312]
# Diff:  [0.5876315]
# Same Numbers
# Modelo: [41.0279]
# Real:   [40.623]
# Diff:  [0.4049007]
# Same Numbers
# Modelo: [41.193592]
# Real:   [39.761]
# Diff:  [1.43259207]
# Different
# Modelo: [41.191795]
# Real:   [39.379]
# Diff:  [1.81279535]
# Different
# Modelo: [41.110466]
# Real:   [37.673]
# Diff:  [3.437466]
# Different
# Modelo: [40.77919]
# Real:   [35.7]
# Diff:  [5.07919006]
# Different
# Modelo: [40.167583]
# Real:   [35.352]
# Diff:  [4.81558347]
# Different
# Modelo: [39.54812]
# Real:   [34.873]
# Diff:  [4.67511859]
# Different
# Modelo: [39.03131]
# Real:   [33.229]
# Diff:  [5.80231104]
# Different
# Modelo: [38.32948]
# Real:   [33.278]
# Diff:  [5.05147922]
# Different
# Modelo: [37.70106]
# Real:   [33.535]
# Diff:  [4.16606125]
# Different
# Modelo: [37.199852]
# Real:   [37.601]
# Diff:  [-0.40114801]
# Same Numbers
# Modelo: [37.68367]
# Real:   [39.737]
# Diff:  [-2.05332996]
# Different
# Modelo: [38.387558]
# Real:   [40.297]
# Diff:  [-1.90944202]
# Different
# Modelo: [39.055912]
# Real:   [41.432]
# Diff:  [-2.37608798]
# Different
# Modelo: [39.766712]
# Real:   [40.973]
# Diff:  [-1.20628781]
# Different
# Modelo: [39.927876]
# Real:   [47.4]
# Diff:  [-7.47212448]
# Different
# Modelo: [41.065228]
# Real:   [52.602]
# Diff:  [-11.53677249]
# Different
# Modelo: [42.896046]
# Real:   [54.211]
# Diff:  [-11.31495432]
# Different
# Modelo: [44.784027]
# Real:   [52.169]
# Diff:  [-7.3849729]
# Different
# Modelo: [46.27333]
# Real:   [52.5]
# Diff:  [-6.22666931]
# Different
# Modelo: [47.50154]
# Real:   [53.106]
# Diff:  [-5.60445886]
# Different
# Modelo: [48.589626]
# Real:   [52.942]
# Diff:  [-4.35237369]
# Different
# Modelo: [49.385166]
# Real:   [52.189]
# Diff:  [-2.80383383]
# Different
# Modelo: [49.92513]
# Real:   [47.108]
# Diff:  [2.81712894]
# Different
# Modelo: [49.531242]
# Real:   [44.88]
# Diff:  [4.65124237]
# Different
# Modelo: [48.764393]
# Real:   [42.179]
# Diff:  [6.58539285]
# Different
# Modelo: [47.625694]
# Real:   [42.042]
# Diff:  [5.58369427]
# Different
# Modelo: [46.603962]
# Real:   [41.631]
# Diff:  [4.97296194]
# Different
# Modelo: [45.65552]
# Real:   [42.575]
# Diff:  [3.08052139]
# Different
# Modelo: [45.003845]
# Real:   [42.384]
# Diff:  [2.61984521]
# Different
# Modelo: [44.456642]
# Real:   [41.833]
# Diff:  [2.62364215]
# Different
# Modelo: [43.908375]
# Real:   [42.204]
# Diff:  [1.70437479]
# Different
# Modelo: [43.541386]
# Real:   [41.641]
# Diff:  [1.90038565]
# Different
# Modelo: [43.18471]
# Real:   [42.113]
# Diff:  [1.07171146]
# Different
# Modelo: [42.98335]
# Real:   [41.852]
# Diff:  [1.13134885]
# Different
# Modelo: [42.80646]
# Real:   [41.819]
# Diff:  [0.98746133]
# Same Numbers
# Modelo: [42.68423]
# Real:   [42.403]
# Diff:  [0.2812308]
# Same Numbers
# Modelo: [42.66072]
# Real:   [41.655]
# Diff:  [1.00572083]
# Different
# Modelo: [42.53965]
# Real:   [41.488]
# Diff:  [1.05164996]
# Different
# Modelo: [42.442657]
# Real:   [41.174]
# Diff:  [1.26865747]
# Different
# Modelo: [42.31682]
# Real:   [40.929]
# Diff:  [1.38781824]
# Different
# Modelo: [42.171764]
# Real:   [40.454]
# Diff:  [1.71776437]
# Different
# Modelo: [41.97426]
# Real:   [39.813]
# Diff:  [2.16125842]
# Different
# Modelo: [41.675453]
# Real:   [40.868]
# Diff:  [0.80745319]
# Same Numbers
# Modelo: [41.58161]
# Real:   [40.851]
# Diff:  [0.73061163]
# Same Numbers
# Modelo: [41.518894]
# Real:   [40.387]
# Diff:  [1.1318942]
# Different
# Modelo: [41.407104]
# Real:   [40.585]
# Diff:  [0.82210449]
# Same Numbers
# Modelo: [41.317993]
# Real:   [39.837]
# Diff:  [1.48099316]
# Different
# Modelo: [41.140057]
# Real:   [40.037]
# Diff:  [1.10305661]
# Different
# Modelo: [41.02221]
# Real:   [40.16]
# Diff:  [0.86220917]
# Same Numbers
# Modelo: [40.946163]
# Real:   [40.14]
# Diff:  [0.80616318]
# Same Numbers
# Modelo: [40.897675]
# Real:   [40.026]
# Diff:  [0.87167456]
# Same Numbers
# Modelo: [40.842884]
# Real:   [39.959]
# Diff:  [0.88388406]
# Same Numbers
# Modelo: [40.789192]
# Real:   [40.4]
# Diff:  [0.3891922]
# Same Numbers
# Modelo: [40.81307]
# Real:   [39.95]
# Diff:  [0.86306839]
# Same Numbers
# Modelo: [40.73995]
# Real:   [40.321]
# Diff:  [0.41894827]
# Same Numbers
# Modelo: [40.744503]
# Real:   [40.229]
# Diff:  [0.51550302]
# Same Numbers
# Modelo: [40.743847]
# Real:   [39.809]
# Diff:  [0.93484689]
# Same Numbers
# Modelo: [40.68617]
# Real:   [39.889]
# Diff:  [0.79716867]
# Same Numbers
# Modelo: [40.6404]
# Real:   [39.792]
# Diff:  [0.84839993]
# Same Numbers
# Modelo: [40.59176]
# Real:   [39.88]
# Diff:  [0.71175873]
# Same Numbers
# Modelo: [40.567688]
# Real:   [39.591]
# Diff:  [0.97668799]
# Same Numbers
# Modelo: [40.50776]
# Real:   [39.293]
# Diff:  [1.21475909]
# Different
# Modelo: [40.385376]
# Real:   [39.694]
# Diff:  [0.69137598]
# Same Numbers
# Modelo: [40.3501]
# Real:   [39.68]
# Diff:  [0.67010147]
# Same Numbers
# Modelo: [40.327698]
# Real:   [39.743]
# Diff:  [0.58469775]
# Same Numbers
# Modelo: [40.326374]
# Real:   [39.626]
# Diff:  [0.70037405]
# Same Numbers
# Modelo: [40.39285]
# Real:   [42.53]
# Diff:  [-2.13715103]
# Different
# Modelo: [40.891335]
# Real:   [38.22]
# Diff:  [2.67133453]
# Different
# Modelo: [40.69804]
# Real:   [47.561]
# Diff:  [-6.86295999]
# Different
# Modelo: [41.87521]
# Real:   [48.207]
# Diff:  [-6.33179019]
# Different
# Modelo: [43.169094]
# Real:   [55.878]
# Diff:  [-12.70890591]
# Different
# Modelo: [45.3973]
# Real:   [51.09]
# Diff:  [-5.69269928]
# Different
# Modelo: [46.651905]
# Real:   [53.1]
# Diff:  [-6.44809494]
# Different
# Modelo: [47.955956]
# Real:   [53.651]
# Diff:  [-5.69504449]
# Different
# Modelo: [48.786377]
# Real:   [40.003]
# Diff:  [8.78337695]
# Different
# Modelo: [47.45832]
# Real:   [45.539]
# Diff:  [1.91932062]
# Different
# Modelo: [47.01578]
# Real:   [38.191]
# Diff:  [8.8247814]
# Different
# Modelo: [45.60521]
# Real:   [36.112]
# Diff:  [9.49320935]
# Different
# Modelo: [44.17924]
# Real:   [38.302]
# Diff:  [5.87724118]
# Different
# Modelo: [43.184406]
# Real:   [36.757]
# Diff:  [6.42740628]
# Different
# Modelo: [42.153988]
# Real:   [38.954]
# Diff:  [3.19998788]
# Different
# Modelo: [41.62638]
# Real:   [34.64]
# Diff:  [6.98638092]
# Different
# Modelo: [40.41289]
# Real:   [41.112]
# Diff:  [-0.69910861]
# Same Numbers
# Modelo: [40.33474]
# Real:   [35.764]
# Diff:  [4.57073969]
# Different
# Modelo: [39.660767]
# Real:   [35.547]
# Diff:  [4.1137666]
# Different
# Modelo: [39.049168]
# Real:   [38.682]
# Diff:  [0.36716763]
# Same Numbers
# Modelo: [39.315987]
# Real:   [37.256]
# Diff:  [2.05998663]
# Different
# Modelo: [39.343525]
# Real:   [39.039]
# Diff:  [0.30452493]
# Same Numbers
# Modelo: [39.577168]
# Real:   [35.717]
# Diff:  [3.86016751]
# Different
# Modelo: [39.29603]
# Real:   [41.692]
# Diff:  [-2.39597186]
# Different
# Modelo: [39.87839]
# Real:   [41.816]
# Diff:  [-1.93760873]
# Different
# Modelo: [40.43346]
# Real:   [36.365]
# Diff:  [4.06846024]
# Different
# Modelo: [40.10792]
# Real:   [40.525]
# Diff:  [-0.4170784]
# Same Numbers
# Modelo: [40.339672]
# Real:   [37.861]
# Diff:  [2.47867209]
# Different
# Modelo: [40.17262]
# Real:   [38.686]
# Diff:  [1.48661887]
# Different
# Modelo: [40.13079]
# Real:   [39.812]
# Diff:  [0.31879071]
# Same Numbers
# Modelo: [40.24136]
# Real:   [37.766]
# Diff:  [2.47535971]
# Different
# Modelo: [40.03518]
# Real:   [41.157]
# Diff:  [-1.12182086]
# Different
# Modelo: [40.07879]
# Real:   [35.558]
# Diff:  [4.52078876]
# Different
# Modelo: [39.433056]
# Real:   [45.7]
# Diff:  [-6.26694412]
# Different
# Modelo: [40.356346]
# Real:   [38.309]
# Diff:  [2.04734613]
# Different
# Modelo: [40.204247]
# Real:   [34.23]
# Diff:  [5.97424652]
# Different
# Modelo: [39.174168]
# Real:   [36.715]
# Diff:  [2.45916763]
# Different
# Modelo: [38.665947]
# Real:   [38.479]
# Diff:  [0.18694696]
# Same Numbers
# Modelo: [38.549194]
# Real:   [37.77]
# Diff:  [0.77919434]
# Same Numbers
# Modelo: [38.42112]
# Real:   [38.281]
# Diff:  [0.14011969]
# Same Numbers
# Modelo: [38.93478]
# Real:   [37.822]
# Diff:  [1.11278012]
# Different
# Modelo: [39.188995]
# Real:   [41.026]
# Diff:  [-1.83700464]
# Different
# Modelo: [39.786064]
# Real:   [42.223]
# Diff:  [-2.43693585]
# Different
# Modelo: [40.435036]
# Real:   [42.744]
# Diff:  [-2.30896429]
# Different
# Modelo: [41.832615]
# Real:   [43.136]
# Diff:  [-1.3033851]
# Different
# Modelo: [42.83022]
# Real:   [40.908]
# Diff:  [1.92221927]
# Different
# Modelo: [43.164085]
# Real:   [42.95]
# Diff:  [0.21408539]
# Same Numbers
# Modelo: [43.618404]
# Real:   [43.276]
# Diff:  [0.34240439]
# Same Numbers
# Modelo: [44.285423]
# Real:   [40.61]
# Diff:  [3.67542328]
# Different
# Modelo: [44.284073]
# Real:   [39.596]
# Diff:  [4.68807288]
# Different
# Modelo: [43.993946]
# Real:   [40.484]
# Diff:  [3.50994608]
# Different
# Modelo: [43.76745]
# Real:   [43.988]
# Diff:  [-0.22055157]
# Same Numbers
# Modelo: [43.511436]
# Real:   [42.646]
# Diff:  [0.86543646]
# Same Numbers
# Modelo: [43.236935]
# Real:   [39.937]
# Diff:  [3.29993466]
# Different
# Modelo: [42.66016]
# Real:   [38.544]
# Diff:  [4.11616006]
# Different
# Modelo: [42.013615]
# Real:   [37.423]
# Diff:  [4.59061465]
# Different
# Modelo: [40.9332]
# Real:   [40.774]
# Diff:  [0.15920084]
# Same Numbers
# Modelo: [40.662693]
# Real:   [41.217]
# Diff:  [-0.55430698]
# Same Numbers
# Modelo: [40.61355]
# Real:   [40.362]
# Diff:  [0.25154828]
# Same Numbers
# Modelo: [40.550453]
# Real:   [41.594]
# Diff:  [-1.04354681]
# Different
# Modelo: [40.732674]
# Real:   [40.919]
# Diff:  [-0.18632635]
# Same Numbers
# Modelo: [40.828953]
# Real:   [41.322]
# Diff:  [-0.49304721]
# Same Numbers
# Modelo: [41.007847]
# Real:   [41.27]
# Diff:  [-0.26215317]
# Same Numbers
# Modelo: [41.18755]
# Real:   [39.634]
# Diff:  [1.55354959]
# Different
# Modelo: [41.10325]
# Real:   [40.214]
# Diff:  [0.8892486]
# Same Numbers
# Modelo: [41.097664]
# Real:   [39.82]
# Diff:  [1.27766388]
# Different
# Modelo: [41.047455]
# Real:   [38.017]
# Diff:  [3.03045483]
# Different
# Modelo: [40.736126]
# Real:   [39.677]
# Diff:  [1.05912595]
# Different
# Modelo: [40.60858]
# Real:   [39.509]
# Diff:  [1.09958154]
# Different
# Modelo: [40.50427]
# Real:   [40.647]
# Diff:  [-0.14273135]
# Same Numbers
# Modelo: [40.601364]
# Real:   [40.183]
# Diff:  [0.41836414]
# Same Numbers
# Modelo: [40.62907]
# Real:   [40.692]
# Diff:  [-0.06292972]
# Same Numbers
# Modelo: [40.684715]
# Real:   [39.539]
# Diff:  [1.14571527]
# Different
# Modelo: [40.573433]
# Real:   [40.304]
# Diff:  [0.26943292]
# Same Numbers
# Modelo: [40.594128]
# Real:   [40.37]
# Diff:  [0.22412766]
# Same Numbers
# Modelo: [40.627613]
# Real:   [39.671]
# Diff:  [0.95661307]
# Same Numbers
# Modelo: [40.52758]
# Real:   [39.83]
# Diff:  [0.69758026]
# Same Numbers
# Modelo: [40.473965]
# Real:   [39.74]
# Diff:  [0.73396469]
# Same Numbers
# Modelo: [40.42179]
# Real:   [39.787]
# Diff:  [0.63479108]
# Same Numbers
# Modelo: [40.391212]
# Real:   [39.525]
# Diff:  [0.86621246]
# Same Numbers
# Modelo: [40.330124]
# Real:   [39.814]
# Diff:  [0.5161239]
# Same Numbers
# Modelo: [40.326767]
# Real:   [40.069]
# Diff:  [0.25776697]
# Same Numbers
# Modelo: [40.369297]
# Real:   [39.648]
# Diff:  [0.72129703]
# Same Numbers
# Modelo: [40.34943]
# Real:   [39.133]
# Diff:  [1.21643008]
# Different
# Modelo: [40.25199]
# Real:   [39.629]
# Diff:  [0.62299127]
# Same Numbers
# Modelo: [40.2435]
# Real:   [39.266]
# Diff:  [0.97749976]
# Same Numbers
# Modelo: [40.185883]
# Real:   [39.771]
# Diff:  [0.41488257]
# Same Numbers
# Modelo: [40.215733]
# Real:   [39.433]
# Diff:  [0.78273257]
# Same Numbers
# Modelo: [40.169968]
# Real:   [40.003]
# Diff:  [0.16696765]
# Same Numbers
# Modelo: [40.227043]
# Real:   [39.472]
# Diff:  [0.75504315]
# Same Numbers
# Modelo: [40.20528]
# Real:   [39.531]
# Diff:  [0.6742803]
# Same Numbers
# Modelo: [40.19886]
# Real:   [39.282]
# Diff:  [0.91686017]
# Same Numbers
# Modelo: [40.141018]
# Real:   [39.471]
# Diff:  [0.67001791]
# Same Numbers
# Modelo: [40.125328]
# Real:   [39.123]
# Diff:  [1.00232806]
# Different
# Modelo: [40.066357]
# Real:   [39.961]
# Diff:  [0.10535666]
# Same Numbers
# Modelo: [40.169823]
# Real:   [40.57]
# Diff:  [-0.40017731]
# Same Numbers
# Modelo: [40.55048]
# Real:   [39.199]
# Diff:  [1.35147989]
# Different
# Modelo: [40.634808]
# Real:   [42.499]
# Diff:  [-1.86419241]
# Different
# Modelo: [41.1794]
# Real:   [39.643]
# Diff:  [1.5364014]
# Different
# Modelo: [41.19761]
# Real:   [46.86]
# Diff:  [-5.66239105]
# Different
# Modelo: [43.109524]
# Real:   [48.837]
# Diff:  [-5.72747623]
# Different
# Modelo: [44.854416]
# Real:   [54.652]
# Diff:  [-9.79758411]
# Different
# Modelo: [47.090096]
# Real:   [52.908]
# Diff:  [-5.81790448]
# Different
# Modelo: [48.695774]
# Real:   [45.927]
# Diff:  [2.76877408]
# Different
# Modelo: [48.285496]
# Real:   [44.386]
# Diff:  [3.89949576]
# Different
# Modelo: [47.60371]
# Real:   [44.317]
# Diff:  [3.28671017]
# Different
# Modelo: [47.047398]
# Real:   [38.08]
# Diff:  [8.96739761]
# Different
# Modelo: [45.66124]
# Real:   [39.55]
# Diff:  [6.11123962]
# Different
# Modelo: [44.05879]
# Real:   [36.584]
# Diff:  [7.4747883]
# Different
# Modelo: [42.437202]
# Real:   [40.498]
# Diff:  [1.93920245]
# Different
# Modelo: [41.754948]
# Real:   [36.703]
# Diff:  [5.05194766]
# Different
# Modelo: [40.80562]
# Real:   [34.665]
# Diff:  [6.14061829]
# Different
# Modelo: [39.701725]
# Real:   [39.532]
# Diff:  [0.16972501]
# Same Numbers
# Modelo: [39.50729]
# Real:   [36.291]
# Diff:  [3.21628989]
# Different
# Modelo: [39.04583]
# Real:   [39.915]
# Diff:  [-0.86917023]
# Same Numbers
# Modelo: [39.20394]
# Real:   [35.358]
# Diff:  [3.84594135]
# Different
# Modelo: [38.84269]
# Real:   [39.943]
# Diff:  [-1.10031049]
# Different
# Modelo: [39.159233]
# Real:   [39.816]
# Diff:  [-0.65676691]
# Same Numbers
# Modelo: [39.458176]
# Real:   [41.907]
# Diff:  [-2.44882434]
# Different
# Modelo: [40.018444]
# Real:   [37.536]
# Diff:  [2.48244406]
# Different
# Modelo: [40.09143]
# Real:   [43.065]
# Diff:  [-2.97356934]
# Different
# Modelo: [40.83738]
# Real:   [42.058]
# Diff:  [-1.22062054]
# Different
# Modelo: [41.348366]
# Real:   [40.269]
# Diff:  [1.07936578]
# Different
# Modelo: [41.489925]
# Real:   [46.605]
# Diff:  [-5.11507462]
# Different
# Modelo: [42.3199]
# Real:   [41.157]
# Diff:  [1.16290051]
# Different
# Modelo: [42.332344]
# Real:   [37.905]
# Diff:  [4.42734406]
# Different
# Modelo: [41.834797]
# Real:   [39.427]
# Diff:  [2.40779691]
# Different
# Modelo: [41.597828]
# Real:   [35.534]
# Diff:  [6.06382791]
# Different
# Modelo: [40.92136]
# Real:   [39.641]
# Diff:  [1.28036002]
# Different
# Modelo: [40.848377]
# Real:   [36.619]
# Diff:  [4.22937723]
# Different
# Modelo: [40.409187]
# Real:   [39.764]
# Diff:  [0.64518732]
# Same Numbers
# Modelo: [40.449905]
# Real:   [38.751]
# Diff:  [1.6989054]
# Different
# Modelo: [40.113647]
# Real:   [39.868]
# Diff:  [0.24564746]
# Same Numbers
# Modelo: [40.064762]
# Real:   [40.224]
# Diff:  [-0.15923788]
# Same Numbers
# Modelo: [40.118446]
# Real:   [39.194]
# Diff:  [0.92444635]
# Same Numbers
# Modelo: [40.038822]
# Real:   [40.113]
# Diff:  [-0.07417783]
# Same Numbers
# Modelo: [40.361755]
# Real:   [41.133]
# Diff:  [-0.77124463]
# Same Numbers
# Modelo: [40.720955]
# Real:   [43.527]
# Diff:  [-2.8060451]
# Different
# Modelo: [41.333916]
# Real:   [44.217]
# Diff:  [-2.88308429]
# Different
# Modelo: [41.962543]
# Real:   [42.011]
# Diff:  [-0.04845651]
# Same Numbers
# Modelo: [42.390385]
# Real:   [43.188]
# Diff:  [-0.79761533]
# Same Numbers
# Modelo: [42.82306]
# Real:   [45.187]
# Diff:  [-2.36394092]
# Different
# Modelo: [43.410725]
# Real:   [45.923]
# Diff:  [-2.51227536]
# Different
# Modelo: [43.98322]
# Real:   [43.849]
# Diff:  [0.13421915]
# Same Numbers
# Modelo: [44.00321]
# Real:   [44.06]
# Diff:  [-0.05679184]
# Same Numbers
# Modelo: [44.042744]
# Real:   [49.266]
# Diff:  [-5.22325632]
# Different
# Modelo: [44.83178]
# Real:   [54.688]
# Diff:  [-9.85622052]
# Different
# Modelo: [46.360657]
# Real:   [48.434]
# Diff:  [-2.07334326]
# Different
# Modelo: [46.808]
# Real:   [43.778]
# Diff:  [3.02999866]
# Different
# Modelo: [46.43691]
# Real:   [41.98]
# Diff:  [4.45690872]
# Different
# Modelo: [45.756474]
# Real:   [41.886]
# Diff:  [3.87047354]
# Different
# Modelo: [45.096725]
# Real:   [41.835]
# Diff:  [3.26172546]
# Different
# Modelo: [44.382965]
# Real:   [41.975]
# Diff:  [2.40796509]
# Different
# Modelo: [43.851875]
# Real:   [41.615]
# Diff:  [2.23687531]
# Different
# Modelo: [43.355553]
# Real:   [41.335]
# Diff:  [2.02055267]
# Different
# Modelo: [42.922543]
# Real:   [42.424]
# Diff:  [0.49854257]
# Same Numbers
# Modelo: [42.88539]
# Real:   [42.373]
# Diff:  [0.51239124]
# Same Numbers
# Modelo: [42.863983]
# Real:   [42.25]
# Diff:  [0.61398315]
# Same Numbers
# Modelo: [42.824177]
# Real:   [41.755]
# Diff:  [1.06917679]
# Different
# Modelo: [42.725685]
# Real:   [41.978]
# Diff:  [0.74768512]
# Same Numbers
# Modelo: [42.52054]
# Real:   [40.936]
# Diff:  [1.58453833]
# Different
# Modelo: [42.24651]
# Real:   [41.409]
# Diff:  [0.83750955]
# Same Numbers
# Modelo: [42.116875]
# Real:   [41.551]
# Diff:  [0.56587469]
# Same Numbers
# Modelo: [42.058926]
# Real:   [40.523]
# Diff:  [1.53592563]
# Different
# Modelo: [41.932407]
# Real:   [41.363]
# Diff:  [0.56940738]
# Same Numbers
# Modelo: [41.94231]
# Real:   [41.161]
# Diff:  [0.78131033]
# Same Numbers
# Modelo: [41.90562]
# Real:   [41.259]
# Diff:  [0.64662057]
# Same Numbers
# Modelo: [41.91329]
# Real:   [40.775]
# Diff:  [1.13828812]
# Different
# Modelo: [41.869736]
# Real:   [40.864]
# Diff:  [1.00573572]
# Different
# Modelo: [41.808575]
# Real:   [41.077]
# Diff:  [0.73157468]
# Same Numbers
# Modelo: [41.78965]
# Real:   [41.129]
# Diff:  [0.66064996]
# Same Numbers
# Modelo: [41.78122]
# Real:   [40.38]
# Diff:  [1.40121948]
# Different
# Modelo: [41.611546]
# Real:   [40.152]
# Diff:  [1.45954556]
# Different
# Modelo: [41.429497]
# Real:   [40.743]
# Diff:  [0.68649677]
# Same Numbers
# Modelo: [41.359142]
# Real:   [39.777]
# Diff:  [1.5821423]
# Different
# Modelo: [41.15672]
# Real:   [40.039]
# Diff:  [1.11771921]
# Different
# Modelo: [41.02249]
# Real:   [40.152]
# Diff:  [0.87049146]
# Same Numbers
# Modelo: [40.927822]
# Real:   [40.002]
# Diff:  [0.92582211]
# Same Numbers
# Modelo: [40.830902]
# Real:   [40.169]
# Diff:  [0.6619021]
# Same Numbers
# Modelo: [40.77946]
# Real:   [39.912]
# Diff:  [0.86746091]
# Same Numbers
# Modelo: [40.67575]
# Real:   [40.143]
# Diff:  [0.53275073]
# Same Numbers
# Modelo: [40.635315]
# Real:   [40.119]
# Diff:  [0.51631494]
# Same Numbers
# Modelo: [40.60875]
# Real:   [40.016]
# Diff:  [0.59274939]
# Same Numbers
# Modelo: [40.579784]
# Real:   [40.218]
# Diff:  [0.36178439]
# Same Numbers
# Modelo: [40.60631]
# Real:   [39.846]
# Diff:  [0.7603118]
# Same Numbers
# Modelo: [40.57478]
# Real:   [39.662]
# Diff:  [0.91277951]
# Same Numbers
# Modelo: [40.51966]
# Real:   [39.792]
# Diff:  [0.72766095]
# Same Numbers
# Modelo: [40.491154]
# Real:   [39.691]
# Diff:  [0.80015372]
# Same Numbers
# Modelo: [40.439484]
# Real:   [39.812]
# Diff:  [0.62748364]
# Same Numbers
# Modelo: [40.419216]
# Real:   [39.952]
# Diff:  [0.46721616]
# Same Numbers
# Modelo: [40.42836]
# Real:   [39.955]
# Diff:  [0.47335999]
# Same Numbers
# Modelo: [40.44187]
# Real:   [40.093]
# Diff:  [0.34887164]
# Same Numbers
# Modelo: [40.568947]
# Real:   [42.6]
# Diff:  [-2.03105316]
# Different
# Modelo: [41.076195]
# Real:   [41.991]
# Diff:  [-0.91480524]
# Same Numbers
# Modelo: [41.387077]
# Real:   [41.442]
# Diff:  [-0.05492267]
# Same Numbers
# Modelo: [41.57897]
# Real:   [43.658]
# Diff:  [-2.07902814]
# Different
# Modelo: [42.93994]
# Real:   [40.165]
# Diff:  [2.77494141]
# Different
# Modelo: [43.385662]
# Real:   [42.812]
# Diff:  [0.57366208]
# Same Numbers
# Modelo: [43.9364]
# Real:   [43.845]
# Diff:  [0.09140137]
# Same Numbers
# Modelo: [44.44865]
# Real:   [49.775]
# Diff:  [-5.32634964]
# Different
# Modelo: [45.025993]
# Real:   [45.852]
# Diff:  [-0.82600665]
# Same Numbers
# Modelo: [45.065212]
# Real:   [44.033]
# Diff:  [1.03221225]
# Different
# Modelo: [44.95466]
# Real:   [36.189]
# Diff:  [8.76565851]
# Different
# Modelo: [43.729935]
# Real:   [38.133]
# Diff:  [5.59693469]
# Different
# Modelo: [42.484127]
# Real:   [38.968]
# Diff:  [3.51612704]
# Different
# Modelo: [41.64918]
# Real:   [37.213]
# Diff:  [4.43618137]
# Different
# Modelo: [40.82423]
# Real:   [38.828]
# Diff:  [1.99623019]
# Different
# Modelo: [40.436924]
# Real:   [43.063]
# Diff:  [-2.62607602]
# Different
# Modelo: [40.75466]
# Real:   [38.043]
# Diff:  [2.71166156]
# Different
# Modelo: [40.45358]
# Real:   [43.024]
# Diff:  [-2.57042105]
# Different
# Modelo: [40.906425]
# Real:   [38.614]
# Diff:  [2.29242548]
# Different
# Modelo: [40.733696]
# Real:   [43.031]
# Diff:  [-2.29730402]
# Different
# Modelo: [41.31604]
# Real:   [39.061]
# Diff:  [2.25504004]
# Different
# Modelo: [41.268204]
# Real:   [38.927]
# Diff:  [2.34120374]
# Different
# Modelo: [41.134052]
# Real:   [35.241]
# Diff:  [5.89305228]
# Different
# Modelo: [40.458607]
# Real:   [39.502]
# Diff:  [0.95660672]
# Same Numbers
# Modelo: [40.53251]
# Real:   [41.981]
# Diff:  [-1.44849115]
# Different
# Modelo: [40.948765]
# Real:   [39.763]
# Diff:  [1.1857648]
# Different
# Modelo: [41.02172]
# Real:   [44.164]
# Diff:  [-3.14227911]
# Different
# Modelo: [41.67115]
# Real:   [37.483]
# Diff:  [4.18815021]
# Different
# Modelo: [41.338085]
# Real:   [37.322]
# Diff:  [4.01608517]
# Different
# Modelo: [40.913795]
# Real:   [38.363]
# Diff:  [2.55079547]
# Different
# Modelo: [40.652752]
# Real:   [40.053]
# Diff:  [0.59975192]
# Same Numbers
# Modelo: [40.6807]
# Real:   [38.957]
# Diff:  [1.72369839]
# Different
# Modelo: [40.237507]
# Real:   [41.986]
# Diff:  [-1.74849313]
# Different
# Modelo: [40.370636]
# Real:   [40.29]
# Diff:  [0.08063599]
# Same Numbers
# Modelo: [40.359093]
# Real:   [42.745]
# Diff:  [-2.38590729]
# Different
# Modelo: [40.724174]
# Real:   [39.907]
# Diff:  [0.8171745]
# Same Numbers
# Modelo: [40.800503]
# Real:   [36.032]
# Diff:  [4.76850278]
# Different
# Modelo: [40.25521]
# Real:   [36.196]
# Diff:  [4.05921088]
# Different
# Modelo: [39.755272]
# Real:   [36.291]
# Diff:  [3.46427191]
# Different
# Modelo: [39.315094]
# Real:   [38.2]
# Diff:  [1.11509399]
# Different
# Modelo: [39.453064]
# Real:   [40.18]
# Diff:  [-0.72693604]
# Same Numbers
# Modelo: [39.81245]
# Real:   [40.973]
# Diff:  [-1.16054959]
# Different
# Modelo: [40.24164]
# Real:   [40.636]
# Diff:  [-0.39436182]
# Same Numbers
# Modelo: [40.555782]
# Real:   [41.071]
# Diff:  [-0.51521768]
# Same Numbers
# Modelo: [41.030605]
# Real:   [40.904]
# Diff:  [0.12660532]
# Same Numbers
# Modelo: [41.338333]
# Real:   [41.373]
# Diff:  [-0.03466687]
# Same Numbers
# Modelo: [41.611267]
# Real:   [40.692]
# Diff:  [0.91926709]
# Same Numbers
# Modelo: [41.69513]
# Real:   [40.761]
# Diff:  [0.93412939]
# Same Numbers
# Modelo: [42.082966]
# Real:   [40.909]
# Diff:  [1.17396585]
# Different
# Modelo: [42.30585]
# Real:   [41.223]
# Diff:  [1.08285098]
# Different
# Modelo: [42.46941]
# Real:   [41.952]
# Diff:  [0.51740994]
# Same Numbers
# Modelo: [42.659164]
# Real:   [41.086]
# Diff:  [1.57316443]
# Different
# Modelo: [42.295204]
# Real:   [42.072]
# Diff:  [0.22320416]
# Same Numbers
# Modelo: [42.20429]
# Real:   [41.972]
# Diff:  [0.23228848]
# Same Numbers
# Modelo: [42.16284]
# Real:   [42.735]
# Diff:  [-0.5721582]
# Same Numbers
# Modelo: [42.281242]
# Real:   [42.152]
# Diff:  [0.12924237]
# Same Numbers
# Modelo: [42.116974]
# Real:   [41.463]
# Diff:  [0.65397388]
# Same Numbers
# Modelo: [41.94839]
# Real:   [41.805]
# Diff:  [0.14339096]
# Same Numbers
# Modelo: [41.893333]
# Real:   [42.491]
# Diff:  [-0.59766656]
# Same Numbers
# Modelo: [41.979565]
# Real:   [42.399]
# Diff:  [-0.41943533]
# Same Numbers
# Modelo: [42.122795]
# Real:   [42.601]
# Diff:  [-0.4782049]
# Same Numbers
# Modelo: [42.282303]
# Real:   [41.88]
# Diff:  [0.40230286]
# Same Numbers
# Modelo: [42.311066]
# Real:   [41.978]
# Diff:  [0.33306567]
# Same Numbers
# Modelo: [42.343594]
# Real:   [41.318]
# Diff:  [1.0255936]
# Different
# Modelo: [42.211548]
# Real:   [41.063]
# Diff:  [1.14854785]
# ...
# Real:   [36.233]
# Diff:  [3.1427515]
# Different
# Modelo: [39.019352]
# Real:   [36.094]
# Diff:  [2.92535196]
# Different
# Modelo: [38.686085]
# Real:   [36.399]
# Diff:  [2.28708475]
# Different
# Modelo: [38.41846]
# Real:   [36.505]
# Diff:  [1.91346085]
# Different
# Modelo: [38.206913]
# Real:   [36.256]
# Diff:  [1.95091299]
# Different
# Modelo: [37.994015]
# Real:   [36.393]
# Diff:  [1.60101474]
# Different
# Modelo: [37.837444]
# Real:   [36.242]
# Diff:  [1.59544431]
# Different
# Modelo: [37.687874]
# Real:   [36.194]
# Diff:  [1.49387384]
# Different
# Modelo: [37.559464]
# Real:   [37.512]
# Diff:  [0.0474635]
# Same Numbers
# Modelo: [37.65421]
# Real:   [43.147]
# Diff:  [-5.49279086]
# Different
# Modelo: [38.597713]
# Real:   [42.856]
# Diff:  [-4.25828653]
# Different
# Modelo: [39.54444]
# Real:   [43.051]
# Diff:  [-3.50655878]
# Different
# Modelo: [40.360294]
# Real:   [42.8]
# Diff:  [-2.43970566]
# Different
# Modelo: [40.98419]
# Real:   [45.305]
# Diff:  [-4.32080811]
# Different
# Modelo: [41.852848]
# Real:   [45.868]
# Diff:  [-4.01515195]
# Different
# Modelo: [42.78531]
# Real:   [42.337]
# Diff:  [0.44830884]
# Same Numbers
# Modelo: [42.980232]
# Real:   [45.553]
# Diff:  [-2.57276776]
# Different
# Modelo: [43.553757]
# Real:   [44.538]
# Diff:  [-0.98424329]
# Same Numbers
# Modelo: [43.842316]
# Real:   [38.613]
# Diff:  [5.22931567]
# Different
# Modelo: [43.101776]
# Real:   [38.683]
# Diff:  [4.41877612]
# Different
# Modelo: [42.424507]
# Real:   [38.916]
# Diff:  [3.50850714]
# Different
# Modelo: [41.846996]
# Real:   [39.045]
# Diff:  [2.80199631]
# Different
# Modelo: [41.370636]
# Real:   [38.758]
# Diff:  [2.61263599]
# Different
# Modelo: [40.933716]
# Real:   [38.754]
# Diff:  [2.17971582]
# Different
# Modelo: [40.578712]
# Real:   [38.764]
# Diff:  [1.81471246]
# Different
# Modelo: [40.298138]
# Real:   [38.676]
# Diff:  [1.62213766]
# Different
# Modelo: [40.066685]
# Real:   [38.5]
# Diff:  [1.56668472]
# Different
# Modelo: [39.83827]
# Real:   [38.972]
# Diff:  [0.86626828]
# Same Numbers
# Modelo: [39.737553]
# Real:   [38.805]
# Diff:  [0.93255264]
# Same Numbers
# Modelo: [39.64806]
# Real:   [38.732]
# Diff:  [0.91605984]
# Same Numbers
# Modelo: [39.576744]
# Real:   [38.314]
# Diff:  [1.26274408]
# Different
# Modelo: [39.48304]
# Real:   [38.363]
# Diff:  [1.12003986]
# Different
# Modelo: [39.41091]
# Real:   [38.346]
# Diff:  [1.06491156]
# Different
# Modelo: [39.34896]
# Real:   [38.27]
# Diff:  [1.07896088]
# Different
# Modelo: [39.287746]
# Real:   [38.617]
# Diff:  [0.67074643]
# Same Numbers
# Modelo: [39.314625]
# Real:   [38.82]
# Diff:  [0.49462479]
# Same Numbers
# Modelo: [39.36658]
# Real:   [38.742]
# Diff:  [0.62458096]
# Same Numbers
# Modelo: [39.39993]
# Real:   [38.465]
# Diff:  [0.93492905]
# Same Numbers
# Modelo: [39.38553]
# Real:   [38.613]
# Diff:  [0.77252856]
# Same Numbers
# Modelo: [39.374985]
# Real:   [38.806]
# Diff:  [0.56898474]
# Same Numbers
# Modelo: [39.398254]
# Real:   [38.717]
# Diff:  [0.68125439]
# Same Numbers
# Modelo: [39.408115]
# Real:   [38.634]
# Diff:  [0.77411539]
# Same Numbers
# Modelo: [39.405434]
# Real:   [38.398]
# Diff:  [1.00743365]
# Different
# Modelo: [39.36851]
# Real:   [38.368]
# Diff:  [1.0005112]
# Different
# Modelo: [39.330395]
# Real:   [38.469]
# Diff:  [0.86139474]
# Same Numbers
# Modelo: [39.311985]
# Real:   [38.376]
# Diff:  [0.93598502]
# Same Numbers
# Modelo: [39.28305]
# Real:   [38.292]
# Diff:  [0.99105054]
# Same Numbers
# Modelo: [39.239716]
# Real:   [38.327]
# Diff:  [0.91271558]
# Same Numbers
# Modelo: [39.2102]
# Real:   [38.335]
# Diff:  [0.87520126]
# Same Numbers
# Modelo: [39.188538]
# Real:   [38.224]
# Diff:  [0.9645376]
# Same Numbers
# Modelo: [39.155594]
# Real:   [38.323]
# Diff:  [0.83259387]
# Same Numbers
# Modelo: [39.141903]
# Real:   [38.432]
# Diff:  [0.70990292]
# Same Numbers
# Modelo: [39.149162]
# Real:   [38.33]
# Diff:  [0.81916229]
# Same Numbers
# Modelo: [39.14276]
# Real:   [38.353]
# Diff:  [0.78976123]
# Same Numbers
# Modelo: [39.141953]
# Real:   [38.336]
# Diff:  [0.80595251]
# Same Numbers
# Modelo: [39.15775]
# Real:   [38.339]
# Diff:  [0.81874918]
# Same Numbers
# Modelo: [39.16685]
# Real:   [38.444]
# Diff:  [0.72285104]
# Same Numbers
# Modelo: [39.18734]
# Real:   [38.26]
# Diff:  [0.92733978]
# Same Numbers
# Modelo: [39.175465]
# Real:   [38.39]
# Diff:  [0.78546463]
# Same Numbers
# Modelo: [39.164223]
# Real:   [38.339]
# Diff:  [0.82522272]
# Same Numbers
# Modelo: [39.15123]
# Real:   [38.236]
# Diff:  [0.91522986]
# Same Numbers
# Modelo: [39.127193]
# Real:   [38.185]
# Diff:  [0.94219345]
# Same Numbers
# Modelo: [39.10014]
# Real:   [38.347]
# Diff:  [0.75313962]
# Same Numbers
# Modelo: [39.112305]
# Real:   [38.366]
# Diff:  [0.74630469]
# Same Numbers
# Modelo: [39.124752]
# Real:   [38.197]
# Diff:  [0.92775204]
# Same Numbers
# Modelo: [39.10977]
# Real:   [38.17]
# Diff:  [0.93977173]
# Same Numbers
# Modelo: [39.09146]
# Real:   [38.271]
# Diff:  [0.82046118]
# Same Numbers
# Modelo: [39.110245]
# Real:   [38.206]
# Diff:  [0.90424475]
# Same Numbers
# Modelo: [39.110863]
# Real:   [38.158]
# Diff:  [0.95286273]
# Same Numbers
# Modelo: [39.100304]
# Real:   [38.352]
# Diff:  [0.74830365]
# Same Numbers
# Modelo: [39.117573]
# Real:   [38.506]
# Diff:  [0.61157278]
# Same Numbers
# Modelo: [39.122284]
# Real:   [38.54]
# Diff:  [0.58228394]
# Same Numbers
# Modelo: [39.14146]
# Real:   [38.345]
# Diff:  [0.79646042]
# Same Numbers
# Modelo: [39.13952]
# Real:   [38.658]
# Diff:  [0.48151874]
# Same Numbers
# Modelo: [39.193676]
# Real:   [38.451]
# Diff:  [0.74267599]
# Same Numbers
# Modelo: [39.029575]
# Real:   [39.089]
# Diff:  [-0.05942465]
# Same Numbers
# Modelo: [39.02997]
# Real:   [38.814]
# Diff:  [0.21596826]
# Same Numbers
# Modelo: [39.029716]
# Real:   [36.408]
# Diff:  [2.62171649]
# Different
# Modelo: [38.6812]
# Real:   [36.341]
# Diff:  [2.34019812]
# Different
# Modelo: [38.412113]
# Real:   [34.11]
# Diff:  [4.30211319]
# Different
# Modelo: [37.85826]
# Real:   [36.079]
# Diff:  [1.77926111]
# Different
# Modelo: [37.661617]
# Real:   [36.315]
# Diff:  [1.34661728]
# Different
# Modelo: [37.555805]
# Real:   [36.336]
# Diff:  [1.21980521]
# Different
# Modelo: [37.48425]
# Real:   [35.951]
# Diff:  [1.53324911]
# Different
# Modelo: [37.380497]
# Real:   [36.161]
# Diff:  [1.21949698]
# Different
# Modelo: [37.339428]
# Real:   [36.022]
# Diff:  [1.31742795]
# Different
# Modelo: [37.278687]
# Real:   [36.241]
# Diff:  [1.03768652]
# Different
# Modelo: [37.265167]
# Real:   [35.864]
# Diff:  [1.40116724]
# Different
# Modelo: [37.202488]
# Real:   [35.981]
# Diff:  [1.22148795]
# Different
# Modelo: [37.169357]
# Real:   [36.223]
# Diff:  [0.9463573]
# Same Numbers
# Modelo: [37.181526]
# Real:   [36.071]
# Diff:  [1.11052618]
# Different
# Modelo: [37.539238]
# Real:   [36.155]
# Diff:  [1.38423798]
# Different
# Modelo: [37.758923]
# Real:   [36.084]
# Diff:  [1.67492258]
# Different
# Modelo: [37.863476]
# Real:   [36.603]
# Diff:  [1.2604758]
# Different
# Modelo: [37.982315]
# Real:   [36.149]
# Diff:  [1.83331506]
# Different
# Modelo: [37.673153]
# Real:   [36.137]
# Diff:  [1.53615292]
# Different
# Modelo: [37.47421]
# Real:   [36.255]
# Diff:  [1.21920883]
# Different
# Modelo: [37.36591]
# Real:   [36.103]
# Diff:  [1.26290958]
# Different
# Modelo: [37.284554]
# Real:   [36.263]
# Diff:  [1.02155353]
# Different
# Modelo: [37.207577]
# Real:   [36.281]
# Diff:  [0.92657675]
# Same Numbers
# Modelo: [37.178455]
# Real:   [36.026]
# Diff:  [1.15245535]
# Different
# Modelo: [37.13897]
# Real:   [36.715]
# Diff:  [0.42396942]
# Same Numbers
# Modelo: [37.222084]
# Real:   [36.337]
# Diff:  [0.88508405]
# Same Numbers
# Modelo: [37.41593]
# Real:   [35.232]
# Diff:  [2.1839317]
# Different
# Modelo: [37.372223]
# Real:   [36.081]
# Diff:  [1.2912229]
# Different
# Modelo: [37.41712]
# Real:   [34.963]
# Diff:  [2.45412189]
# Different
# Modelo: [37.27529]
# Real:   [35.827]
# Diff:  [1.44829144]
# Different
# Modelo: [37.71209]
# Real:   [37.951]
# Diff:  [-0.23891046]
# Same Numbers
# Modelo: [38.27266]
# Real:   [38.625]
# Diff:  [-0.3523407]
# Same Numbers
# Modelo: [38.7755]
# Real:   [39.14]
# Diff:  [-0.36449875]
# Same Numbers
# Modelo: [39.223324]
# Real:   [38.919]
# Diff:  [0.30432382]
# Same Numbers
# Modelo: [39.618134]
# Real:   [39.105]
# Diff:  [0.51313354]
# Same Numbers
# Modelo: [39.909653]
# Real:   [38.768]
# Diff:  [1.14165271]
# Different
# Modelo: [40.05127]
# Real:   [39.084]
# Diff:  [0.96726953]
# Same Numbers
# Modelo: [40.17316]
# Real:   [39.085]
# Diff:  [1.08816055]
# Different
# Modelo: [39.72876]
# Real:   [38.884]
# Diff:  [0.84475977]
# Same Numbers
# Modelo: [39.443882]
# Real:   [39.493]
# Diff:  [-0.04911801]
# Same Numbers
# Modelo: [39.370197]
# Real:   [39.036]
# Diff:  [0.3341973]
# Same Numbers
# Modelo: [39.298862]
# Real:   [39.16]
# Diff:  [0.13886246]
# Same Numbers
# Modelo: [39.290108]
# Real:   [38.788]
# Diff:  [0.50210773]
# Same Numbers
# Modelo: [39.257103]
# Real:   [38.916]
# Diff:  [0.34110297]
# Same Numbers
# Modelo: [39.26753]
# Real:   [39.108]
# Diff:  [0.15952853]
# Same Numbers
# Modelo: [39.32022]
# Real:   [39.068]
# Diff:  [0.25222095]
# Same Numbers
# Modelo: [39.37279]
# Real:   [38.953]
# Diff:  [0.41979129]
# Same Numbers
# Modelo: [39.408104]
# Real:   [38.758]
# Diff:  [0.65010394]
# Same Numbers
# Modelo: [39.41287]
# Real:   [38.771]
# Diff:  [0.6418685]
# Same Numbers
# Modelo: [39.420185]
# Real:   [38.909]
# Diff:  [0.51118509]
# Same Numbers
# Modelo: [39.41033]
# Real:   [38.863]
# Diff:  [0.54733173]
# Same Numbers
# Modelo: [39.40842]
# Real:   [38.957]
# Diff:  [0.45142056]
# Same Numbers
# Modelo: [39.42973]
# Real:   [38.71]
# Diff:  [0.71972946]
# Same Numbers
# Modelo: [39.4173]
# Real:   [38.817]
# Diff:  [0.60030118]
# Same Numbers
# Modelo: [39.45586]
# Real:   [39.007]
# Diff:  [0.44886014]
# Same Numbers
# Modelo: [39.51151]
# Real:   [38.955]
# Diff:  [0.55650894]
# Same Numbers
# Modelo: [39.5489]
# Real:   [39.053]
# Diff:  [0.4959006]
# Same Numbers
# Modelo: [39.59323]
# Real:   [38.585]
# Diff:  [1.0082312]
# Different
# Modelo: [39.56135]
# Real:   [38.436]
# Diff:  [1.12535178]
# Different
# Modelo: [39.505966]
# Real:   [38.761]
# Diff:  [0.74496619]
# Same Numbers
# Modelo: [39.503033]
# Real:   [38.47]
# Diff:  [1.03303268]
# Different
# Modelo: [39.456722]
# Real:   [38.423]
# Diff:  [1.03372226]
# Different
# Modelo: [39.38345]
# Real:   [38.268]
# Diff:  [1.11544955]
# Different
# Modelo: [39.3045]
# Real:   [38.346]
# Diff:  [0.95850058]
# Same Numbers
# Modelo: [39.253532]
# Real:   [38.396]
# Diff:  [0.85753241]
# Same Numbers
# Modelo: [39.222607]
# Real:   [38.372]
# Diff:  [0.85060666]
# Same Numbers
# Modelo: [39.187943]
# Real:   [38.575]
# Diff:  [0.6129425]
# Same Numbers
# Modelo: [39.19571]
# Real:   [38.628]
# Diff:  [0.56770923]
# Same Numbers
# Modelo: [39.216507]
# Real:   [38.877]
# Diff:  [0.33950696]
# Same Numbers
# Modelo: [39.27645]
# Real:   [38.702]
# Diff:  [0.57445111]
# Same Numbers
# Modelo: [39.311123]
# Real:   [38.411]
# Diff:  [0.90012289]
# Same Numbers
# Modelo: [39.29579]
# Real:   [38.393]
# Diff:  [0.90279163]
# Same Numbers
# Modelo: [39.276386]
# Real:   [38.295]
# Diff:  [0.98138626]
# Same Numbers
# Modelo: [39.242393]
# Real:   [38.343]
# Diff:  [0.89939349]
# Same Numbers
# Modelo: [39.217564]
# Real:   [38.443]
# Diff:  [0.77456363]
# Same Numbers
# Modelo: [39.2117]
# Real:   [38.455]
# Diff:  [0.75670044]
# Same Numbers
# Modelo: [39.21002]
# Real:   [38.53]
# Diff:  [0.68001816]
# Same Numbers
# Modelo: [39.22131]
# Real:   [38.291]
# Diff:  [0.93030966]
# Same Numbers
# Modelo: [39.191162]
# Real:   [38.485]
# Diff:  [0.70616211]
# Same Numbers
# Modelo: [39.19544]
# Real:   [38.531]
# Diff:  [0.66443839]
# Same Numbers
# Modelo: [39.207764]
# Real:   [38.634]
# Diff:  [0.57376367]
# Same Numbers
# Modelo: [39.235634]
# Real:   [38.409]
# Diff:  [0.82663385]
# Same Numbers
# Modelo: [39.225483]
# Real:   [38.478]
# Diff:  [0.74748294]
# Same Numbers
# Modelo: [39.226826]
# Real:   [38.311]
# Diff:  [0.91582571]
# Same Numbers
# Modelo: [39.202614]
# Real:   [38.31]
# Diff:  [0.89261383]
# Same Numbers
# Modelo: [39.18083]
# Real:   [38.385]
# Diff:  [0.79582809]
# Same Numbers
# Modelo: [39.171093]
# Real:   [38.514]
# Diff:  [0.65709299]
# Same Numbers
# Modelo: [39.183655]
# Real:   [38.862]
# Diff:  [0.32165479]
# Same Numbers
# Modelo: [39.24903]
# Real:   [38.809]
# Diff:  [0.44003107]
# Same Numbers
# Modelo: [39.300385]
# Real:   [38.589]
# Diff:  [0.71138452]
# Same Numbers
# Modelo: [39.335747]
# Real:   [38.843]
# Diff:  [0.49274677]
# Same Numbers
# Modelo: [39.39534]
# Real:   [38.705]
# Diff:  [0.69033997]
# Same Numbers
# Modelo: [39.420376]
# Real:   [38.66]
# Diff:  [0.76037582]
# Same Numbers
# Modelo: [39.43008]
# Real:   [38.353]
# Diff:  [1.07708041]
# Different
# Modelo: [39.358974]
# Real:   [37.638]
# Diff:  [1.72097446]
# Different
# Modelo: [39.19349]
# Real:   [37.993]
# Diff:  [1.20048907]
# Different
# Modelo: [39.10375]
# Real:   [35.892]
# Diff:  [3.21174832]
# Different
# Modelo: [38.713356]
# Real:   [35.976]
# Diff:  [2.73735602]
# Different
# Modelo: [38.164566]
# Real:   [36.004]
# Diff:  [2.16056604]
# Different
# Modelo: [37.76478]
# Real:   [35.822]
# Diff:  [1.94277814]
# Different
# Modelo: [37.447002]
# Real:   [35.973]
# Diff:  [1.47400241]
# Different
# Modelo: [37.239937]
# Real:   [36.049]
# Diff:  [1.19093683]
# Different
# Modelo: [37.14567]
# Real:   [35.924]
# Diff:  [1.22167184]
# Different
# Modelo: [37.06468]
# Real:   [36.]
# Diff:  [1.06467819]
# Different
# Modelo: [37.021294]
# Real:   [36.133]
# Diff:  [0.88829364]
# Same Numbers
# Modelo: [37.01585]
# Real:   [35.882]
# Diff:  [1.13385007]
# Different
# Modelo: [36.9797]
# Real:   [36.018]
# Diff:  [0.96169818]
# Same Numbers
# Modelo: [36.975475]
# Real:   [36.124]
# Diff:  [0.85147531]
# Same Numbers
# Modelo: [36.99304]
# Real:   [35.889]
# Diff:  [1.10403818]
# Different
# Modelo: [36.977345]
# Real:   [36.049]
# Diff:  [0.92834451]
# Same Numbers
# Modelo: [37.002575]
# Real:   [36.075]
# Diff:  [0.92757492]
# Same Numbers
# Modelo: [37.02593]
# Real:   [36.146]
# Diff:  [0.8799285]
# Same Numbers
# Modelo: [37.05542]
# Real:   [36.204]
# Diff:  [0.85141992]
# Same Numbers
# Modelo: [37.08854]
# Real:   [35.996]
# Diff:  [1.09253912]
# Different
# Modelo: [37.07893]
# Real:   [36.156]
# Diff:  [0.9229299]
# Same Numbers
# Modelo: [37.093937]
# Real:   [36.031]
# Diff:  [1.06293692]
# Different
# Modelo: [37.088116]
# Real:   [36.364]
# Diff:  [0.72411569]
# Same Numbers
# Modelo: [37.132416]
# Real:   [36.003]
# Diff:  [1.12941577]
# Different
# Modelo: [37.131668]
# Real:   [36.14]
# Diff:  [0.99166809]
# Same Numbers
# Modelo: [37.145733]
# Real:   [36.048]
# Diff:  [1.09773288]
# Different
# Modelo: [37.140476]
# Real:   [35.809]
# Diff:  [1.33147623]
# Different
# Modelo: [37.09724]
# Real:   [35.793]
# Diff:  [1.30424045]
# Different
# Modelo: [36.99549]
# Real:   [36.333]
# Diff:  [0.66249103]
# Same Numbers
# Modelo: [37.005043]
# Real:   [35.747]
# Diff:  [1.25804303]
# Different
# Modelo: [36.93985]
# Real:   [35.9]
# Diff:  [1.03984985]
# Different
# Modelo: [36.913677]
# Real:   [35.788]
# Diff:  [1.12567722]
# Different
# Modelo: [37.076714]
# Real:   [36.277]
# Diff:  [0.79971356]
# Same Numbers
# Modelo: [37.2359]
# Real:   [38.027]
# Diff:  [-0.79109912]
# Same Numbers
# Modelo: [37.603424]
# Real:   [38.887]
# Diff:  [-1.28357593]
# Different
# Modelo: [38.035103]
# Real:   [38.761]
# Diff:  [-0.72589716]
# Same Numbers
# Modelo: [38.47326]
# Real:   [39.185]
# Diff:  [-0.71174103]
# Same Numbers
# Modelo: [38.868595]
# Real:   [39.057]
# Diff:  [-0.18840488]
# Same Numbers
# Modelo: [39.152554]
# Real:   [38.697]
# Diff:  [0.45555356]
# Same Numbers
# Modelo: [39.308853]
# Real:   [38.446]
# Diff:  [0.86285315]
# Same Numbers
# Modelo: [39.387947]
# Real:   [38.76]
# Diff:  [0.62794708]
# Same Numbers
# Modelo: [39.473007]
# Real:   [38.994]
# Diff:  [0.4790072]
# Same Numbers
# Modelo: [39.561493]
# Real:   [39.027]
# Diff:  [0.53449292]
# Same Numbers
# Modelo: [39.629566]
# Real:   [38.644]
# Diff:  [0.98556619]
# Same Numbers
# Modelo: [39.608444]
# Real:   [38.42]
# Diff:  [1.18844421]
# Different
# Modelo: [39.549465]
# Real:   [38.528]
# Diff:  [1.02146518]
# Different
# Modelo: [39.508614]
# Real:   [38.313]
# Diff:  [1.19561359]
# Different
# Modelo: [39.43842]
# Real:   [38.273]
# Diff:  [1.16541934]
# Different
# Modelo: [39.36108]
# Real:   [38.848]
# Diff:  [0.51308017]
# Same Numbers
# Modelo: [39.384262]
# Real:   [38.98]
# Diff:  [0.40426208]
# Same Numbers
# Modelo: [39.430725]
# Real:   [38.676]
# Diff:  [0.7547251]
# Same Numbers
# Modelo: [39.430347]
# Real:   [38.451]
# Diff:  [0.97934744]
# Same Numbers
# Modelo: [39.39442]
# Real:   [38.424]
# Diff:  [0.97042062]
# Same Numbers
# Modelo: [39.358746]
# Real:   [38.288]
# Diff:  [1.07074557]
# Different
# Modelo: [39.30738]
# Real:   [38.932]
# Diff:  [0.37538068]
# Same Numbers
# Modelo: [39.36067]
# Real:   [39.218]
# Diff:  [0.14266818]
# Same Numbers
# Modelo: [39.4632]
# Real:   [38.82]
# Diff:  [0.64319962]
# Same Numbers
# Modelo: [39.493416]
# Real:   [38.481]
# Diff:  [1.01241583]
# Different
# Modelo: [39.465527]
# Real:   [38.313]
# Diff:  [1.15252658]
# Different
# Modelo: [39.410873]
# Real:   [38.493]
# Diff:  [0.91787341]
# Same Numbers
# Modelo: [39.351685]
# Real:   [38.577]
# Diff:  [0.77468457]
# Same Numbers
# Modelo: [39.323387]
# Real:   [38.619]
# Diff:  [0.70438715]
# Same Numbers
# Quantity of same numbers:  1385  records
# Quantity of different numbers:  1149  records
# Percentage:  54.7 %
