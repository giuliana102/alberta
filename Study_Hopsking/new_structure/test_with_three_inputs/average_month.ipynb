# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
# Out:
# C:\Users\lagg\AppData\Local\Temp\ipykernel_19372\388347847.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["Vacation"]
del df["summer_classes"]
del df["Theres_sun"]
del df["temp_ant"]
del df["Average_hour_day_ant"]
del df["month"]
del df["Timestamp"]

df
# Out:
#        RealPower  EV_Power  Average_hour_month
# 0         51.488       0.0           52.269892
# 1         51.794       0.0           52.269892
# 2         51.397       0.0           52.269892
# 3         50.765       0.0           52.269892
# 4         51.206       0.0           51.763875
# ...          ...       ...                 ...
# 26299     38.313       0.0           40.184637
# 26300     38.493       0.0           40.048847
# 26301     38.577       0.0           40.048847
# 26302     38.619       0.0           40.048847
# 26303     38.394       0.0           40.048847
#
# [26304 rows x 3 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
#df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power  Average_hour_month
# count  26304.000000  26304.000000        26304.000000
# mean      48.307932      6.167214           48.305800
# std        5.717560      9.099070            4.685430
# min       -1.161000     -6.400000           37.582581
# 25%       45.886000      0.000000           45.643573
# 50%       48.319000      0.000000           48.419089
# 75%       51.776500      9.480000           52.001367
# max       82.339000     55.150000           56.401933

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (21043, 3)
# Validation set size: (2630, 3)
# Testing set size: (2631, 3)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20946, 96, 3), y_tr: (20946, 1, 1)
# Set de validación - x_vl: (2533, 96, 3), y_vl: (2533, 1, 1)
# Set de prueba - x_ts: (2534, 96, 3), y_ts: (2534, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488     ,  0.        , 52.26989167],
#        [51.794     ,  0.        , 52.26989167],
#        [51.397     ,  0.        , 52.26989167],
#        [50.765     ,  0.        , 52.26989167],
#        [51.206     ,  0.        , 51.763875  ],
#        [51.219     ,  0.        , 51.763875  ],
#        [50.654     ,  0.        , 51.763875  ],
#        [50.491     ,  0.        , 51.763875  ],
#        [50.577     ,  0.        , 51.51185   ],
#        [50.654     ,  0.        , 51.51185   ],
#        [50.275     ,  0.        , 51.51185   ],
#        [50.022     ,  0.        , 51.51185   ],
#        [49.987     ,  0.        , 51.30015   ],
#        [50.443     ,  0.        , 51.30015   ],
#        [50.345     ,  0.        , 51.30015   ],
#        [50.239     ,  0.        , 51.30015   ],
#        [50.716     ,  0.        , 51.242325  ],
#        [50.673     ,  0.        , 51.242325  ],
#        [50.407     ,  0.        , 51.242325  ],
#        [50.605     ,  0.        , 51.242325  ],
#        [50.733     ,  0.        , 52.51599167],
#        [52.101     ,  0.        , 52.51599167],
#        [52.23      ,  0.        , 52.51599167],
#        [53.73      ,  0.        , 52.51599167],
#        [53.611     ,  0.        , 53.92976667],
#        [53.646     ,  0.        , 53.92976667],
#        [53.21      ,  0.        , 53.92976667],
#        [53.806     ,  0.        , 53.92976667],
#        [53.582     ,  0.        , 53.794325  ],
#        [52.526     ,  0.        , 53.794325  ],
#        [49.983     ,  5.2       , 53.794325  ],
#        [50.513     ,  8.11      , 53.794325  ],
#        [53.22      , 11.01      , 54.11181667],
#        [55.027     , 16.35      , 54.11181667],
#        [53.067     , 17.54      , 54.11181667],
#        [52.949     , 22.48      , 54.11181667],
#        [51.79      , 23.2       , 54.09016667],
#        [50.477     , 22.37      , 54.09016667],
#        [48.413     , 29.37      , 54.09016667],
#        [50.593     , 25.27      , 54.09016667],
#        [51.712     , 28.57      , 54.350775  ],
#        [49.816     , 33.57      , 54.350775  ],
#        [54.568     , 22.7       , 54.350775  ],
#        [59.61      , 15.93      , 54.350775  ],
#        [56.574     , 10.3       , 55.38069167],
#        [52.774     ,  9.7       , 55.38069167],
#        [56.809     ,  9.7       , 55.38069167],
#        [51.718     ,  5.7       , 55.38069167],
#        [53.128     ,  3.18      , 55.67538333],
#        [54.716     , 12.23      , 55.67538333],
#        [48.839     , 13.79      , 55.67538333],
#        [53.15      , 18.32      , 55.67538333],
#        [56.602     , 10.62      , 55.95880833],
#        [67.519     , 21.57      , 55.95880833],
#        [65.695     , 24.67      , 55.95880833],
#        [62.946     , 11.98      , 55.95880833],
#        [50.613     , 11.69      , 55.6755    ],
#        [48.255     , 10.14      , 55.6755    ],
#        [46.57      ,  8.14      , 55.6755    ],
#        [45.438     ,  8.54      , 55.6755    ],
#        [59.025     ,  7.12      , 55.05800833],
#        [57.188     ,  7.27      , 55.05800833],
#        [59.485     , 10.95      , 55.05800833],
#        [59.79      , 16.3       , 55.05800833],
#        [59.683     , 14.12      , 54.77663333],
#        [59.392     ,  8.99      , 54.77663333],
#        [57.961     ,  8.59      , 54.77663333],
#        [58.789     ,  6.        , 54.77663333],
#        [61.564     ,  5.53      , 54.4477    ],
#        [54.152     ,  5.53      , 54.4477    ],
#        [54.354     ,  5.53      , 54.4477    ],
#        [55.792     ,  5.53      , 54.4477    ],
#        [53.667     ,  5.53      , 54.121675  ],
#        [55.323     ,  5.53      , 54.121675  ],
#        [53.986     ,  5.06      , 54.121675  ],
#        [53.523     ,  4.3       , 54.121675  ],
#        [56.197     ,  5.07      , 56.40193333],
#        [56.316     , 12.39      , 56.40193333],
#        [57.141     , 15.58      , 56.40193333],
#        [56.48      , 15.58      , 56.40193333],
#        [56.714     , 14.87      , 55.93644167],
#        [56.187     , 12.17      , 55.93644167],
#        [55.675     , 19.89      , 55.93644167],
#        [57.27      , 14.77      , 55.93644167],
#        [55.669     ,  9.07      , 55.46695833],
#        [56.501     ,  9.07      , 55.46695833],
#        [55.379     ,  9.07      , 55.46695833],
#        [53.727     ,  4.67      , 55.46695833],
#        [53.533     ,  0.4       , 53.61235   ],
#        [53.248     ,  0.        , 53.61235   ],
#        [52.776     ,  0.        , 53.61235   ],
#        [52.309     ,  0.        , 53.61235   ],
#        [52.465     ,  0.        , 52.66370833],
#        [51.948     ,  0.        , 52.66370833],
#        [51.993     ,  0.        , 52.66370833],
#        [51.682     ,  0.        , 52.66370833]])

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]])

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -1.0000000000000004
# Maximun value per dimension: 0.8385052802599514

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (3):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 110 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/110
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 47s - loss: 0.2242 - accuracy: 0.0000e+00 - val_loss: 0.0883 - val_accuracy: 0.0000e+00 - 47s/epoch - 579ms/step
# Epoch 2/110
# 82/82 - 33s - loss: 0.1783 - accuracy: 0.0000e+00 - val_loss: 0.0907 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 3/110
# 82/82 - 32s - loss: 0.1374 - accuracy: 0.0000e+00 - val_loss: 0.0952 - val_accuracy: 0.0000e+00 - 32s/epoch - 391ms/step
# Epoch 4/110
# 82/82 - 32s - loss: 0.1075 - accuracy: 0.0000e+00 - val_loss: 0.0989 - val_accuracy: 0.0000e+00 - 32s/epoch - 394ms/step
# Epoch 5/110
# 82/82 - 32s - loss: 0.0950 - accuracy: 0.0000e+00 - val_loss: 0.0952 - val_accuracy: 0.0000e+00 - 32s/epoch - 389ms/step
# Epoch 6/110
# 82/82 - 32s - loss: 0.0899 - accuracy: 0.0000e+00 - val_loss: 0.0902 - val_accuracy: 0.0000e+00 - 32s/epoch - 395ms/step
# Epoch 7/110
# 82/82 - 37s - loss: 0.0857 - accuracy: 0.0000e+00 - val_loss: 0.0855 - val_accuracy: 0.0000e+00 - 37s/epoch - 455ms/step
# Epoch 8/110
# 82/82 - 41s - loss: 0.0820 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00 - 41s/epoch - 505ms/step
# Epoch 9/110
# 82/82 - 45s - loss: 0.0787 - accuracy: 0.0000e+00 - val_loss: 0.0779 - val_accuracy: 0.0000e+00 - 45s/epoch - 550ms/step
# Epoch 10/110
# 82/82 - 46s - loss: 0.0757 - accuracy: 0.0000e+00 - val_loss: 0.0747 - val_accuracy: 0.0000e+00 - 46s/epoch - 557ms/step
# Epoch 11/110
# 82/82 - 46s - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0723 - val_accuracy: 0.0000e+00 - 46s/epoch - 555ms/step
# Epoch 12/110
# 82/82 - 45s - loss: 0.0707 - accuracy: 0.0000e+00 - val_loss: 0.0706 - val_accuracy: 0.0000e+00 - 45s/epoch - 552ms/step
# Epoch 13/110
# 82/82 - 44s - loss: 0.0689 - accuracy: 0.0000e+00 - val_loss: 0.0691 - val_accuracy: 0.0000e+00 - 44s/epoch - 541ms/step
# Epoch 14/110
# 82/82 - 44s - loss: 0.0676 - accuracy: 0.0000e+00 - val_loss: 0.0682 - val_accuracy: 0.0000e+00 - 44s/epoch - 541ms/step
# Epoch 15/110
# 82/82 - 44s - loss: 0.0665 - accuracy: 0.0000e+00 - val_loss: 0.0677 - val_accuracy: 0.0000e+00 - 44s/epoch - 536ms/step
# Epoch 16/110
# 82/82 - 45s - loss: 0.0658 - accuracy: 0.0000e+00 - val_loss: 0.0669 - val_accuracy: 0.0000e+00 - 45s/epoch - 550ms/step
# Epoch 17/110
# 82/82 - 43s - loss: 0.0653 - accuracy: 0.0000e+00 - val_loss: 0.0664 - val_accuracy: 0.0000e+00 - 43s/epoch - 523ms/step
# Epoch 18/110
# 82/82 - 44s - loss: 0.0646 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 19/110
# 82/82 - 44s - loss: 0.0643 - accuracy: 0.0000e+00 - val_loss: 0.0659 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 20/110
# 82/82 - 44s - loss: 0.0639 - accuracy: 0.0000e+00 - val_loss: 0.0651 - val_accuracy: 0.0000e+00 - 44s/epoch - 538ms/step
# Epoch 21/110
# 82/82 - 44s - loss: 0.0637 - accuracy: 0.0000e+00 - val_loss: 0.0647 - val_accuracy: 0.0000e+00 - 44s/epoch - 533ms/step
# Epoch 22/110
# 82/82 - 44s - loss: 0.0633 - accuracy: 0.0000e+00 - val_loss: 0.0633 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 23/110
# 82/82 - 44s - loss: 0.0631 - accuracy: 0.0000e+00 - val_loss: 0.0640 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 24/110
# 82/82 - 44s - loss: 0.0627 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00 - 44s/epoch - 541ms/step
# Epoch 25/110
# 82/82 - 45s - loss: 0.0626 - accuracy: 0.0000e+00 - val_loss: 0.0623 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 26/110
# 82/82 - 44s - loss: 0.0624 - accuracy: 0.0000e+00 - val_loss: 0.0619 - val_accuracy: 0.0000e+00 - 44s/epoch - 538ms/step
# Epoch 27/110
# 82/82 - 45s - loss: 0.0620 - accuracy: 4.7742e-05 - val_loss: 0.0616 - val_accuracy: 0.0000e+00 - 45s/epoch - 543ms/step
# Epoch 28/110
# 82/82 - 44s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0613 - val_accuracy: 0.0000e+00 - 44s/epoch - 536ms/step
# Epoch 29/110
# 82/82 - 44s - loss: 0.0617 - accuracy: 4.7742e-05 - val_loss: 0.0608 - val_accuracy: 0.0000e+00 - 44s/epoch - 533ms/step
# Epoch 30/110
# 82/82 - 45s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0597 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 31/110
# 82/82 - 45s - loss: 0.0614 - accuracy: 4.7742e-05 - val_loss: 0.0602 - val_accuracy: 0.0000e+00 - 45s/epoch - 548ms/step
# Epoch 32/110
# 82/82 - 45s - loss: 0.0611 - accuracy: 4.7742e-05 - val_loss: 0.0597 - val_accuracy: 0.0000e+00 - 45s/epoch - 551ms/step
# Epoch 33/110
# 82/82 - 44s - loss: 0.0611 - accuracy: 4.7742e-05 - val_loss: 0.0590 - val_accuracy: 0.0000e+00 - 44s/epoch - 538ms/step
# Epoch 34/110
# 82/82 - 46s - loss: 0.0609 - accuracy: 4.7742e-05 - val_loss: 0.0588 - val_accuracy: 0.0000e+00 - 46s/epoch - 556ms/step
# Epoch 35/110
# 82/82 - 45s - loss: 0.0607 - accuracy: 4.7742e-05 - val_loss: 0.0586 - val_accuracy: 0.0000e+00 - 45s/epoch - 547ms/step
# Epoch 36/110
# 82/82 - 45s - loss: 0.0606 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 45s/epoch - 552ms/step
# Epoch 37/110
# 82/82 - 46s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 46s/epoch - 563ms/step
# Epoch 38/110
# 82/82 - 45s - loss: 0.0603 - accuracy: 4.7742e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 45s/epoch - 554ms/step
# Epoch 39/110
# 82/82 - 45s - loss: 0.0602 - accuracy: 4.7742e-05 - val_loss: 0.0576 - val_accuracy: 0.0000e+00 - 45s/epoch - 551ms/step
# Epoch 40/110
# 82/82 - 45s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 45s/epoch - 549ms/step
# Epoch 41/110
# 82/82 - 44s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0571 - val_accuracy: 0.0000e+00 - 44s/epoch - 542ms/step
# Epoch 42/110
# 82/82 - 45s - loss: 0.0599 - accuracy: 4.7742e-05 - val_loss: 0.0563 - val_accuracy: 0.0000e+00 - 45s/epoch - 546ms/step
# Epoch 43/110
# 82/82 - 44s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0567 - val_accuracy: 0.0000e+00 - 44s/epoch - 533ms/step
# Epoch 44/110
# 82/82 - 44s - loss: 0.0597 - accuracy: 4.7742e-05 - val_loss: 0.0559 - val_accuracy: 0.0000e+00 - 44s/epoch - 540ms/step
# Epoch 45/110
# 82/82 - 44s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0557 - val_accuracy: 0.0000e+00 - 44s/epoch - 538ms/step
# Epoch 46/110
# 82/82 - 43s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0553 - val_accuracy: 0.0000e+00 - 43s/epoch - 528ms/step
# Epoch 47/110
# 82/82 - 47s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0553 - val_accuracy: 0.0000e+00 - 47s/epoch - 569ms/step
# Epoch 48/110
# 82/82 - 42s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0549 - val_accuracy: 0.0000e+00 - 42s/epoch - 518ms/step
# Epoch 49/110
# 82/82 - 42s - loss: 0.0593 - accuracy: 4.7742e-05 - val_loss: 0.0552 - val_accuracy: 0.0000e+00 - 42s/epoch - 508ms/step
# Epoch 50/110
# 82/82 - 45s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0547 - val_accuracy: 0.0000e+00 - 45s/epoch - 551ms/step
# Epoch 51/110
# 82/82 - 44s - loss: 0.0589 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 44s/epoch - 534ms/step
# Epoch 52/110
# 82/82 - 43s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0540 - val_accuracy: 0.0000e+00 - 43s/epoch - 529ms/step
# Epoch 53/110
# 82/82 - 39s - loss: 0.0589 - accuracy: 4.7742e-05 - val_loss: 0.0546 - val_accuracy: 0.0000e+00 - 39s/epoch - 473ms/step
# Epoch 54/110
# 82/82 - 37s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 37s/epoch - 457ms/step
# Epoch 55/110
# 82/82 - 37s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0541 - val_accuracy: 0.0000e+00 - 37s/epoch - 450ms/step
# Epoch 56/110
# 82/82 - 31s - loss: 0.0588 - accuracy: 4.7742e-05 - val_loss: 0.0540 - val_accuracy: 0.0000e+00 - 31s/epoch - 374ms/step
# Epoch 57/110
# 82/82 - 29s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0534 - val_accuracy: 0.0000e+00 - 29s/epoch - 357ms/step
# Epoch 58/110
# 82/82 - 31s - loss: 0.0586 - accuracy: 4.7742e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 31s/epoch - 377ms/step
# Epoch 59/110
# 82/82 - 32s - loss: 0.0585 - accuracy: 4.7742e-05 - val_loss: 0.0533 - val_accuracy: 0.0000e+00 - 32s/epoch - 392ms/step
# Epoch 60/110
# 82/82 - 35s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0533 - val_accuracy: 0.0000e+00 - 35s/epoch - 427ms/step
# Epoch 61/110
# 82/82 - 32s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 32s/epoch - 388ms/step
# Epoch 62/110
# 82/82 - 31s - loss: 0.0583 - accuracy: 4.7742e-05 - val_loss: 0.0534 - val_accuracy: 0.0000e+00 - 31s/epoch - 381ms/step
# Epoch 63/110
# 82/82 - 31s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0530 - val_accuracy: 0.0000e+00 - 31s/epoch - 375ms/step
# Epoch 64/110
# 82/82 - 31s - loss: 0.0582 - accuracy: 4.7742e-05 - val_loss: 0.0528 - val_accuracy: 0.0000e+00 - 31s/epoch - 377ms/step
# Epoch 65/110
# 82/82 - 32s - loss: 0.0581 - accuracy: 4.7742e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 32s/epoch - 387ms/step
# Epoch 66/110
# 82/82 - 31s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0528 - val_accuracy: 0.0000e+00 - 31s/epoch - 382ms/step
# Epoch 67/110
# 82/82 - 31s - loss: 0.0580 - accuracy: 4.7742e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 31s/epoch - 379ms/step
# Epoch 68/110
# 82/82 - 32s - loss: 0.0579 - accuracy: 4.7742e-05 - val_loss: 0.0527 - val_accuracy: 0.0000e+00 - 32s/epoch - 386ms/step
# Epoch 69/110
# 82/82 - 32s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 32s/epoch - 386ms/step
# Epoch 70/110
# 82/82 - 33s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 71/110
# 82/82 - 36s - loss: 0.0578 - accuracy: 4.7742e-05 - val_loss: 0.0524 - val_accuracy: 0.0000e+00 - 36s/epoch - 437ms/step
# Epoch 72/110
# 82/82 - 38s - loss: 0.0577 - accuracy: 4.7742e-05 - val_loss: 0.0524 - val_accuracy: 0.0000e+00 - 38s/epoch - 464ms/step
# Epoch 73/110
# 82/82 - 37s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 37s/epoch - 451ms/step
# Epoch 74/110
# 82/82 - 35s - loss: 0.0577 - accuracy: 4.7742e-05 - val_loss: 0.0522 - val_accuracy: 0.0000e+00 - 35s/epoch - 426ms/step
# Epoch 75/110
# 82/82 - 37s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 37s/epoch - 445ms/step
# Epoch 76/110
# 82/82 - 39s - loss: 0.0576 - accuracy: 4.7742e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 39s/epoch - 472ms/step
# Epoch 77/110
# 82/82 - 36s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 36s/epoch - 443ms/step
# Epoch 78/110
# 82/82 - 34s - loss: 0.0575 - accuracy: 4.7742e-05 - val_loss: 0.0522 - val_accuracy: 0.0000e+00 - 34s/epoch - 417ms/step
# Epoch 79/110
# 82/82 - 39s - loss: 0.0574 - accuracy: 4.7742e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 39s/epoch - 477ms/step
# Epoch 80/110
# 82/82 - 40s - loss: 0.0573 - accuracy: 4.7742e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 40s/epoch - 485ms/step
# Epoch 81/110
# 82/82 - 36s - loss: 0.0572 - accuracy: 4.7742e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 36s/epoch - 442ms/step
# Epoch 82/110
# 82/82 - 38s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 38s/epoch - 468ms/step
# Epoch 83/110
# 82/82 - 35s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0511 - val_accuracy: 0.0000e+00 - 35s/epoch - 430ms/step
# Epoch 84/110
# 82/82 - 39s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 39s/epoch - 472ms/step
# Epoch 85/110
# 82/82 - 37s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0511 - val_accuracy: 0.0000e+00 - 37s/epoch - 450ms/step
# Epoch 86/110
# 82/82 - 36s - loss: 0.0570 - accuracy: 4.7742e-05 - val_loss: 0.0511 - val_accuracy: 0.0000e+00 - 36s/epoch - 434ms/step
# Epoch 87/110
# 82/82 - 36s - loss: 0.0570 - accuracy: 4.7742e-05 - val_loss: 0.0512 - val_accuracy: 0.0000e+00 - 36s/epoch - 440ms/step
# Epoch 88/110
# 82/82 - 35s - loss: 0.0571 - accuracy: 4.7742e-05 - val_loss: 0.0507 - val_accuracy: 0.0000e+00 - 35s/epoch - 428ms/step
# Epoch 89/110
# 82/82 - 39s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 39s/epoch - 472ms/step
# Epoch 90/110
# 82/82 - 37s - loss: 0.0569 - accuracy: 4.7742e-05 - val_loss: 0.0507 - val_accuracy: 0.0000e+00 - 37s/epoch - 454ms/step
# Epoch 91/110
# 82/82 - 37s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0507 - val_accuracy: 0.0000e+00 - 37s/epoch - 449ms/step
# Epoch 92/110
# 82/82 - 38s - loss: 0.0568 - accuracy: 4.7742e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 38s/epoch - 458ms/step
# Epoch 93/110
# 82/82 - 36s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 36s/epoch - 443ms/step
# Epoch 94/110
# 82/82 - 38s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0512 - val_accuracy: 0.0000e+00 - 38s/epoch - 459ms/step
# Epoch 95/110
# 82/82 - 40s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 40s/epoch - 483ms/step
# Epoch 96/110
# 82/82 - 39s - loss: 0.0566 - accuracy: 4.7742e-05 - val_loss: 0.0502 - val_accuracy: 0.0000e+00 - 39s/epoch - 472ms/step
# Epoch 97/110
# 82/82 - 39s - loss: 0.0567 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 39s/epoch - 475ms/step
# Epoch 98/110
# 82/82 - 38s - loss: 0.0564 - accuracy: 4.7742e-05 - val_loss: 0.0498 - val_accuracy: 0.0000e+00 - 38s/epoch - 466ms/step
# Epoch 99/110
# 82/82 - 38s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0500 - val_accuracy: 0.0000e+00 - 38s/epoch - 459ms/step
# Epoch 100/110
# 82/82 - 37s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 37s/epoch - 446ms/step
# Epoch 101/110
# 82/82 - 40s - loss: 0.0564 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 40s/epoch - 486ms/step
# Epoch 102/110
# 82/82 - 39s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0503 - val_accuracy: 0.0000e+00 - 39s/epoch - 477ms/step
# Epoch 103/110
# 82/82 - 40s - loss: 0.0565 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 40s/epoch - 483ms/step
# Epoch 104/110
# 82/82 - 38s - loss: 0.0564 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 38s/epoch - 462ms/step
# Epoch 105/110
# 82/82 - 39s - loss: 0.0563 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 39s/epoch - 480ms/step
# Epoch 106/110
# 82/82 - 36s - loss: 0.0563 - accuracy: 4.7742e-05 - val_loss: 0.0497 - val_accuracy: 0.0000e+00 - 36s/epoch - 445ms/step
# Epoch 107/110
# 82/82 - 34s - loss: 0.0562 - accuracy: 4.7742e-05 - val_loss: 0.0507 - val_accuracy: 0.0000e+00 - 34s/epoch - 418ms/step
# Epoch 108/110
# 82/82 - 37s - loss: 0.0563 - accuracy: 4.7742e-05 - val_loss: 0.0499 - val_accuracy: 0.0000e+00 - 37s/epoch - 453ms/step
# Epoch 109/110
# 82/82 - 36s - loss: 0.0562 - accuracy: 4.7742e-05 - val_loss: 0.0501 - val_accuracy: 0.0000e+00 - 36s/epoch - 439ms/step
# Epoch 110/110
# 82/82 - 34s - loss: 0.0562 - accuracy: 4.7742e-05 - val_loss: 0.0498 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 655/655 [==============================] - 30s 40ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.046
#   RMSE val:	 0.045
#   RMSE test:	 0.045

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 80/80 [==============================] - 3s 39ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values
# Out:
# array([[39.64831 ],
#        [39.612305],
#        [39.572514],
#        [39.62775 ],
#        [39.670567],
#        [39.67421 ],
#        [39.646523],
#        [39.60868 ],
#        [39.579784],
#        [39.575874]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()

# %%
similar=0
different=0

for i in range(len(y_predict_trans)):
    
    print("Modelo:", y_predict_trans[i])
    print("Real:  ", y_mesuared[i])
    
    diff= y_predict_trans[i]-y_mesuared[i]

    print("Diff: ", diff)

    if -1.5<diff<1.5 :
        similar+=1
        print("Same Numbers")
    else:
        different+=1
        print("Different")

ratio=np.round((similar/(similar+different))*100,1)

print("Quantity of same numbers: ", similar, " records")
print("Quantity of different numbers: ", different, " records")
print("Percentage: ", ratio, "%")
# Out:
# Modelo: [39.735207]
# Real:   [39.416]
# Diff:  [0.3192066]
# Same Numbers
# Modelo: [39.635384]
# Real:   [38.634]
# Diff:  [1.00138361]
# Same Numbers
# Modelo: [39.536198]
# Real:   [39.007]
# Diff:  [0.52919766]
# Same Numbers
# Modelo: [39.53078]
# Real:   [40.407]
# Diff:  [-0.87621921]
# Same Numbers
# Modelo: [39.678444]
# Real:   [36.734]
# Diff:  [2.94444391]
# Different
# Modelo: [39.40629]
# Real:   [39.16]
# Diff:  [0.24628815]
# Same Numbers
# Modelo: [39.442005]
# Real:   [40.376]
# Diff:  [-0.93399484]
# Same Numbers
# Modelo: [39.656986]
# Real:   [40.18]
# Diff:  [-0.52301376]
# Same Numbers
# Modelo: [40.25248]
# Real:   [40.988]
# Diff:  [-0.73552045]
# Same Numbers
# Modelo: [40.798542]
# Real:   [44.586]
# Diff:  [-3.78745798]
# Different
# Modelo: [41.653084]
# Real:   [44.598]
# Diff:  [-2.9449162]
# Different
# Modelo: [42.36548]
# Real:   [44.401]
# Diff:  [-2.03552148]
# Different
# Modelo: [43.14498]
# Real:   [44.495]
# Diff:  [-1.35001862]
# Same Numbers
# Modelo: [43.746964]
# Real:   [44.073]
# Diff:  [-0.3260365]
# Same Numbers
# Modelo: [44.12589]
# Real:   [44.705]
# Diff:  [-0.57911118]
# Same Numbers
# Modelo: [44.449196]
# Real:   [42.5]
# Diff:  [1.94919586]
# Different
# Modelo: [44.411987]
# Real:   [41.697]
# Diff:  [2.7149873]
# Different
# Modelo: [44.2157]
# Real:   [41.067]
# Diff:  [3.14869824]
# Different
# Modelo: [43.882923]
# Real:   [42.264]
# Diff:  [1.61892313]
# Different
# Modelo: [43.689632]
# Real:   [41.4]
# Diff:  [2.28963242]
# Different
# Modelo: [43.32009]
# Real:   [41.701]
# Diff:  [1.61909125]
# Different
# Modelo: [43.064003]
# Real:   [40.553]
# Diff:  [2.51100299]
# Different
# Modelo: [42.700516]
# Real:   [43.069]
# Diff:  [-0.36848425]
# Same Numbers
# Modelo: [42.74461]
# Real:   [43.542]
# Diff:  [-0.79739017]
# Same Numbers
# Modelo: [42.82041]
# Real:   [46.468]
# Diff:  [-3.64758832]
# Different
# Modelo: [43.29799]
# Real:   [44.944]
# Diff:  [-1.64601111]
# Different
# Modelo: [43.528477]
# Real:   [41.796]
# Diff:  [1.73247672]
# Different
# Modelo: [43.330837]
# Real:   [41.322]
# Diff:  [2.00883725]
# Different
# Modelo: [43.06916]
# Real:   [40.461]
# Diff:  [2.60816046]
# Different
# Modelo: [42.726788]
# Real:   [42.685]
# Diff:  [0.04178757]
# Same Numbers
# Modelo: [42.70496]
# Real:   [43.59]
# Diff:  [-0.88504013]
# Same Numbers
# Modelo: [42.80758]
# Real:   [42.227]
# Diff:  [0.58057904]
# Same Numbers
# Modelo: [42.705585]
# Real:   [42.92]
# Diff:  [-0.21441452]
# Same Numbers
# Modelo: [42.7328]
# Real:   [42.136]
# Diff:  [0.59679953]
# Same Numbers
# Modelo: [42.65863]
# Real:   [42.206]
# Diff:  [0.45263037]
# Same Numbers
# Modelo: [42.635952]
# Real:   [42.15]
# Diff:  [0.485952]
# Same Numbers
# Modelo: [42.598797]
# Real:   [42.506]
# Diff:  [0.09279684]
# Same Numbers
# Modelo: [42.625168]
# Real:   [41.596]
# Diff:  [1.02916785]
# Same Numbers
# Modelo: [42.542458]
# Real:   [42.652]
# Diff:  [-0.10954242]
# Same Numbers
# Modelo: [42.608833]
# Real:   [41.632]
# Diff:  [0.97683331]
# Same Numbers
# Modelo: [42.516064]
# Real:   [41.695]
# Diff:  [0.82106369]
# Same Numbers
# Modelo: [42.45001]
# Real:   [40.924]
# Diff:  [1.52600839]
# Different
# Modelo: [42.29938]
# Real:   [41.594]
# Diff:  [0.70538126]
# Same Numbers
# Modelo: [42.256912]
# Real:   [41.169]
# Diff:  [1.08791223]
# Same Numbers
# Modelo: [42.121544]
# Real:   [41.221]
# Diff:  [0.90054388]
# Same Numbers
# Modelo: [42.025677]
# Real:   [41.359]
# Diff:  [0.66667673]
# Same Numbers
# Modelo: [41.97383]
# Real:   [40.942]
# Diff:  [1.03183118]
# Same Numbers
# Modelo: [41.887844]
# Real:   [41.298]
# Diff:  [0.58984409]
# Same Numbers
# Modelo: [41.84869]
# Real:   [40.885]
# Diff:  [0.96369003]
# Same Numbers
# Modelo: [41.773914]
# Real:   [41.373]
# Diff:  [0.40091434]
# Same Numbers
# Modelo: [41.78043]
# Real:   [41.481]
# Diff:  [0.29942984]
# Same Numbers
# Modelo: [41.808594]
# Real:   [41.236]
# Diff:  [0.57259375]
# Same Numbers
# Modelo: [41.796886]
# Real:   [41.438]
# Diff:  [0.35888644]
# Same Numbers
# Modelo: [41.819084]
# Real:   [40.847]
# Diff:  [0.97208417]
# Same Numbers
# Modelo: [41.768036]
# Real:   [41.443]
# Diff:  [0.32503589]
# Same Numbers
# Modelo: [41.801857]
# Real:   [41.068]
# Diff:  [0.73385699]
# Same Numbers
# Modelo: [41.782993]
# Real:   [40.776]
# Diff:  [1.00699332]
# Same Numbers
# Modelo: [41.73141]
# Real:   [40.8]
# Diff:  [0.93141098]
# Same Numbers
# Modelo: [41.689846]
# Real:   [40.85]
# Diff:  [0.83984604]
# Same Numbers
# Modelo: [41.66067]
# Real:   [40.522]
# Diff:  [1.13867123]
# Same Numbers
# Modelo: [41.605648]
# Real:   [40.813]
# Diff:  [0.79264804]
# Same Numbers
# Modelo: [41.592987]
# Real:   [40.724]
# Diff:  [0.86898706]
# Same Numbers
# Modelo: [41.569885]
# Real:   [40.906]
# Diff:  [0.66388525]
# Same Numbers
# Modelo: [41.57281]
# Real:   [42.892]
# Diff:  [-1.31918887]
# Same Numbers
# Modelo: [42.093777]
# Real:   [49.045]
# Diff:  [-6.9512233]
# Different
# Modelo: [43.29822]
# Real:   [55.624]
# Diff:  [-12.32577841]
# Different
# Modelo: [45.16678]
# Real:   [52.876]
# Diff:  [-7.70922144]
# Different
# Modelo: [46.41765]
# Real:   [48.549]
# Diff:  [-2.13135168]
# Different
# Modelo: [47.068333]
# Real:   [45.784]
# Diff:  [1.28433267]
# Same Numbers
# Modelo: [47.17236]
# Real:   [43.407]
# Diff:  [3.76535947]
# Different
# Modelo: [46.859188]
# Real:   [39.319]
# Diff:  [7.54018808]
# Different
# Modelo: [45.98911]
# Real:   [39.733]
# Diff:  [6.25610904]
# Different
# Modelo: [44.77119]
# Real:   [43.025]
# Diff:  [1.74619064]
# Different
# Modelo: [44.125935]
# Real:   [43.494]
# Diff:  [0.6319346]
# Same Numbers
# Modelo: [43.72258]
# Real:   [43.343]
# Diff:  [0.37957996]
# Same Numbers
# Modelo: [43.43102]
# Real:   [43.486]
# Diff:  [-0.05498117]
# Same Numbers
# Modelo: [43.144485]
# Real:   [46.992]
# Diff:  [-3.84751453]
# Different
# Modelo: [43.404327]
# Real:   [42.763]
# Diff:  [0.64132739]
# Same Numbers
# Modelo: [43.17309]
# Real:   [43.891]
# Diff:  [-0.71790811]
# Same Numbers
# Modelo: [43.11076]
# Real:   [41.062]
# Diff:  [2.04875974]
# Different
# Modelo: [42.619675]
# Real:   [43.763]
# Diff:  [-1.14332532]
# Same Numbers
# Modelo: [42.563858]
# Real:   [41.619]
# Diff:  [0.94485803]
# Same Numbers
# Modelo: [42.31678]
# Real:   [41.615]
# Diff:  [0.70178009]
# Same Numbers
# Modelo: [42.129795]
# Real:   [39.766]
# Diff:  [2.36379507]
# Different
# Modelo: [41.823093]
# Real:   [43.123]
# Diff:  [-1.29990659]
# Same Numbers
# Modelo: [41.96043]
# Real:   [42.54]
# Diff:  [-0.57956985]
# Same Numbers
# Modelo: [42.03443]
# Real:   [43.792]
# Diff:  [-1.75756854]
# Different
# Modelo: [42.273132]
# Real:   [42.813]
# Diff:  [-0.53986768]
# Same Numbers
# Modelo: [42.466328]
# Real:   [43.172]
# Diff:  [-0.70567233]
# Same Numbers
# Modelo: [42.667248]
# Real:   [43.726]
# Diff:  [-1.05875223]
# Same Numbers
# Modelo: [42.9047]
# Real:   [41.698]
# Diff:  [1.20670123]
# Same Numbers
# Modelo: [42.842857]
# Real:   [43.299]
# Diff:  [-0.45614264]
# Same Numbers
# Modelo: [42.833664]
# Real:   [42.36]
# Diff:  [0.47366394]
# Same Numbers
# Modelo: [42.72456]
# Real:   [42.901]
# Diff:  [-0.17644022]
# Same Numbers
# Modelo: [42.729855]
# Real:   [42.173]
# Diff:  [0.55685458]
# Same Numbers
# Modelo: [42.650146]
# Real:   [38.832]
# Diff:  [3.81814648]
# Different
# Modelo: [42.08641]
# Real:   [41.038]
# Diff:  [1.04841052]
# Same Numbers
# Modelo: [41.864605]
# Real:   [39.24]
# Diff:  [2.62460495]
# Different
# Modelo: [41.502804]
# Real:   [35.782]
# Diff:  [5.7208038]
# Different
# Modelo: [40.78072]
# Real:   [38.161]
# Diff:  [2.61971976]
# Different
# Modelo: [40.377]
# Real:   [41.717]
# Diff:  [-1.3400011]
# Same Numbers
# Modelo: [40.50915]
# Real:   [41.033]
# Diff:  [-0.52384854]
# Same Numbers
# Modelo: [40.616028]
# Real:   [44.079]
# Diff:  [-3.46297217]
# Different
# Modelo: [41.12679]
# Real:   [43.993]
# Diff:  [-2.86621091]
# Different
# Modelo: [42.004906]
# Real:   [43.786]
# Diff:  [-1.7810943]
# Different
# Modelo: [42.700157]
# Real:   [41.159]
# Diff:  [1.54115717]
# Different
# Modelo: [42.86626]
# Real:   [43.316]
# Diff:  [-0.44973947]
# Same Numbers
# Modelo: [43.17845]
# Real:   [42.658]
# Diff:  [0.52045154]
# Same Numbers
# Modelo: [43.550335]
# Real:   [40.079]
# Diff:  [3.47133493]
# Different
# Modelo: [43.450035]
# Real:   [38.861]
# Diff:  [4.5890351]
# Different
# Modelo: [43.112904]
# Real:   [38.608]
# Diff:  [4.50490359]
# Different
# Modelo: [42.71008]
# Real:   [40.026]
# Diff:  [2.68407919]
# Different
# Modelo: [42.51628]
# Real:   [40.731]
# Diff:  [1.78528113]
# Different
# Modelo: [42.410057]
# Real:   [40.393]
# Diff:  [2.01705707]
# Different
# Modelo: [42.26046]
# Real:   [40.471]
# Diff:  [1.7894599]
# Different
# Modelo: [42.13245]
# Real:   [40.66]
# Diff:  [1.4724501]
# Same Numbers
# Modelo: [41.93092]
# Real:   [40.93]
# Diff:  [1.00091965]
# Same Numbers
# Modelo: [41.803757]
# Real:   [40.848]
# Diff:  [0.95575671]
# Same Numbers
# Modelo: [41.702793]
# Real:   [40.97]
# Diff:  [0.73279312]
# Same Numbers
# Modelo: [41.649807]
# Real:   [40.919]
# Diff:  [0.73080698]
# Same Numbers
# Modelo: [41.562218]
# Real:   [42.365]
# Diff:  [-0.80278229]
# Same Numbers
# Modelo: [41.694454]
# Real:   [42.082]
# Diff:  [-0.38754581]
# Same Numbers
# Modelo: [41.796112]
# Real:   [41.558]
# Diff:  [0.23811206]
# Same Numbers
# Modelo: [41.833485]
# Real:   [41.839]
# Diff:  [-0.00551535]
# Same Numbers
# Modelo: [41.895195]
# Real:   [42.011]
# Diff:  [-0.11580499]
# Same Numbers
# Modelo: [41.979767]
# Real:   [42.098]
# Diff:  [-0.11823315]
# Same Numbers
# Modelo: [42.071697]
# Real:   [41.648]
# Diff:  [0.42369724]
# Same Numbers
# Modelo: [42.098457]
# Real:   [41.314]
# Diff:  [0.78445734]
# Same Numbers
# Modelo: [42.02901]
# Real:   [41.805]
# Diff:  [0.22401077]
# Same Numbers
# Modelo: [42.041515]
# Real:   [41.789]
# Diff:  [0.25251535]
# Same Numbers
# Modelo: [42.069878]
# Real:   [41.928]
# Diff:  [0.14187762]
# Same Numbers
# Modelo: [42.11916]
# Real:   [42.081]
# Diff:  [0.0381597]
# Same Numbers
# Modelo: [42.15974]
# Real:   [41.699]
# Diff:  [0.46074045]
# Same Numbers
# Modelo: [42.144123]
# Real:   [42.008]
# Diff:  [0.13612308]
# Same Numbers
# Modelo: [42.172646]
# Real:   [41.412]
# Diff:  [0.76064557]
# Same Numbers
# Modelo: [42.125687]
# Real:   [40.601]
# Diff:  [1.52468665]
# Different
# Modelo: [41.949486]
# Real:   [40.556]
# Diff:  [1.39348578]
# Same Numbers
# Modelo: [41.80023]
# Real:   [40.065]
# Diff:  [1.73522812]
# Different
# Modelo: [41.612103]
# Real:   [40.863]
# Diff:  [0.74910251]
# Same Numbers
# Modelo: [41.565952]
# Real:   [40.541]
# Diff:  [1.0249523]
# Same Numbers
# Modelo: [41.451935]
# Real:   [40.751]
# Diff:  [0.70093481]
# Same Numbers
# Modelo: [41.400295]
# Real:   [40.5]
# Diff:  [0.90029526]
# Same Numbers
# Modelo: [41.34009]
# Real:   [40.394]
# Diff:  [0.94609171]
# Same Numbers
# Modelo: [41.28616]
# Real:   [40.104]
# Diff:  [1.18215952]
# Same Numbers
# Modelo: [41.192093]
# Real:   [39.949]
# Diff:  [1.2430929]
# Same Numbers
# Modelo: [41.10013]
# Real:   [40.067]
# Diff:  [1.03312817]
# Same Numbers
# Modelo: [41.0432]
# Real:   [39.899]
# Diff:  [1.14420145]
# Same Numbers
# Modelo: [40.97974]
# Real:   [39.848]
# Diff:  [1.13174014]
# Same Numbers
# Modelo: [40.91199]
# Real:   [39.567]
# Diff:  [1.34499112]
# Same Numbers
# Modelo: [40.824493]
# Real:   [40.049]
# Diff:  [0.77549341]
# Same Numbers
# Modelo: [40.815716]
# Real:   [39.724]
# Diff:  [1.09171579]
# Same Numbers
# Modelo: [40.773212]
# Real:   [39.638]
# Diff:  [1.13521243]
# Same Numbers
# Modelo: [40.726547]
# Real:   [39.481]
# Diff:  [1.24554724]
# Same Numbers
# Modelo: [40.669586]
# Real:   [39.752]
# Diff:  [0.91758618]
# Same Numbers
# Modelo: [40.657494]
# Real:   [42.071]
# Diff:  [-1.41350641]
# Same Numbers
# Modelo: [40.947132]
# Real:   [39.802]
# Diff:  [1.14513211]
# Same Numbers
# Modelo: [40.9306]
# Real:   [39.608]
# Diff:  [1.32259921]
# Same Numbers
# Modelo: [40.888256]
# Real:   [39.696]
# Diff:  [1.19225607]
# Same Numbers
# Modelo: [40.855392]
# Real:   [39.764]
# Diff:  [1.09139246]
# Same Numbers
# Modelo: [40.831173]
# Real:   [39.838]
# Diff:  [0.99317294]
# Same Numbers
# Modelo: [41.078335]
# Real:   [39.766]
# Diff:  [1.31233481]
# Same Numbers
# Modelo: [41.228424]
# Real:   [39.486]
# Diff:  [1.74242407]
# Different
# Modelo: [41.26987]
# Real:   [39.837]
# Diff:  [1.43287076]
# Same Numbers
# Modelo: [41.306408]
# Real:   [39.871]
# Diff:  [1.43540793]
# Same Numbers
# Modelo: [41.462]
# Real:   [39.53]
# Diff:  [1.9320018]
# Different
# Modelo: [41.494884]
# Real:   [39.885]
# Diff:  [1.60988449]
# Different
# Modelo: [41.51854]
# Real:   [39.667]
# Diff:  [1.85153943]
# Different
# Modelo: [41.47191]
# Real:   [39.634]
# Diff:  [1.83790857]
# Different
# Modelo: [40.98243]
# Real:   [40.116]
# Diff:  [0.8664295]
# Same Numbers
# Modelo: [40.688557]
# Real:   [39.261]
# Diff:  [1.42755667]
# Same Numbers
# Modelo: [40.39299]
# Real:   [37.172]
# Diff:  [3.22099011]
# Different
# Modelo: [39.92544]
# Real:   [37.194]
# Diff:  [2.73144174]
# Different
# Modelo: [39.4618]
# Real:   [37.002]
# Diff:  [2.45979962]
# Different
# Modelo: [39.09192]
# Real:   [37.931]
# Diff:  [1.16091895]
# Same Numbers
# Modelo: [38.94865]
# Real:   [40.908]
# Diff:  [-1.95934964]
# Different
# Modelo: [39.241543]
# Real:   [40.263]
# Diff:  [-1.02145718]
# Same Numbers
# Modelo: [39.33761]
# Real:   [37.525]
# Diff:  [1.81260834]
# Different
# Modelo: [39.129173]
# Real:   [36.471]
# Diff:  [2.65817328]
# Different
# Modelo: [38.84399]
# Real:   [38.398]
# Diff:  [0.44599033]
# Same Numbers
# Modelo: [38.861443]
# Real:   [39.184]
# Diff:  [-0.32255743]
# Same Numbers
# Modelo: [39.058475]
# Real:   [41.067]
# Diff:  [-2.00852451]
# Different
# Modelo: [39.48725]
# Real:   [40.875]
# Diff:  [-1.38774872]
# Same Numbers
# Modelo: [39.850506]
# Real:   [38.565]
# Diff:  [1.28550583]
# Same Numbers
# Modelo: [39.878597]
# Real:   [40.753]
# Diff:  [-0.87440274]
# Same Numbers
# Modelo: [40.246517]
# Real:   [40.949]
# Diff:  [-0.70248282]
# Same Numbers
# Modelo: [40.58243]
# Real:   [40.105]
# Diff:  [0.47743179]
# Same Numbers
# Modelo: [40.7287]
# Real:   [37.283]
# Diff:  [3.44569873]
# Different
# Modelo: [40.477993]
# Real:   [39.554]
# Diff:  [0.92399301]
# Same Numbers
# Modelo: [40.385303]
# Real:   [37.953]
# Diff:  [2.4323035]
# Different
# Modelo: [40.097893]
# Real:   [38.739]
# Diff:  [1.35889276]
# Same Numbers
# Modelo: [39.944065]
# Real:   [38.029]
# Diff:  [1.91506509]
# Different
# Modelo: [39.751305]
# Real:   [38.356]
# Diff:  [1.39530463]
# Same Numbers
# Modelo: [39.572132]
# Real:   [40.713]
# Diff:  [-1.14086789]
# Same Numbers
# Modelo: [39.730854]
# Real:   [40.797]
# Diff:  [-1.06614597]
# Same Numbers
# Modelo: [39.915493]
# Real:   [40.028]
# Diff:  [-0.11250699]
# Same Numbers
# Modelo: [40.006092]
# Real:   [41.173]
# Diff:  [-1.16690793]
# Same Numbers
# Modelo: [40.181763]
# Real:   [41.386]
# Diff:  [-1.2042373]
# Same Numbers
# Modelo: [40.387165]
# Real:   [40.837]
# Diff:  [-0.44983493]
# Same Numbers
# Modelo: [40.517075]
# Real:   [40.746]
# Diff:  [-0.22892542]
# Same Numbers
# Modelo: [40.627857]
# Real:   [40.821]
# Diff:  [-0.19314279]
# Same Numbers
# Modelo: [41.150696]
# Real:   [40.13]
# Diff:  [1.0206958]
# Same Numbers
# Modelo: [41.440205]
# Real:   [41.081]
# Diff:  [0.35920462]
# Same Numbers
# Modelo: [41.743263]
# Real:   [40.763]
# Diff:  [0.98026324]
# Same Numbers
# Modelo: [41.877594]
# Real:   [41.357]
# Diff:  [0.52059399]
# Same Numbers
# Modelo: [42.23807]
# Real:   [41.849]
# Diff:  [0.38907144]
# Same Numbers
# Modelo: [42.523674]
# Real:   [41.397]
# Diff:  [1.12667401]
# Same Numbers
# Modelo: [42.625153]
# Real:   [40.881]
# Diff:  [1.74415259]
# Different
# Modelo: [42.58789]
# Real:   [40.274]
# Diff:  [2.31389062]
# Different
# Modelo: [42.512554]
# Real:   [41.479]
# Diff:  [1.03355417]
# Same Numbers
# Modelo: [42.541595]
# Real:   [41.665]
# Diff:  [0.87659546]
# Same Numbers
# Modelo: [42.55013]
# Real:   [40.688]
# Diff:  [1.86212894]
# Different
# Modelo: [42.401646]
# Real:   [41.227]
# Diff:  [1.17464566]
# Same Numbers
# Modelo: [42.24847]
# Real:   [40.801]
# Diff:  [1.44747031]
# Same Numbers
# Modelo: [42.07446]
# Real:   [40.637]
# Diff:  [1.43745908]
# Same Numbers
# Modelo: [41.92596]
# Real:   [40.991]
# Diff:  [0.93496054]
# Same Numbers
# Modelo: [41.838554]
# Real:   [40.64]
# Diff:  [1.19855438]
# Same Numbers
# Modelo: [41.658386]
# Real:   [41.449]
# Diff:  [0.20938623]
# Same Numbers
# Modelo: [41.637066]
# Real:   [41.128]
# Diff:  [0.50906589]
# Same Numbers
# Modelo: [41.60352]
# Real:   [41.028]
# Diff:  [0.57551944]
# Same Numbers
# Modelo: [41.579308]
# Real:   [40.601]
# Diff:  [0.97830756]
# Same Numbers
# Modelo: [41.50639]
# Real:   [41.952]
# Diff:  [-0.44561038]
# Same Numbers
# Modelo: [41.634525]
# Real:   [41.368]
# Diff:  [0.2665253]
# Same Numbers
# Modelo: [41.66701]
# Real:   [41.765]
# Diff:  [-0.09798874]
# Same Numbers
# Modelo: [41.726246]
# Real:   [41.118]
# Diff:  [0.60824588]
# Same Numbers
# Modelo: [41.672077]
# Real:   [41.574]
# Diff:  [0.09807718]
# Same Numbers
# Modelo: [41.70259]
# Real:   [41.549]
# Diff:  [0.15359094]
# Same Numbers
# Modelo: [41.74174]
# Real:   [40.961]
# Diff:  [0.78074118]
# Same Numbers
# Modelo: [41.711533]
# Real:   [41.165]
# Diff:  [0.54653259]
# Same Numbers
# Modelo: [41.6904]
# Real:   [40.824]
# Diff:  [0.86639917]
# Same Numbers
# Modelo: [41.637653]
# Real:   [41.091]
# Diff:  [0.54665335]
# Same Numbers
# Modelo: [41.632275]
# Real:   [41.153]
# Diff:  [0.47927463]
# Same Numbers
# Modelo: [41.642033]
# Real:   [41.28]
# Diff:  [0.36203262]
# Same Numbers
# Modelo: [41.645878]
# Real:   [40.522]
# Diff:  [1.12387784]
# Same Numbers
# Modelo: [41.56246]
# Real:   [41.043]
# Diff:  [0.51946185]
# Same Numbers
# Modelo: [41.561108]
# Real:   [40.812]
# Diff:  [0.74910764]
# Same Numbers
# Modelo: [41.536907]
# Real:   [40.405]
# Diff:  [1.1319072]
# Same Numbers
# Modelo: [41.418392]
# Real:   [40.454]
# Diff:  [0.96439218]
# Same Numbers
# Modelo: [41.333805]
# Real:   [41.006]
# Diff:  [0.32780508]
# Same Numbers
# Modelo: [41.342598]
# Real:   [40.731]
# Diff:  [0.61159796]
# Same Numbers
# Modelo: [41.32815]
# Real:   [40.631]
# Diff:  [0.6971517]
# Same Numbers
# Modelo: [41.292797]
# Real:   [38.213]
# Diff:  [3.07979709]
# Different
# Modelo: [40.96386]
# Real:   [37.796]
# Diff:  [3.16785956]
# Different
# Modelo: [40.613087]
# Real:   [40.327]
# Diff:  [0.2860867]
# Same Numbers
# Modelo: [40.628902]
# Real:   [40.296]
# Diff:  [0.33290244]
# Same Numbers
# Modelo: [40.660934]
# Real:   [39.928]
# Diff:  [0.73293445]
# Same Numbers
# Modelo: [40.66415]
# Real:   [40.149]
# Diff:  [0.51515024]
# Same Numbers
# Modelo: [40.70647]
# Real:   [39.861]
# Diff:  [0.84547049]
# Same Numbers
# Modelo: [40.713593]
# Real:   [39.7]
# Diff:  [1.01359253]
# Same Numbers
# Modelo: [40.698708]
# Real:   [39.728]
# Diff:  [0.97070758]
# Same Numbers
# Modelo: [40.690414]
# Real:   [40.279]
# Diff:  [0.41141443]
# Same Numbers
# Modelo: [40.754322]
# Real:   [40.236]
# Diff:  [0.51832205]
# Same Numbers
# Modelo: [40.807083]
# Real:   [40.006]
# Diff:  [0.80108313]
# Same Numbers
# Modelo: [40.836033]
# Real:   [39.618]
# Diff:  [1.21803287]
# Same Numbers
# Modelo: [40.808453]
# Real:   [39.51]
# Diff:  [1.29845261]
# Same Numbers
# Modelo: [40.76578]
# Real:   [39.426]
# Diff:  [1.3397814]
# Same Numbers
# Modelo: [40.71381]
# Real:   [39.866]
# Diff:  [0.84780997]
# Same Numbers
# Modelo: [40.982655]
# Real:   [39.714]
# Diff:  [1.26865457]
# Same Numbers
# Modelo: [41.142677]
# Real:   [39.173]
# Diff:  [1.96967731]
# Different
# Modelo: [41.159863]
# Real:   [39.124]
# Diff:  [2.03586252]
# Different
# Modelo: [41.122902]
# Real:   [39.253]
# Diff:  [1.86990192]
# Different
# Modelo: [41.22443]
# Real:   [39.331]
# Diff:  [1.89343008]
# Different
# Modelo: [41.264046]
# Real:   [39.408]
# Diff:  [1.85604572]
# Different
# Modelo: [41.259495]
# Real:   [39.217]
# Diff:  [2.04249478]
# Different
# Modelo: [41.193005]
# Real:   [39.25]
# Diff:  [1.94300461]
# Different
# Modelo: [40.69654]
# Real:   [39.202]
# Diff:  [1.49454083]
# Same Numbers
# Modelo: [40.32895]
# Real:   [39.358]
# Diff:  [0.97094897]
# Same Numbers
# Modelo: [40.098454]
# Real:   [39.333]
# Diff:  [0.76545352]
# Same Numbers
# Modelo: [39.95504]
# Real:   [39.317]
# Diff:  [0.63803998]
# Same Numbers
# Modelo: [39.77786]
# Real:   [39.384]
# Diff:  [0.39385873]
# Same Numbers
# Modelo: [39.70303]
# Real:   [37.984]
# Diff:  [1.71902963]
# Different
# Modelo: [39.49733]
# Real:   [37.125]
# Diff:  [2.37232971]
# Different
# Modelo: [39.239372]
# Real:   [37.665]
# Diff:  [1.57437225]
# Different
# Modelo: [38.98691]
# Real:   [37.25]
# Diff:  [1.73691177]
# Different
# Modelo: [38.762978]
# Real:   [36.505]
# Diff:  [2.2579776]
# Different
# Modelo: [38.516785]
# Real:   [37.169]
# Diff:  [1.34778467]
# Same Numbers
# Modelo: [38.408802]
# Real:   [37.23]
# Diff:  [1.17880203]
# Same Numbers
# Modelo: [38.417065]
# Real:   [37.61]
# Diff:  [0.80706467]
# Same Numbers
# Modelo: [38.491096]
# Real:   [37.462]
# Diff:  [1.0290965]
# Same Numbers
# Modelo: [38.547634]
# Real:   [37.784]
# Diff:  [0.76363412]
# Same Numbers
# Modelo: [38.66462]
# Real:   [37.443]
# Diff:  [1.22161945]
# Same Numbers
# Modelo: [38.783897]
# Real:   [37.643]
# Diff:  [1.1408974]
# Same Numbers
# Modelo: [38.872562]
# Real:   [38.711]
# Diff:  [0.16156241]
# Same Numbers
# Modelo: [39.040718]
# Real:   [37.681]
# Diff:  [1.35971808]
# Same Numbers
# Modelo: [39.06824]
# Real:   [37.515]
# Diff:  [1.55324112]
# Different
# Modelo: [38.94325]
# Real:   [38.034]
# Diff:  [0.90924875]
# Same Numbers
# Modelo: [38.924587]
# Real:   [37.877]
# Diff:  [1.04758725]
# Same Numbers
# Modelo: [38.90406]
# Real:   [38.145]
# Diff:  [0.75906036]
# Same Numbers
# Modelo: [38.933857]
# Real:   [38.219]
# Diff:  [0.71485696]
# Same Numbers
# Modelo: [38.917255]
# Real:   [38.922]
# Diff:  [-0.0047446]
# Same Numbers
# Modelo: [39.005444]
# Real:   [38.806]
# Diff:  [0.19944357]
# Same Numbers
# Modelo: [39.078945]
# Real:   [35.905]
# Diff:  [3.17394516]
# Different
# Modelo: [38.791832]
# Real:   [37.209]
# Diff:  [1.58283197]
# Different
# Modelo: [38.643833]
# Real:   [38.804]
# Diff:  [-0.16016684]
# Same Numbers
# Modelo: [38.73484]
# Real:   [38.885]
# Diff:  [-0.15015961]
# Same Numbers
# Modelo: [38.852768]
# Real:   [41.406]
# Diff:  [-2.55323206]
# Different
# Modelo: [39.29285]
# Real:   [40.843]
# Diff:  [-1.55014951]
# Different
# Modelo: [40.03798]
# Real:   [42.78]
# Diff:  [-2.74202087]
# Different
# Modelo: [40.868603]
# Real:   [44.988]
# Diff:  [-4.11939725]
# Different
# Modelo: [41.79412]
# Real:   [42.765]
# Diff:  [-0.97087921]
# Same Numbers
# Modelo: [42.240257]
# Real:   [39.839]
# Diff:  [2.40125726]
# Different
# Modelo: [42.43428]
# Real:   [38.466]
# Diff:  [3.9682804]
# Different
# Modelo: [42.31351]
# Real:   [38.041]
# Diff:  [4.27251089]
# Different
# Modelo: [42.051292]
# Real:   [39.112]
# Diff:  [2.93929242]
# Different
# Modelo: [41.894012]
# Real:   [40.245]
# Diff:  [1.64901245]
# Different
# Modelo: [41.865665]
# Real:   [40.676]
# Diff:  [1.18966544]
# Same Numbers
# Modelo: [41.869167]
# Real:   [40.9]
# Diff:  [0.96916733]
# Same Numbers
# Modelo: [41.878654]
# Real:   [41.082]
# Diff:  [0.79665448]
# Same Numbers
# Modelo: [41.90859]
# Real:   [40.562]
# Diff:  [1.34658841]
# Same Numbers
# Modelo: [41.769238]
# Real:   [41.76]
# Diff:  [0.00923752]
# Same Numbers
# Modelo: [41.793495]
# Real:   [41.72]
# Diff:  [0.07349518]
# Same Numbers
# Modelo: [41.79099]
# Real:   [41.269]
# Diff:  [0.52198892]
# Same Numbers
# Modelo: [41.753563]
# Real:   [41.19]
# Diff:  [0.56356293]
# Same Numbers
# Modelo: [41.675533]
# Real:   [41.512]
# Diff:  [0.16353329]
# Same Numbers
# Modelo: [41.669743]
# Real:   [41.407]
# Diff:  [0.26274258]
# Same Numbers
# Modelo: [41.670227]
# Real:   [42.034]
# Diff:  [-0.36377295]
# Same Numbers
# Modelo: [41.743374]
# Real:   [40.776]
# Diff:  [0.96737387]
# Same Numbers
# Modelo: [41.666996]
# Real:   [41.377]
# Diff:  [0.289996]
# Same Numbers
# Modelo: [41.691475]
# Real:   [40.787]
# Diff:  [0.90447491]
# Same Numbers
# Modelo: [41.648598]
# Real:   [41.484]
# Diff:  [0.16459772]
# Same Numbers
# Modelo: [41.704624]
# Real:   [40.652]
# Diff:  [1.05262418]
# Same Numbers
# Modelo: [41.60211]
# Real:   [41.609]
# Diff:  [-0.00688818]
# Same Numbers
# Modelo: [41.6459]
# Real:   [41.055]
# Diff:  [0.59090073]
# Same Numbers
# Modelo: [41.627518]
# Real:   [41.127]
# Diff:  [0.5005177]
# Same Numbers
# Modelo: [41.63837]
# Real:   [41.511]
# Diff:  [0.12737051]
# Same Numbers
# Modelo: [41.65579]
# Real:   [41.068]
# Diff:  [0.58778842]
# Same Numbers
# Modelo: [41.628906]
# Real:   [40.984]
# Diff:  [0.64490625]
# Same Numbers
# Modelo: [41.613968]
# Real:   [41.201]
# Diff:  [0.4129679]
# Same Numbers
# Modelo: [41.638233]
# Real:   [41.615]
# Diff:  [0.02323318]
# Same Numbers
# Modelo: [41.692795]
# Real:   [41.014]
# Diff:  [0.6787948]
# Same Numbers
# Modelo: [41.67488]
# Real:   [40.984]
# Diff:  [0.69088098]
# Same Numbers
# Modelo: [41.661137]
# Real:   [40.209]
# Diff:  [1.45213663]
# Same Numbers
# Modelo: [41.55139]
# Real:   [40.665]
# Diff:  [0.8863916]
# Same Numbers
# Modelo: [41.456997]
# Real:   [40.818]
# Diff:  [0.63899692]
# Same Numbers
# Modelo: [41.419422]
# Real:   [40.675]
# Diff:  [0.74442215]
# Same Numbers
# Modelo: [41.38634]
# Real:   [40.45]
# Diff:  [0.93634109]
# Same Numbers
# Modelo: [41.3409]
# Real:   [40.821]
# Diff:  [0.51990042]
# Same Numbers
# Modelo: [41.337753]
# Real:   [40.671]
# Diff:  [0.6667533]
# Same Numbers
# Modelo: [41.326633]
# Real:   [40.625]
# Diff:  [0.70163345]
# Same Numbers
# Modelo: [41.319252]
# Real:   [41.004]
# Diff:  [0.31525201]
# Same Numbers
# Modelo: [41.36689]
# Real:   [40.75]
# Diff:  [0.61688995]
# Same Numbers
# Modelo: [41.36915]
# Real:   [40.623]
# Diff:  [0.74614825]
# Same Numbers
# Modelo: [41.360184]
# Real:   [40.268]
# Diff:  [1.09218372]
# Same Numbers
# Modelo: [41.310177]
# Real:   [40.079]
# Diff:  [1.23117685]
# Same Numbers
# Modelo: [41.243652]
# Real:   [40.64]
# Diff:  [0.60365234]
# Same Numbers
# Modelo: [41.254677]
# Real:   [40.279]
# Diff:  [0.97567682]
# Same Numbers
# Modelo: [41.221848]
# Real:   [39.899]
# Diff:  [1.32284753]
# Same Numbers
# Modelo: [41.14695]
# Real:   [40.446]
# Diff:  [0.70094977]
# Same Numbers
# Modelo: [41.151886]
# Real:   [40.212]
# Diff:  [0.93988599]
# Same Numbers
# Modelo: [41.139698]
# Real:   [40.561]
# Diff:  [0.57869803]
# Same Numbers
# Modelo: [41.173145]
# Real:   [39.825]
# Diff:  [1.34814529]
# Same Numbers
# Modelo: [41.107952]
# Real:   [39.409]
# Diff:  [1.69895212]
# Different
# Modelo: [41.0026]
# Real:   [40.789]
# Diff:  [0.21360162]
# Same Numbers
# Modelo: [41.35262]
# Real:   [40.881]
# Diff:  [0.47161917]
# Same Numbers
# Modelo: [41.61086]
# Real:   [42.672]
# Diff:  [-1.06114108]
# Same Numbers
# Modelo: [42.008106]
# Real:   [39.205]
# Diff:  [2.80310623]
# Different
# Modelo: [41.86653]
# Real:   [43.222]
# Diff:  [-1.35546863]
# Same Numbers
# Modelo: [42.321846]
# Real:   [43.112]
# Diff:  [-0.79015399]
# Same Numbers
# Modelo: [42.659393]
# Real:   [39.499]
# Diff:  [3.16039331]
# Different
# Modelo: [42.481667]
# Real:   [42.537]
# Diff:  [-0.05533344]
# Same Numbers
# Modelo: [42.641544]
# Real:   [39.843]
# Diff:  [2.79854434]
# Different
# Modelo: [41.980972]
# Real:   [36.875]
# Diff:  [5.10597229]
# Different
# Modelo: [41.0803]
# Real:   [36.37]
# Diff:  [4.71029938]
# Different
# Modelo: [40.292645]
# Real:   [38.162]
# Diff:  [2.1306445]
# Different
# Modelo: [39.88566]
# Real:   [38.971]
# Diff:  [0.91465826]
# Same Numbers
# Modelo: [39.600674]
# Real:   [39.334]
# Diff:  [0.26667368]
# Same Numbers
# Modelo: [39.44925]
# Real:   [35.639]
# Diff:  [3.81024927]
# Different
# Modelo: [38.95238]
# Real:   [43.085]
# Diff:  [-4.13261887]
# Different
# Modelo: [39.464756]
# Real:   [32.322]
# Diff:  [7.14275601]
# Different
# Modelo: [38.558575]
# Real:   [42.964]
# Diff:  [-4.40542532]
# Different
# Modelo: [39.061333]
# Real:   [34.067]
# Diff:  [4.9943327]
# Different
# Modelo: [38.513237]
# Real:   [36.011]
# Diff:  [2.502237]
# Different
# Modelo: [38.250874]
# Real:   [39.145]
# Diff:  [-0.89412643]
# Same Numbers
# Modelo: [38.494957]
# Real:   [40.071]
# Diff:  [-1.57604303]
# Different
# Modelo: [38.850475]
# Real:   [40.702]
# Diff:  [-1.85152469]
# Different
# Modelo: [39.236668]
# Real:   [40.091]
# Diff:  [-0.85433237]
# Same Numbers
# Modelo: [39.477222]
# Real:   [40.665]
# Diff:  [-1.18777756]
# Same Numbers
# Modelo: [39.841812]
# Real:   [39.91]
# Diff:  [-0.06818787]
# Same Numbers
# Modelo: [40.052692]
# Real:   [40.762]
# Diff:  [-0.70930759]
# Same Numbers
# Modelo: [40.324986]
# Real:   [39.753]
# Diff:  [0.5719855]
# Same Numbers
# Modelo: [40.420006]
# Real:   [40.126]
# Diff:  [0.2940058]
# Same Numbers
# Modelo: [40.369728]
# Real:   [40.312]
# Diff:  [0.05772809]
# Same Numbers
# Modelo: [40.389206]
# Real:   [40.623]
# Diff:  [-0.23379407]
# Same Numbers
# Modelo: [40.48083]
# Real:   [39.761]
# Diff:  [0.71983115]
# Same Numbers
# Modelo: [40.458282]
# Real:   [39.379]
# Diff:  [1.07928247]
# Same Numbers
# Modelo: [40.30882]
# Real:   [37.673]
# Diff:  [2.63581882]
# Different
# Modelo: [39.99753]
# Real:   [35.7]
# Diff:  [4.29753189]
# Different
# Modelo: [39.48352]
# Real:   [35.352]
# Diff:  [4.13152051]
# Different
# Modelo: [38.984722]
# Real:   [34.873]
# Diff:  [4.11172214]
# Different
# Modelo: [38.45423]
# Real:   [33.229]
# Diff:  [5.22523126]
# Different
# Modelo: [37.83354]
# Real:   [33.278]
# Diff:  [4.55554187]
# Different
# Modelo: [37.31613]
# Real:   [33.535]
# Diff:  [3.78113159]
# Different
# Modelo: [36.937958]
# Real:   [37.601]
# Diff:  [-0.66304224]
# Same Numbers
# Modelo: [37.51302]
# Real:   [39.737]
# Diff:  [-2.22398044]
# Different
# Modelo: [38.280384]
# Real:   [40.297]
# Diff:  [-2.01661594]
# Different
# Modelo: [38.984142]
# Real:   [41.432]
# Diff:  [-2.4478577]
# Different
# Modelo: [39.69542]
# Real:   [40.973]
# Diff:  [-1.27758069]
# Same Numbers
# Modelo: [40.437206]
# Real:   [47.4]
# Diff:  [-6.96279373]
# Different
# Modelo: [41.79334]
# Real:   [52.602]
# Diff:  [-10.80866122]
# Different
# Modelo: [43.58482]
# Real:   [54.211]
# Diff:  [-10.62618021]
# Different
# Modelo: [45.326363]
# Real:   [52.169]
# Diff:  [-6.84263739]
# Different
# Modelo: [46.575394]
# Real:   [52.5]
# Diff:  [-5.92460632]
# Different
# Modelo: [47.629227]
# Real:   [53.106]
# Diff:  [-5.47677332]
# Different
# Modelo: [48.571606]
# Real:   [52.942]
# Diff:  [-4.37039432]
# Different
# Modelo: [49.284824]
# Real:   [52.189]
# Diff:  [-2.90417563]
# Different
# Modelo: [49.64263]
# Real:   [47.108]
# Diff:  [2.53463153]
# Different
# Modelo: [49.25914]
# Real:   [44.88]
# Diff:  [4.37914001]
# Different
# Modelo: [48.589844]
# Real:   [42.179]
# Diff:  [6.41084375]
# Different
# Modelo: [47.617714]
# Real:   [42.042]
# Diff:  [5.57571393]
# Different
# Modelo: [46.672924]
# Real:   [41.631]
# Diff:  [5.04192404]
# Different
# Modelo: [45.80263]
# Real:   [42.575]
# Diff:  [3.22763138]
# Different
# Modelo: [45.185345]
# Real:   [42.384]
# Diff:  [2.8013447]
# Different
# Modelo: [44.654377]
# Real:   [41.833]
# Diff:  [2.82137698]
# Different
# Modelo: [44.138077]
# Real:   [42.204]
# Diff:  [1.93407678]
# Different
# Modelo: [43.76784]
# Real:   [41.641]
# Diff:  [2.12684134]
# Different
# Modelo: [43.40409]
# Real:   [42.113]
# Diff:  [1.29109088]
# Same Numbers
# Modelo: [43.17357]
# Real:   [41.852]
# Diff:  [1.32156873]
# Same Numbers
# Modelo: [42.914616]
# Real:   [41.819]
# Diff:  [1.09561563]
# Same Numbers
# Modelo: [42.72249]
# Real:   [42.403]
# Diff:  [0.3194884]
# Same Numbers
# Modelo: [42.63672]
# Real:   [41.655]
# Diff:  [0.98171875]
# Same Numbers
# Modelo: [42.485516]
# Real:   [41.488]
# Diff:  [0.99751559]
# Same Numbers
# Modelo: [42.33931]
# Real:   [41.174]
# Diff:  [1.16530969]
# Same Numbers
# Modelo: [42.19534]
# Real:   [40.929]
# Diff:  [1.2663392]
# Same Numbers
# Modelo: [42.055244]
# Real:   [40.454]
# Diff:  [1.60124445]
# Different
# Modelo: [41.88456]
# Real:   [39.813]
# Diff:  [2.07155963]
# Different
# Modelo: [41.62968]
# Real:   [40.868]
# Diff:  [0.76168063]
# Same Numbers
# Modelo: [41.555363]
# Real:   [40.851]
# Diff:  [0.7043627]
# Same Numbers
# Modelo: [41.512596]
# Real:   [40.387]
# Diff:  [1.12559613]
# Same Numbers
# Modelo: [41.432842]
# Real:   [40.585]
# Diff:  [0.84784225]
# Same Numbers
# Modelo: [41.34893]
# Real:   [39.837]
# Diff:  [1.51193036]
# Different
# Modelo: [41.19822]
# Real:   [40.037]
# Diff:  [1.1612193]
# Same Numbers
# Modelo: [41.105713]
# Real:   [40.16]
# Diff:  [0.94571289]
# Same Numbers
# Modelo: [41.05255]
# Real:   [40.14]
# Diff:  [0.91255127]
# Same Numbers
# Modelo: [40.99596]
# Real:   [40.026]
# Diff:  [0.96996024]
# Same Numbers
# Modelo: [40.94477]
# Real:   [39.959]
# Diff:  [0.98577081]
# Same Numbers
# Modelo: [40.901714]
# Real:   [40.4]
# Diff:  [0.50171432]
# Same Numbers
# Modelo: [40.928394]
# Real:   [39.95]
# Diff:  [0.97839432]
# Same Numbers
# Modelo: [40.889664]
# Real:   [40.321]
# Diff:  [0.5686637]
# Same Numbers
# Modelo: [40.91018]
# Real:   [40.229]
# Diff:  [0.68117914]
# Same Numbers
# Modelo: [40.922474]
# Real:   [39.809]
# Diff:  [1.11347391]
# Same Numbers
# Modelo: [40.883972]
# Real:   [39.889]
# Diff:  [0.99497217]
# Same Numbers
# Modelo: [40.85882]
# Real:   [39.792]
# Diff:  [1.06682187]
# Same Numbers
# Modelo: [40.826447]
# Real:   [39.88]
# Diff:  [0.94644653]
# Same Numbers
# Modelo: [40.811275]
# Real:   [39.591]
# Diff:  [1.22027548]
# Same Numbers
# Modelo: [40.762962]
# Real:   [39.293]
# Diff:  [1.46996234]
# Same Numbers
# Modelo: [40.6945]
# Real:   [39.694]
# Diff:  [1.00049997]
# Same Numbers
# Modelo: [40.68362]
# Real:   [39.68]
# Diff:  [1.00362045]
# Same Numbers
# Modelo: [40.672]
# Real:   [39.743]
# Diff:  [0.92900089]
# Same Numbers
# Modelo: [40.670288]
# Real:   [39.626]
# Diff:  [1.04428809]
# Same Numbers
# Modelo: [40.91464]
# Real:   [42.53]
# Diff:  [-1.61536148]
# Different
# Modelo: [41.46134]
# Real:   [38.22]
# Diff:  [3.24134186]
# Different
# Modelo: [41.349556]
# Real:   [47.561]
# Diff:  [-6.21144403]
# Different
# Modelo: [42.36262]
# Real:   [48.207]
# Diff:  [-5.84437869]
# Different
# Modelo: [43.492607]
# Real:   [55.878]
# Diff:  [-12.38539288]
# Different
# Modelo: [45.393116]
# Real:   [51.09]
# Diff:  [-5.696884]
# Different
# Modelo: [46.418648]
# Real:   [53.1]
# Diff:  [-6.68135223]
# Different
# Modelo: [47.49615]
# Real:   [53.651]
# Diff:  [-6.15484903]
# Different
# Modelo: [48.002674]
# Real:   [40.003]
# Diff:  [7.9996741]
# Different
# Modelo: [46.723583]
# Real:   [45.539]
# Diff:  [1.18458322]
# Same Numbers
# Modelo: [46.263252]
# Real:   [38.191]
# Diff:  [8.07225226]
# Different
# Modelo: [44.98776]
# Real:   [36.112]
# Diff:  [8.87575864]
# Different
# Modelo: [43.506462]
# Real:   [38.302]
# Diff:  [5.2044621]
# Different
# Modelo: [42.49289]
# Real:   [36.757]
# Diff:  [5.7358894]
# Different
# Modelo: [41.49813]
# Real:   [38.954]
# Diff:  [2.5441308]
# Different
# Modelo: [40.961666]
# Real:   [34.64]
# Diff:  [6.32166611]
# Different
# Modelo: [39.95537]
# Real:   [41.112]
# Diff:  [-1.15662814]
# Same Numbers
# Modelo: [39.88171]
# Real:   [35.764]
# Diff:  [4.11771005]
# Different
# Modelo: [39.304867]
# Real:   [35.547]
# Diff:  [3.75786679]
# Different
# Modelo: [38.77065]
# Real:   [38.682]
# Diff:  [0.08864896]
# Same Numbers
# Modelo: [38.782913]
# Real:   [37.256]
# Diff:  [1.52691321]
# Different
# Modelo: [38.698006]
# Real:   [39.039]
# Diff:  [-0.34099432]
# Same Numbers
# Modelo: [38.850037]
# Real:   [35.717]
# Diff:  [3.13303662]
# Different
# Modelo: [38.62829]
# Real:   [41.692]
# Diff:  [-3.06371173]
# Different
# Modelo: [39.21509]
# Real:   [41.816]
# Diff:  [-2.60090829]
# Different
# Modelo: [39.783806]
# Real:   [36.365]
# Diff:  [3.41880585]
# Different
# Modelo: [39.596786]
# Real:   [40.525]
# Diff:  [-0.9282135]
# Same Numbers
# Modelo: [39.864098]
# Real:   [37.861]
# Diff:  [2.0030976]
# Different
# Modelo: [39.66939]
# Real:   [38.686]
# Diff:  [0.98339163]
# Same Numbers
# Modelo: [39.60289]
# Real:   [39.812]
# Diff:  [-0.20910999]
# Same Numbers
# Modelo: [39.67823]
# Real:   [37.766]
# Diff:  [1.91223029]
# Different
# Modelo: [39.48982]
# Real:   [41.157]
# Diff:  [-1.66718143]
# Different
# Modelo: [39.662888]
# Real:   [35.558]
# Diff:  [4.10488757]
# Different
# Modelo: [39.20419]
# Real:   [45.7]
# Diff:  [-6.4958107]
# Different
# Modelo: [40.02754]
# Real:   [38.309]
# Diff:  [1.7185383]
# Different
# Modelo: [39.935608]
# Real:   [34.23]
# Diff:  [5.70560791]
# Different
# Modelo: [39.282024]
# Real:   [36.715]
# Diff:  [2.56702438]
# Different
# Modelo: [38.9972]
# Real:   [38.479]
# Diff:  [0.51820001]
# Same Numbers
# Modelo: [38.996193]
# Real:   [37.77]
# Diff:  [1.22619293]
# Same Numbers
# Modelo: [38.95687]
# Real:   [38.281]
# Diff:  [0.67587103]
# Same Numbers
# Modelo: [39.39906]
# Real:   [37.822]
# Diff:  [1.5770593]
# Different
# Modelo: [39.665916]
# Real:   [41.026]
# Diff:  [-1.36008356]
# Same Numbers
# Modelo: [40.219177]
# Real:   [42.223]
# Diff:  [-2.00382275]
# Different
# Modelo: [40.80579]
# Real:   [42.744]
# Diff:  [-1.93821005]
# Different
# Modelo: [41.572647]
# Real:   [43.136]
# Diff:  [-1.56335291]
# Different
# Modelo: [42.204403]
# Real:   [40.908]
# Diff:  [1.29640292]
# Same Numbers
# Modelo: [42.393143]
# Real:   [42.95]
# Diff:  [-0.5568573]
# Same Numbers
# Modelo: [42.757965]
# Real:   [43.276]
# Diff:  [-0.51803491]
# Same Numbers
# Modelo: [43.090275]
# Real:   [40.61]
# Diff:  [2.48027481]
# Different
# Modelo: [42.987957]
# Real:   [39.596]
# Diff:  [3.391957]
# Different
# Modelo: [42.716705]
# Real:   [40.484]
# Diff:  [2.23270532]
# Different
# Modelo: [42.54184]
# Real:   [43.988]
# Diff:  [-1.4461604]
# Same Numbers
# Modelo: [42.726]
# Real:   [42.646]
# Diff:  [0.08000174]
# Same Numbers
# Modelo: [42.72541]
# Real:   [39.937]
# Diff:  [2.78841046]
# Different
# Modelo: [42.371746]
# Real:   [38.544]
# Diff:  [3.82774606]
# Different
# Modelo: [41.896553]
# Real:   [37.423]
# Diff:  [4.47355304]
# Different
# Modelo: [41.295456]
# Real:   [40.774]
# Diff:  [0.52145593]
# Same Numbers
# Modelo: [41.223366]
# Real:   [41.217]
# Diff:  [0.00636578]
# Same Numbers
# Modelo: [41.23197]
# Real:   [40.362]
# Diff:  [0.86997174]
# Same Numbers
# Modelo: [41.15976]
# Real:   [41.594]
# Diff:  [-0.43424048]
# Same Numbers
# Modelo: [41.25655]
# Real:   [40.919]
# Diff:  [0.33754984]
# Same Numbers
# Modelo: [41.25318]
# Real:   [41.322]
# Diff:  [-0.06881854]
# Same Numbers
# Modelo: [41.313217]
# Real:   [41.27]
# Diff:  [0.04321716]
# Same Numbers
# Modelo: [41.37598]
# Real:   [39.634]
# Diff:  [1.74198038]
# Different
# Modelo: [41.171192]
# Real:   [40.214]
# Diff:  [0.95719217]
# Same Numbers
# Modelo: [41.065506]
# Real:   [39.82]
# Diff:  [1.24550598]
# Same Numbers
# Modelo: [40.955482]
# Real:   [38.017]
# Diff:  [2.93848248]
# Different
# Modelo: [40.654488]
# Real:   [39.677]
# Diff:  [0.97748761]
# Same Numbers
# Modelo: [40.57934]
# Real:   [39.509]
# Diff:  [1.07034189]
# Same Numbers
# Modelo: [40.522335]
# Real:   [40.647]
# Diff:  [-0.12466495]
# Same Numbers
# Modelo: [40.637363]
# Real:   [40.183]
# Diff:  [0.45436343]
# Same Numbers
# Modelo: [40.695198]
# Real:   [40.692]
# Diff:  [0.00319806]
# Same Numbers
# Modelo: [40.792473]
# Real:   [39.539]
# Diff:  [1.25347284]
# Same Numbers
# Modelo: [40.740646]
# Real:   [40.304]
# Diff:  [0.43664636]
# Same Numbers
# Modelo: [40.79595]
# Real:   [40.37]
# Diff:  [0.42595184]
# Same Numbers
# Modelo: [40.856846]
# Real:   [39.671]
# Diff:  [1.18584586]
# Same Numbers
# Modelo: [40.775097]
# Real:   [39.83]
# Diff:  [0.94509689]
# Same Numbers
# Modelo: [40.734093]
# Real:   [39.74]
# Diff:  [0.99409271]
# Same Numbers
# Modelo: [40.69657]
# Real:   [39.787]
# Diff:  [0.90957135]
# Same Numbers
# Modelo: [40.6782]
# Real:   [39.525]
# Diff:  [1.15319977]
# Same Numbers
# Modelo: [40.61714]
# Real:   [39.814]
# Diff:  [0.80314172]
# Same Numbers
# Modelo: [40.609478]
# Real:   [40.069]
# Diff:  [0.540478]
# Same Numbers
# Modelo: [40.643753]
# Real:   [39.648]
# Diff:  [0.99575305]
# Same Numbers
# Modelo: [40.627373]
# Real:   [39.133]
# Diff:  [1.49437274]
# Same Numbers
# Modelo: [40.539124]
# Real:   [39.629]
# Diff:  [0.91012354]
# Same Numbers
# Modelo: [40.528797]
# Real:   [39.266]
# Diff:  [1.26279715]
# Same Numbers
# Modelo: [40.478275]
# Real:   [39.771]
# Diff:  [0.7072753]
# Same Numbers
# Modelo: [40.502243]
# Real:   [39.433]
# Diff:  [1.06924304]
# Same Numbers
# Modelo: [40.480755]
# Real:   [40.003]
# Diff:  [0.47775485]
# Same Numbers
# Modelo: [40.53787]
# Real:   [39.472]
# Diff:  [1.0658685]
# Same Numbers
# Modelo: [40.52333]
# Real:   [39.531]
# Diff:  [0.99233069]
# Same Numbers
# Modelo: [40.519028]
# Real:   [39.282]
# Diff:  [1.23702771]
# Same Numbers
# Modelo: [40.494347]
# Real:   [39.471]
# Diff:  [1.02334662]
# Same Numbers
# Modelo: [40.49401]
# Real:   [39.123]
# Diff:  [1.37101093]
# Same Numbers
# Modelo: [40.44851]
# Real:   [39.961]
# Diff:  [0.48750922]
# Same Numbers
# Modelo: [40.529835]
# Real:   [40.57]
# Diff:  [-0.04016525]
# Same Numbers
# Modelo: [40.92041]
# Real:   [39.199]
# Diff:  [1.72141016]
# Different
# Modelo: [41.038242]
# Real:   [42.499]
# Diff:  [-1.46075766]
# Same Numbers
# Modelo: [41.512417]
# Real:   [39.643]
# Diff:  [1.86941684]
# Different
# Modelo: [41.499836]
# Real:   [46.86]
# Diff:  [-5.36016403]
# Different
# Modelo: [42.50042]
# Real:   [48.837]
# Diff:  [-6.33658038]
# Different
# Modelo: [43.60044]
# Real:   [54.652]
# Diff:  [-11.05155902]
# Different
# Modelo: [45.27853]
# Real:   [52.908]
# Diff:  [-7.62946988]
# Different
# Modelo: [46.519478]
# Real:   [45.927]
# Diff:  [0.59247784]
# Same Numbers
# Modelo: [46.219048]
# Real:   [44.386]
# Diff:  [1.83304755]
# Different
# Modelo: [45.721718]
# Real:   [44.317]
# Diff:  [1.40471783]
# Same Numbers
# Modelo: [45.31314]
# Real:   [38.08]
# Diff:  [7.23314087]
# Different
# Modelo: [44.193565]
# Real:   [39.55]
# Diff:  [4.64356537]
# Different
# Modelo: [43.268135]
# Real:   [36.584]
# Diff:  [6.68413507]
# Different
# Modelo: [42.14908]
# Real:   [40.498]
# Diff:  [1.65107837]
# Different
# Modelo: [41.701515]
# Real:   [36.703]
# Diff:  [4.9985152]
# Different
# Modelo: [40.937965]
# Real:   [34.665]
# Diff:  [6.27296539]
# Different
# Modelo: [39.91508]
# Real:   [39.532]
# Diff:  [0.38308102]
# Same Numbers
# Modelo: [39.63989]
# Real:   [36.291]
# Diff:  [3.34888876]
# Different
# Modelo: [39.160362]
# Real:   [39.915]
# Diff:  [-0.75463776]
# Same Numbers
# Modelo: [39.20507]
# Real:   [35.358]
# Diff:  [3.8470705]
# Different
# Modelo: [38.83012]
# Real:   [39.943]
# Diff:  [-1.11287991]
# Same Numbers
# Modelo: [39.051624]
# Real:   [39.816]
# Diff:  [-0.7643757]
# Same Numbers
# Modelo: [39.28467]
# Real:   [41.907]
# Diff:  [-2.62232822]
# Different
# Modelo: [39.744884]
# Real:   [37.536]
# Diff:  [2.20888449]
# Different
# Modelo: [39.720367]
# Real:   [43.065]
# Diff:  [-3.34463257]
# Different
# Modelo: [40.30854]
# Real:   [42.058]
# Diff:  [-1.74945966]
# Different
# Modelo: [40.736168]
# Real:   [40.269]
# Diff:  [0.46716791]
# Same Numbers
# Modelo: [40.8648]
# Real:   [46.605]
# Diff:  [-5.7402005]
# Different
# Modelo: [41.559765]
# Real:   [41.157]
# Diff:  [0.40276486]
# Same Numbers
# Modelo: [41.567345]
# Real:   [37.905]
# Diff:  [3.66234467]
# Different
# Modelo: [41.151707]
# Real:   [39.427]
# Diff:  [1.7247067]
# Different
# Modelo: [40.972965]
# Real:   [35.534]
# Diff:  [5.43896524]
# Different
# Modelo: [40.226532]
# Real:   [39.641]
# Diff:  [0.58553198]
# Same Numbers
# Modelo: [40.044582]
# Real:   [36.619]
# Diff:  [3.42558237]
# Different
# Modelo: [39.60941]
# Real:   [39.764]
# Diff:  [-0.15459067]
# Same Numbers
# Modelo: [39.59964]
# Real:   [38.751]
# Diff:  [0.84863989]
# Same Numbers
# Modelo: [39.507538]
# Real:   [39.868]
# Diff:  [-0.36046216]
# Same Numbers
# Modelo: [39.615055]
# Real:   [40.224]
# Diff:  [-0.60894492]
# Same Numbers
# Modelo: [39.782932]
# Real:   [39.194]
# Diff:  [0.58893228]
# Same Numbers
# Modelo: [39.826572]
# Real:   [40.113]
# Diff:  [-0.28642758]
# Same Numbers
# Modelo: [40.38277]
# Real:   [41.133]
# Diff:  [-0.75022946]
# Same Numbers
# Modelo: [40.923855]
# Real:   [43.527]
# Diff:  [-2.60314517]
# Different
# Modelo: [41.616463]
# Real:   [44.217]
# Diff:  [-2.60053729]
# Different
# Modelo: [42.27549]
# Real:   [42.011]
# Diff:  [0.26448981]
# Same Numbers
# Modelo: [42.761795]
# Real:   [43.188]
# Diff:  [-0.42620496]
# Same Numbers
# Modelo: [43.231483]
# Real:   [45.187]
# Diff:  [-1.95551654]
# Different
# Modelo: [43.79836]
# Real:   [45.923]
# Diff:  [-2.12464108]
# Different
# Modelo: [44.319237]
# Real:   [43.849]
# Diff:  [0.47023676]
# Same Numbers
# Modelo: [44.491615]
# Real:   [44.06]
# Diff:  [0.4316153]
# Same Numbers
# Modelo: [44.605427]
# Real:   [49.266]
# Diff:  [-4.66057321]
# Different
# Modelo: [45.30883]
# Real:   [54.688]
# Diff:  [-9.37916974]
# Different
# Modelo: [46.60473]
# Real:   [48.434]
# Diff:  [-1.8292713]
# Different
# Modelo: [46.853554]
# Real:   [43.778]
# Diff:  [3.07555377]
# Different
# Modelo: [46.46089]
# Real:   [41.98]
# Diff:  [4.48089172]
# Different
# Modelo: [45.84907]
# Real:   [41.886]
# Diff:  [3.9630715]
# Different
# Modelo: [45.276485]
# Real:   [41.835]
# Diff:  [3.44148544]
# Different
# Modelo: [44.713028]
# Real:   [41.975]
# Diff:  [2.73802795]
# Different
# Modelo: [44.266872]
# Real:   [41.615]
# Diff:  [2.65187241]
# Different
# Modelo: [43.831596]
# Real:   [41.335]
# Diff:  [2.49659637]
# Different
# Modelo: [43.4286]
# Real:   [42.424]
# Diff:  [1.00460031]
# Same Numbers
# Modelo: [43.227592]
# Real:   [42.373]
# Diff:  [0.85459247]
# Same Numbers
# Modelo: [43.0753]
# Real:   [42.25]
# Diff:  [0.82529831]
# Same Numbers
# Modelo: [42.934204]
# Real:   [41.755]
# Diff:  [1.1792041]
# Same Numbers
# Modelo: [42.761196]
# Real:   [41.978]
# Diff:  [0.78319614]
# Same Numbers
# Modelo: [42.599277]
# Real:   [40.936]
# Diff:  [1.6632775]
# Different
# Modelo: [42.349342]
# Real:   [41.409]
# Diff:  [0.94034235]
# Same Numbers
# Modelo: [42.20966]
# Real:   [41.551]
# Diff:  [0.65865958]
# Same Numbers
# Modelo: [42.124718]
# Real:   [40.523]
# Diff:  [1.60171771]
# Different
# Modelo: [41.91121]
# Real:   [41.363]
# Diff:  [0.54820911]
# Same Numbers
# Modelo: [41.843994]
# Real:   [41.161]
# Diff:  [0.68299414]
# Same Numbers
# Modelo: [41.7621]
# Real:   [41.259]
# Diff:  [0.50310022]
# Same Numbers
# Modelo: [41.739075]
# Real:   [40.775]
# Diff:  [0.96407471]
# Same Numbers
# Modelo: [41.648758]
# Real:   [40.864]
# Diff:  [0.78475793]
# Same Numbers
# Modelo: [41.577232]
# Real:   [41.077]
# Diff:  [0.50023236]
# Same Numbers
# Modelo: [41.567772]
# Real:   [41.129]
# Diff:  [0.43877191]
# Same Numbers
# Modelo: [41.587524]
# Real:   [40.38]
# Diff:  [1.20752441]
# Same Numbers
# Modelo: [41.470936]
# Real:   [40.152]
# Diff:  [1.31893582]
# Same Numbers
# Modelo: [41.353714]
# Real:   [40.743]
# Diff:  [0.61071399]
# Same Numbers
# Modelo: [41.337242]
# Real:   [39.777]
# Diff:  [1.56024213]
# Different
# Modelo: [41.2109]
# Real:   [40.039]
# Diff:  [1.17189935]
# Same Numbers
# Modelo: [41.121387]
# Real:   [40.152]
# Diff:  [0.96938748]
# Same Numbers
# Modelo: [41.067425]
# Real:   [40.002]
# Diff:  [1.06542477]
# Same Numbers
# Modelo: [41.011086]
# Real:   [40.169]
# Diff:  [0.84208551]
# Same Numbers
# Modelo: [40.991]
# Real:   [39.912]
# Diff:  [1.07900113]
# Same Numbers
# Modelo: [40.935402]
# Real:   [40.143]
# Diff:  [0.79240192]
# Same Numbers
# Modelo: [40.923534]
# Real:   [40.119]
# Diff:  [0.80453439]
# Same Numbers
# Modelo: [40.916744]
# Real:   [40.016]
# Diff:  [0.90074423]
# Same Numbers
# Modelo: [40.902916]
# Real:   [40.218]
# Diff:  [0.68491595]
# Same Numbers
# Modelo: [40.916775]
# Real:   [39.846]
# Diff:  [1.07077475]
# Same Numbers
# Modelo: [40.885056]
# Real:   [39.662]
# Diff:  [1.22305554]
# Same Numbers
# Modelo: [40.835503]
# Real:   [39.792]
# Diff:  [1.04350262]
# Same Numbers
# Modelo: [40.80933]
# Real:   [39.691]
# Diff:  [1.11832999]
# Same Numbers
# Modelo: [40.78579]
# Real:   [39.812]
# Diff:  [0.97378949]
# Same Numbers
# Modelo: [40.7795]
# Real:   [39.952]
# Diff:  [0.82749905]
# Same Numbers
# Modelo: [40.791107]
# Real:   [39.955]
# Diff:  [0.83610718]
# Same Numbers
# Modelo: [40.801495]
# Real:   [40.093]
# Diff:  [0.7084946]
# Same Numbers
# Modelo: [41.08885]
# Real:   [42.6]
# Diff:  [-1.51115189]
# Different
# Modelo: [41.63607]
# Real:   [41.991]
# Diff:  [-0.35492975]
# Same Numbers
# Modelo: [41.957565]
# Real:   [41.442]
# Diff:  [0.51556531]
# Same Numbers
# Modelo: [42.12674]
# Real:   [43.658]
# Diff:  [-1.5312605]
# Different
# Modelo: [42.646366]
# Real:   [40.165]
# Diff:  [2.48136612]
# Different
# Modelo: [42.63046]
# Real:   [42.812]
# Diff:  [-0.18154117]
# Same Numbers
# Modelo: [42.86728]
# Real:   [43.845]
# Diff:  [-0.97772095]
# Same Numbers
# Modelo: [43.15977]
# Real:   [49.775]
# Diff:  [-6.61522903]
# Different
# Modelo: [43.67843]
# Real:   [45.852]
# Diff:  [-2.17357135]
# Different
# Modelo: [43.698124]
# Real:   [44.033]
# Diff:  [-0.33487607]
# Same Numbers
# Modelo: [43.576683]
# Real:   [36.189]
# Diff:  [7.38768304]
# Different
# Modelo: [42.518383]
# Real:   [38.133]
# Diff:  [4.38538303]
# Different
# Modelo: [41.700317]
# Real:   [38.968]
# Diff:  [2.73231738]
# Different
# Modelo: [41.130714]
# Real:   [37.213]
# Diff:  [3.91771442]
# Different
# Modelo: [40.493835]
# Real:   [38.828]
# Diff:  [1.66583545]
# Different
# Modelo: [40.178574]
# Real:   [43.063]
# Diff:  [-2.88442639]
# Different
# Modelo: [40.356464]
# Real:   [38.043]
# Diff:  [2.31346439]
# Different
# Modelo: [40.027523]
# Real:   [43.024]
# Diff:  [-2.99647696]
# Different
# Modelo: [40.35215]
# Real:   [38.614]
# Diff:  [1.73814996]
# Different
# Modelo: [40.177586]
# Real:   [43.031]
# Diff:  [-2.8534144]
# Different
# Modelo: [40.589813]
# Real:   [39.061]
# Diff:  [1.52881323]
# Different
# Modelo: [40.5285]
# Real:   [38.927]
# Diff:  [1.6014996]
# Different
# Modelo: [40.42261]
# Real:   [35.241]
# Diff:  [5.18161124]
# Different
# Modelo: [39.892143]
# Real:   [39.502]
# Diff:  [0.39014325]
# Same Numbers
# Modelo: [39.970142]
# Real:   [41.981]
# Diff:  [-2.01085764]
# Different
# Modelo: [40.355396]
# Real:   [39.763]
# Diff:  [0.59239627]
# Same Numbers
# Modelo: [40.468903]
# Real:   [44.164]
# Diff:  [-3.69509741]
# Different
# Modelo: [41.06701]
# Real:   [37.483]
# Diff:  [3.58400897]
# Different
# Modelo: [40.698032]
# Real:   [37.322]
# Diff:  [3.37603238]
# Different
# Modelo: [40.313087]
# Real:   [38.363]
# Diff:  [1.95008746]
# Different
# Modelo: [40.116135]
# Real:   [40.053]
# Diff:  [0.06313464]
# Same Numbers
# Modelo: [40.18721]
# Real:   [38.957]
# Diff:  [1.23021008]
# Same Numbers
# Modelo: [40.037983]
# Real:   [41.986]
# Diff:  [-1.94801706]
# Different
# Modelo: [40.29329]
# Real:   [40.29]
# Diff:  [0.00328918]
# Same Numbers
# Modelo: [40.38412]
# Real:   [42.745]
# Diff:  [-2.36087906]
# Different
# Modelo: [40.74968]
# Real:   [39.907]
# Diff:  [0.84267957]
# Same Numbers
# Modelo: [40.677113]
# Real:   [36.032]
# Diff:  [4.64511258]
# Different
# Modelo: [40.142544]
# Real:   [36.196]
# Diff:  [3.94654379]
# Different
# Modelo: [39.686947]
# Real:   [36.291]
# Diff:  [3.39594687]
# Different
# Modelo: [39.304302]
# Real:   [38.2]
# Diff:  [1.10430222]
# Same Numbers
# Modelo: [39.618866]
# Real:   [40.18]
# Diff:  [-0.56113403]
# Same Numbers
# Modelo: [40.076744]
# Real:   [40.973]
# Diff:  [-0.89625592]
# Same Numbers
# Modelo: [40.544167]
# Real:   [40.636]
# Diff:  [-0.09183344]
# Same Numbers
# Modelo: [40.877544]
# Real:   [41.071]
# Diff:  [-0.1934556]
# Same Numbers
# Modelo: [41.40779]
# Real:   [40.904]
# Diff:  [0.50379114]
# Same Numbers
# Modelo: [41.766518]
# Real:   [41.373]
# Diff:  [0.39351764]
# Same Numbers
# Modelo: [42.058838]
# Real:   [40.692]
# Diff:  [1.36683789]
# Same Numbers
# Modelo: [42.15999]
# Real:   [40.761]
# Diff:  [1.3989884]
# Same Numbers
# Modelo: [42.236336]
# Real:   [40.909]
# Diff:  [1.32733575]
# Same Numbers
# Modelo: [42.26997]
# Real:   [41.223]
# Diff:  [1.04696994]
# Same Numbers
# Modelo: [42.307747]
# Real:   [41.952]
# Diff:  [0.35574689]
# Same Numbers
# Modelo: [42.402985]
# Real:   [41.086]
# Diff:  [1.31698462]
# Same Numbers
# Modelo: [42.26142]
# Real:   [42.072]
# Diff:  [0.1894212]
# Same Numbers
# Modelo: [42.2657]
# Real:   [41.972]
# Diff:  [0.29370129]
# Same Numbers
# Modelo: [42.264206]
# Real:   [42.735]
# Diff:  [-0.47079407]
# Same Numbers
# Modelo: [42.3699]
# Real:   [42.152]
# Diff:  [0.21789975]
# Same Numbers
# Modelo: [42.34543]
# Real:   [41.463]
# Diff:  [0.88242847]
# Same Numbers
# Modelo: [42.25166]
# Real:   [41.805]
# Diff:  [0.44665939]
# Same Numbers
# Modelo: [42.220097]
# Real:   [42.491]
# Diff:  [-0.27090341]
# Same Numbers
# Modelo: [42.288654]
# Real:   [42.399]
# Diff:  [-0.11034567]
# Same Numbers
# Modelo: [42.341427]
# ...
# Diff:  [3.27475146]
# Different
# Modelo: [39.177402]
# Real:   [36.094]
# Diff:  [3.0834025]
# Different
# Modelo: [38.89525]
# Real:   [36.399]
# Diff:  [2.49624841]
# Different
# Modelo: [38.624172]
# Real:   [36.505]
# Diff:  [2.11917221]
# Different
# Modelo: [38.42887]
# Real:   [36.256]
# Diff:  [2.17287115]
# Different
# Modelo: [38.254326]
# Real:   [36.393]
# Diff:  [1.86132587]
# Different
# Modelo: [38.14117]
# Real:   [36.242]
# Diff:  [1.8991705]
# Different
# Modelo: [37.98472]
# Real:   [36.194]
# Diff:  [1.79071832]
# Different
# Modelo: [37.868603]
# Real:   [37.512]
# Diff:  [0.35660275]
# Same Numbers
# Modelo: [37.9566]
# Real:   [43.147]
# Diff:  [-5.19039981]
# Different
# Modelo: [38.766426]
# Real:   [42.856]
# Diff:  [-4.08957391]
# Different
# Modelo: [39.87607]
# Real:   [43.051]
# Diff:  [-3.17493188]
# Different
# Modelo: [40.808987]
# Real:   [42.8]
# Diff:  [-1.99101334]
# Different
# Modelo: [41.510494]
# Real:   [45.305]
# Diff:  [-3.79450577]
# Different
# Modelo: [42.3649]
# Real:   [45.868]
# Diff:  [-3.50310132]
# Different
# Modelo: [43.34719]
# Real:   [42.337]
# Diff:  [1.01019086]
# Same Numbers
# Modelo: [43.648155]
# Real:   [45.553]
# Diff:  [-1.90484479]
# Different
# Modelo: [44.220547]
# Real:   [44.538]
# Diff:  [-0.31745328]
# Same Numbers
# Modelo: [44.507797]
# Real:   [38.613]
# Diff:  [5.89479724]
# Different
# Modelo: [43.964287]
# Real:   [38.683]
# Diff:  [5.2812868]
# Different
# Modelo: [43.4222]
# Real:   [38.916]
# Diff:  [4.50619925]
# Different
# Modelo: [42.92055]
# Real:   [39.045]
# Diff:  [3.8755513]
# Different
# Modelo: [42.46834]
# Real:   [38.758]
# Diff:  [3.71034183]
# Different
# Modelo: [41.936134]
# Real:   [38.754]
# Diff:  [3.18213434]
# Different
# Modelo: [41.488102]
# Real:   [38.764]
# Diff:  [2.72410196]
# Different
# Modelo: [41.120316]
# Real:   [38.676]
# Diff:  [2.44431555]
# Different
# Modelo: [40.81155]
# Real:   [38.5]
# Diff:  [2.31155014]
# Different
# Modelo: [40.492397]
# Real:   [38.972]
# Diff:  [1.52039731]
# Different
# Modelo: [40.30637]
# Real:   [38.805]
# Diff:  [1.50136978]
# Different
# Modelo: [40.15258]
# Real:   [38.732]
# Diff:  [1.42058026]
# Same Numbers
# Modelo: [40.034283]
# Real:   [38.314]
# Diff:  [1.72028268]
# Different
# Modelo: [39.882576]
# Real:   [38.363]
# Diff:  [1.51957599]
# Different
# Modelo: [39.774826]
# Real:   [38.346]
# Diff:  [1.42882605]
# Same Numbers
# Modelo: [39.69408]
# Real:   [38.27]
# Diff:  [1.42408035]
# Same Numbers
# Modelo: [39.62693]
# Real:   [38.617]
# Diff:  [1.00993024]
# Same Numbers
# Modelo: [39.573795]
# Real:   [38.82]
# Diff:  [0.75379532]
# Same Numbers
# Modelo: [39.573776]
# Real:   [38.742]
# Diff:  [0.83177625]
# Same Numbers
# Modelo: [39.58188]
# Real:   [38.465]
# Diff:  [1.11687866]
# Same Numbers
# Modelo: [39.56691]
# Real:   [38.613]
# Diff:  [0.95390979]
# Same Numbers
# Modelo: [39.55719]
# Real:   [38.806]
# Diff:  [0.75118994]
# Same Numbers
# Modelo: [39.585533]
# Real:   [38.717]
# Diff:  [0.86853314]
# Same Numbers
# Modelo: [39.60945]
# Real:   [38.634]
# Diff:  [0.97545129]
# Same Numbers
# Modelo: [39.627205]
# Real:   [38.398]
# Diff:  [1.2292049]
# Same Numbers
# Modelo: [39.591526]
# Real:   [38.368]
# Diff:  [1.22352603]
# Same Numbers
# Modelo: [39.56452]
# Real:   [38.469]
# Diff:  [1.09552179]
# Same Numbers
# Modelo: [39.56071]
# Real:   [38.376]
# Diff:  [1.18471091]
# Same Numbers
# Modelo: [39.551426]
# Real:   [38.292]
# Diff:  [1.25942593]
# Same Numbers
# Modelo: [39.488186]
# Real:   [38.327]
# Diff:  [1.16118588]
# Same Numbers
# Modelo: [39.450974]
# Real:   [38.335]
# Diff:  [1.11597351]
# Same Numbers
# Modelo: [39.431927]
# Real:   [38.224]
# Diff:  [1.20792673]
# Same Numbers
# Modelo: [39.41123]
# Real:   [38.323]
# Diff:  [1.08822818]
# Same Numbers
# Modelo: [39.395035]
# Real:   [38.432]
# Diff:  [0.96303479]
# Same Numbers
# Modelo: [39.40477]
# Real:   [38.33]
# Diff:  [1.0747699]
# Same Numbers
# Modelo: [39.408806]
# Real:   [38.353]
# Diff:  [1.05580585]
# Same Numbers
# Modelo: [39.421314]
# Real:   [38.336]
# Diff:  [1.08531424]
# Same Numbers
# Modelo: [39.42241]
# Real:   [38.339]
# Diff:  [1.08340906]
# Same Numbers
# Modelo: [39.42915]
# Real:   [38.444]
# Diff:  [0.98514963]
# Same Numbers
# Modelo: [39.452717]
# Real:   [38.26]
# Diff:  [1.19271683]
# Same Numbers
# Modelo: [39.45315]
# Real:   [38.39]
# Diff:  [1.0631517]
# Same Numbers
# Modelo: [39.46855]
# Real:   [38.339]
# Diff:  [1.12955164]
# Same Numbers
# Modelo: [39.477478]
# Real:   [38.236]
# Diff:  [1.24147803]
# Same Numbers
# Modelo: [39.473488]
# Real:   [38.185]
# Diff:  [1.28848785]
# Same Numbers
# Modelo: [39.463932]
# Real:   [38.347]
# Diff:  [1.11693204]
# Same Numbers
# Modelo: [39.48725]
# Real:   [38.366]
# Diff:  [1.12125128]
# Same Numbers
# Modelo: [39.50833]
# Real:   [38.197]
# Diff:  [1.3113313]
# Same Numbers
# Modelo: [39.503426]
# Real:   [38.17]
# Diff:  [1.3334256]
# Same Numbers
# Modelo: [39.49345]
# Real:   [38.271]
# Diff:  [1.22245016]
# Same Numbers
# Modelo: [39.75369]
# Real:   [38.206]
# Diff:  [1.54768881]
# Different
# Modelo: [39.91701]
# Real:   [38.158]
# Diff:  [1.75901126]
# Different
# Modelo: [39.999607]
# Real:   [38.352]
# Diff:  [1.64760709]
# Different
# Modelo: [40.05204]
# Real:   [38.506]
# Diff:  [1.5460401]
# Different
# Modelo: [40.235096]
# Real:   [38.54]
# Diff:  [1.69509598]
# Different
# Modelo: [40.34062]
# Real:   [38.345]
# Diff:  [1.99561813]
# Different
# Modelo: [40.36063]
# Real:   [38.658]
# Diff:  [1.70263004]
# Different
# Modelo: [40.381367]
# Real:   [38.451]
# Diff:  [1.93036673]
# Different
# Modelo: [39.935352]
# Real:   [39.089]
# Diff:  [0.84635233]
# Same Numbers
# Modelo: [39.677464]
# Real:   [38.814]
# Diff:  [0.86346353]
# Same Numbers
# Modelo: [39.475513]
# Real:   [36.408]
# Diff:  [3.06751346]
# Different
# Modelo: [39.031925]
# Real:   [36.341]
# Diff:  [2.6909252]
# Different
# Modelo: [38.58794]
# Real:   [34.11]
# Diff:  [4.47794022]
# Different
# Modelo: [37.98537]
# Real:   [36.079]
# Diff:  [1.90637064]
# Different
# Modelo: [37.749725]
# Real:   [36.315]
# Diff:  [1.43472534]
# Same Numbers
# Modelo: [37.63756]
# Real:   [36.336]
# Diff:  [1.3015618]
# Same Numbers
# Modelo: [37.472168]
# Real:   [35.951]
# Diff:  [1.52116797]
# Different
# Modelo: [37.339405]
# Real:   [36.161]
# Diff:  [1.17840506]
# Same Numbers
# Modelo: [37.304874]
# Real:   [36.022]
# Diff:  [1.28287442]
# Same Numbers
# Modelo: [37.27959]
# Real:   [36.241]
# Diff:  [1.03859061]
# Same Numbers
# Modelo: [37.358273]
# Real:   [35.864]
# Diff:  [1.49427255]
# Same Numbers
# Modelo: [37.387775]
# Real:   [35.981]
# Diff:  [1.40677542]
# Same Numbers
# Modelo: [37.43047]
# Real:   [36.223]
# Diff:  [1.20746951]
# Same Numbers
# Modelo: [37.499214]
# Real:   [36.071]
# Diff:  [1.42821417]
# Same Numbers
# Modelo: [37.622837]
# Real:   [36.155]
# Diff:  [1.46783707]
# Same Numbers
# Modelo: [37.72327]
# Real:   [36.084]
# Diff:  [1.63927042]
# Different
# Modelo: [37.774715]
# Real:   [36.603]
# Diff:  [1.17171542]
# Same Numbers
# Modelo: [37.867153]
# Real:   [36.149]
# Diff:  [1.71815317]
# Different
# Modelo: [37.758793]
# Real:   [36.137]
# Diff:  [1.62179288]
# Different
# Modelo: [37.67692]
# Real:   [36.255]
# Diff:  [1.42192184]
# Same Numbers
# Modelo: [37.636982]
# Real:   [36.103]
# Diff:  [1.53398196]
# Different
# Modelo: [37.598175]
# Real:   [36.263]
# Diff:  [1.33517505]
# Same Numbers
# Modelo: [37.52189]
# Real:   [36.281]
# Diff:  [1.24088873]
# Same Numbers
# Modelo: [37.483128]
# Real:   [36.026]
# Diff:  [1.45712759]
# Same Numbers
# Modelo: [37.440556]
# Real:   [36.715]
# Diff:  [0.72555557]
# Same Numbers
# Modelo: [37.50714]
# Real:   [36.337]
# Diff:  [1.17014111]
# Same Numbers
# Modelo: [37.476543]
# Real:   [35.232]
# Diff:  [2.24454343]
# Different
# Modelo: [37.329857]
# Real:   [36.081]
# Diff:  [1.24885687]
# Same Numbers
# Modelo: [37.318153]
# Real:   [34.963]
# Diff:  [2.35515338]
# Different
# Modelo: [37.19512]
# Real:   [35.827]
# Diff:  [1.36812177]
# Same Numbers
# Modelo: [37.592613]
# Real:   [37.951]
# Diff:  [-0.35838678]
# Same Numbers
# Modelo: [38.156315]
# Real:   [38.625]
# Diff:  [-0.46868515]
# Same Numbers
# Modelo: [38.67236]
# Real:   [39.14]
# Diff:  [-0.46764053]
# Same Numbers
# Modelo: [39.132446]
# Real:   [38.919]
# Diff:  [0.21344629]
# Same Numbers
# Modelo: [39.674667]
# Real:   [39.105]
# Diff:  [0.56966736]
# Same Numbers
# Modelo: [40.081047]
# Real:   [38.768]
# Diff:  [1.31304706]
# Same Numbers
# Modelo: [40.307972]
# Real:   [39.084]
# Diff:  [1.22397195]
# Same Numbers
# Modelo: [40.47551]
# Real:   [39.085]
# Diff:  [1.39050964]
# Same Numbers
# Modelo: [40.601566]
# Real:   [38.884]
# Diff:  [1.71756631]
# Different
# Modelo: [40.63516]
# Real:   [39.493]
# Diff:  [1.14215854]
# Same Numbers
# Modelo: [40.70274]
# Real:   [39.036]
# Diff:  [1.66673972]
# Different
# Modelo: [40.674347]
# Real:   [39.16]
# Diff:  [1.51434692]
# Different
# Modelo: [40.557236]
# Real:   [38.788]
# Diff:  [1.76923572]
# Different
# Modelo: [40.410538]
# Real:   [38.916]
# Diff:  [1.49453772]
# Same Numbers
# Modelo: [40.305492]
# Real:   [39.108]
# Diff:  [1.1974924]
# Same Numbers
# Modelo: [40.246532]
# Real:   [39.068]
# Diff:  [1.17853244]
# Same Numbers
# Modelo: [40.149296]
# Real:   [38.953]
# Diff:  [1.19629581]
# Same Numbers
# Modelo: [40.068794]
# Real:   [38.758]
# Diff:  [1.31079425]
# Same Numbers
# Modelo: [39.990158]
# Real:   [38.771]
# Diff:  [1.21915808]
# Same Numbers
# Modelo: [39.93656]
# Real:   [38.909]
# Diff:  [1.02756158]
# Same Numbers
# Modelo: [39.90384]
# Real:   [38.863]
# Diff:  [1.04083911]
# Same Numbers
# Modelo: [39.88221]
# Real:   [38.957]
# Diff:  [0.92520978]
# Same Numbers
# Modelo: [39.88594]
# Real:   [38.71]
# Diff:  [1.17594055]
# Same Numbers
# Modelo: [39.865738]
# Real:   [38.817]
# Diff:  [1.04873792]
# Same Numbers
# Modelo: [39.81758]
# Real:   [39.007]
# Diff:  [0.81058118]
# Same Numbers
# Modelo: [39.815052]
# Real:   [38.955]
# Diff:  [0.86005203]
# Same Numbers
# Modelo: [39.82017]
# Real:   [39.053]
# Diff:  [0.76717136]
# Same Numbers
# Modelo: [39.848057]
# Real:   [38.585]
# Diff:  [1.26305679]
# Same Numbers
# Modelo: [39.79587]
# Real:   [38.436]
# Diff:  [1.35987173]
# Same Numbers
# Modelo: [39.74094]
# Real:   [38.761]
# Diff:  [0.97994009]
# Same Numbers
# Modelo: [39.742233]
# Real:   [38.47]
# Diff:  [1.27223328]
# Same Numbers
# Modelo: [39.713463]
# Real:   [38.423]
# Diff:  [1.29046283]
# Same Numbers
# Modelo: [39.66188]
# Real:   [38.268]
# Diff:  [1.39388049]
# Same Numbers
# Modelo: [39.606167]
# Real:   [38.346]
# Diff:  [1.26016684]
# Same Numbers
# Modelo: [39.575344]
# Real:   [38.396]
# Diff:  [1.17934409]
# Same Numbers
# Modelo: [39.561623]
# Real:   [38.372]
# Diff:  [1.18962262]
# Same Numbers
# Modelo: [39.50354]
# Real:   [38.575]
# Diff:  [0.92854004]
# Same Numbers
# Modelo: [39.49373]
# Real:   [38.628]
# Diff:  [0.86572864]
# Same Numbers
# Modelo: [39.505768]
# Real:   [38.877]
# Diff:  [0.62876782]
# Same Numbers
# Modelo: [39.559166]
# Real:   [38.702]
# Diff:  [0.85716595]
# Same Numbers
# Modelo: [39.573753]
# Real:   [38.411]
# Diff:  [1.16275336]
# Same Numbers
# Modelo: [39.55858]
# Real:   [38.393]
# Diff:  [1.16557849]
# Same Numbers
# Modelo: [39.548973]
# Real:   [38.295]
# Diff:  [1.25397308]
# Same Numbers
# Modelo: [39.532337]
# Real:   [38.343]
# Diff:  [1.18933719]
# Same Numbers
# Modelo: [39.515198]
# Real:   [38.443]
# Diff:  [1.07219775]
# Same Numbers
# Modelo: [39.51816]
# Real:   [38.455]
# Diff:  [1.06316177]
# Same Numbers
# Modelo: [39.527084]
# Real:   [38.53]
# Diff:  [0.99708435]
# Same Numbers
# Modelo: [39.54814]
# Real:   [38.291]
# Diff:  [1.25714148]
# Same Numbers
# Modelo: [39.535423]
# Real:   [38.485]
# Diff:  [1.05042328]
# Same Numbers
# Modelo: [39.550804]
# Real:   [38.531]
# Diff:  [1.01980414]
# Same Numbers
# Modelo: [39.571815]
# Real:   [38.634]
# Diff:  [0.93781549]
# Same Numbers
# Modelo: [39.60478]
# Real:   [38.409]
# Diff:  [1.19577829]
# Same Numbers
# Modelo: [39.616722]
# Real:   [38.478]
# Diff:  [1.13872211]
# Same Numbers
# Modelo: [39.633286]
# Real:   [38.311]
# Diff:  [1.32228552]
# Same Numbers
# Modelo: [39.62368]
# Real:   [38.31]
# Diff:  [1.31368011]
# Same Numbers
# Modelo: [39.612465]
# Real:   [38.385]
# Diff:  [1.2274649]
# Same Numbers
# Modelo: [39.8684]
# Real:   [38.514]
# Diff:  [1.35440057]
# Same Numbers
# Modelo: [40.052704]
# Real:   [38.862]
# Diff:  [1.19070386]
# Same Numbers
# Modelo: [40.20512]
# Real:   [38.809]
# Diff:  [1.39612009]
# Same Numbers
# Modelo: [40.288227]
# Real:   [38.589]
# Diff:  [1.69922708]
# Different
# Modelo: [40.44997]
# Real:   [38.843]
# Diff:  [1.60697025]
# Different
# Modelo: [40.563007]
# Real:   [38.705]
# Diff:  [1.85800735]
# Different
# Modelo: [40.59205]
# Real:   [38.66]
# Diff:  [1.93204865]
# Different
# Modelo: [40.57066]
# Real:   [38.353]
# Diff:  [2.21765964]
# Different
# Modelo: [40.06868]
# Real:   [37.638]
# Diff:  [2.43067981]
# Different
# Modelo: [39.606865]
# Real:   [37.993]
# Diff:  [1.61386493]
# Different
# Modelo: [39.315346]
# Real:   [35.892]
# Diff:  [3.42334576]
# Different
# Modelo: [38.850746]
# Real:   [35.976]
# Diff:  [2.87474615]
# Different
# Modelo: [38.401127]
# Real:   [36.004]
# Diff:  [2.39712686]
# Different
# Modelo: [38.07213]
# Real:   [35.822]
# Diff:  [2.2501283]
# Different
# Modelo: [37.816944]
# Real:   [35.973]
# Diff:  [1.84394412]
# Different
# Modelo: [37.659344]
# Real:   [36.049]
# Diff:  [1.61034372]
# Different
# Modelo: [37.452084]
# Real:   [35.924]
# Diff:  [1.52808359]
# Different
# Modelo: [37.310772]
# Real:   [36.]
# Diff:  [1.31077194]
# Same Numbers
# Modelo: [37.244473]
# Real:   [36.133]
# Diff:  [1.1114725]
# Same Numbers
# Modelo: [37.240864]
# Real:   [35.882]
# Diff:  [1.3588638]
# Same Numbers
# Modelo: [37.285015]
# Real:   [36.018]
# Diff:  [1.26701511]
# Same Numbers
# Modelo: [37.3507]
# Real:   [36.124]
# Diff:  [1.22670038]
# Same Numbers
# Modelo: [37.425705]
# Real:   [35.889]
# Diff:  [1.53670496]
# Different
# Modelo: [37.46326]
# Real:   [36.049]
# Diff:  [1.41426065]
# Same Numbers
# Modelo: [37.59189]
# Real:   [36.075]
# Diff:  [1.51688843]
# Different
# Modelo: [37.690193]
# Real:   [36.146]
# Diff:  [1.54419318]
# Different
# Modelo: [37.76709]
# Real:   [36.204]
# Diff:  [1.56308984]
# Different
# Modelo: [37.82624]
# Real:   [35.996]
# Diff:  [1.83024054]
# Different
# Modelo: [37.71968]
# Real:   [36.156]
# Diff:  [1.56368079]
# Different
# Modelo: [37.6607]
# Real:   [36.031]
# Diff:  [1.62970175]
# Different
# Modelo: [37.610107]
# Real:   [36.364]
# Diff:  [1.24610742]
# Same Numbers
# Modelo: [37.622135]
# Real:   [36.003]
# Diff:  [1.61913516]
# Different
# Modelo: [37.525562]
# Real:   [36.14]
# Diff:  [1.38556229]
# Same Numbers
# Modelo: [37.482445]
# Real:   [36.048]
# Diff:  [1.43444476]
# Same Numbers
# Modelo: [37.455273]
# Real:   [35.809]
# Diff:  [1.64627267]
# Different
# Modelo: [37.418835]
# Real:   [35.793]
# Diff:  [1.62583469]
# Different
# Modelo: [37.340588]
# Real:   [36.333]
# Diff:  [1.00758762]
# Same Numbers
# Modelo: [37.36176]
# Real:   [35.747]
# Diff:  [1.61475919]
# Different
# Modelo: [37.327637]
# Real:   [35.9]
# Diff:  [1.42763672]
# Same Numbers
# Modelo: [37.33144]
# Real:   [35.788]
# Diff:  [1.54343997]
# Different
# Modelo: [37.723724]
# Real:   [36.277]
# Diff:  [1.44672437]
# Same Numbers
# Modelo: [38.057438]
# Real:   [38.027]
# Diff:  [0.0304379]
# Same Numbers
# Modelo: [38.49664]
# Real:   [38.887]
# Diff:  [-0.39036075]
# Same Numbers
# Modelo: [38.931995]
# Real:   [38.761]
# Diff:  [0.17099539]
# Same Numbers
# Modelo: [39.468513]
# Real:   [39.185]
# Diff:  [0.28351349]
# Same Numbers
# Modelo: [39.904774]
# Real:   [39.057]
# Diff:  [0.84777371]
# Same Numbers
# Modelo: [40.18884]
# Real:   [38.697]
# Diff:  [1.49183896]
# Same Numbers
# Modelo: [40.322937]
# Real:   [38.446]
# Diff:  [1.87693701]
# Different
# Modelo: [40.387226]
# Real:   [38.76]
# Diff:  [1.6272261]
# Different
# Modelo: [40.4319]
# Real:   [38.994]
# Diff:  [1.43790002]
# Same Numbers
# Modelo: [40.461975]
# Real:   [39.027]
# Diff:  [1.4349751]
# Same Numbers
# Modelo: [40.464714]
# Real:   [38.644]
# Diff:  [1.82071405]
# Different
# Modelo: [40.311066]
# Real:   [38.42]
# Diff:  [1.89106567]
# Different
# Modelo: [40.151833]
# Real:   [38.528]
# Diff:  [1.62383258]
# Different
# Modelo: [40.033466]
# Real:   [38.313]
# Diff:  [1.72046634]
# Different
# Modelo: [39.91101]
# Real:   [38.273]
# Diff:  [1.63801074]
# Different
# Modelo: [39.75804]
# Real:   [38.848]
# Diff:  [0.91004138]
# Same Numbers
# Modelo: [39.71775]
# Real:   [38.98]
# Diff:  [0.73775055]
# Same Numbers
# Modelo: [39.71926]
# Real:   [38.676]
# Diff:  [1.04326117]
# Same Numbers
# Modelo: [39.698395]
# Real:   [38.451]
# Diff:  [1.24739478]
# Same Numbers
# Modelo: [39.64831]
# Real:   [38.424]
# Diff:  [1.22431161]
# Same Numbers
# Modelo: [39.612305]
# Real:   [38.288]
# Diff:  [1.32430469]
# Same Numbers
# Modelo: [39.572514]
# Real:   [38.932]
# Diff:  [0.64051358]
# Same Numbers
# Modelo: [39.62775]
# Real:   [39.218]
# Diff:  [0.4097504]
# Same Numbers
# Modelo: [39.670567]
# Real:   [38.82]
# Diff:  [0.85056656]
# Same Numbers
# Modelo: [39.67421]
# Real:   [38.481]
# Diff:  [1.19320959]
# Same Numbers
# Modelo: [39.646523]
# Real:   [38.313]
# Diff:  [1.33352252]
# Same Numbers
# Modelo: [39.60868]
# Real:   [38.493]
# Diff:  [1.11568073]
# Same Numbers
# Modelo: [39.579784]
# Real:   [38.577]
# Diff:  [1.00278439]
# Same Numbers
# Modelo: [39.575874]
# Real:   [38.619]
# Diff:  [0.95687433]
# Same Numbers
# Quantity of same numbers:  1682  records
# Quantity of different numbers:  852  records
# Percentage:  66.4 %
