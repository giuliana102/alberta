# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["Vacation"]
del df["summer_classes"]
del df["Theres_sun"]
del df["temp_ant"]
del df["Average_hour_day_ant"]
del df["Timestamp"]
del df["Average_hour_month"]

df
# Out:
#        RealPower  EV_Power  month
# 0         51.488       0.0      4
# 1         51.794       0.0      4
# 2         51.397       0.0      4
# 3         50.765       0.0      4
# 4         51.206       0.0      4
# ...          ...       ...    ...
# 26299     38.313       0.0     12
# 26300     38.493       0.0     12
# 26301     38.577       0.0     12
# 26302     38.619       0.0     12
# 26303     38.394       0.0     12
#
# [26304 rows x 3 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
#df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power         month
# count  26304.000000  26304.000000  26304.000000
# mean      48.307932      6.167214      8.021898
# std        5.717560      9.099070      2.572977
# min       -1.161000     -6.400000      4.000000
# 25%       45.886000      0.000000      6.000000
# 50%       48.319000      0.000000      8.000000
# 75%       51.776500      9.480000     10.000000
# max       82.339000     55.150000     12.000000

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (21043, 3)
# Validation set size: (2630, 3)
# Testing set size: (2631, 3)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20946, 96, 3), y_tr: (20946, 1, 1)
# Set de validación - x_vl: (2533, 96, 3), y_vl: (2533, 1, 1)
# Set de prueba - x_ts: (2534, 96, 3), y_ts: (2534, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488,  0.   ,  4.   ],
#        [51.794,  0.   ,  4.   ],
#        [51.397,  0.   ,  4.   ],
#        [50.765,  0.   ,  4.   ],
#        [51.206,  0.   ,  4.   ],
#        [51.219,  0.   ,  4.   ],
#        [50.654,  0.   ,  4.   ],
#        [50.491,  0.   ,  4.   ],
#        [50.577,  0.   ,  4.   ],
#        [50.654,  0.   ,  4.   ],
#        [50.275,  0.   ,  4.   ],
#        [50.022,  0.   ,  4.   ],
#        [49.987,  0.   ,  4.   ],
#        [50.443,  0.   ,  4.   ],
#        [50.345,  0.   ,  4.   ],
#        [50.239,  0.   ,  4.   ],
#        [50.716,  0.   ,  4.   ],
#        [50.673,  0.   ,  4.   ],
#        [50.407,  0.   ,  4.   ],
#        [50.605,  0.   ,  4.   ],
#        [50.733,  0.   ,  4.   ],
#        [52.101,  0.   ,  4.   ],
#        [52.23 ,  0.   ,  4.   ],
#        [53.73 ,  0.   ,  4.   ],
#        [53.611,  0.   ,  4.   ],
#        [53.646,  0.   ,  4.   ],
#        [53.21 ,  0.   ,  4.   ],
#        [53.806,  0.   ,  4.   ],
#        [53.582,  0.   ,  4.   ],
#        [52.526,  0.   ,  4.   ],
#        [49.983,  5.2  ,  4.   ],
#        [50.513,  8.11 ,  4.   ],
#        [53.22 , 11.01 ,  4.   ],
#        [55.027, 16.35 ,  4.   ],
#        [53.067, 17.54 ,  4.   ],
#        [52.949, 22.48 ,  4.   ],
#        [51.79 , 23.2  ,  4.   ],
#        [50.477, 22.37 ,  4.   ],
#        [48.413, 29.37 ,  4.   ],
#        [50.593, 25.27 ,  4.   ],
#        [51.712, 28.57 ,  4.   ],
#        [49.816, 33.57 ,  4.   ],
#        [54.568, 22.7  ,  4.   ],
#        [59.61 , 15.93 ,  4.   ],
#        [56.574, 10.3  ,  4.   ],
#        [52.774,  9.7  ,  4.   ],
#        [56.809,  9.7  ,  4.   ],
#        [51.718,  5.7  ,  4.   ],
#        [53.128,  3.18 ,  4.   ],
#        [54.716, 12.23 ,  4.   ],
#        [48.839, 13.79 ,  4.   ],
#        [53.15 , 18.32 ,  4.   ],
#        [56.602, 10.62 ,  4.   ],
#        [67.519, 21.57 ,  4.   ],
#        [65.695, 24.67 ,  4.   ],
#        [62.946, 11.98 ,  4.   ],
#        [50.613, 11.69 ,  4.   ],
#        [48.255, 10.14 ,  4.   ],
#        [46.57 ,  8.14 ,  4.   ],
#        [45.438,  8.54 ,  4.   ],
#        [59.025,  7.12 ,  4.   ],
#        [57.188,  7.27 ,  4.   ],
#        [59.485, 10.95 ,  4.   ],
#        [59.79 , 16.3  ,  4.   ],
#        [59.683, 14.12 ,  4.   ],
#        [59.392,  8.99 ,  4.   ],
#        [57.961,  8.59 ,  4.   ],
#        [58.789,  6.   ,  4.   ],
#        [61.564,  5.53 ,  4.   ],
#        [54.152,  5.53 ,  4.   ],
#        [54.354,  5.53 ,  4.   ],
#        [55.792,  5.53 ,  4.   ],
#        [53.667,  5.53 ,  4.   ],
#        [55.323,  5.53 ,  4.   ],
#        [53.986,  5.06 ,  4.   ],
#        [53.523,  4.3  ,  4.   ],
#        [56.197,  5.07 ,  4.   ],
#        [56.316, 12.39 ,  4.   ],
#        [57.141, 15.58 ,  4.   ],
#        [56.48 , 15.58 ,  4.   ],
#        [56.714, 14.87 ,  4.   ],
#        [56.187, 12.17 ,  4.   ],
#        [55.675, 19.89 ,  4.   ],
#        [57.27 , 14.77 ,  4.   ],
#        [55.669,  9.07 ,  4.   ],
#        [56.501,  9.07 ,  4.   ],
#        [55.379,  9.07 ,  4.   ],
#        [53.727,  4.67 ,  4.   ],
#        [53.533,  0.4  ,  4.   ],
#        [53.248,  0.   ,  4.   ],
#        [52.776,  0.   ,  4.   ],
#        [52.309,  0.   ,  4.   ],
#        [52.465,  0.   ,  4.   ],
#        [51.948,  0.   ,  4.   ],
#        [51.993,  0.   ,  4.   ],
#        [51.682,  0.   ,  4.   ]])

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]])

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -0.8830219333874898
# Maximun value per dimension: 1.0

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (3):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 80 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/80
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 23s - loss: 0.2256 - accuracy: 0.0000e+00 - val_loss: 0.0984 - val_accuracy: 0.0000e+00 - 23s/epoch - 281ms/step
# Epoch 2/80
# 82/82 - 21s - loss: 0.1865 - accuracy: 0.0000e+00 - val_loss: 0.1020 - val_accuracy: 0.0000e+00 - 21s/epoch - 255ms/step
# Epoch 3/80
# 82/82 - 24s - loss: 0.1524 - accuracy: 0.0000e+00 - val_loss: 0.1068 - val_accuracy: 0.0000e+00 - 24s/epoch - 295ms/step
# Epoch 4/80
# 82/82 - 23s - loss: 0.1269 - accuracy: 0.0000e+00 - val_loss: 0.1116 - val_accuracy: 0.0000e+00 - 23s/epoch - 286ms/step
# Epoch 5/80
# 82/82 - 24s - loss: 0.1139 - accuracy: 0.0000e+00 - val_loss: 0.1117 - val_accuracy: 0.0000e+00 - 24s/epoch - 296ms/step
# Epoch 6/80
# 82/82 - 28s - loss: 0.1074 - accuracy: 0.0000e+00 - val_loss: 0.1088 - val_accuracy: 0.0000e+00 - 28s/epoch - 341ms/step
# Epoch 7/80
# 82/82 - 34s - loss: 0.1015 - accuracy: 0.0000e+00 - val_loss: 0.1061 - val_accuracy: 0.0000e+00 - 34s/epoch - 412ms/step
# Epoch 8/80
# 82/82 - 33s - loss: 0.0958 - accuracy: 0.0000e+00 - val_loss: 0.1037 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 9/80
# 82/82 - 33s - loss: 0.0903 - accuracy: 0.0000e+00 - val_loss: 0.1027 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 10/80
# 82/82 - 31s - loss: 0.0852 - accuracy: 0.0000e+00 - val_loss: 0.1012 - val_accuracy: 0.0000e+00 - 31s/epoch - 383ms/step
# Epoch 11/80
# 82/82 - 33s - loss: 0.0804 - accuracy: 0.0000e+00 - val_loss: 0.1007 - val_accuracy: 0.0000e+00 - 33s/epoch - 407ms/step
# Epoch 12/80
# 82/82 - 31s - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0998 - val_accuracy: 0.0000e+00 - 31s/epoch - 384ms/step
# Epoch 13/80
# 82/82 - 32s - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0993 - val_accuracy: 0.0000e+00 - 32s/epoch - 390ms/step
# Epoch 14/80
# 82/82 - 33s - loss: 0.0704 - accuracy: 0.0000e+00 - val_loss: 0.0989 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 15/80
# 82/82 - 33s - loss: 0.0687 - accuracy: 0.0000e+00 - val_loss: 0.0975 - val_accuracy: 0.0000e+00 - 33s/epoch - 399ms/step
# Epoch 16/80
# 82/82 - 31s - loss: 0.0678 - accuracy: 0.0000e+00 - val_loss: 0.0957 - val_accuracy: 0.0000e+00 - 31s/epoch - 384ms/step
# Epoch 17/80
# 82/82 - 31s - loss: 0.0673 - accuracy: 0.0000e+00 - val_loss: 0.0938 - val_accuracy: 0.0000e+00 - 31s/epoch - 384ms/step
# Epoch 18/80
# 82/82 - 33s - loss: 0.0667 - accuracy: 0.0000e+00 - val_loss: 0.0932 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 19/80
# 82/82 - 32s - loss: 0.0666 - accuracy: 0.0000e+00 - val_loss: 0.0936 - val_accuracy: 0.0000e+00 - 32s/epoch - 389ms/step
# Epoch 20/80
# 82/82 - 32s - loss: 0.0662 - accuracy: 0.0000e+00 - val_loss: 0.0893 - val_accuracy: 0.0000e+00 - 32s/epoch - 391ms/step
# Epoch 21/80
# 82/82 - 33s - loss: 0.0660 - accuracy: 0.0000e+00 - val_loss: 0.0896 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 22/80
# 82/82 - 34s - loss: 0.0657 - accuracy: 0.0000e+00 - val_loss: 0.0864 - val_accuracy: 0.0000e+00 - 34s/epoch - 417ms/step
# Epoch 23/80
# 82/82 - 34s - loss: 0.0655 - accuracy: 4.7742e-05 - val_loss: 0.0874 - val_accuracy: 0.0000e+00 - 34s/epoch - 411ms/step
# Epoch 24/80
# 82/82 - 33s - loss: 0.0652 - accuracy: 4.7742e-05 - val_loss: 0.0868 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 25/80
# 82/82 - 34s - loss: 0.0650 - accuracy: 4.7742e-05 - val_loss: 0.0848 - val_accuracy: 0.0000e+00 - 34s/epoch - 414ms/step
# Epoch 26/80
# 82/82 - 31s - loss: 0.0648 - accuracy: 4.7742e-05 - val_loss: 0.0836 - val_accuracy: 0.0000e+00 - 31s/epoch - 377ms/step
# Epoch 27/80
# 82/82 - 36s - loss: 0.0645 - accuracy: 4.7742e-05 - val_loss: 0.0823 - val_accuracy: 0.0000e+00 - 36s/epoch - 436ms/step
# Epoch 28/80
# 82/82 - 36s - loss: 0.0644 - accuracy: 4.7742e-05 - val_loss: 0.0824 - val_accuracy: 0.0000e+00 - 36s/epoch - 438ms/step
# Epoch 29/80
# 82/82 - 32s - loss: 0.0641 - accuracy: 4.7742e-05 - val_loss: 0.0803 - val_accuracy: 0.0000e+00 - 32s/epoch - 393ms/step
# Epoch 30/80
# 82/82 - 31s - loss: 0.0640 - accuracy: 4.7742e-05 - val_loss: 0.0789 - val_accuracy: 0.0000e+00 - 31s/epoch - 384ms/step
# Epoch 31/80
# 82/82 - 30s - loss: 0.0638 - accuracy: 4.7742e-05 - val_loss: 0.0788 - val_accuracy: 0.0000e+00 - 30s/epoch - 370ms/step
# Epoch 32/80
# 82/82 - 31s - loss: 0.0635 - accuracy: 4.7742e-05 - val_loss: 0.0779 - val_accuracy: 0.0000e+00 - 31s/epoch - 373ms/step
# Epoch 33/80
# 82/82 - 30s - loss: 0.0635 - accuracy: 4.7742e-05 - val_loss: 0.0771 - val_accuracy: 0.0000e+00 - 30s/epoch - 369ms/step
# Epoch 34/80
# 82/82 - 30s - loss: 0.0632 - accuracy: 4.7742e-05 - val_loss: 0.0757 - val_accuracy: 0.0000e+00 - 30s/epoch - 369ms/step
# Epoch 35/80
# 82/82 - 34s - loss: 0.0631 - accuracy: 4.7742e-05 - val_loss: 0.0762 - val_accuracy: 0.0000e+00 - 34s/epoch - 410ms/step
# Epoch 36/80
# 82/82 - 34s - loss: 0.0630 - accuracy: 4.7742e-05 - val_loss: 0.0743 - val_accuracy: 0.0000e+00 - 34s/epoch - 415ms/step
# Epoch 37/80
# 82/82 - 37s - loss: 0.0628 - accuracy: 4.7742e-05 - val_loss: 0.0733 - val_accuracy: 0.0000e+00 - 37s/epoch - 445ms/step
# Epoch 38/80
# 82/82 - 34s - loss: 0.0626 - accuracy: 4.7742e-05 - val_loss: 0.0741 - val_accuracy: 0.0000e+00 - 34s/epoch - 411ms/step
# Epoch 39/80
# 82/82 - 35s - loss: 0.0625 - accuracy: 4.7742e-05 - val_loss: 0.0738 - val_accuracy: 0.0000e+00 - 35s/epoch - 426ms/step
# Epoch 40/80
# 82/82 - 32s - loss: 0.0623 - accuracy: 4.7742e-05 - val_loss: 0.0730 - val_accuracy: 0.0000e+00 - 32s/epoch - 394ms/step
# Epoch 41/80
# 82/82 - 34s - loss: 0.0622 - accuracy: 4.7742e-05 - val_loss: 0.0724 - val_accuracy: 0.0000e+00 - 34s/epoch - 413ms/step
# Epoch 42/80
# 82/82 - 33s - loss: 0.0621 - accuracy: 4.7742e-05 - val_loss: 0.0714 - val_accuracy: 0.0000e+00 - 33s/epoch - 407ms/step
# Epoch 43/80
# 82/82 - 33s - loss: 0.0620 - accuracy: 4.7742e-05 - val_loss: 0.0714 - val_accuracy: 0.0000e+00 - 33s/epoch - 401ms/step
# Epoch 44/80
# 82/82 - 36s - loss: 0.0619 - accuracy: 4.7742e-05 - val_loss: 0.0703 - val_accuracy: 0.0000e+00 - 36s/epoch - 439ms/step
# Epoch 45/80
# 82/82 - 35s - loss: 0.0618 - accuracy: 4.7742e-05 - val_loss: 0.0701 - val_accuracy: 0.0000e+00 - 35s/epoch - 432ms/step
# Epoch 46/80
# 82/82 - 35s - loss: 0.0617 - accuracy: 4.7742e-05 - val_loss: 0.0684 - val_accuracy: 0.0000e+00 - 35s/epoch - 423ms/step
# Epoch 47/80
# 82/82 - 34s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0683 - val_accuracy: 0.0000e+00 - 34s/epoch - 420ms/step
# Epoch 48/80
# 82/82 - 34s - loss: 0.0615 - accuracy: 4.7742e-05 - val_loss: 0.0679 - val_accuracy: 0.0000e+00 - 34s/epoch - 412ms/step
# Epoch 49/80
# 82/82 - 36s - loss: 0.0614 - accuracy: 4.7742e-05 - val_loss: 0.0681 - val_accuracy: 0.0000e+00 - 36s/epoch - 433ms/step
# Epoch 50/80
# 82/82 - 33s - loss: 0.0613 - accuracy: 4.7742e-05 - val_loss: 0.0680 - val_accuracy: 0.0000e+00 - 33s/epoch - 405ms/step
# Epoch 51/80
# 82/82 - 35s - loss: 0.0610 - accuracy: 4.7742e-05 - val_loss: 0.0667 - val_accuracy: 0.0000e+00 - 35s/epoch - 427ms/step
# Epoch 52/80
# 82/82 - 37s - loss: 0.0610 - accuracy: 4.7742e-05 - val_loss: 0.0656 - val_accuracy: 0.0000e+00 - 37s/epoch - 455ms/step
# Epoch 53/80
# 82/82 - 36s - loss: 0.0609 - accuracy: 4.7742e-05 - val_loss: 0.0670 - val_accuracy: 0.0000e+00 - 36s/epoch - 433ms/step
# Epoch 54/80
# 82/82 - 33s - loss: 0.0608 - accuracy: 4.7742e-05 - val_loss: 0.0660 - val_accuracy: 0.0000e+00 - 33s/epoch - 404ms/step
# Epoch 55/80
# 82/82 - 35s - loss: 0.0608 - accuracy: 4.7742e-05 - val_loss: 0.0656 - val_accuracy: 0.0000e+00 - 35s/epoch - 427ms/step
# Epoch 56/80
# 82/82 - 33s - loss: 0.0607 - accuracy: 4.7742e-05 - val_loss: 0.0658 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 57/80
# 82/82 - 36s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0642 - val_accuracy: 0.0000e+00 - 36s/epoch - 435ms/step
# Epoch 58/80
# 82/82 - 33s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0650 - val_accuracy: 0.0000e+00 - 33s/epoch - 402ms/step
# Epoch 59/80
# 82/82 - 35s - loss: 0.0605 - accuracy: 4.7742e-05 - val_loss: 0.0646 - val_accuracy: 0.0000e+00 - 35s/epoch - 429ms/step
# Epoch 60/80
# 82/82 - 36s - loss: 0.0602 - accuracy: 4.7742e-05 - val_loss: 0.0640 - val_accuracy: 0.0000e+00 - 36s/epoch - 434ms/step
# Epoch 61/80
# 82/82 - 34s - loss: 0.0602 - accuracy: 4.7742e-05 - val_loss: 0.0634 - val_accuracy: 0.0000e+00 - 34s/epoch - 419ms/step
# Epoch 62/80
# 82/82 - 35s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0647 - val_accuracy: 0.0000e+00 - 35s/epoch - 426ms/step
# Epoch 63/80
# 82/82 - 35s - loss: 0.0601 - accuracy: 4.7742e-05 - val_loss: 0.0633 - val_accuracy: 0.0000e+00 - 35s/epoch - 427ms/step
# Epoch 64/80
# 82/82 - 34s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0636 - val_accuracy: 0.0000e+00 - 34s/epoch - 417ms/step
# Epoch 65/80
# 82/82 - 36s - loss: 0.0600 - accuracy: 4.7742e-05 - val_loss: 0.0634 - val_accuracy: 0.0000e+00 - 36s/epoch - 437ms/step
# Epoch 66/80
# 82/82 - 37s - loss: 0.0599 - accuracy: 4.7742e-05 - val_loss: 0.0637 - val_accuracy: 0.0000e+00 - 37s/epoch - 452ms/step
# Epoch 67/80
# 82/82 - 35s - loss: 0.0598 - accuracy: 4.7742e-05 - val_loss: 0.0618 - val_accuracy: 0.0000e+00 - 35s/epoch - 422ms/step
# Epoch 68/80
# 82/82 - 34s - loss: 0.0597 - accuracy: 4.7742e-05 - val_loss: 0.0631 - val_accuracy: 0.0000e+00 - 34s/epoch - 420ms/step
# Epoch 69/80
# 82/82 - 33s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0633 - val_accuracy: 0.0000e+00 - 33s/epoch - 408ms/step
# Epoch 70/80
# 82/82 - 33s - loss: 0.0596 - accuracy: 4.7742e-05 - val_loss: 0.0616 - val_accuracy: 0.0000e+00 - 33s/epoch - 406ms/step
# Epoch 71/80
# 82/82 - 32s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0630 - val_accuracy: 0.0000e+00 - 32s/epoch - 385ms/step
# Epoch 72/80
# 82/82 - 34s - loss: 0.0594 - accuracy: 4.7742e-05 - val_loss: 0.0633 - val_accuracy: 0.0000e+00 - 34s/epoch - 414ms/step
# Epoch 73/80
# 82/82 - 35s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0620 - val_accuracy: 0.0000e+00 - 35s/epoch - 427ms/step
# Epoch 74/80
# 82/82 - 37s - loss: 0.0595 - accuracy: 4.7742e-05 - val_loss: 0.0613 - val_accuracy: 0.0000e+00 - 37s/epoch - 451ms/step
# Epoch 75/80
# 82/82 - 35s - loss: 0.0592 - accuracy: 4.7742e-05 - val_loss: 0.0613 - val_accuracy: 0.0000e+00 - 35s/epoch - 422ms/step
# Epoch 76/80
# 82/82 - 35s - loss: 0.0593 - accuracy: 4.7742e-05 - val_loss: 0.0614 - val_accuracy: 0.0000e+00 - 35s/epoch - 428ms/step
# Epoch 77/80
# 82/82 - 37s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0618 - val_accuracy: 0.0000e+00 - 37s/epoch - 456ms/step
# Epoch 78/80
# 82/82 - 43s - loss: 0.0591 - accuracy: 4.7742e-05 - val_loss: 0.0615 - val_accuracy: 0.0000e+00 - 43s/epoch - 526ms/step
# Epoch 79/80
# 82/82 - 41s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0612 - val_accuracy: 0.0000e+00 - 41s/epoch - 504ms/step
# Epoch 80/80
# 82/82 - 38s - loss: 0.0590 - accuracy: 4.7742e-05 - val_loss: 0.0612 - val_accuracy: 0.0000e+00 - 38s/epoch - 461ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 655/655 [==============================] - 32s 45ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.049
#   RMSE val:	 0.057
#   RMSE test:	 0.069

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 80/80 [==============================] - 3s 41ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values5
# Out:
# array([[41.020416],
#        [41.003326],
#        [40.972073],
#        [40.99583 ],
#        [41.04904 ],
#        [41.071304],
#        [41.061005],
#        [41.030365],
#        [41.011417],
#        [41.00025 ]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()
