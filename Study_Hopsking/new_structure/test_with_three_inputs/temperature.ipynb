# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop

# %% [markdown]
# **Open csv**

# %%
df=pd.read_csv("C:/Users/lagg/Desktop/giuliaa/alberta/Study_Hopsking/new_inputs/df_mix.csv")

df=pd.DataFrame(df)

df["DateTime"]=pd.to_datetime(df["DateTime"])
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False               0       False      16.1
# 1              False    2     False               0       False      16.1
# 2              False    2     False               0       False      16.1
# 3              False    2     False               0       False      16.1
# 4              False    2     False               0       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True               0       False      10.0
# 26300           True   31      True               0       False      10.0
# 26301           True   31      True               0       False      10.0
# 26302           True   31      True               0       False      10.0
# 26303           True   31      True               0       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# *Change of format in "summer_clases"*

# %%
def change_format(row):
    valor=row["summer_classes"]
    if valor == 0:
        return False
    elif valor == 1:
        return True
    else:
        # Manejar otros casos si es necesario
        return None  # O cualquier otro valor por defecto

df["summer_classes"]=df.apply(change_format, axis=1)
df
# Out:
#        Unnamed: 0            DateTime  RealPower  EV_Power  \
# 0              96 2019-04-02 00:00:00     51.488       0.0
# 1              97 2019-04-02 00:15:00     51.794       0.0
# 2              98 2019-04-02 00:30:00     51.397       0.0
# 3              99 2019-04-02 00:45:00     50.765       0.0
# 4             100 2019-04-02 01:00:00     51.206       0.0
# ...           ...                 ...        ...       ...
# 26299       26395 2019-12-31 22:45:00     38.313       0.0
# 26300       26396 2019-12-31 23:00:00     38.493       0.0
# 26301       26397 2019-12-31 23:15:00     38.577       0.0
# 26302       26398 2019-12-31 23:30:00     38.619       0.0
# 26303       26399 2019-12-31 23:45:00     38.394       0.0
#
#                  Timestamp  month  season_fall  season_spring  season_summer  \
# 0      1554163200000000000      4        False           True          False
# 1      1554164100000000000      4        False           True          False
# 2      1554165000000000000      4        False           True          False
# 3      1554165900000000000      4        False           True          False
# 4      1554166800000000000      4        False           True          False
# ...                    ...    ...          ...            ...            ...
# 26299  1577832300000000000     12        False          False          False
# 26300  1577833200000000000     12        False          False          False
# 26301  1577834100000000000     12        False          False          False
# 26302  1577835000000000000     12        False          False          False
# 26303  1577835900000000000     12        False          False          False
#
#        season_winter  day  Vacation  summer_classes  Theres_sun  temp_ant  \
# 0              False    2     False           False       False      16.1
# 1              False    2     False           False       False      16.1
# 2              False    2     False           False       False      16.1
# 3              False    2     False           False       False      16.1
# 4              False    2     False           False       False      16.1
# ...              ...  ...       ...             ...         ...       ...
# 26299           True   31      True           False       False      10.0
# 26300           True   31      True           False       False      10.0
# 26301           True   31      True           False       False      10.0
# 26302           True   31      True           False       False      10.0
# 26303           True   31      True           False       False      10.0
#
#        Hour  Average_hour_month  Its_higher_than_average  \
# 0         0           52.269892                        0
# 1         0           52.269892                        0
# 2         0           52.269892                        0
# 3         0           52.269892                        0
# 4         1           51.763875                        0
# ...     ...                 ...                      ...
# 26299    22           40.184637                        0
# 26300    23           40.048847                        0
# 26301    23           40.048847                        0
# 26302    23           40.048847                        0
# 26303    23           40.048847                        0
#
#        Average_hour_day_ant  Its_higher_than_average_day_ant
# 0                  51.17875                                0
# 1                  51.17875                                0
# 2                  51.17875                                0
# 3                  51.17875                                0
# 4                  51.05075                                0
# ...                     ...                              ...
# 26299              38.95800                                0
# 26300              38.56300                                0
# 26301              38.56300                                0
# 26302              38.56300                                0
# 26303              38.56300                                0
#
# [26304 rows x 20 columns]

# %% [markdown]
# **Eliminate variables with no correlation**

# %%
del df["Unnamed: 0"]
del df["season_fall"]
del df["season_spring"]
del df["season_summer"]
del df["season_winter"]
del df["day"]
del df["Hour"]
del df["Its_higher_than_average"]
del df["Its_higher_than_average_day_ant"]
del df["DateTime"]
del df["Vacation"]
del df["summer_classes"]
del df["Theres_sun"]

del df["Average_hour_month"]
del df["Average_hour_day_ant"]
del df["month"]
del df["Timestamp"]

df
# Out:
#        RealPower  EV_Power  temp_ant
# 0         51.488       0.0      16.1
# 1         51.794       0.0      16.1
# 2         51.397       0.0      16.1
# 3         50.765       0.0      16.1
# 4         51.206       0.0      16.1
# ...          ...       ...       ...
# 26299     38.313       0.0      10.0
# 26300     38.493       0.0      10.0
# 26301     38.577       0.0      10.0
# 26302     38.619       0.0      10.0
# 26303     38.394       0.0      10.0
#
# [26304 rows x 3 columns]

# %% [markdown]
# **Eliminate outliers**

# %%
df=df[(df["temp_ant"]>0)]
#df=df[(df["RealPower"]>0)]

df.describe()
# Out:
#           RealPower      EV_Power      temp_ant
# count  26112.000000  26112.000000  26112.000000
# mean      48.300279      6.138444     17.595840
# std        5.733787      9.075675      3.841522
# min       -1.161000     -6.400000      5.000000
# 25%       45.859500      0.000000     15.560000
# 50%       48.315000      0.000000     17.800000
# 75%       51.784000      9.440000     20.000000
# max       82.339000     55.150000     34.400000

# %% [markdown]
# **Split data in training, validation and testing**

# %%
# Function to split a time series into training, validation and testing sets

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):

    # Define number of data in each subseries
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Amount of training data
    Nval = int(vl_size*N)    # Amount of validation data
    Ntst = N - Ntrain - Nval # Amount of testing data

    # Split the data
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Use the function to split df
tr, vl, ts = train_val_test_split(df)

#Print the size of each set
print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (20889, 3)
# Validation set size: (2611, 3)
# Testing set size: (2612, 3)

# %% [markdown]
# *Graphic subplots of training, validation and testing*

# %%
fig, ax =plt.subplots(figsize=(16,5))
ax.plot(tr["RealPower"], label="Train")
ax.plot(vl["RealPower"], label="Validation")
ax.plot(ts["RealPower"], label="Test")
plt.legend()

# %% [markdown]
# **Creates a dataset (arrays) with the inputs (x) and outputs (y) for every window**

# %%
window = 96 
OUTPUT_LENGTH = 1

def create_dataset(array, window, output_length):

    X, Y = [], []    #list where will store the values for the input (96) and the output (1)
    
    fils, cols = array.shape  #exa: (21043, 2)

    # Generate the input and output data in a list
    for i in range(fils-window-output_length):
        X.append(array[i:i+window,0:cols])
        Y.append(array[i+window:i+window+output_length,0].reshape(output_length,1))
    
    # Convert the list to numpy arrays
    X = np.array(X)
    Y = np.array(Y)
    
    return X, Y

# %%
#Call the function to create datset for training, validation and testing
x_tr, y_tr = create_dataset(tr.values, window, OUTPUT_LENGTH)
x_vl, y_vl = create_dataset(vl.values, window, OUTPUT_LENGTH)
x_ts, y_ts = create_dataset(ts.values, window, OUTPUT_LENGTH)

# Print the shape of the input and output data
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (20792, 96, 3), y_tr: (20792, 1, 1)
# Set de validación - x_vl: (2514, 96, 3), y_vl: (2514, 1, 1)
# Set de prueba - x_ts: (2515, 96, 3), y_ts: (2515, 1, 1)

# %%
x_tr[0,:,:] #First window of 96 values of the time series
# Out:
# array([[51.488,  0.   , 16.1  ],
#        [51.794,  0.   , 16.1  ],
#        [51.397,  0.   , 16.1  ],
#        [50.765,  0.   , 16.1  ],
#        [51.206,  0.   , 16.1  ],
#        [51.219,  0.   , 16.1  ],
#        [50.654,  0.   , 16.1  ],
#        [50.491,  0.   , 16.1  ],
#        [50.577,  0.   , 16.1  ],
#        [50.654,  0.   , 16.1  ],
#        [50.275,  0.   , 16.1  ],
#        [50.022,  0.   , 16.1  ],
#        [49.987,  0.   , 16.1  ],
#        [50.443,  0.   , 16.1  ],
#        [50.345,  0.   , 16.1  ],
#        [50.239,  0.   , 16.1  ],
#        [50.716,  0.   , 16.1  ],
#        [50.673,  0.   , 16.1  ],
#        [50.407,  0.   , 16.1  ],
#        [50.605,  0.   , 16.1  ],
#        [50.733,  0.   , 16.1  ],
#        [52.101,  0.   , 16.1  ],
#        [52.23 ,  0.   , 16.1  ],
#        [53.73 ,  0.   , 16.1  ],
#        [53.611,  0.   , 16.1  ],
#        [53.646,  0.   , 16.1  ],
#        [53.21 ,  0.   , 16.1  ],
#        [53.806,  0.   , 20.85 ],
#        [53.582,  0.   , 20.85 ],
#        [52.526,  0.   , 20.85 ],
#        [49.983,  5.2  , 20.85 ],
#        [50.513,  8.11 , 20.85 ],
#        [53.22 , 11.01 , 20.85 ],
#        [55.027, 16.35 , 20.85 ],
#        [53.067, 17.54 , 20.85 ],
#        [52.949, 22.48 , 20.85 ],
#        [51.79 , 23.2  , 20.85 ],
#        [50.477, 22.37 , 20.85 ],
#        [48.413, 29.37 , 20.85 ],
#        [50.593, 25.27 , 20.85 ],
#        [51.712, 28.57 , 20.85 ],
#        [49.816, 33.57 , 20.85 ],
#        [54.568, 22.7  , 20.85 ],
#        [59.61 , 15.93 , 20.85 ],
#        [56.574, 10.3  , 20.85 ],
#        [52.774,  9.7  , 20.85 ],
#        [56.809,  9.7  , 20.85 ],
#        [51.718,  5.7  , 20.85 ],
#        [53.128,  3.18 , 20.85 ],
#        [54.716, 12.23 , 20.85 ],
#        [48.839, 13.79 , 25.6  ],
#        [53.15 , 18.32 , 25.6  ],
#        [56.602, 10.62 , 25.6  ],
#        [67.519, 21.57 , 25.6  ],
#        [65.695, 24.67 , 20.85 ],
#        [62.946, 11.98 , 20.85 ],
#        [50.613, 11.69 , 20.85 ],
#        [48.255, 10.14 , 20.85 ],
#        [46.57 ,  8.14 , 20.85 ],
#        [45.438,  8.54 , 20.85 ],
#        [59.025,  7.12 , 20.85 ],
#        [57.188,  7.27 , 20.85 ],
#        [59.485, 10.95 , 20.85 ],
#        [59.79 , 16.3  , 20.85 ],
#        [59.683, 14.12 , 20.85 ],
#        [59.392,  8.99 , 20.85 ],
#        [57.961,  8.59 , 20.85 ],
#        [58.789,  6.   , 20.85 ],
#        [61.564,  5.53 , 20.85 ],
#        [54.152,  5.53 , 20.85 ],
#        [54.354,  5.53 , 20.85 ],
#        [55.792,  5.53 , 20.85 ],
#        [53.667,  5.53 , 20.85 ],
#        [55.323,  5.53 , 20.85 ],
#        [53.986,  5.06 , 20.85 ],
#        [53.523,  4.3  , 20.85 ],
#        [56.197,  5.07 , 20.85 ],
#        [56.316, 12.39 , 16.1  ],
#        [57.141, 15.58 , 16.1  ],
#        [56.48 , 15.58 , 16.1  ],
#        [56.714, 14.87 , 16.1  ],
#        [56.187, 12.17 , 16.1  ],
#        [55.675, 19.89 , 16.1  ],
#        [57.27 , 14.77 , 16.1  ],
#        [55.669,  9.07 , 16.1  ],
#        [56.501,  9.07 , 16.1  ],
#        [55.379,  9.07 , 16.1  ],
#        [53.727,  4.67 , 16.1  ],
#        [53.533,  0.4  , 16.1  ],
#        [53.248,  0.   , 16.1  ],
#        [52.776,  0.   , 16.1  ],
#        [52.309,  0.   , 16.1  ],
#        [52.465,  0.   , 16.1  ],
#        [51.948,  0.   , 16.1  ],
#        [51.993,  0.   , 16.1  ],
#        [51.682,  0.   , 16.1  ]])

# %%
y_tr[0,:,:]
# Out:
# array([[51.878]])

# %% [markdown]
# **Scaled the data into -1 to 1**

# %%
from sklearn.preprocessing import MinMaxScaler

def scaler(data_input):

    # Joins the arrays into one single array because we will use the MinMaxScaler to scale de input data
    x_total=np.concatenate((data_input["x_tr"],data_input["x_vl"],data_input["x_ts"]), axis=0)

    # Number of feature in the input data
    NFEATS = data_input['x_tr'].shape[2] 

    # Create a list of MinMaxScaler objects, one for each feature
    scaler = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)] 

    # Create empty arrays to store the scale data 
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)
    total = np.zeros(x_total.shape)

    # Scale the input data
    for i in range(NFEATS):
        total[:,:,i]=scaler[i].fit_transform(x_total[:,:,i])

    for i in range(NFEATS):
        x_tr_s[:, :, i] = scaler[i].transform(data_input['x_tr'][:, :, i])
        x_vl_s[:, :, i] = scaler[i].transform(data_input['x_vl'][:, :, i])
        x_ts_s[:, :, i] = scaler[i].transform(data_input['x_ts'][:, :, i])
    
    # Scale the output data
    y_scaler = MinMaxScaler(feature_range=(-1, 1))
    y_tr_s[:, :, 0] = y_scaler.fit_transform(data_input['y_tr'][:, :, 0])
    y_vl_s[:, :, 0] = y_scaler.transform(data_input['y_vl'][:, :, 0])
    y_ts_s[:, :, 0] = y_scaler.transform(data_input['y_ts'][:, :, 0])

    # Create a dictionary to store the scaled data
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    # Return the dictionary and scaler objects to inverse the scaling later
    return data_scaled, scaler, y_scaler

# %%
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Call the function to scale the data
data_s, scaler, y_scaler = scaler(data_in)

# Extract the scaler values into different arrays
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %% [markdown]
# **Verify if the data is scaled correctly**

# %%
min_values = np.min(x_ts_s, axis=(0, 1, 2))
max_values = np.max(x_ts_s, axis=(0, 1, 2))

print("Minimum value per dimension:", min_values)
print("Maximun value per dimension:", max_values)
# Out:
# Minimum value per dimension: -0.9999999999999999
# Maximun value per dimension: 0.8385052802599514

# %% [markdown]
# *Graphic the scaled variables*

# %%
NFEATS = x_tr.shape[2]

fig, ax=plt.subplots(figsize=(12,4))

for i in range (3):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax=plt.subplots(figsize=(6,4))

ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(["RealPower (output)"])
# Out:
# [Text(1, 0, 'RealPower (output)')]

# %%
x_tr_s.shape[1]
# Out:
# 96

# %% [markdown]
# **Model the LSTM**

# %%
# Set parameters for training reproducibility
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

N_UNITS = 150 
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 96 (window) x 2 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' as we want to forecast (regression)

# Loss: the RMSE (root mean squared error) will be used for training.
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compile the model
optimizador = RMSprop(learning_rate=5e-6)
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
    metrics=["accuracy"]
)

EPOCHS = 110 
BATCH_SIZE = 256 
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# Epoch 1/110
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 82/82 - 20s - loss: 0.2289 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 2/110
# 82/82 - 18s - loss: 0.1863 - accuracy: 0.0000e+00 - val_loss: 0.0818 - val_accuracy: 0.0000e+00 - 18s/epoch - 214ms/step
# Epoch 3/110
# 82/82 - 20s - loss: 0.1495 - accuracy: 0.0000e+00 - val_loss: 0.1050 - val_accuracy: 0.0000e+00 - 20s/epoch - 247ms/step
# Epoch 4/110
# 82/82 - 21s - loss: 0.1231 - accuracy: 0.0000e+00 - val_loss: 0.1337 - val_accuracy: 0.0000e+00 - 21s/epoch - 260ms/step
# Epoch 5/110
# 82/82 - 19s - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.1450 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 6/110
# 82/82 - 19s - loss: 0.1011 - accuracy: 0.0000e+00 - val_loss: 0.1407 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 7/110
# 82/82 - 19s - loss: 0.0935 - accuracy: 0.0000e+00 - val_loss: 0.1346 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 8/110
# 82/82 - 19s - loss: 0.0863 - accuracy: 0.0000e+00 - val_loss: 0.1256 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 9/110
# 82/82 - 19s - loss: 0.0797 - accuracy: 0.0000e+00 - val_loss: 0.1176 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 10/110
# 82/82 - 19s - loss: 0.0743 - accuracy: 0.0000e+00 - val_loss: 0.1092 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 11/110
# 82/82 - 19s - loss: 0.0696 - accuracy: 0.0000e+00 - val_loss: 0.1005 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 12/110
# 82/82 - 19s - loss: 0.0667 - accuracy: 0.0000e+00 - val_loss: 0.0929 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 13/110
# 82/82 - 19s - loss: 0.0651 - accuracy: 0.0000e+00 - val_loss: 0.0849 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 14/110
# 82/82 - 19s - loss: 0.0644 - accuracy: 4.8095e-05 - val_loss: 0.0816 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 15/110
# 82/82 - 19s - loss: 0.0641 - accuracy: 4.8095e-05 - val_loss: 0.0786 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 16/110
# 82/82 - 19s - loss: 0.0637 - accuracy: 4.8095e-05 - val_loss: 0.0751 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 17/110
# 82/82 - 19s - loss: 0.0635 - accuracy: 4.8095e-05 - val_loss: 0.0720 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 18/110
# 82/82 - 19s - loss: 0.0632 - accuracy: 4.8095e-05 - val_loss: 0.0698 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 19/110
# 82/82 - 19s - loss: 0.0630 - accuracy: 4.8095e-05 - val_loss: 0.0699 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 20/110
# 82/82 - 20s - loss: 0.0628 - accuracy: 4.8095e-05 - val_loss: 0.0680 - val_accuracy: 0.0000e+00 - 20s/epoch - 240ms/step
# Epoch 21/110
# 82/82 - 19s - loss: 0.0626 - accuracy: 4.8095e-05 - val_loss: 0.0663 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 22/110
# 82/82 - 19s - loss: 0.0625 - accuracy: 4.8095e-05 - val_loss: 0.0663 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 23/110
# 82/82 - 19s - loss: 0.0622 - accuracy: 4.8095e-05 - val_loss: 0.0647 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 24/110
# 82/82 - 19s - loss: 0.0621 - accuracy: 4.8095e-05 - val_loss: 0.0639 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 25/110
# 82/82 - 19s - loss: 0.0620 - accuracy: 4.8095e-05 - val_loss: 0.0628 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 26/110
# 82/82 - 19s - loss: 0.0617 - accuracy: 4.8095e-05 - val_loss: 0.0627 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 27/110
# 82/82 - 19s - loss: 0.0617 - accuracy: 4.8095e-05 - val_loss: 0.0620 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 28/110
# 82/82 - 19s - loss: 0.0616 - accuracy: 4.8095e-05 - val_loss: 0.0601 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 29/110
# 82/82 - 19s - loss: 0.0615 - accuracy: 4.8095e-05 - val_loss: 0.0604 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 30/110
# 82/82 - 19s - loss: 0.0613 - accuracy: 4.8095e-05 - val_loss: 0.0596 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 31/110
# 82/82 - 19s - loss: 0.0611 - accuracy: 4.8095e-05 - val_loss: 0.0591 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 32/110
# 82/82 - 19s - loss: 0.0610 - accuracy: 4.8095e-05 - val_loss: 0.0579 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 33/110
# 82/82 - 19s - loss: 0.0609 - accuracy: 4.8095e-05 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 19s/epoch - 236ms/step
# Epoch 34/110
# 82/82 - 19s - loss: 0.0608 - accuracy: 4.8095e-05 - val_loss: 0.0581 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 35/110
# 82/82 - 19s - loss: 0.0606 - accuracy: 4.8095e-05 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 36/110
# 82/82 - 19s - loss: 0.0605 - accuracy: 4.8095e-05 - val_loss: 0.0578 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 37/110
# 82/82 - 19s - loss: 0.0605 - accuracy: 4.8095e-05 - val_loss: 0.0562 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 38/110
# 82/82 - 19s - loss: 0.0605 - accuracy: 4.8095e-05 - val_loss: 0.0557 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 39/110
# 82/82 - 19s - loss: 0.0604 - accuracy: 4.8095e-05 - val_loss: 0.0574 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 40/110
# 82/82 - 19s - loss: 0.0602 - accuracy: 4.8095e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 41/110
# 82/82 - 19s - loss: 0.0602 - accuracy: 4.8095e-05 - val_loss: 0.0558 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 42/110
# 82/82 - 19s - loss: 0.0599 - accuracy: 4.8095e-05 - val_loss: 0.0552 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 43/110
# 82/82 - 19s - loss: 0.0600 - accuracy: 4.8095e-05 - val_loss: 0.0550 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 44/110
# 82/82 - 19s - loss: 0.0598 - accuracy: 4.8095e-05 - val_loss: 0.0552 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 45/110
# 82/82 - 19s - loss: 0.0599 - accuracy: 4.8095e-05 - val_loss: 0.0551 - val_accuracy: 0.0000e+00 - 19s/epoch - 237ms/step
# Epoch 46/110
# 82/82 - 19s - loss: 0.0597 - accuracy: 4.8095e-05 - val_loss: 0.0544 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 47/110
# 82/82 - 19s - loss: 0.0597 - accuracy: 4.8095e-05 - val_loss: 0.0543 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 48/110
# 82/82 - 19s - loss: 0.0596 - accuracy: 4.8095e-05 - val_loss: 0.0540 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 49/110
# 82/82 - 19s - loss: 0.0594 - accuracy: 4.8095e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 50/110
# 82/82 - 19s - loss: 0.0596 - accuracy: 4.8095e-05 - val_loss: 0.0541 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 51/110
# 82/82 - 19s - loss: 0.0595 - accuracy: 4.8095e-05 - val_loss: 0.0546 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 52/110
# 82/82 - 19s - loss: 0.0593 - accuracy: 4.8095e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 19s/epoch - 233ms/step
# Epoch 53/110
# 82/82 - 19s - loss: 0.0592 - accuracy: 4.8095e-05 - val_loss: 0.0542 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 54/110
# 82/82 - 19s - loss: 0.0590 - accuracy: 4.8095e-05 - val_loss: 0.0535 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 55/110
# 82/82 - 19s - loss: 0.0591 - accuracy: 4.8095e-05 - val_loss: 0.0536 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 56/110
# 82/82 - 19s - loss: 0.0591 - accuracy: 4.8095e-05 - val_loss: 0.0538 - val_accuracy: 0.0000e+00 - 19s/epoch - 234ms/step
# Epoch 57/110
# 82/82 - 19s - loss: 0.0589 - accuracy: 4.8095e-05 - val_loss: 0.0546 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 58/110
# 82/82 - 19s - loss: 0.0589 - accuracy: 4.8095e-05 - val_loss: 0.0533 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 59/110
# 82/82 - 19s - loss: 0.0587 - accuracy: 4.8095e-05 - val_loss: 0.0534 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 60/110
# 82/82 - 19s - loss: 0.0587 - accuracy: 4.8095e-05 - val_loss: 0.0529 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 61/110
# 82/82 - 19s - loss: 0.0587 - accuracy: 4.8095e-05 - val_loss: 0.0532 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 62/110
# 82/82 - 19s - loss: 0.0587 - accuracy: 4.8095e-05 - val_loss: 0.0524 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 63/110
# 82/82 - 19s - loss: 0.0586 - accuracy: 4.8095e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 64/110
# 82/82 - 19s - loss: 0.0586 - accuracy: 4.8095e-05 - val_loss: 0.0522 - val_accuracy: 0.0000e+00 - 19s/epoch - 233ms/step
# Epoch 65/110
# 82/82 - 19s - loss: 0.0585 - accuracy: 4.8095e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 66/110
# 82/82 - 19s - loss: 0.0584 - accuracy: 4.8095e-05 - val_loss: 0.0526 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 67/110
# 82/82 - 19s - loss: 0.0583 - accuracy: 4.8095e-05 - val_loss: 0.0520 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 68/110
# 82/82 - 20s - loss: 0.0583 - accuracy: 4.8095e-05 - val_loss: 0.0520 - val_accuracy: 0.0000e+00 - 20s/epoch - 244ms/step
# Epoch 69/110
# 82/82 - 19s - loss: 0.0582 - accuracy: 4.8095e-05 - val_loss: 0.0525 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 70/110
# 82/82 - 19s - loss: 0.0581 - accuracy: 4.8095e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 71/110
# 82/82 - 19s - loss: 0.0581 - accuracy: 4.8095e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 72/110
# 82/82 - 19s - loss: 0.0581 - accuracy: 4.8095e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 73/110
# 82/82 - 19s - loss: 0.0581 - accuracy: 4.8095e-05 - val_loss: 0.0517 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 74/110
# 82/82 - 19s - loss: 0.0580 - accuracy: 4.8095e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 19s/epoch - 233ms/step
# Epoch 75/110
# 82/82 - 19s - loss: 0.0580 - accuracy: 4.8095e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 76/110
# 82/82 - 18s - loss: 0.0578 - accuracy: 4.8095e-05 - val_loss: 0.0524 - val_accuracy: 0.0000e+00 - 18s/epoch - 225ms/step
# Epoch 77/110
# 82/82 - 19s - loss: 0.0579 - accuracy: 4.8095e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 78/110
# 82/82 - 19s - loss: 0.0578 - accuracy: 4.8095e-05 - val_loss: 0.0517 - val_accuracy: 0.0000e+00 - 19s/epoch - 234ms/step
# Epoch 79/110
# 82/82 - 19s - loss: 0.0578 - accuracy: 4.8095e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 19s/epoch - 226ms/step
# Epoch 80/110
# 82/82 - 19s - loss: 0.0576 - accuracy: 4.8095e-05 - val_loss: 0.0522 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 81/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.8095e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 82/110
# 82/82 - 19s - loss: 0.0576 - accuracy: 4.8095e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 83/110
# 82/82 - 19s - loss: 0.0577 - accuracy: 4.8095e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 84/110
# 82/82 - 19s - loss: 0.0576 - accuracy: 4.8095e-05 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 85/110
# 82/82 - 19s - loss: 0.0575 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 86/110
# 82/82 - 19s - loss: 0.0574 - accuracy: 4.8095e-05 - val_loss: 0.0531 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 87/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.8095e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 88/110
# 82/82 - 19s - loss: 0.0574 - accuracy: 4.8095e-05 - val_loss: 0.0520 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 89/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.8095e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 19s/epoch - 235ms/step
# Epoch 90/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.8095e-05 - val_loss: 0.0523 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 91/110
# 82/82 - 19s - loss: 0.0572 - accuracy: 4.8095e-05 - val_loss: 0.0511 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 92/110
# 82/82 - 19s - loss: 0.0571 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 93/110
# 82/82 - 19s - loss: 0.0573 - accuracy: 4.8095e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 94/110
# 82/82 - 19s - loss: 0.0572 - accuracy: 4.8095e-05 - val_loss: 0.0519 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 95/110
# 82/82 - 19s - loss: 0.0572 - accuracy: 4.8095e-05 - val_loss: 0.0512 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 96/110
# 82/82 - 19s - loss: 0.0571 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 97/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0518 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 98/110
# 82/82 - 19s - loss: 0.0571 - accuracy: 4.8095e-05 - val_loss: 0.0510 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 99/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0505 - val_accuracy: 0.0000e+00 - 19s/epoch - 229ms/step
# Epoch 100/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 101/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0502 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step
# Epoch 102/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 231ms/step
# Epoch 103/110
# 82/82 - 19s - loss: 0.0568 - accuracy: 4.8095e-05 - val_loss: 0.0515 - val_accuracy: 0.0000e+00 - 19s/epoch - 233ms/step
# Epoch 104/110
# 82/82 - 19s - loss: 0.0569 - accuracy: 4.8095e-05 - val_loss: 0.0508 - val_accuracy: 0.0000e+00 - 19s/epoch - 232ms/step
# Epoch 105/110
# 82/82 - 19s - loss: 0.0568 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 106/110
# 82/82 - 19s - loss: 0.0568 - accuracy: 4.8095e-05 - val_loss: 0.0514 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 107/110
# 82/82 - 19s - loss: 0.0567 - accuracy: 4.8095e-05 - val_loss: 0.0516 - val_accuracy: 0.0000e+00 - 19s/epoch - 228ms/step
# Epoch 108/110
# 82/82 - 19s - loss: 0.0566 - accuracy: 4.8095e-05 - val_loss: 0.0513 - val_accuracy: 0.0000e+00 - 19s/epoch - 226ms/step
# Epoch 109/110
# 82/82 - 19s - loss: 0.0566 - accuracy: 4.8095e-05 - val_loss: 0.0504 - val_accuracy: 0.0000e+00 - 19s/epoch - 230ms/step
# Epoch 110/110
# 82/82 - 19s - loss: 0.0568 - accuracy: 4.8095e-05 - val_loss: 0.0517 - val_accuracy: 0.0000e+00 - 19s/epoch - 227ms/step

# %% [markdown]
# *Plot loss: Verify if there's overfitting*

# %%
# Graphic training loss and validation loss values
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('Loss (RMSE)')
plt.title('Training and Validation Loss')

plt.legend()

# %% [markdown]
# *Prediction of training values using final model*

# %%
y_predict_train= modelo.predict(x_tr_s)

y_predict_train_trans= y_scaler.inverse_transform(y_predict_train)

y_mesuared_train= y_scaler.inverse_transform(y_tr_s[:,:,0])
# Out:
# 650/650 [==============================] - 14s 20ms/step

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_train_trans, "r--", label="LSTM")
plt.plot(y_mesuared_train, "k--", label="Measured")
plt.ylabel("Power Building")
plt.title('Training model')

plt.legend()

# %% [markdown]
# **Model performace**

# %%
# Find the rmses for training, validation and set test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Print the results
print('Compare performance:')
print(f'  RMSE train:\t {rmse_tr[0]:.3f}')
print(f'  RMSE val:\t {rmse_vl[0]:.3f}')
print(f'  RMSE test:\t {rmse_ts[0]:.3f}')
# Out:
# Compare performance:
#   RMSE train:	 0.047
#   RMSE val:	 0.047
#   RMSE test:	 0.052

# %% [markdown]
# **LSTM: Prediction of testing set using training model**

# %%
y_predict= modelo.predict(x_ts_s)

y_predict_trans= y_scaler.inverse_transform(y_predict)

y_mesuared= y_scaler.inverse_transform(y_ts_s[:,:,0])
# Out:
# 79/79 [==============================] - 2s 21ms/step

# %%
y_mesuared[-10:] #last 10 mesured values
# Out:
# array([[38.424],
#        [38.288],
#        [38.932],
#        [39.218],
#        [38.82 ],
#        [38.481],
#        [38.313],
#        [38.493],
#        [38.577],
#        [38.619]])

# %%
y_predict_trans[-10:] #last 10 predicted values
# Out:
# array([[39.906723],
#        [39.873314],
#        [39.821556],
#        [39.88281 ],
#        [39.98851 ],
#        [40.02038 ],
#        [39.99139 ],
#        [39.934265],
#        [39.91089 ],
#        [39.904957]], dtype=float32)

# %% [markdown]
# *Plot of mesuared value between lstm model*

# %%
plt.figure(figsize=(40,30))
plt.subplot(2,1,1)
plt.plot( y_predict_trans, "r--", label="LSTM")
plt.plot(y_mesuared, "k--", label="Measured")
plt.ylabel("Power Building")
plt.legend()
